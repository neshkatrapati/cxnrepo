# %%
import pandas as pd
import numpy
import spacy

# %%
data_file = 'data/wikitext-2/train.txt'
nlp = spacy.load("en")

# %%
# def tokenize(x):
#     return x.strip().split(' ')

def tokenize(x):
    return nlp(x, parse=False, tag=False, entity=False)

def load_file(file_name):
    with open(data_file) as d:
        for line in d:
            yield [x.text for x in tokenize(line)]

def get_tokens(file):
    tokens = {}
    for sent in file:
        for token in sent:
            try:
                tokens[token] += 1
            except:
                tokens[token] = 1
    return tokens

# %%
# %%time 
f = load_file(data_file)
tokens = get_tokens(f)
print(len(tokens))
# Out:
# 33242
# CPU times: user 5.63 s, sys: 1.09 ms, total: 5.63 s
# Wall time: 5.64 s

# %%
tokens = list(tokens)

# %%
# %%time
from collections import Counter
pairs = Counter()
for token in tokens:
    token = token.strip()
    if len(token) > 4:
        token = f"*{token}#"
        pairs[('*',)] += 1
        for ci in range(len(token)-1):
            pc, c = token[ci], token[ci+1]
            pairs[(pc,c)] += 1
            pairs[(c,)] += 1
# Out:
# CPU times: user 197 ms, sys: 0 ns, total: 197 ms
# Wall time: 196 ms

# %%
import math
def calc_assocs(pairs):
    
    total = sum(pairs.values())
    assocs = Counter()
    for p in pairs:
        if len(p) > 1:
            x, y = p
            cXY = pairs[(x, y)]
            cX = pairs[(x,)]
            if cX == 0:
                print(x)
            cY = pairs[(y,)]

            p_x_given_y = float(cXY) / cY 
            p_x_and_not_y = float(cX - cXY)
            p_not_y = total - cY
            p_x_given_not_y = p_x_and_not_y / float(p_not_y)       


            p_y_given_x = float(cXY) / cX 
            p_y_and_not_x = float(cY - cXY)
            p_not_x = total - cX
            p_y_given_not_x = p_y_and_not_x / float(p_not_x)

            delta_p = p_x_given_y - p_x_given_not_y
            delta_p_r = p_y_given_x - p_y_given_not_x
            #delta_p = delta_p / 2.0
#             delta_p, delta_p_r = 0, 0
#             try:
#                 delta_p = -math.log(p_x_given_y) + math.log(p_x_given_not_y)
#                 delta_p_r = -math.log(p_y_given_x) + math.log(p_y_given_not_x)
#             except:
#                 pass
#             p_x_y = float(cXY) / total
#             p_x, p_y = float(cX)/total, float(cY)/total
#             pmi_x_y = math.log(p_x_y/(p_x*p_y))
#             delta_p = pmi_x_y + math.log(p_x_y)
#             delta_p_r = delta_p
            assocs[(x,y)] = (delta_p + delta_p_r) / 2, delta_p_r
    return assocs

# %%
# %%time
assocs = calc_assocs(pairs)
# Out:
# CPU times: user 4.25 ms, sys: 0 ns, total: 4.25 ms
# Wall time: 4.05 ms

# %%
def calc_sequence(token, assocs):
    seq = []
    token = f"*{token}#"
    for ci in range(len(token)-1):
        pc, c = token[ci], token[ci+1]
        
        assoc_score = assocs[(pc,c)]
        if type(assoc_score) != tuple :
            assoc_score = (-10,-10)
        
        seq.append((pc, c, assoc_score))
    return seq

# %%
#def format_seq_item(seq_item):
    

def break_sequence(token, assocs):
    seq_scores = calc_sequence(token, assocs)
    segments = [[seq_scores[0]]]
    
    for pair in seq_scores[1:]:
        prev_seg = segments[-1][-1]
        #print(pair, prev_seg)
        prev_score = prev_seg[-1][0]
        current_score = pair[-1][0]
        
        prev_score_r = prev_seg[-1][1]
        current_score_r = pair[-1][1]

        if current_score >= prev_score :       
            segments[-1].append(pair)
        else:
            segments.append([pair])
    return segments

def get_segments(segments):
    #string = [segments[0][0][0]]
    #string[0] = segments[0][0]
    string = []
    for seg in segments:
        string.append(''.join([x[1] for x in seg]))
    string[0] = segments[0][0][0] + string[0]
    
    return string

# %%
tokens[:10]
# Out:
# [' \n', ' ', '=', 'Valkyria', 'Chronicles', 'III', '\n', 'Senjō', 'no', '3']

# %%
from pprint import pprint
segments = break_sequence('pictures', assocs)
pprint(segments)
get_segments(segments)
# Out:
# [[('*', 'p', (0.1311015515781312, 0.042354210131006466))],
#  [('p', 'i', (0.031185753925970575, 0.04821829069895062)),
#   ('i', 'c', (0.11520417482608117, 0.0728002665488222))],
#  [('c', 't', (0.05615470179520681, 0.07153683733698775))],
#  [('t', 'u', (0.033010876453544405, 0.020970869601242517)),
#   ('u', 'r', (0.09340248135713808, 0.1320753958047427)),
#   ('r', 'e', (0.11807387017001868, 0.14048887076092767)),
#   ('e', 's', (0.1261080069497572, 0.0983210116511411)),
#   ('s', '#', (0.269699683397255, 0.3456234344006285))]]
# ['*p', 'ic', 't', 'ures#']

# %%
# %%time
from collections import Counter
c_pairs = Counter()
for token in tokens:
    token = token.strip()
    if len(token) > 4:
        segments = get_segments(break_sequence(token,assocs))
        c_pairs[(segments[0],)] += 1
        for ci in range(len(segments)-1):
            pc, c = segments[ci], segments[ci+1]
            c_pairs[(pc,c)] += 1
            c_pairs[(c,)] += 1
# Out:
# CPU times: user 342 ms, sys: 7.28 ms, total: 350 ms
# Wall time: 348 ms

# %%
c_assocs = calc_assocs(c_pairs)

# %%
def c_calc_sequence(token, assocs, c_assocs):
    seq = []
    token = get_segments(break_sequence(token,assocs))
    for ci in range(len(token)-1):
        pc, c = token[ci], token[ci+1]
        assoc_score = c_assocs[(pc,c)]
        if type(assoc_score) != tuple :
            assoc_score = (-10,-10)
        seq.append((pc, c, assoc_score))
    if len(seq) == 0:
        return token
    return seq


def c_break_sequence(token, assocs, c_assocs):
    seq_scores = c_calc_sequence(token, assocs,c_assocs)
    
    segments = [[seq_scores[0]]]
    
    for pair in seq_scores[1:]:
        prev_seg = segments[-1][-1]
        prev_score = prev_seg[-1][0]
        current_score = pair[-1][0]
        prev_score_r = prev_seg[-1][1]
        current_score_r = pair[-1][1]

        if current_score >= prev_score and current_score_r > prev_score_r:
            segments[-1].append(pair)
        else:
            segments.append([pair])
    return segments

# %%
c_calc_sequence('apples', assocs, c_assocs)
# Out:
# ['*apples#']

# %%
segs = c_break_sequence('pictures', assocs, c_assocs)
pprint(segs)
get_segments(segs)
# Out:
# [[('*p', 'ic', (0.006277062600799739, 0.0027433061082693683)),
#   ('ic', 't', (0.01768971830260924, 0.030021624374684374))],
#  [('t', 'ures#', (0.08493006426974567, 0.002659853322716279))]]
# ['*pict', 'ures#']

# %%
all_segs = {x : get_segments(c_break_sequence(x, assocs, c_assocs)) for x in tokens[:3000] if len(x) > 5}

# %%
pprint(all_segs)
# Out:
# {'Abraham': ['*Abra', 'ham', '#'],
#  'According': ['*Ac', 'cor', 'ding#'],
#  'Action': ['*Action', '#'],
#  'Adaptations': ['*Ad', 'aptation', 's#'],
#  'Administration': ['*Ad', 'minist', 'ration', '#'],
#  'Advertiser': ['*Ad', 'ver', 'ti', 's', 'er#'],
#  'Africa': ['*Afric', 'a', '#'],
#  'African': ['*Afric', 'an', '#'],
#  'Allies': ['*Alli', 'es#'],
#  'Alongside': ['*Al', 'ong', 'side#'],
#  'Alphabet': ['*Al', 'phab', 'e', 't#'],
#  'Although': ['*Al', 'though', '#'],
#  'Always': ['*Al', 'way', 's#'],
#  'American': ['*Americ', 'an#'],
#  'Americans': ['*Americ', 'ans#'],
#  'Andrew': ['*And', 're', 'w#'],
#  'Andrews': ['*And', 're', 'ws#'],
#  'Angeles': ['*Ang', 'e', 'les#'],
#  'Anglican': ['*Ang', 'lican#'],
#  'Another': ['*An', 'other#'],
#  'Antiquities': ['*Anti', 'qu', 'ities#'],
#  'Archipelago': ['*Ar', 'chi', 'pelag', 'o#'],
#  'Arkadelphia': ['*Ar', 'kade', 'l', 'phi', 'a#'],
#  'Arkansas': ['*Ar', 'kan', 's', 'as#'],
#  'Armored': ['*Ar', 'mored#'],
#  'Arniel': ['*Ar', 'ni', 'el#'],
#  'Arsenal': ['*Ar', 's', 'en', 'al#'],
#  'Arthur': ['*Ar', 'th', 'ur', '#'],
#  'Artillery': ['*Ar', 'ti', 'llery#'],
#  'Assistant': ['*Assist', 'an', 't', '#'],
#  'Association': ['*Associ', 'ation', '#'],
#  'August': ['*Au', 'gust', '#'],
#  'Australia': ['*Australi', 'a#'],
#  'Australian': ['*Australi', 'an#'],
#  'Autumn': ['*Autum', 'n#'],
#  'Avenue': ['*Aven', 'ue#'],
#  'Azerbaijan': ['*Azerba', 'i', 'jan#'],
#  'Babcock': ['*Ba', 'b', 'cock#'],
#  'Background': ['*Ba', 'ck', 'ground#'],
#  'Banner': ['*Ban', 'ner#'],
#  'Baptist': ['*Ba', 'pti', 'st#'],
#  'Barker': ['*Bar', 'ker#'],
#  'Barracks': ['*Bar', 'racks#'],
#  'Barton': ['*Bar', 'ton#'],
#  'Battalion': ['*Bat', 'tali', 'on#'],
#  'Battle': ['*Bat', 'tle#'],
#  'Battlefield': ['*Bat', 'tle', 'fiel', 'd#'],
#  'Beautiful': ['*Be', 'auti', 'f', 'ul', '#'],
#  'Bernie': ['*Ber', 'nie#'],
#  'Besides': ['*Besi', 'des#'],
#  'Biography': ['*Biograph', 'y#'],
#  'Biology': ['*Bio', 'lo', 'g', 'y#'],
#  'Blackie': ['*Black', 'i', 'e#'],
#  'Bonaparte': ['*Bonaparte', '#'],
#  'Brooks': ['*Bro', 'oks#'],
#  'Building': ['*Bu', 'il', 'ding#'],
#  'Calamity': ['*Cal', 'a', 'mit', 'y#'],
#  'Caldecott': ['*Cal', 'de', 'cot', 't#'],
#  'Calthrop': ['*Cal', 'th', 'rop#'],
#  'Camden': ['*Ca', 'm', 'den#'],
#  'Canadiens': ['*Can', 'adi', 'en', 's#'],
#  'Captain': ['*Ca', 'p', 'tain', '#'],
#  'Carter': ['*Car', 'ter#'],
#  'Cavalry': ['*Ca', 'val', 'ry#'],
#  'Cecily': ['*Cecily#'],
#  'Center': ['*Center#'],
#  'Championship': ['*Ch', 'a', 'mp', 'ion', 'shi', 'p', '#'],
#  'Changing': ['*Ch', 'ang', 'ing#'],
#  'Chapel': ['*Ch', 'a', 'pel#'],
#  'Chapter': ['*Ch', 'a', 'p', 'ter#'],
#  'Character': ['*Ch', 'ara', 'c', 'ter#'],
#  'Characters': ['*Ch', 'ara', 'c', 'ters#'],
#  'Cherry': ['*Ch', 'er', 'ry#'],
#  'Chicago': ['*Ch', 'ica', 'g', 'o#'],
#  'Children': ['*Ch', 'i', 'l', 'd', 'ren', '#'],
#  'Chinese': ['*Ch', 'inese#'],
#  'Christ': ['*Ch', 'ri', 'st#'],
#  'Christian': ['*Ch', 'ri', 'sti', 'an#'],
#  'Christmas': ['*Ch', 'ri', 'st', 'mas#'],
#  'Chronicles': ['*Ch', 'ronic', 'les#'],
#  'Church': ['*Ch', 'urch#'],
#  'Clayton': ['*Clay', 'ton#'],
#  'Colton': ['*Co', 'l', 'ton#'],
#  'Columbian': ['*Co', 'l', 'umb', 'i', 'an#'],
#  'Columbus': ['*Co', 'l', 'umb', 'us#'],
#  'Coming': ['*Co', 'm', 'ing#'],
#  'Command': ['*Co', 'mman', 'd#'],
#  'Commonwealth': ['*Co', 'mmon', 'we', 'al', 'th#'],
#  'Competition': ['*Co', 'mp', 'e', 'ti', 'tion#'],
#  'Concept': ['*Con', 'cep', 't#'],
#  'Confederate': ['*Con', 'feder', 'ate', '#'],
#  'Confederates': ['*Con', 'feder', 'ates#'],
#  'Confederation': ['*Con', 'feder', 'ation', '#'],
#  'Consequently': ['*Con', 'sequ', 'ent', 'ly#'],
#  'Conservation': ['*Con', 'ser', 'vation', '#'],
#  'Construction': ['*Con', 'str', 'uction', '#'],
#  'Conway': ['*Con', 'way#'],
#  'Cornwall': ['*Co', 'r', 'nwal', 'l', '#'],
#  'Costume': ['*Co', 'st', 'ume#'],
#  'Crimson': ['*Cri', 'mson#'],
#  'Croydon': ['*Cro', 'y', 'don#'],
#  'Darcsen': ['*Dar', 'csen#'],
#  'Darling': ['*Dar', 'ling#'],
#  'Dasyatis': ['*Da', 's', 'yati', 's#'],
#  'Dengeki': ['*De', 'nge', 'ki#'],
#  'Department': ['*De', 'par', 't', 'ment#'],
#  'Depictions': ['*De', 'piction', 's#'],
#  'Depression': ['*De', 'pression#'],
#  'Description': ['*Des', 'cri', 'ption', '#'],
#  'Development': ['*De', 'velo', 'p', 'ment#'],
#  'Direct': ['*Di', 'rect#'],
#  'Discovery': ['*Dis', 'cover', 'y#'],
#  'Distribution': ['*Dist', 'ribu', 'tion#'],
#  'District': ['*District#'],
#  'Dorothy': ['*Dor', 'othy#'],
#  'Douglas': ['*Dou', 'gla', 's#'],
#  'Dunnington': ['*Dunning', 'ton#'],
#  'During': ['*During#'],
#  'Edition': ['*Edition#'],
#  'Edmonton': ['*Ed', 'mont', 'on#'],
#  'Edmund': ['*Ed', 'mund#'],
#  'Edward': ['*Ed', 'ward#'],
#  'Eleanor': ['*Ele', 'an', 'or#'],
#  'Empire': ['*Emp', 'ire', '#'],
#  'Engineers': ['*Eng', 'in', 'e', 'ers#'],
#  'England': ['*Eng', 'land#'],
#  'English': ['*Eng', 'li', 'sh#'],
#  'Epiphany': ['*Epiphan', 'y#'],
#  'Europan': ['*Eur', 'o', 'pan#'],
#  'Europe': ['*Eur', 'o', 'pe#'],
#  'Everett': ['*Ever', 'ett#'],
#  'Except': ['*Ex', 'cep', 't#'],
#  'Expedition': ['*Exp', 'edi', 'tion#'],
#  'Exposition': ['*Exp', 'o', 'sition', '#'],
#  'Fairies': ['*Fa', 'i', 'ries#'],
#  'Family': ['*Fa', 'mi', 'ly#'],
#  'Famitsu': ['*Fa', 'mit', 'su#'],
#  'Faulkner': ['*Fa', 'ul', 'k', 'ner#'],
#  'February': ['*Fe', 'bru', 'ary#'],
#  'Federal': ['*Feder', 'al#'],
#  'Feeding': ['*Fe', 'eding#'],
#  'Flower': ['*Flower', '#'],
#  'Flowers': ['*Flower', 's#'],
#  'Following': ['*Fo', 'll', 'ow', 'ing#'],
#  'Football': ['*Fo', 'ot', 'ball', '#'],
#  'Forces': ['*For', 'ces#'],
#  'Foster': ['*Fo', 'ster#'],
#  'Frederick': ['*Fred', 'er', 'ick#'],
#  'Friendly': ['*Fr', 'i', 'end', 'ly#'],
#  'Funding': ['*Fund', 'ing#'],
#  'Furthermore': ['*Further', 'more#'],
#  'Gallia': ['*Gal', 'li', 'a#'],
#  'Gallian': ['*Gal', 'lian#'],
#  'Gambia': ['*Ga', 'mb', 'i', 'a#'],
#  'Gameplay': ['*Ga', 'me', 'play#'],
#  'Garden': ['*Gar', 'den#'],
#  'Gardens': ['*Gar', 'dens#'],
#  'Gazette': ['*Ga', 'ze', 't', 'te#'],
#  'Geddes': ['*Geddes#'],
#  'General': ['*Gen', 'eral#'],
#  'George': ['*Ge', 'orge#'],
#  'Gibson': ['*Gib', 's', 'on#'],
#  'Gladys': ['*Gla', 'd', 'ys#'],
#  'Gospel': ['*Go', 'spe', 'l#'],
#  'Government': ['*Gover', 'nment#'],
#  'Governor': ['*Gover', 'nor', '#'],
#  'Greenaway': ['*Gre', 'en', 'away#'],
#  'Groundsel': ['*Gr', 'ound', 'sel#'],
#  'Guardian': ['*Gu', 'ar', 'dian#'],
#  'Guinea': ['*Gu', 'ine', 'a#'],
#  'Harrel': ['*Ha', 'r', 're', 'l#'],
#  'Harvey': ['*Ha', 'r', 'vey#'],
#  'Hindman': ['*Hind', 'man#'],
#  'Hiroshi': ['*Hi', 'ro', 'shi', '#'],
#  'Hiroyuki': ['*Hi', 'roy', 'uki#'],
#  'Historic': ['*Hist', 'or', 'ic#'],
#  'Historically': ['*Hist', 'or', 'ical', 'ly#'],
#  'History': ['*Hist', 'or', 'y#'],
#  'Hitoshi': ['*Hit', 'o', 'shi', '#'],
#  'Hockey': ['*Ho', 'ck', 'e', 'y#'],
#  'Holiday': ['*Ho', 'li', 'day#'],
#  'Honjou': ['*Hon', 'jou', '#'],
#  'Hospital': ['*Ho', 'spit', 'al#'],
#  'Howson': ['*How', 'son#'],
#  'Imperial': ['*Imp', 'eri', 'al#'],
#  'Indian': ['*In', 'd', 'ian#'],
#  'Industrial': ['*In', 'd', 'ustri', 'al#'],
#  'Infantry': ['*In', 'fant', 'ry#'],
#  'Ingram': ['*Ing', 'ra', 'm#'],
#  'Inside': ['*In', 's', 'i', 'de#'],
#  'International': ['*In', 'ternation', 'al#'],
#  'Irving': ['*Irving#'],
#  'Islanders': ['*Is', 'landers#'],
#  'Islands': ['*Is', 'lands#'],
#  'Jackets': ['*Ja', 'ck', 'e', 'ts#'],
#  'Jackson': ['*Ja', 'ck', 'son#'],
#  'January': ['*Ja', 'n', 'uar', 'y#'],
#  'Japanese': ['*Ja', 'pan', 'es', 'e#'],
#  'Joseph': ['*Jo', 'se', 'ph#'],
#  'Kadokawa': ['*Ka', 'd', 'ok', 'awa#'],
#  'Knowledge': ['*Kn', 'ow', 'ledge#'],
#  'Kotaku': ['*Ko', 'taku', '#'],
#  'Laboratory': ['*La', 'b', 'orator', 'y#'],
#  'Landmark': ['*Land', 'mark#'],
#  'Larger': ['*La', 'r', 'ger#'],
#  'Leadeth': ['*Le', 'adeth#'],
#  'Leading': ['*Le', 'ading#'],
#  'League': ['*Le', 'agu', 'e#'],
#  'Legacy': ['*Le', 'gacy#'],
#  'Library': ['*Li', 'brary#'],
#  'Lieutenant': ['*Li', 'euten', 'ant', '#'],
#  'Lincoln': ['*Lin', 'col', 'n#'],
#  'Litter': ['*Li', 't', 'ter#'],
#  'Little': ['*Li', 't', 'tle#'],
#  'Lively': ['*Lively#'],
#  'Llandaff': ['*Lland', 'aff', '#'],
#  'Looking': ['*Lo', 'oking#'],
#  'MacArthur': ['*Ma', 'c', 'Arth', 'ur', '#'],
#  'Machinery': ['*Ma', 'ch', 'iner', 'y#'],
#  'Macmillan': ['*Ma', 'c', 'mill', 'an#'],
#  'Magazine': ['*Ma', 'g', 'az', 'in', 'e#'],
#  'Manager': ['*Ma', 'n', 'ager#'],
#  'Margaret': ['*Ma', 'r', 'garet#'],
#  'Market': ['*Ma', 'r', 'ket#'],
#  'Massey': ['*Ma', 's', 'sey#'],
#  'Masters': ['*Ma', 'ster', 's#'],
#  'Material': ['*Ma', 'teri', 'al#'],
#  'Maximilian': ['*Ma', 'xi', 'mi', 'li', 'an#'],
#  'Memoirs': ['*Memoirs#'],
#  'Memorial': ['*Memor', 'i', 'al#'],
#  'Memphis': ['*Memphis#'],
#  'Methodist': ['*Me', 'tho', 'di', 'st#'],
#  'Middle': ['*Mi', 'd', 'dle#'],
#  'Military': ['*Mi', 'lit', 'ary#'],
#  'Militia': ['*Mi', 'liti', 'a#'],
#  'Millais': ['*Mi', 'lla', 'is#'],
#  'Mission': ['*Mis', 'sion#'],
#  'Mississippi': ['*Mis', 'sissi', 'pp', 'i', '#'],
#  'Montreal': ['*Mon', 't', 're', 'al#'],
#  'Morocco': ['*Mor', 'o', 'cco', '#'],
#  'Moscow': ['*Mo', 'scow', '#'],
#  'Mountain': ['*Mount', 'a', 'in', '#'],
#  'Mounted': ['*Mou', 'nted#'],
#  'Multiple': ['*Multi', 'ple#'],
#  'Murphy': ['*Mur', 'phy#'],
#  'Museum': ['*Mus', 'e', 'um#'],
#  'Nameless': ['*Na', 'me', 'less#'],
#  'Napoleon': ['*Na', 'pole', 'on#'],
#  'National': ['*Nation', 'al#'],
#  'Native': ['*Native#'],
#  'Natural': ['*Nat', 'ural#'],
#  'Nature': ['*Nat', 'ure#'],
#  'Necklaces': ['*Ne', 'ck', 'lac', 'es#'],
#  'Neotrygon': ['*Ne', 'otrygon', '#'],
#  'Network': ['*Ne', 't', 'work#'],
#  'Nikita': ['*Ni', 'ki', 't', 'a#'],
#  'Nintendo': ['*Ninten', 'd', 'o#'],
#  'Northern': ['*Nor', 'ther', 'n#'],
#  'Nothing': ['*No', 'th', 'ing#'],
#  'November': ['*No', 've', 'mber', '#'],
#  'Numbers': ['*Number', 's#'],
#  'October': ['*Oct', 'ober', '#'],
#  'Official': ['*Offici', 'al#'],
#  'Oilers': ['*Oilers#'],
#  'Oklahoma': ['*Ok', 'la', 'homa#'],
#  'Ordnance': ['*Or', 'd', 'nance#'],
#  'Organisation': ['*Or', 'ganis', 'ation', '#'],
#  'Originally': ['*Ori', 'g', 'in', 'ally#'],
#  'Oswald': ['*Os', 'wald#'],
#  'Ottawa': ['*Ot', 'tawa', '#'],
#  'Outside': ['*Out', 'side#'],
#  'Pacific': ['*Pa', 'c', 'ific', '#'],
#  'Parable': ['*Par', 'a', 'ble#'],
#  'Penarth': ['*Pen', 'arth#'],
#  'Penguin': ['*Pengu', 'in#'],
#  'People': ['*Pe', 'ople#'],
#  'Performed': ['*Per', 'formed#'],
#  'Perhaps': ['*Per', 'haps#'],
#  'Personal': ['*Per', 'son', 'al#'],
#  'Philadelphia': ['*Phi', 'ladel', 'phi', 'a#'],
#  'Picture': ['*Pict', 'ure#'],
#  'Pictures': ['*Pict', 'ures#'],
#  'Pitlake': ['*Pit', 'lake#'],
#  'Places': ['*Plac', 'es#'],
#  'PlayStation': ['*Play', 'Station', '#'],
#  'Points': ['*Po', 'int', 's#'],
#  'Portable': ['*Por', 'table#'],
#  'Potential': ['*Po', 'tenti', 'al#'],
#  'Potentials': ['*Po', 'tenti', 'al', 's#'],
#  'Preservation': ['*Pres', 'er', 'vation', '#'],
#  'President': ['*Pres', 'i', 'dent#'],
#  'Primrose': ['*Pr', 'i', 'm', 'rose#'],
#  'Production': ['*Pro', 'd', 'uction', '#'],
#  'Progress': ['*Pro', 'gres', 's#'],
#  'Project': ['*Pro', 'ject', '#'],
#  'Public': ['*Public', '#'],
#  'Queensland': ['*Qu', 'eens', 'land#'],
#  'Ramsey': ['*Ra', 'm', 'sey#'],
#  'Randolph': ['*Rand', 'olph#'],
#  'Raphael': ['*Ra', 'phael#'],
#  'Reaching': ['*Re', 'aching#'],
#  'Reception': ['*Re', 'cep', 'tion#'],
#  'Records': ['*Re', 'cor', 'ds#'],
#  'Rector': ['*Re', 'ctor', '#'],
#  'Regiment': ['*Re', 'giment', '#'],
#  'Regiments': ['*Re', 'giment', 's#'],
#  'Register': ['*Re', 'gister', '#'],
#  'Regular': ['*Re', 'gular#'],
#  'Release': ['*Re', 'lease#'],
#  'Released': ['*Re', 'leased#'],
#  'Religious': ['*Re', 'lig', 'ious#'],
#  'Research': ['*Re', 'search#'],
#  'Return': ['*Re', 'turn#'],
#  'Revolution': ['*Re', 'vol', 'ution', '#'],
#  'Rhymes': ['*Rhy', 'mes#'],
#  'Richard': ['*Rich', 'ar', 'd#'],
#  'Richards': ['*Rich', 'ar', 'ds#'],
#  'Rifles': ['*Rif', 'les#'],
#  'Robert': ['*Ro', 'bert#'],
#  'Rushie': ['*Rush', 'i', 'e#'],
#  'Sakimoto': ['*Sakimo', 'to#'],
#  'Salmon': ['*Sal', 'mon#'],
#  'Sanford': ['*San', 'ford#'],
#  'School': ['*Sch', 'o', 'ol', '#'],
#  'Science': ['*Sci', 'ence#'],
#  'Scientific': ['*Sci', 'entific', '#'],
#  'Scouts': ['*Scou', 'ts#'],
#  'Seaside': ['*Se', 'asi', 'de#'],
#  'Seasons': ['*Se', 'ason', 's#'],
#  'Second': ['*Second#'],
#  'Senators': ['*Sen', 'ator', 's#'],
#  'September': ['*Se', 'p', 'tember', '#'],
#  'Shakespeare': ['*Sha', 'ke', 's', 'pe', 'are#'],
#  'Shinji': ['*Shin', 'ji', '#'],
#  'Shoten': ['*Sho', 'ten', '#'],
#  'Sierra': ['*Sier', 'ra#'],
#  'Similar': ['*Similar', '#'],
#  'Society': ['*Society#'],
#  'Soldier': ['*Soldi', 'er#'],
#  'Speaking': ['*Spe', 'aking#'],
#  'Special': ['*Spec', 'i', 'al#'],
#  'Spring': ['*Spring', '#'],
#  'Staples': ['*St', 'a', 'ples#'],
#  'States': ['*St', 'ates#'],
#  'Station': ['*St', 'ation', '#'],
#  'Steele': ['*Ste', 'ele#'],
#  'Stevenson': ['*Ste', 'ven', 'son#'],
#  'Stories': ['*St', 'ori', 'es#'],
#  'Storrington': ['*St', 'or', 'rington#'],
#  'Summary': ['*Summar', 'y#'],
#  'Summer': ['*Summer#'],
#  'Supper': ['*Su', 'pper#'],
#  'Surrey': ['*Surre', 'y#'],
#  'Sussex': ['*Sussex#'],
#  'Taiwanese': ['*Ta', 'i', 'wan', 'es', 'e#'],
#  'Takeshi': ['*Take', 's', 'hi', '#'],
#  'Taxonomy': ['*Ta', 'xon', 'omy#'],
#  'Territory': ['*Ter', 'rit', 'ory#'],
#  'Thirty': ['*Th', 'i', 'rty#'],
#  'Thomas': ['*Th', 'omas#'],
#  'Though': ['*Th', 'ough', '#'],
#  'Thousand': ['*Th', 'ous', 'and#'],
#  'Threatened': ['*Th', 'reate', 'n', 'ed#'],
#  'Tobias': ['*To', 'bi', 'as#'],
#  'Together': ['*To', 'gether#'],
#  'Totten': ['*To', 'tten', '#'],
#  'Traveler': ['*Tr', 'a', 've', 'ler#'],
#  'Treason': ['*Tre', 'ason#'],
#  'Treasury': ['*Tre', 'asury#'],
#  'Troops': ['*Tr', 'o', 'ops#'],
#  'Tunisia': ['*Tunis', 'ia#'],
#  'United': ['*Un', 'ited#'],
#  'Unlike': ['*Un', 'like#'],
#  'Valkyria': ['*Val', 'kyri', 'a#'],
#  'Veterans': ['*Ve', 'ter', 'ans#'],
#  'Victoria': ['*Vi', 'ctori', 'a#'],
#  'Victorian': ['*Vi', 'ctori', 'an#'],
#  'Village': ['*Vi', 'lla', 'ge#'],
#  'Vision': ['*Vi', 's', 'ion#'],
#  'Waddon': ['*Wa', 'd', 'don#'],
#  'Waldrons': ['*Wal', 'drons#'],
#  'Walker': ['*Wal', 'ker#'],
#  'Walter': ['*Wal', 'ter#'],
#  'Washington': ['*Wa', 'sh', 'ing', 'ton#'],
#  'Western': ['*West', 'ern#'],
#  'Whitby': ['*Whi', 't', 'by#'],
#  'William': ['*Wi', 'lli', 'am#'],
#  'Window': ['*Win', 'd', 'ow', '#'],
#  'Winter': ['*Win', 'ter#'],
#  'Wisniewski': ['*Wi', 's', 'niewski#'],
#  'Without': ['*Wi', 'th', 'out#'],
#  'Woodward': ['*Wo', 'od', 'ward#'],
#  'Worthing': ['*Wor', 'th', 'ing#'],
#  'Yorkshire': ['*Yo', 'r', 'kshi', 're', '#'],
#  'abandoned': ['*aband', 'on', 'ed#'],
#  'abandons': ['*aband', 'ons#'],
#  'abilities': ['*abi', 'lities#'],
#  'abuses': ['*abus', 'es#'],
#  'access': ['*acces', 's#'],
#  'accompanying': ['*acco', 'mp', 'an', 'ying#'],
#  'account': ['*acco', 'u', 'nt#'],
#  'accountability': ['*acco', 'u', 'nt', 'abi', 'lit', 'y#'],
#  'accused': ['*accus', 'ed#'],
#  'achieve': ['*achi', 'eve', '#'],
#  'acquire': ['*acqu', 'i', 're', '#'],
#  'acquired': ['*acqu', 'i', 'red#'],
#  'acquisition': ['*acqu', 'is', 'ition#'],
#  'across': ['*across#'],
#  'action': ['*action#'],
#  'activate': ['*acti', 'v', 'ate', '#'],
#  'active': ['*acti', 've#'],
#  'activities': ['*acti', 'vi', 'ties#'],
#  'activity': ['*acti', 'vit', 'y#'],
#  'adaptation': ['*adap', 'tation', '#'],
#  'adaptations': ['*adap', 'tation', 's#'],
#  'adapted': ['*adap', 'ted#'],
#  'addition': ['*addition#'],
#  'additional': ['*addition', 'al#'],
#  'adjusted': ['*adju', 'st', 'ed#'],
#  'adjustments': ['*adju', 'st', 'ments#'],
#  'admitted': ['*admit', 'ted#'],
#  'advances': ['*advan', 'ces#'],
#  'advancing': ['*advan', 'c', 'ing#'],
#  'advantage': ['*advant', 'a', 'ge#'],
#  'affect': ['*aff', 'e', 'ct#'],
#  'affected': ['*aff', 'e', 'cted#'],
#  'affiliated': ['*affi', 'li', 'ated#'],
#  'afternoon': ['*af', 'ter', 'no', 'on#'],
#  'afterward': ['*af', 'ter', 'ward#'],
#  'against': ['*aga', 'in', 'st#'],
#  'agency': ['*agenc', 'y#'],
#  'agreed': ['*agre', 'ed#'],
#  'agreement': ['*agre', 'ement#'],
#  'allegiance': ['*alle', 'gian', 'ce#'],
#  'allies': ['*alli', 'es#'],
#  'allocated': ['*all', 'o', 'cated#'],
#  'allowed': ['*all', 'ow', 'ed#'],
#  'allowing': ['*all', 'ow', 'ing#'],
#  'almost': ['*almost', '#'],
#  'alongside': ['*alongside#'],
#  'already': ['*alread', 'y#'],
#  'altered': ['*alter', 'ed#'],
#  'alternating': ['*alter', 'nating#'],
#  'although': ['*although', '#'],
#  'always': ['*alway', 's#'],
#  'amateur': ['*amate', 'ur', '#'],
#  'ammunition': ['*ammun', 'ition#'],
#  'amongst': ['*among', 'st#'],
#  'amount': ['*amou', 'nt#'],
#  'amusing': ['*amus', 'ing#'],
#  'analysis': ['*analy', 'sis#'],
#  'analytical': ['*analy', 'tic', 'al#'],
#  'ancestral': ['*ancest', 'ral#'],
#  'ancient': ['*anci', 'ent#'],
#  'animated': ['*animat', 'ed#'],
#  'animation': ['*animation', '#'],
#  'annotata': ['*annotat', 'a', '#'],
#  'announced': ['*annou', 'n', 'ced#'],
#  'annoying': ['*anno', 'y', 'ing#'],
#  'anonymous': ['*anon', 'ymous#'],
#  'another': ['*another#'],
#  'appeal': ['*appeal#'],
#  'appearance': ['*appear', 'ance#'],
#  'appearances': ['*appear', 'an', 'ces#'],
#  'appeared': ['*appeared#'],
#  'approach': ['*appro', 'ach#'],
#  'appropriated': ['*appro', 'pri', 'ated#'],
#  'approximately': ['*appro', 'ximate', 'ly#'],
#  'armory': ['*armor', 'y#'],
#  'around': ['*around#'],
#  'arranged': ['*arrang', 'ed#'],
#  'arrest': ['*arrest', '#'],
#  'arriving': ['*arriving#'],
#  'arsenal': ['*ars', 'en', 'al#'],
#  'article': ['*artic', 'le#'],
#  'artifacts': ['*arti', 'f', 'act', 's#'],
#  'artillery': ['*arti', 'llery#'],
#  'artist': ['*arti', 'st#'],
#  'artistic': ['*arti', 'stic', '#'],
#  'artists': ['*arti', 'sts#'],
#  'artworks': ['*art', 'works#'],
#  'asking': ['*asking#'],
#  'aspect': ['*aspect', '#'],
#  'aspects': ['*aspect', 's#'],
#  'assemble': ['*assemble', '#'],
#  'assembled': ['*assembled#'],
#  'assessed': ['*asses', 'sed#'],
#  'assigned': ['*assig', 'ned#'],
#  'assistance': ['*assist', 'an', 'ce#'],
#  'association': ['*ass', 'oci', 'ation', '#'],
#  'associations': ['*ass', 'oci', 'ation', 's#'],
#  'assumed': ['*assumed#'],
#  'atmosphere': ['*atmo', 'spher', 'e', '#'],
#  'attached': ['*attach', 'ed#'],
#  'attack': ['*attack', '#'],
#  'attacks': ['*attack', 's#'],
#  'attempted': ['*atte', 'mp', 'ted#'],
#  'attend': ['*atten', 'd#'],
#  'attended': ['*atten', 'ded#'],
#  'attendees': ['*atten', 'de', 'es#'],
#  'attention': ['*atte', 'ntion#'],
#  'attorney': ['*attorney#'],
#  'attractions': ['*attrac', 'tion', 's#'],
#  'attributes': ['*attribu', 'tes#'],
#  'author': ['*auth', 'or', '#'],
#  'authored': ['*auth', 'ored#'],
#  'authorities': ['*auth', 'or', 'i', 'ties#'],
#  'authority': ['*auth', 'or', 'i', 'ty#'],
#  'authorized': ['*auth', 'or', 'ized#'],
#  'autumn': ['*autum', 'n#'],
#  'availability': ['*availab', 'i', 'lit', 'y#'],
#  'available': ['*available#'],
#  'awarded': ['*awarded#'],
#  'awkward': ['*awkwar', 'd#'],
#  'balance': ['*bal', 'ance#'],
#  'banner': ['*ban', 'ner#'],
#  'baptismal': ['*ba', 'pti', 's', 'mal#'],
#  'barely': ['*barely#'],
#  'barracks': ['*bar', 'racks#'],
#  'basement': ['*ba', 'sement', '#'],
#  'battery': ['*bat', 'ter', 'y#'],
#  'battle': ['*bat', 'tle#'],
#  'battlefield': ['*bat', 'tle', 'fiel', 'd#'],
#  'became': ['*be', 'came', '#'],
#  'because': ['*be', 'cause#'],
#  'become': ['*be', 'come#'],
#  'becomes': ['*be', 'comes#'],
#  'becoming': ['*be', 'com', 'ing#'],
#  'before': ['*be', 'fore', '#'],
#  'beginning': ['*be', 'gin', 'ning#'],
#  'behind': ['*be', 'hind#'],
#  'believing': ['*be', 'lieving#'],
#  'belonged': ['*be', 'l', 'ong', 'ed#'],
#  'benefactor': ['*ben', 'e', 'fact', 'or#'],
#  'bequeathed': ['*bequeat', 'h', 'ed#'],
#  'besides': ['*bes', 'i', 'des#'],
#  'between': ['*be', 't', 'we', 'en#'],
#  'birthday': ['*bi', 'rth', 'day#'],
#  'birthplace': ['*bi', 'rth', 'plac', 'e#'],
#  'blotches': ['*blo', 'tches#'],
#  'bodied': ['*bo', 'di', 'ed#'],
#  'booklet': ['*bo', 'ok', 'le', 't#'],
#  'borrow': ['*bor', 'row#'],
#  'borrowed': ['*bor', 'row', 'ed#'],
#  'bottom': ['*bo', 't', 'tom#'],
#  'bottomed': ['*bo', 't', 'tomed#'],
#  'bought': ['*bought#'],
#  'briefly': ['*bri', 'efly#'],
#  'broken': ['*bro', 'ken', '#'],
#  'bronze': ['*bronze#'],
#  'brought': ['*brough', 't#'],
#  'bubbles': ['*bubbles#'],
#  'budget': ['*bud', 'ge', 't#'],
#  'builder': ['*bu', 'il', 'der#'],
#  'building': ['*bu', 'il', 'ding#'],
#  'buildings': ['*bu', 'il', 'ding', 's#'],
#  'bullet': ['*bullet#'],
#  'caliber': ['*cali', 'ber', '#'],
#  'called': ['*cal', 'led#'],
#  'campaign': ['*camp', 'a', 'ign#'],
#  'camped': ['*camp', 'ed#'],
#  'camping': ['*camp', 'ing#'],
#  'cannon': ['*can', 'non#'],
#  'capacity': ['*ca', 'pac', 'ity#'],
#  'capital': ['*ca', 'p', 'ital#'],
#  'captain': ['*ca', 'p', 'tain', '#'],
#  'capture': ['*ca', 'p', 'ture#'],
#  'capturing': ['*ca', 'p', 'tur', 'ing#'],
#  'career': ['*care', 'er#'],
#  'carpenter': ['*car', 'penter', '#'],
#  'carriages': ['*car', 'ri', 'ages#'],
#  'carried': ['*car', 'ri', 'ed#'],
#  'carrying': ['*car', 'rying#'],
#  'cartridge': ['*car', 'tri', 'd', 'ge#'],
#  'cartridges': ['*car', 'tri', 'd', 'ges#'],
#  'caught': ['*ca', 'ught#'],
#  'caused': ['*ca', 'us', 'ed#'],
#  'center': ['*center', '#'],
#  'central': ['*central#'],
#  'century': ['*cent', 'ur', 'y#'],
#  'certain': ['*cer', 'tain', '#'],
#  'certainly': ['*cer', 'tain', 'ly#'],
#  'challenge': ['*chal', 'leng', 'e#'],
#  'challenges': ['*chal', 'leng', 'es#'],
#  'chance': ['*chance#'],
#  'change': ['*chang', 'e#'],
#  'changed': ['*chang', 'ed#'],
#  'changes': ['*chang', 'es#'],
#  'changing': ['*chang', 'ing#'],
#  'chapel': ['*cha', 'pel#'],
#  'character': ['*char', 'a', 'c', 'ter#'],
#  'characters': ['*char', 'a', 'c', 'ters#'],
#  'charge': ['*char', 'ge#'],
#  'charitable': ['*char', 'i', 't', 'able#'],
#  'charter': ['*char', 'ter#'],
#  'charts': ['*char', 'ts#'],
#  'chemical': ['*che', 'mic', 'al#'],
#  'childhood': ['*chi', 'l', 'd', 'hood#'],
#  'children': ['*chi', 'l', 'd', 'ren', '#'],
#  'choice': ['*cho', 'ice#'],
#  'chosen': ['*cho', 'sen#'],
#  'church': ['*church#'],
#  'churches': ['*churches#'],
#  'churchyard': ['*church', 'yard#'],
#  'citing': ['*citing#'],
#  'citizen': ['*citize', 'n', '#'],
#  'citizens': ['*citize', 'n', 's#'],
#  'civilian': ['*civi', 'li', 'an#'],
#  'clades': ['*cla', 'des#'],
#  'claimed': ['*cla', 'imed#'],
#  'classes': ['*cla', 's', 'ses#'],
#  'classified': ['*cla', 's', 'sified#'],
#  'clerks': ['*cler', 'ks#'],
#  'closed': ['*clo', 'sed#'],
#  'closely': ['*clo', 'sely#'],
#  'closing': ['*clo', 'sing#'],
#  'closure': ['*clo', 'sure#'],
#  'clothing': ['*clo', 'th', 'ing#'],
#  'coastline': ['*coast', 'line#'],
#  'collaborated': ['*collab', 'or', 'ated#'],
#  'collaboration': ['*collab', 'or', 'ation', '#'],
#  'collection': ['*colle', 'ction', '#'],
#  'collision': ['*colli', 's', 'ion#'],
#  'colonel': ['*col', 'on', 'el#'],
#  'coloration': ['*col', 'or', 'ation', '#'],
#  'combined': ['*com', 'b', 'ined#'],
#  'coming': ['*com', 'ing#'],
#  'command': ['*com', 'man', 'd#'],
#  'commander': ['*com', 'man', 'der#'],
#  'commanding': ['*com', 'man', 'd', 'ing#'],
#  'commemorate': ['*com', 'memor', 'ate', '#'],
#  'commenced': ['*com', 'men', 'ced#'],
#  'commercial': ['*com', 'mer', 'cial#'],
#  'common': ['*com', 'mon', '#'],
#  'commonly': ['*com', 'mon', 'ly#'],
#  'companies': ['*comp', 'an', 'ies#'],
#  'company': ['*comp', 'an', 'y#'],
#  'compared': ['*comp', 'ared#'],
#  'compatible': ['*comp', 'ati', 'ble#'],
#  'competed': ['*comp', 'e', 'ted#'],
#  'competent': ['*comp', 'e', 'tent#'],
#  'competition': ['*comp', 'e', 'ti', 'tion#'],
#  'completed': ['*comp', 'le', 'ted#'],
#  'completely': ['*comp', 'le', 'te', 'ly#'],
#  'completing': ['*comp', 'le', 'ting#'],
#  'completion': ['*comp', 'le', 'tion#'],
#  'complex': ['*comp', 'lex', '#'],
#  'components': ['*comp', 'onents#'],
#  'compose': ['*comp', 'o', 'se#'],
#  'composed': ['*comp', 'o', 'sed#'],
#  'composer': ['*comp', 'o', 'ser#'],
#  'comprising': ['*comp', 'ris', 'ing#'],
#  'concept': ['*concep', 't#'],
#  'conclusion': ['*conc', 'lus', 'ion#'],
#  'condition': ['*condi', 'tion#'],
#  'conducted': ['*cond', 'ucted#'],
#  'conflict': ['*conflict', '#'],
#  'confronts': ['*confront', 's#'],
#  'connection': ['*connection', '#'],
#  'conquered': ['*conqu', 'ered#'],
#  'consciousness': ['*cons', 'ciou', 's', 'ness#'],
#  'conscripted': ['*cons', 'cri', 'pted#'],
#  'consensus': ['*cons', 'ens', 'us#'],
#  'consequence': ['*cons', 'equen', 'ce#'],
#  'consequences': ['*cons', 'equen', 'ces#'],
#  'conservation': ['*cons', 'er', 'vation', '#'],
#  'consider': ['*cons', 'i', 'der#'],
#  'considered': ['*cons', 'i', 'dered#'],
#  'consisted': ['*cons', 'ist', 'ed#'],
#  'consisting': ['*cons', 'isting#'],
#  'consists': ['*cons', 'ists#'],
#  'constructed': ['*constr', 'ucted#'],
#  'construction': ['*constr', 'uction', '#'],
#  'consume': ['*cons', 'ume#'],
#  'contains': ['*cont', 'ain', 's#'],
#  'content': ['*conte', 'nt#'],
#  'continent': ['*contin', 'ent#'],
#  'continental': ['*contin', 'ent', 'al#'],
#  'continue': ['*contin', 'ue#'],
#  'continued': ['*continued#'],
#  'continues': ['*contin', 'ues#'],
#  'control': ['*cont', 'ro', 'l#'],
#  'controversial': ['*cont', 'rover', 's', 'ial#'],
#  'convention': ['*conve', 'ntion#'],
#  'converge': ['*conver', 'ge#'],
#  'converted': ['*conver', 'ted#'],
#  'converting': ['*conver', 'ting#'],
#  'cooperative': ['*cooperati', 've#'],
#  'corners': ['*cor', 'ners#'],
#  'correspondence': ['*cor', 'respon', 'dence#'],
#  'costumes': ['*cost', 'umes#'],
#  'countries': ['*cou', 'nt', 'ries#'],
#  'country': ['*cou', 'nt', 'ry#'],
#  'coupled': ['*cou', 'pled#'],
#  'course': ['*cou', 'rs', 'e#'],
#  'courses': ['*cou', 'rs', 'es#'],
#  'covers': ['*cover', 's#'],
#  'create': ['*create', '#'],
#  'created': ['*created#'],
#  'creating': ['*cre', 'ating#'],
#  'criminals': ['*cri', 'min', 'al', 's#'],
#  'crisis': ['*cri', 's', 'is#'],
#  'critic': ['*cri', 'tic', '#'],
#  'critically': ['*cri', 'tic', 'ally#'],
#  'criticism': ['*cri', 'tic', 'ism#'],
#  'criticisms': ['*cri', 'tic', 'is', 'ms#'],
#  'criticized': ['*cri', 'tic', 'ized#'],
#  'critics': ['*cri', 'tic', 's#'],
#  'crossover': ['*cross', 'over', '#'],
#  'crucial': ['*cruci', 'al', '#'],
#  'cryptic': ['*cry', 'ptic', '#'],
#  'customized': ['*cust', 'om', 'ized#'],
#  'cutscenes': ['*cut', 's', 'cen', 'es#'],
#  'damaged': ['*dama', 'ged#'],
#  'dangerous': ['*danger', 'ous#'],
#  'dangers': ['*danger', 's#'],
#  'darker': ['*dar', 'ker#'],
#  'daughter': ['*da', 'ughter', '#'],
#  'decades': ['*deca', 'des#'],
#  'decided': ['*dec', 'ided#'],
#  'decides': ['*dec', 'ides#'],
#  'decommissioned': ['*decom', 'mission', 'ed#'],
#  'decommissioning': ['*decom', 'mission', 'ing#'],
#  'dedicated': ['*dedic', 'ated#'],
#  'deemed': ['*deemed#'],
#  'defeat': ['*defe', 'at', '#'],
#  'defects': ['*defect', 's#'],
#  'defenseman': ['*defen', 's', 'eman#'],
#  'delayed': ['*delay', 'ed#'],
#  'delegates': ['*dele', 'gat', 'es#'],
#  'delicate': ['*delic', 'ate', '#'],
#  'delivery': ['*deliver', 'y#'],
#  'demand': ['*deman', 'd#'],
#  'demolished': ['*demo', 'li', 'shed#'],
#  'denied': ['*deni', 'ed#'],
#  'denticles': ['*dentic', 'les#'],
#  'depending': ['*depen', 'd', 'ing#'],
#  'depicting': ['*depic', 'ting#'],
#  'deployment': ['*deplo', 'yment', '#'],
#  'deposit': ['*depo', 'sit', '#'],
#  'dermal': ['*dermal#'],
#  'descendant': ['*descen', 'd', 'ant', '#'],
#  'described': ['*desc', 'ri', 'bed#'],
#  'description': ['*desc', 'ri', 'ption', '#'],
#  'design': ['*desig', 'n#'],
#  'designated': ['*desig', 'nat', 'ed#'],
#  'designed': ['*desig', 'ned#'],
#  'designer': ['*desig', 'ner#'],
#  'designs': ['*desig', 'ns#'],
#  'desperate': ['*desper', 'ate', '#'],
#  'desperately': ['*desper', 'ate', 'ly#'],
#  'despite': ['*desp', 'ite#'],
#  'destination': ['*destin', 'ation', '#'],
#  'destitute': ['*desti', 't', 'ute#'],
#  'destroyed': ['*dest', 'ro', 'y', 'ed#'],
#  'destroys': ['*dest', 'ro', 'ys#'],
#  'detached': ['*detach', 'ed#'],
#  'detail': ['*detail#'],
#  'detailing': ['*deta', 'iling#'],
#  'details': ['*deta', 'ils#'],
#  'deteriorate': ['*deteri', 'orate', '#'],
#  'deterioration': ['*deteri', 'oration', '#'],
#  'determine': ['*deter', 'min', 'e#'],
#  'determined': ['*deter', 'min', 'ed#'],
#  'develop': ['*develo', 'p', '#'],
#  'developed': ['*develo', 'ped#'],
#  'developing': ['*develo', 'p', 'ing#'],
#  'development': ['*develo', 'p', 'ment#'],
#  'devolved': ['*devol', 've', 'd#'],
#  'devoted': ['*dev', 'o', 'ted#'],
#  'devout': ['*dev', 'ou', 't#'],
#  'diamond': ['*diamon', 'd#'],
#  'dictated': ['*dict', 'ated#'],
#  'different': ['*differ', 'e', 'nt#'],
#  'differing': ['*differ', 'ing#'],
#  'difficulty': ['*difficul', 'ty#'],
#  'digging': ['*dig', 'ging#'],
#  'directed': ['*dire', 'cted#'],
#  'direction': ['*dire', 'ction', '#'],
#  'directly': ['*dire', 'ct', 'ly#'],
#  'director': ['*dire', 'ctor', '#'],
#  'disappeared': ['*dis', 'appe', 'ared#'],
#  'discarded': ['*dis', 'car', 'ded#'],
#  'disciples': ['*dis', 'ci', 'ples#'],
#  'dispatch': ['*dis', 'patch', '#'],
#  'dispatched': ['*dis', 'patch', 'ed#'],
#  'displayed': ['*dis', 'play', 'ed#'],
#  'distance': ['*dist', 'an', 'ce#'],
#  'distinct': ['*distin', 'ct', '#'],
#  'distress': ['*dist', 'ress#'],
#  'distributed': ['*dist', 'ribu', 'ted#'],
#  'distributing': ['*dist', 'ribu', 'ting#'],
#  'distribution': ['*dist', 'ribu', 'tion#'],
#  'district': ['*dist', 'rict#'],
#  'diverged': ['*diver', 'ged#'],
#  'divergence': ['*diver', 'gence#'],
#  'divided': ['*divided#'],
#  'division': ['*divis', 'ion#'],
#  'divorced': ['*divor', 'ced#'],
#  'documents': ['*document', 's#'],
#  'donated': ['*don', 'ated#'],
#  'donation': ['*don', 'ation', '#'],
#  'dorsal': ['*dors', 'al#'],
#  'download': ['*dow', 'n', 'load#'],
#  'downloadable': ['*dow', 'n', 'lo', 'adable#'],
#  'downtown': ['*dow', 'nt', 'own#'],
#  'drastically': ['*dra', 'stic', 'ally#'],
#  'drawings': ['*dra', 'wing', 's#'],
#  'during': ['*during#'],
#  'duties': ['*duti', 'es#'],
#  'dweller': ['*dweller#'],
#  'earliest': ['*earli', 'est', '#'],
#  'echelons': ['*eche', 'l', 'ons#'],
#  'ecology': ['*ecol', 'o', 'g', 'y#'],
#  'economic': ['*econom', 'ic#'],
#  'edition': ['*edi', 'tion#'],
#  'editions': ['*edi', 'tion', 's#'],
#  'educate': ['*educat', 'e', '#'],
#  'education': ['*education', '#'],
#  'effected': ['*effe', 'cted#'],
#  'effort': ['*effor', 't#'],
#  'efforts': ['*effor', 'ts#'],
#  'eighth': ['*eigh', 'th#'],
#  'either': ['*either#'],
#  'elected': ['*elected#'],
#  'electric': ['*elect', 'ric', '#'],
#  'elements': ['*elements#'],
#  'elevated': ['*elevat', 'ed#'],
#  'elongated': ['*elong', 'ated#'],
#  'embryos': ['*embry', 'os#'],
#  'emergency': ['*emergen', 'c', 'y#'],
#  'employed': ['*empl', 'o', 'yed#'],
#  'employment': ['*empl', 'o', 'yment', '#'],
#  'encounters': ['*enco', 'u', 'nter', 's#'],
#  'ending': ['*end', 'ing#'],
#  'enemies': ['*enemi', 'es#'],
#  'engage': ['*engage#'],
#  'engine': ['*engin', 'e#'],
#  'enjoyed': ['*enjo', 'y', 'ed#'],
#  'enjoying': ['*enjo', 'y', 'ing#'],
#  'enlightening': ['*enligh', 'ten', 'ing#'],
#  'enlisted': ['*enli', 'st', 'ed#'],
#  'enough': ['*enough', '#'],
#  'enraged': ['*enraged#'],
#  'entered': ['*entered#'],
#  'enterprise': ['*enterpris', 'e#'],
#  'entertaining': ['*enterta', 'in', 'ing#'],
#  'entire': ['*entire', '#'],
#  'entrance': ['*entran', 'ce#'],
#  'entries': ['*entri', 'es#'],
#  'episode': ['*episode#'],
#  'episodes': ['*episodes#'],
#  'episodic': ['*episodic', '#'],
#  'equally': ['*equal', 'ly#'],
#  'equipment': ['*equip', 'ment', '#'],
#  'erased': ['*era', 'sed#'],
#  'escorted': ['*escor', 'ted#'],
#  'essential': ['*essential', '#'],
#  'essentially': ['*essential', 'ly#'],
#  'established': ['*est', 'abli', 'shed#'],
#  'establishment': ['*est', 'abli', 'sh', 'ment#'],
#  'estimated': ['*esti', 'mat', 'ed#'],
#  'evacuation': ['*evac', 'uation', '#'],
#  'evening': ['*even', 'ing#'],
#  'events': ['*event', 's#'],
#  'eventually': ['*event', 'ually#'],
#  'evidence': ['*eviden', 'ce#'],
#  'exceeding': ['*exceed', 'ing#'],
#  'excellent': ['*exce', 'llent#'],
#  'except': ['*excep', 't#'],
#  'exchange': ['*exchang', 'e#'],
#  'excited': ['*exc', 'ited#'],
#  'exclusive': ['*exc', 'lus', 'ive', '#'],
#  'exclusively': ['*exc', 'lus', 'ive', 'ly#'],
#  'executive': ['*executi', 've#'],
#  'exemplified': ['*exemp', 'li', 'fied#'],
#  'exerted': ['*exer', 'ted#'],
#  'exhausted': ['*exha', 'usted#'],
#  'exhibit': ['*exhibit', '#'],
#  'exhibited': ['*exhi', 'bited#'],
#  'exhibition': ['*exhibiti', 'on', '#'],
#  'exists': ['*exists#'],
#  'expanded': ['*exp', 'an', 'ded#'],
#  'expectations': ['*exp', 'e', 'ct', 'ation', 's#'],
#  'expected': ['*exp', 'e', 'cted#'],
#  'expense': ['*exp', 'ens', 'e#'],
#  'experience': ['*exp', 'eri', 'ence#'],
#  'exploit': ['*exp', 'lo', 'it#'],
#  'expose': ['*exp', 'ose#'],
#  'expressing': ['*exp', 'ressing#'],
#  'exquisite': ['*exquis', 'ite#'],
#  'extended': ['*exten', 'ded#'],
#  'extends': ['*exten', 'ds#'],
#  'extensive': ['*exten', 's', 'ive#'],
#  'extent': ['*extent#'],
#  'exterior': ['*exteri', 'or#'],
#  'fabrication': ['*fabric', 'ation', '#'],
#  'factors': ['*fact', 'ors#'],
#  'failed': ['*fa', 'iled#'],
#  'fairies': ['*fa', 'i', 'ries#'],
#  'fairly': ['*fa', 'i', 'rly#'],
#  'falsely': ['*fal', 'sely#'],
#  'families': ['*fami', 'li', 'es#'],
#  'family': ['*fami', 'ly#'],
#  'fanfare': ['*fan', 'fare#'],
#  'fantasy': ['*fant', 'as', 'y#'],
#  'farther': ['*far', 'ther#'],
#  'father': ['*fath', 'er#'],
#  'favorite': ['*fav', 'or', 'i', 'te#'],
#  'feature': ['*fe', 'ature#'],
#  'featured': ['*fe', 'at', 'ured#'],
#  'features': ['*fe', 'at', 'ures#'],
#  'featuring': ['*fe', 'at', 'uring#'],
#  'federal': ['*feder', 'al#'],
#  'feeling': ['*fe', 'eling', '#'],
#  'fellow': ['*fellow', '#'],
#  'female': ['*fe', 'mal', 'e#'],
#  'females': ['*fe', 'mal', 'es#'],
#  'fielded': ['*fi', 'el', 'ded#'],
#  'finalized': ['*fin', 'al', 'ized#'],
#  'finally': ['*fin', 'ally#'],
#  'financial': ['*fin', 'an', 'ci', 'al#'],
#  'finish': ['*fin', 'ish#'],
#  'finished': ['*fin', 'ished#'],
#  'fished': ['*fi', 'shed#'],
#  'fisheries': ['*fi', 'sher', 'i', 'es#'],
#  'fishes': ['*fi', 'shes#'],
#  'flattened': ['*flat', 'ten', 'ed#'],
#  'flintlock': ['*flint', 'lock', '#'],
#  'floors': ['*flo', 'ors#'],
#  'flower': ['*flow', 'er', '#'],
#  'flowers': ['*flow', 'er', 's#'],
#  'focused': ['*fo', 'cus', 'ed#'],
#  'focusing': ['*fo', 'cus', 'ing#'],
#  'following': ['*fo', 'll', 'ow', 'ing#'],
#  'follows': ['*fo', 'll', 'ow', 's#'],
#  'fondness': ['*fond', 'ness#'],
#  'football': ['*fo', 'ot', 'ball', '#'],
#  'footballers': ['*fo', 'ot', 'bal', 'lers#'],
#  'forced': ['*for', 'ced#'],
#  'forces': ['*for', 'ces#'],
#  'foreign': ['*fore', 'ign#'],
#  'forever': ['*fore', 'ver', '#'],
#  'formal': ['*for', 'mal#'],
#  'former': ['*for', 'mer#'],
#  'forward': ['*for', 'ward#'],
#  'fought': ['*fought#'],
#  'founded': ['*fou', 'nded#'],
#  'franchise': ['*franch', 'ise#'],
#  'freedom': ['*fre', 'ed', 'om#'],
#  'freely': ['*fre', 'ely#'],
#  'freeze': ['*fre', 'eze', '#'],
#  'friend': ['*fri', 'en', 'd#'],
#  'friends': ['*fri', 'ends#'],
#  'frontier': ['*fron', 'ti', 'er#'],
#  'functional': ['*function', 'al#'],
#  'functions': ['*function', 's#'],
#  'fundraisers': ['*fund', 'ra', 'isers#'],
#  'funeral': ['*fun', 'er', 'al#'],
#  'further': ['*fur', 'ther#'],
#  'fusion': ['*fusion#'],
#  'futile': ['*futile#'],
#  'gained': ['*gain', 'ed#'],
#  'gameplay': ['*gamepla', 'y#'],
#  'gaming': ['*gaming#'],
#  'garden': ['*garden#'],
#  'garrison': ['*garri', 'son#'],
#  'gathered': ['*gath', 'er', 'ed#'],
#  'gathering': ['*gath', 'er', 'ing#'],
#  'general': ['*gener', 'al#'],
#  'generally': ['*gener', 'ally#'],
#  'genetically': ['*gene', 'tic', 'ally#'],
#  'gently': ['*gently#'],
#  'gestation': ['*gest', 'ation', '#'],
#  'getting': ['*get', 'ting#'],
#  'girlhood': ['*gir', 'lhood#'],
#  'giving': ['*giving#'],
#  'goaltender': ['*go', 'alten', 'der#'],
#  'governess': ['*gover', 'ness#'],
#  'governing': ['*gover', 'ning#'],
#  'government': ['*gover', 'nment#'],
#  'governor': ['*gover', 'nor', '#'],
#  'gracile': ['*grac', 'ile#'],
#  'gradually': ['*grad', 'ually#'],
#  'granted': ['*granted#'],
#  'graphics': ['*graphic', 's#'],
#  'grayish': ['*gray', 'ish#'],
#  'greater': ['*great', 'er#'],
#  'greatly': ['*great', 'ly#'],
#  'growth': ['*growth#'],
#  'guarantee': ['*guar', 'an', 'te', 'e#'],
#  'guardian': ['*guar', 'dian#'],
#  'guitar': ['*guit', 'ar', '#'],
#  'gunboat': ['*gunbo', 'at', '#'],
#  'habitat': ['*hab', 'it', 'at', '#'],
#  'habitats': ['*hab', 'it', 'at', 's#'],
#  'handful': ['*hand', 'ful#'],
#  'handled': ['*hand', 'led#'],
#  'happened': ['*happen', 'ed#'],
#  'happens': ['*happen', 's#'],
#  'having': ['*having#'],
#  'headquartered': ['*head', 'quar', 'ter', 'ed#'],
#  'headquarters': ['*head', 'quar', 'ters#'],
#  'health': ['*heal', 'th#'],
#  'helping': ['*hel', 'ping#'],
#  'herself': ['*hers', 'el', 'f#'],
#  'higher': ['*higher#'],
#  'highest': ['*highest', '#'],
#  'highly': ['*high', 'ly#'],
#  'himself': ['*him', 'self', '#'],
#  'hinting': ['*hinting#'],
#  'historic': ['*histor', 'ic#'],
#  'history': ['*histor', 'y#'],
#  'histotroph': ['*histo', 'tro', 'ph#'],
#  'holotype': ['*hol', 'o', 'type#'],
#  'hopeful': ['*hope', 'ful#'],
#  'horizon': ['*horiz', 'on#'],
#  'housed': ['*hous', 'ed#'],
#  'household': ['*hous', 'e', 'hol', 'd#'],
#  'housekeeper': ['*hous', 'e', 'keeper#'],
#  'however': ['*howe', 'ver', '#'],
#  'identify': ['*identif', 'y#'],
#  'identities': ['*identiti', 'es#'],
#  'illustrated': ['*illust', 'rat', 'ed#'],
#  'illustrating': ['*illust', 'rating#'],
#  'illustration': ['*illust', 'ration', '#'],
#  'illustrations': ['*illust', 'ration', 's#'],
#  'illustrator': ['*illust', 'rat', 'or#'],
#  'impacting': ['*impac', 'ting#'],
#  'impede': ['*impede#'],
#  'impressed': ['*impres', 'sed#'],
#  'improve': ['*impr', 'ove', '#'],
#  'improved': ['*impr', 'ove', 'd#'],
#  'improvements': ['*impr', 'ove', 'ments#'],
#  'inadequate': ['*inadequ', 'ate', '#'],
#  'inaugurated': ['*inaugurated#'],
#  'incidental': ['*inc', 'ident', 'al', '#'],
#  'incidentally': ['*inc', 'ident', 'al', 'ly#'],
#  'include': ['*inc', 'lu', 'de#'],
#  'included': ['*inc', 'lu', 'ded#'],
#  'including': ['*inc', 'lu', 'ding#'],
#  'incorporate': ['*incor', 'por', 'ate', '#'],
#  'incorporated': ['*incor', 'por', 'ated#'],
#  'incorporating': ['*incor', 'por', 'ating#'],
#  'increased': ['*incre', 'ased#'],
#  'incursion': ['*inc', 'urs', 'ion#'],
#  'independence': ['*independence#'],
#  'indicated': ['*ind', 'icated#'],
#  'indicating': ['*ind', 'ic', 'ating#'],
#  'individual': ['*ind', 'ivid', 'ual#'],
#  'individuality': ['*ind', 'ivid', 'uali', 'ty#'],
#  'individuals': ['*ind', 'ivid', 'ual', 's#'],
#  'infantry': ['*infan', 't', 'ry#'],
#  'influence': ['*influ', 'ence#'],
#  'influenced': ['*influ', 'en', 'ced#'],
#  'influences': ['*influ', 'ences#'],
#  'inform': ['*inform#'],
#  'informed': ['*informed#'],
#  'inhabits': ['*inhab', 'it', 's#'],
#  'initial': ['*initi', 'al#'],
#  'initially': ['*initi', 'ally#'],
#  'innate': ['*innate', '#'],
#  'inside': ['*ins', 'i', 'de#'],
#  'inspected': ['*ins', 'pected#'],
#  'inspecting': ['*ins', 'pe', 'cting#'],
#  'inspired': ['*ins', 'pi', 'red#'],
#  'installation': ['*inst', 'all', 'ation', '#'],
#  'installed': ['*inst', 'al', 'led#'],
#  'instead': ['*inst', 'e', 'ad#'],
#  'instinctively': ['*instinctive', 'ly#'],
#  'institutions': ['*instit', 'ution', 's#'],
#  'instruction': ['*inst', 'r', 'uction', '#'],
#  'instructions': ['*inst', 'r', 'uction', 's#'],
#  'instruments': ['*inst', 'r', 'ument', 's#'],
#  'intact': ['*int', 'act', '#'],
#  'intended': ['*inten', 'ded#'],
#  'intensively': ['*inten', 's', 'ive', 'ly#'],
#  'interactions': ['*inter', 'ac', 'tion', 's#'],
#  'interesting': ['*inter', 'esting#'],
#  'interests': ['*inter', 'est', 's#'],
#  'interior': ['*inter', 'i', 'or#'],
#  'international': ['*inter', 'nation', 'al#'],
#  'interpreted': ['*inter', 'pre', 'ted#'],
#  'interview': ['*inter', 'view', '#'],
#  'invading': ['*inva', 'ding#'],
#  'inventory': ['*inve', 'nt', 'ory#'],
#  'invited': ['*invi', 'ted#'],
#  'involved': ['*invol', 've', 'd#'],
#  'ironclad': ['*ironc', 'la', 'd#'],
#  'issued': ['*issu', 'ed#'],
#  'issues': ['*issu', 'es#'],
#  'jackets': ['*ja', 'ck', 'e', 'ts#'],
#  'jockey': ['*jo', 'ck', 'e', 'y#'],
#  'journalists': ['*jour', 'nal', 'i', 'st', 's#'],
#  'juvenile': ['*ju', 'ven', 'ile#'],
#  'killed': ['*killed#'],
#  'kindergarten': ['*kinder', 'gar', 'ten', '#'],
#  'knocked': ['*knock', 'ed#'],
#  'knowledge': ['*knowled', 'ge#'],
#  'laboratory': ['*labor', 'ator', 'y#'],
#  'laborers': ['*laborers#'],
#  'lances': ['*lances#'],
#  'largely': ['*large', 'ly#'],
#  'larger': ['*larger#'],
#  'largest': ['*largest', '#'],
#  'latter': ['*latter#'],
#  'launched': ['*launch', 'ed#'],
#  'layouts': ['*lay', 'outs#'],
#  'leader': ['*leader#'],
#  'leading': ['*leading#'],
#  'league': ['*leagu', 'e#'],
#  'leaves': ['*leaves#'],
#  'leaving': ['*leaving#'],
#  'legislature': ['*legis', 'lat', 'ure#'],
#  'length': ['*length', '#'],
#  'lesser': ['*lesser', '#'],
#  'letters': ['*let', 'ters#'],
#  'levels': ['*leve', 'l', 's#'],
#  'library': ['*librar', 'y#'],
#  'lieutenant': ['*lie', 'uten', 'ant', '#'],
#  'lifelong': ['*lifelong#'],
#  'lifespan': ['*lifes', 'pan#'],
#  'likely': ['*like', 'ly#'],
#  'limitations': ['*limit', 'ation', 's#'],
#  'limited': ['*limi', 'ted#'],
#  'lineage': ['*line', 'age#'],
#  'linear': ['*line', 'ar', '#'],
#  'listed': ['*list', 'ed#'],
#  'listen': ['*list', 'e', 'n', '#'],
#  'literature': ['*liter', 'ature#'],
#  'litters': ['*lit', 'ters#'],
#  'little': ['*lit', 'tle#'],
#  'localized': ['*local', 'ized#'],
#  'located': ['*located#'],
#  'location': ['*location', '#'],
#  'longer': ['*longer#'],
#  'looming': ['*loom', 'ing#'],
#  'losses': ['*losses#'],
#  'lottery': ['*lotter', 'y#'],
#  'loyalists': ['*loy', 'ali', 'st', 's#'],
#  'lyrics': ['*lyric', 's#'],
#  'machinery': ['*mach', 'iner', 'y#'],
#  'magazine': ['*mag', 'az', 'in', 'e#'],
#  'mainly': ['*main', 'ly#'],
#  'maintaining': ['*main', 't', 'ain', 'ing#'],
#  'majority': ['*major', 'i', 'ty#'],
#  'making': ['*making#'],
#  'manage': ['*manage#'],
#  'managed': ['*managed#'],
#  'management': ['*management#'],
#  'manpower': ['*manpower', '#'],
#  'manufacture': ['*manufact', 'ure#'],
#  'manufacturing': ['*manufact', 'uring#'],
#  'marched': ['*march', 'ed#'],
#  'margins': ['*margin', 's#'],
#  'marked': ['*marked#'],
#  'married': ['*marri', 'ed#'],
#  'maskray': ['*mas', 'kra', 'y#'],
#  'maskrays': ['*mas', 'kra', 'ys#'],
#  'masonry': ['*mas', 'on', 'ry#'],
#  'matches': ['*match', 'es#'],
#  'material': ['*mater', 'i', 'al#'],
#  'matter': ['*matter#'],
#  'maturity': ['*maturi', 'ty#'],
#  'maximum': ['*maxim', 'um#'],
#  'meaning': ['*mean', 'ing#'],
#  'measure': ['*measure#'],
#  'measuring': ['*measuring#'],
#  'mechanics': ['*mech', 'an', 'ics#'],
#  'medicines': ['*medic', 'ines#'],
#  'meetings': ['*meeting', 's#'],
#  'melancholy': ['*melan', 'cho', 'ly#'],
#  'member': ['*member', '#'],
#  'members': ['*member', 's#'],
#  'membership': ['*member', 'shi', 'p', '#'],
#  'memorial': ['*memor', 'i', 'al#'],
#  'memory': ['*memor', 'y#'],
#  'merged': ['*merged#'],
#  'message': ['*mess', 'age#'],
#  'method': ['*meth', 'o', 'd#'],
#  'middle': ['*mid', 'dle#'],
#  'midline': ['*mid', 'line#'],
#  'military': ['*milit', 'ary#'],
#  'militia': ['*mili', 'ti', 'a#'],
#  'million': ['*milli', 'on#'],
#  'missed': ['*missed#'],
#  'mission': ['*mission#'],
#  'missionary': ['*mission', 'ary#'],
#  'missions': ['*mission', 's#'],
#  'mitochondrial': ['*mit', 'och', 'ondri', 'al#'],
#  'modelled': ['*mo', 'delled#'],
#  'models': ['*mo', 'del', 's#'],
#  'moderately': ['*mo', 'der', 'ate', 'ly#'],
#  'modern': ['*mo', 'der', 'n#'],
#  'molecular': ['*mo', 'le', 'c', 'ular#'],
#  'months': ['*mon', 'th', 's#'],
#  'morning': ['*mor', 'ning#'],
#  'morphological': ['*mor', 'phol', 'o', 'g', 'ical#'],
#  'mostly': ['*mo', 'st', 'ly#'],
#  'mother': ['*mo', 'ther#'],
#  'moulds': ['*mou', 'l', 'ds#'],
#  'movement': ['*movement#'],
#  'moving': ['*moving#'],
#  'multiple': ['*multi', 'ple#'],
#  'munitions': ['*munition', 's#'],
#  'museum': ['*mus', 'e', 'um#'],
#  'museums': ['*mus', 'e', 'um', 's#'],
#  'musical': ['*mus', 'ical#'],
#  'musket': ['*mus', 'ket#'],
#  'mustered': ['*muster', 'ed#'],
#  'mysterious': ['*myster', 'i', 'ous#'],
#  'narrowed': ['*narrow', 'ed#'],
#  'narrowly': ['*narrow', 'ly#'],
#  'nation': ['*nation', '#'],
#  'national': ['*nation', 'al#'],
#  'nations': ['*nation', 's#'],
#  'native': ['*native#'],
#  'naturally': ['*natural', 'ly#'],
#  'nature': ['*nature#'],
#  'nearly': ['*near', 'ly#'],
#  'necessary': ['*necess', 'ary#'],
#  'needed': ['*need', 'ed#'],
#  'needing': ['*need', 'ing#'],
#  'negatively': ['*negative', 'ly#'],
#  'negotiating': ['*neg', 'oti', 'ating#'],
#  'neither': ['*neither#'],
#  'nevertheless': ['*never', 'the', 'less#'],
#  'newborns': ['*new', 'bor', 'ns#'],
#  'newcomers': ['*new', 'co', 'mers#'],
#  'newfound': ['*new', 'found#'],
#  'northern': ['*north', 'er', 'n#'],
#  'northwest': ['*north', 'west', '#'],
#  'nostalgic': ['*nostal', 'gic#'],
#  'nostrils': ['*nostri', 'ls#'],
#  'noting': ['*noting#'],
#  'nourished': ['*nour', 'i', 'shed#'],
#  'nuclear': ['*nucle', 'ar', '#'],
#  'number': ['*number', '#'],
#  'numbers': ['*number', 's#'],
#  'nursery': ['*nurs', 'ery#'],
#  'nursing': ['*nurs', 'ing#'],
#  'obedience': ['*obedi', 'ence#'],
#  'observing': ['*obser', 'ving#'],
#  'obsolete': ['*obs', 'ole', 'te#'],
#  'obtained': ['*obtain', 'ed#'],
#  'occasional': ['*occa', 'sional#'],
#  'occurred': ['*occur', 'red#'],
#  'occurs': ['*occur', 's#'],
#  'octagonal': ['*octa', 'g', 'onal#'],
#  'offenders': ['*offen', 'ders#'],
#  'offered': ['*offer', 'ed#'],
#  'office': ['*office#'],
#  'officer': ['*officer', '#'],
#  'officers': ['*officer', 's#'],
#  'official': ['*offici', 'al#'],
#  'officially': ['*offici', 'ally#'],
#  'officials': ['*offici', 'al', 's#'],
#  'oldest': ['*oldes', 't', '#'],
#  'ominous': ['*omin', 'ous#'],
#  'opened': ['*opened#'],
#  'opening': ['*opening#'],
#  'operated': ['*operat', 'ed#'],
#  'operates': ['*operat', 'es#'],
#  'operations': ['*operation', 's#'],
#  'opportunity': ['*oppor', 'tun', 'ity#'],
#  'option': ['*opti', 'on#'],
#  'orchestra': ['*orch', 'est', 'ra', '#'],
#  'ordered': ['*order', 'ed#'],
#  'ordering': ['*order', 'ing#'],
#  'orders': ['*orders#'],
#  'ordnance': ['*ord', 'nance#'],
#  'organised': ['*organ', 'is', 'ed#'],
#  'organizations': ['*organ', 'iz', 'ation', 's#'],
#  'organized': ['*organ', 'ized#'],
#  'original': ['*ori', 'g', 'in', 'al#'],
#  'originally': ['*ori', 'g', 'in', 'ally#'],
#  'others': ['*other', 's#'],
#  'otherwise': ['*other', 'wise#'],
#  'outlined': ['*out', 'lin', 'ed#'],
#  'outposts': ['*out', 'posts#'],
#  'outside': ['*out', 'side#'],
#  'outskirts': ['*out', 'skirts#'],
#  'overall': ['*over', 'all#'],
#  'overtime': ['*over', 'time#'],
#  'overturned': ['*over', 'turned#'],
#  'pacing': ['*pac', 'ing#'],
#  'packages': ['*pack', 'ages#'],
#  'packed': ['*pack', 'ed#'],
#  'packing': ['*pack', 'ing#'],
#  'painted': ['*pa', 'in', 'ted#'],
#  'painting': ['*pa', 'in', 'ting#'],
#  'paintings': ['*pa', 'in', 'ting', 's#'],
#  'panels': ['*pan', 'els#'],
#  'papillae': ['*pa', 'p', 'illa', 'e#'],
#  'parallel': ['*par', 'alle', 'l#'],
#  'parents': ['*parent', 's#'],
#  'parishioners': ['*par', 'i', 'sh', 'ion', 'ers#'],
#  'partially': ['*par', 'ti', 'ally#'],
#  'participated': ['*par', 'tic', 'i', 'pated#'],
#  'particular': ['*par', 'tic', 'ular#'],
#  'particularly': ['*par', 'tic', 'ular', 'ly#'],
#  'partly': ['*par', 't', 'ly#'],
#  'partner': ['*par', 't', 'ner#'],
#  'passage': ['*pas', 's', 'age#'],
#  'passing': ['*pas', 'sing#'],
#  'pattern': ['*pat', 'ter', 'n#'],
#  'patterned': ['*pat', 'ter', 'ned#'],
#  'pectoral': ['*pe', 'ctor', 'al#'],
#  'pelvic': ['*pel', 'vic', '#'],
#  'people': ['*pe', 'ople#'],
#  'perceived': ['*per', 'ceive', 'd#'],
#  'percussion': ['*per', 'cussion#'],
#  'perform': ['*per', 'for', 'm#'],
#  'performed': ['*per', 'formed#'],
#  'perhaps': ['*per', 'haps#'],
#  'period': ['*per', 'i', 'o', 'd#'],
#  'permanent': ['*per', 'man', 'ent#'],
#  'permitted': ['*per', 'mit', 'ted#'],
#  'person': ['*per', 'son#'],
#  'personal': ['*per', 'son', 'al#'],
#  'personnel': ['*per', 'son', 'nel#'],
#  'persons': ['*per', 'sons#'],
#  'perspective': ['*per', 's', 'pective', '#'],
#  'philanthropist': ['*phi', 'lant', 'h', 'rop', 'ist#'],
#  'photograph': ['*photo', 'graph', '#'],
#  'phylogenetic': ['*phy', 'logene', 'tic', '#'],
#  'phylogeny': ['*phy', 'logen', 'y#'],
#  'pillars': ['*pillar', 's#'],
#  'pinkish': ['*pin', 'kish#'],
#  'pistols': ['*pistols#'],
#  'pitted': ['*pit', 'ted#'],
#  'placed': ['*pla', 'c', 'ed#'],
#  'placing': ['*pla', 'c', 'ing#'],
#  'planned': ['*plan', 'ned#'],
#  'planning': ['*plan', 'ning#'],
#  'plants': ['*plan', 't', 's#'],
#  'platform': ['*plat', 'form#'],
#  'plausible': ['*pla', 'usi', 'ble#'],
#  'playable': ['*pla', 'y', 'able#'],
#  'played': ['*pla', 'y', 'ed#'],
#  'player': ['*pla', 'y', 'er#'],
#  'players': ['*pla', 'y', 'ers#'],
#  'playing': ['*pla', 'y', 'ing#'],
#  'playoffs': ['*pla', 'y', 'off', 's#'],
#  'pleased': ['*pleased#'],
#  'poetry': ['*po', 'etry#'],
#  'pointed': ['*po', 'inted#'],
#  'points': ['*po', 'int', 's#'],
#  'police': ['*po', 'lic', 'e#'],
#  'polychaete': ['*po', 'ly', 'cha', 'ete', '#'],
#  'popular': ['*po', 'p', 'ular#'],
#  'popularity': ['*po', 'p', 'ular', 'i', 'ty#'],
#  'population': ['*po', 'p', 'ulation', '#'],
#  'portion': ['*portion#'],
#  'portraits': ['*por', 'tra', 'it', 's#'],
#  'position': ['*po', 'sition', '#'],
# ...
#  'prevent': ['*pre', 'vent#'],
#  'preview': ['*pre', 'view', '#'],
#  'previous': ['*pre', 'vious#'],
#  'previously': ['*pre', 'vious', 'ly#'],
#  'principal': ['*prin', 'c', 'i', 'pal', '#'],
#  'principally': ['*prin', 'c', 'i', 'pal', 'ly#'],
#  'principle': ['*prin', 'c', 'i', 'ple#'],
#  'printing': ['*prin', 'ting#'],
#  'private': ['*priv', 'at', 'e', '#'],
#  'privileged': ['*privile', 'ged#'],
#  'probably': ['*pr', 'o', 'bably#'],
#  'problem': ['*pr', 'o', 'ble', 'm#'],
#  'problems': ['*pr', 'o', 'ble', 'ms#'],
#  'procession': ['*pr', 'o', 'cession#'],
#  'procured': ['*pr', 'o', 'cured#'],
#  'produced': ['*pr', 'o', 'd', 'uced#'],
#  'producing': ['*pr', 'o', 'd', 'ucing#'],
#  'production': ['*pr', 'o', 'd', 'uction', '#'],
#  'professional': ['*pr', 'o', 'fession', 'al#'],
#  'proficient': ['*pr', 'o', 'fici', 'ent#'],
#  'profound': ['*pr', 'o', 'found#'],
#  'progresses': ['*pr', 'o', 'gres', 'ses#'],
#  'project': ['*pr', 'o', 'ject', '#'],
#  'prominent': ['*pr', 'omin', 'ent#'],
#  'promise': ['*pr', 'om', 'ise#'],
#  'promote': ['*pr', 'om', 'o', 'te#'],
#  'prompted': ['*pr', 'omp', 'ted#'],
#  'properties': ['*pr', 'o', 'per', 'ties#'],
#  'property': ['*pr', 'o', 'per', 'ty#'],
#  'proposed': ['*pr', 'o', 'posed#'],
#  'prospect': ['*pr', 'o', 'spe', 'ct', '#'],
#  'protagonists': ['*pr', 'o', 'ta', 'gon', 'ists#'],
#  'protect': ['*pr', 'o', 'tect#'],
#  'proved': ['*pr', 'ove', 'd#'],
#  'provide': ['*pr', 'ovi', 'de#'],
#  'provided': ['*pr', 'ovi', 'ded#'],
#  'provisions': ['*pr', 'ovi', 's', 'ion', 's#'],
#  'public': ['*public', '#'],
#  'publication': ['*public', 'ation', '#'],
#  'publicity': ['*public', 'ity#'],
#  'published': ['*publi', 'shed#'],
#  'publishers': ['*publisher', 's#'],
#  'purchase': ['*pur', 'ch', 'a', 'se#'],
#  'purchased': ['*pur', 'ch', 'a', 'sed#'],
#  'purchases': ['*pur', 'ch', 'a', 'ses#'],
#  'purpose': ['*pur', 'pose#'],
#  'purposes': ['*pur', 'poses#'],
#  'pursue': ['*pur', 's', 'ue#'],
#  'putting': ['*putting#'],
#  'qualified': ['*qual', 'i', 'fied#'],
#  'qualifiers': ['*qual', 'i', 'fi', 'ers#'],
#  'qualify': ['*qual', 'i', 'f', 'y#'],
#  'qualifying': ['*qual', 'i', 'f', 'ying#'],
#  'quality': ['*qual', 'i', 'ty#'],
#  'quantity': ['*quan', 'tity#'],
#  'quarters': ['*quar', 'ters#'],
#  'questioned': ['*ques', 'tion', 'ed#'],
#  'quickly': ['*quick', 'ly#'],
#  'racetrack': ['*rac', 'e', 'tra', 'ck#'],
#  'railroads': ['*rail', 'roads#'],
#  'raised': ['*raised#'],
#  'rapidly': ['*rapi', 'd', 'ly#'],
#  'rather': ['*rath', 'er#'],
#  'reactivated': ['*reacti', 'v', 'ated#'],
#  'readily': ['*readily#'],
#  'realistic': ['*reali', 'stic', '#'],
#  'reality': ['*reali', 'ty#'],
#  'reason': ['*reason#'],
#  'rebuild': ['*rebuil', 'd#'],
#  'recalled': ['*recal', 'led#'],
#  'recaptured': ['*recap', 'tured#'],
#  'receive': ['*receive#'],
#  'received': ['*receive', 'd#'],
#  'receives': ['*receive', 's#'],
#  'receiving': ['*rece', 'iving#'],
#  'recently': ['*recently#'],
#  'recognised': ['*reco', 'g', 'nis', 'ed#'],
#  'recommended': ['*recom', 'men', 'ded#'],
#  'record': ['*recor', 'd#'],
#  'recorded': ['*recor', 'ded#'],
#  'records': ['*recor', 'ds#'],
#  'recycled': ['*rec', 'y', 'cled#'],
#  'redeem': ['*rede', 'em#'],
#  'referenced': ['*refere', 'n', 'ced#'],
#  'referendum': ['*refere', 'n', 'd', 'um#'],
#  'referred': ['*refer', 'red#'],
#  'refers': ['*refer', 's#'],
#  'refine': ['*refin', 'e#'],
#  'regained': ['*regain', 'ed#'],
#  'region': ['*region#'],
#  'regional': ['*region', 'al#'],
#  'regret': ['*regre', 't#'],
#  'reinforce': ['*rein', 'for', 'ce#'],
#  'reinforcements': ['*rein', 'for', 'cements#'],
#  'rejected': ['*rejected#'],
#  'related': ['*related#'],
#  'relating': ['*relating#'],
#  'relatively': ['*relati', 've', 'ly#'],
#  'relatives': ['*relati', 've', 's#'],
#  'release': ['*release#'],
#  'released': ['*rele', 'ased#'],
#  'releases': ['*rele', 'ases#'],
#  'religious': ['*reli', 'g', 'ious#'],
#  'relocated': ['*relo', 'cated#'],
#  'remain': ['*rema', 'in#'],
#  'remainder': ['*rema', 'in', 'der#'],
#  'remained': ['*rema', 'in', 'ed#'],
#  'remaining': ['*rema', 'in', 'ing#'],
#  'remarkable': ['*remar', 'k', 'able#'],
#  'remarked': ['*remarked#'],
#  'removal': ['*remov', 'al', '#'],
#  'removed': ['*remove', 'd#'],
#  'renamed': ['*ren', 'amed#'],
#  'renovated': ['*ren', 'ov', 'ated#'],
#  'renovation': ['*ren', 'ov', 'ation', '#'],
#  'repair': ['*repai', 'r#'],
#  'repaired': ['*repai', 'red#'],
#  'repairing': ['*repai', 'ring#'],
#  'repairs': ['*repai', 'rs#'],
#  'repetition': ['*repe', 'tition#'],
#  'replaced': ['*replac', 'ed#'],
#  'replayed': ['*repla', 'y', 'ed#'],
#  'reported': ['*repor', 'ted#'],
#  'reports': ['*reports#'],
#  'representation': ['*repres', 'ent', 'ation', '#'],
#  'representing': ['*representing#'],
#  'represents': ['*repres', 'ent', 's#'],
#  'reprinted': ['*reprin', 'ted#'],
#  'reproductive': ['*repro', 'd', 'ucti', 've#'],
#  'request': ['*request', '#'],
#  'requested': ['*request', 'ed#'],
#  'required': ['*requi', 'red#'],
#  'rescues': ['*rescu', 'es#'],
#  'research': ['*rese', 'arch#'],
#  'researcher': ['*rese', 'arch', 'er#'],
#  'residence': ['*resi', 'dence#'],
#  'respective': ['*respe', 'ctive', '#'],
#  'respectively': ['*respe', 'ctive', 'ly#'],
#  'responded': ['*respon', 'ded#'],
#  'response': ['*respons', 'e#'],
#  'responsibility': ['*respons', 'i', 'bili', 't', 'y#'],
#  'restored': ['*rest', 'ored#'],
#  'resulted': ['*resul', 'ted#'],
#  'retained': ['*retain', 'ed#'],
#  'retaining': ['*retain', 'ing#'],
#  'retention': ['*retention#'],
#  'retired': ['*reti', 'red#'],
#  'return': ['*retur', 'n#'],
#  'returned': ['*retur', 'ned#'],
#  'returning': ['*retur', 'ning#'],
#  'reveal': ['*reve', 'al#'],
#  'revealed': ['*reve', 'al', 'ed#'],
#  'revenge': ['*reve', 'nge#'],
#  'review': ['*review', '#'],
#  'revived': ['*revi', 'ved#'],
#  'revolutionary': ['*revol', 'ution', 'ary#'],
#  'richest': ['*richest', '#'],
#  'rifles': ['*rif', 'les#'],
#  'rights': ['*righ', 'ts#'],
#  'rivals': ['*rival', 's#'],
#  'rounded': ['*rounded#'],
#  'rounds': ['*round', 's#'],
#  'royalties': ['*roy', 'al', 'ties#'],
#  'rumors': ['*rumors#'],
#  'sacraments': ['*sac', 'ra', 'ments#'],
#  'sacred': ['*sac', 'red#'],
#  'sanctioned': ['*san', 'ction', 'ed#'],
#  'scattered': ['*scat', 'ter', 'ed#'],
#  'scenario': ['*scen', 'ar', 'i', 'o#'],
#  'scholastic': ['*scho', 'lastic', '#'],
#  'school': ['*scho', 'ol', '#'],
#  'schools': ['*scho', 'ol', 's#'],
#  'scientific': ['*scienti', 'fic', '#'],
#  'scored': ['*sco', 'red#'],
#  'scoring': ['*scor', 'ing#'],
#  'scratch': ['*sc', 'rat', 'ch#'],
#  'script': ['*scri', 'pt#'],
#  'sealed': ['*se', 'al', 'ed#'],
#  'season': ['*se', 'ason#'],
#  'seasons': ['*se', 'ason', 's#'],
#  'second': ['*secon', 'd#'],
#  'seconds': ['*secon', 'd', 's#'],
#  'secret': ['*sec', 're', 't#'],
#  'secular': ['*sec', 'ular#'],
#  'security': ['*sec', 'uri', 'ty#'],
#  'sediment': ['*sedi', 'ment#'],
#  'seemed': ['*se', 'emed#'],
#  'seemingly': ['*se', 'eming', 'ly#'],
#  'segments': ['*se', 'gments#'],
#  'seized': ['*se', 'ized#'],
#  'seizure': ['*se', 'iz', 'ure#'],
#  'select': ['*sele', 'ct', '#'],
#  'selected': ['*sele', 'cted#'],
#  'selection': ['*selection', '#'],
#  'sending': ['*send', 'ing#'],
#  'sentiment': ['*senti', 'ment#'],
#  'separate': ['*se', 'par', 'ate', '#'],
#  'sequel': ['*sequ', 'el#'],
#  'sequenced': ['*sequen', 'ced#'],
#  'serialized': ['*seri', 'al', 'ized#'],
#  'series': ['*seri', 'es#'],
#  'serious': ['*seri', 'ous#'],
#  'served': ['*ser', 'ved#'],
#  'service': ['*ser', 'vic', 'e#'],
#  'servicemen': ['*ser', 'vic', 'e', 'men#'],
#  'services': ['*ser', 'vic', 'es#'],
#  'serving': ['*ser', 'ving#'],
#  'settings': ['*se', 't', 'ting', 's#'],
#  'seventeen': ['*sevente', 'en', '#'],
#  'several': ['*sever', 'al#'],
#  'sexual': ['*sexual', '#'],
#  'shadow': ['*shad', 'ow', '#'],
#  'shallow': ['*shall', 'ow', '#'],
#  'shaped': ['*shaped#'],
#  'shared': ['*s'],
#  'shield': ['*shi', 'eld#'],
#  'shorter': ['*shor', 'ter#'],
#  'shortly': ['*shor', 'tly#'],
#  'shotguns': ['*sho', 't', 'gun', 's#'],
#  'should': ['*shou', 'l', 'd#'],
#  'shrimp': ['*shri', 'mp', '#'],
#  'signed': ['*signed#'],
#  'significant': ['*signific', 'an', 't', '#'],
#  'signing': ['*sig', 'ning#'],
#  'similar': ['*similar', '#'],
#  'simple': ['*simp', 'le#'],
#  'simply': ['*simp', 'ly#'],
#  'simulation': ['*sim', 'ulation', '#'],
#  'singer': ['*singer#'],
#  'single': ['*single#'],
#  'singles': ['*singles#'],
#  'sister': ['*sister#'],
#  'situation': ['*situ', 'ation', '#'],
#  'situations': ['*situ', 'ation', 's#'],
#  'sketches': ['*sket', 'ches#'],
#  'sketchy': ['*sket', 'ch', 'y#'],
#  'skills': ['*ski', 'lls#'],
#  'slender': ['*slender#'],
#  'smaller': ['*smal', 'ler#'],
#  'smooth': ['*smooth#'],
#  'smoothbore': ['*smoothbore', '#'],
#  'social': ['*soci', 'al#'],
#  'societies': ['*soci', 'eties#'],
#  'society': ['*soci', 'ety#'],
#  'soldiers': ['*sol', 'di', 'ers#'],
#  'solely': ['*sole', 'ly#'],
#  'somber': ['*somb', 'er#'],
#  'something': ['*some', 'th', 'ing#'],
#  'sometimes': ['*some', 'ti', 'mes#'],
#  'somewhat': ['*some', 'w', 'hat', '#'],
#  'sorted': ['*sorted#'],
#  'southern': ['*souther', 'n#'],
#  'sovereign': ['*sover', 'eign#'],
#  'spaced': ['*spac', 'ed#'],
#  'speaking': ['*spe', 'aking#'],
#  'special': ['*spe', 'c', 'i', 'al#'],
#  'specialist': ['*spe', 'c', 'i', 'ali', 'st#'],
#  'species': ['*spe', 'c', 'i', 'es#'],
#  'specific': ['*spe', 'c', 'ific', '#'],
#  'specimen': ['*spe', 'c', 'imen', '#'],
#  'specimens': ['*spe', 'c', 'imen', 's#'],
#  'speech': ['*spe', 'ech#'],
#  'spikes': ['*spi', 'kes#'],
#  'spines': ['*sp', 'ines#'],
#  'spiracles': ['*spi', 'rac', 'les#'],
#  'spirit': ['*spi', 'rit#'],
#  'spirits': ['*spi', 'rit', 's#'],
#  'splendid': ['*splend', 'i', 'd#'],
#  'splitting': ['*split', 'ting#'],
#  'sponsored': ['*spons', 'ored#'],
#  'spread': ['*spread#'],
#  'spring': ['*spring', '#'],
#  'staffed': ['*sta', 'ff', 'ed#'],
#  'staffers': ['*sta', 'ffer', 's#'],
#  'stained': ['*sta', 'in', 'ed#'],
#  'staircase': ['*sta', 'i', 'rca', 'se#'],
#  'stairs': ['*sta', 'i', 'rs#'],
#  'standard': ['*stand', 'ard#'],
#  'standing': ['*stand', 'ing#'],
#  'started': ['*star', 'ted#'],
#  'starting': ['*star', 'ting#'],
#  'stated': ['*stated#'],
#  'station': ['*station', '#'],
#  'stationed': ['*station', 'ed#'],
#  'stayed': ['*sta', 'y', 'ed#'],
#  'stingray': ['*stingra', 'y#'],
#  'stingrays': ['*stingra', 'ys#'],
#  'stings': ['*stings#'],
#  'stoppage': ['*stop', 'pa', 'ge#'],
#  'storage': ['*stor', 'a', 'ge#'],
#  'stores': ['*stores#'],
#  'straight': ['*stra', 'ight#'],
#  'streaks': ['*stre', 'ak', 's#'],
#  'stripped': ['*stri', 'pped#'],
#  'strong': ['*strong', '#'],
#  'structure': ['*str', 'uct', 'ure#'],
#  'students': ['*stu', 'dents#'],
#  'studied': ['*stu', 'di', 'ed#'],
#  'studio': ['*stu', 'dio', '#'],
#  'subject': ['*sub', 'ject', '#'],
#  'subjects': ['*sub', 'ject', 's#'],
#  'submitted': ['*sub', 'mit', 'ted#'],
#  'substantial': ['*sub', 'st', 'an', 'ti', 'al#'],
#  'substrate': ['*sub', 'st', 'rate', '#'],
#  'successful': ['*su', 'c', 'cess', 'ful#'],
#  'successfully': ['*su', 'c', 'cess', 'fully#'],
#  'suffer': ['*su', 'ffer', '#'],
#  'suffered': ['*su', 'ffer', 'ed#'],
#  'suffers': ['*su', 'ffer', 's#'],
#  'sufficient': ['*su', 'ffici', 'ent#'],
#  'suggesting': ['*su', 'g', 'ges', 'ting#'],
#  'suggests': ['*su', 'g', 'ges', 't', 's#'],
#  'suitable': ['*su', 'it', 'able#'],
#  'summer': ['*summer#'],
#  'superiors': ['*su', 'per', 'i', 'ors#'],
#  'supervise': ['*su', 'per', 'vis', 'e#'],
#  'supervised': ['*su', 'per', 'vis', 'ed#'],
#  'supervising': ['*su', 'per', 'vis', 'ing#'],
#  'supply': ['*su', 'pply#'],
#  'support': ['*su', 'ppor', 't#'],
#  'supposed': ['*su', 'ppo', 'sed#'],
#  'supreme': ['*su', 'pre', 'me#'],
#  'surface': ['*sur', 'fac', 'e#'],
#  'surmised': ['*sur', 'mis', 'ed#'],
#  'surrender': ['*sur', 're', 'n', 'der#'],
#  'surrendered': ['*sur', 're', 'n', 'der', 'ed#'],
#  'surrendering': ['*sur', 're', 'n', 'der', 'ing#'],
#  'surrounding': ['*sur', 'rou', 'nd', 'ing#'],
#  'survive': ['*sur', 'vi', 've#'],
#  'sustained': ['*susta', 'in', 'ed#'],
#  'switch': ['*swit', 'ch#'],
#  'synthesized': ['*synth', 'es', 'ized#'],
#  'synthesizer': ['*synth', 'es', 'iz', 'er#'],
#  'system': ['*syste', 'm#'],
#  'systems': ['*syste', 'ms#'],
#  'tactical': ['*tacti', 'c', 'al#'],
#  'taking': ['*taking#'],
#  'target': ['*targe', 't#'],
#  'targeting': ['*targe', 'ting#'],
#  'tasked': ['*tas', 'ked#'],
#  'taught': ['*taught#'],
#  'teaching': ['*teaching#'],
#  'teaser': ['*teaser', '#'],
#  'technical': ['*tech', 'nic', 'al', '#'],
#  'technology': ['*tech', 'nol', 'o', 'g', 'y#'],
#  'telegraph': ['*tele', 'graph', '#'],
#  'television': ['*tele', 'vis', 'ion#'],
#  'telling': ['*telling#'],
#  'temporary': ['*temp', 'or', 'ary#'],
#  'tended': ['*ten', 'ded#'],
#  'tentatively': ['*tent', 'ative', 'ly#'],
#  'territory': ['*terri', 't', 'ory#'],
#  'themed': ['*the', 'med#'],
#  'themes': ['*the', 'mes#'],
#  'themselves': ['*the', 'm', 'sel', 've', 's#'],
#  'theories': ['*the', 'ori', 'es#'],
#  'therefore': ['*ther', 'e', 'fore', '#'],
#  'things': ['*things#'],
#  'thorns': ['*thor', 'ns#'],
#  'though': ['*though', '#'],
#  'thought': ['*thought#'],
#  'threat': ['*thre', 'at', '#'],
#  'through': ['*through', '#'],
#  'throughout': ['*throughou', 't#'],
#  'timeline': ['*time', 'line#'],
#  'together': ['*toge', 'ther#'],
#  'topped': ['*topped#'],
#  'tournament': ['*tour', 'nament', '#'],
#  'tournaments': ['*tour', 'nament', 's#'],
#  'towards': ['*towar', 'ds#'],
#  'tracks': ['*tracks#'],
#  'traded': ['*traded#'],
#  'traitor': ['*trait', 'or#'],
#  'transfer': ['*trans', 'fer#'],
#  'transferred': ['*trans', 'ferred#'],
#  'translated': ['*trans', 'lated#'],
#  'translation': ['*trans', 'lation', '#'],
#  'trawling': ['*traw', 'ling#'],
#  'trawls': ['*traw', 'ls#'],
#  'treason': ['*treason#'],
#  'troops': ['*troop', 's#'],
#  'turned': ['*turned#'],
#  'tweaks': ['*tweak', 's#'],
#  'ultimate': ['*ulti', 'mate', '#'],
#  'ultimately': ['*ulti', 'mate', 'ly#'],
#  'unable': ['*unable#'],
#  'unaltered': ['*unaltered#'],
#  'unconfirmed': ['*uncon', 'fi', 'rmed#'],
#  'underside': ['*unders', 'i', 'de#'],
#  'undertakings': ['*undertaking', 's#'],
#  'underwent': ['*underwent', '#'],
#  'uniforms': ['*unifor', 'm', 's#'],
#  'unique': ['*uniqu', 'e#'],
#  'unknowingly': ['*unknow', 'ing', 'ly#'],
#  'unless': ['*unless#'],
#  'unlikely': ['*unlike', 'ly#'],
#  'unlocked': ['*unlock', 'ed#'],
#  'unoccupied': ['*unoccupi', 'ed#'],
#  'unofficial': ['*unoffici', 'al#'],
#  'unpopularity': ['*unpop', 'ular', 'i', 'ty#'],
#  'unranked': ['*unranked#'],
#  'upgrade': ['*upgra', 'de#'],
#  'usually': ['*usu', 'ally#'],
#  'uterine': ['*uterin', 'e#'],
#  'uterus': ['*uterus#'],
#  'valuable': ['*valu', 'able#'],
#  'variable': ['*vari', 'able#'],
#  'varies': ['*vari', 'es#'],
#  'variety': ['*vari', 'ety#'],
#  'various': ['*vari', 'ous#'],
#  'vehemently': ['*vehe', 'ment', 'ly#'],
#  'vehicles': ['*vehic', 'les#'],
#  'ventral': ['*vent', 'ral#'],
#  'verses': ['*ver', 's', 'es#'],
#  'versions': ['*ver', 's', 'ion', 's#'],
#  'veteran': ['*veter', 'an#'],
#  'veterans': ['*veter', 'ans#'],
#  'vicinity': ['*vic', 'in', 'ity#'],
#  'victory': ['*vic', 'tory#'],
#  'vision': ['*vis', 'ion#'],
#  'visited': ['*vis', 'ited#'],
#  'visitors': ['*vis', 'it', 'ors#'],
#  'visual': ['*vis', 'ual#'],
#  'visuals': ['*vis', 'ual', 's#'],
#  'viviparous': ['*vivi', 'par', 'ous#'],
#  'voiced': ['*vo', 'ic', 'ed#'],
#  'volume': ['*vol', 'ume#'],
#  'volumes': ['*vol', 'umes#'],
#  'wanted': ['*wanted#'],
#  'wanting': ['*wanting#'],
#  'warehouse': ['*warehou', 's', 'e#'],
#  'warrant': ['*warrant', '#'],
#  'weapon': ['*we', 'apon', '#'],
#  'weapons': ['*we', 'apon', 's#'],
#  'website': ['*we', 'bsite', '#'],
#  'western': ['*west', 'ern#'],
#  'widely': ['*wi', 'de', 'ly#'],
#  'widths': ['*wi', 'd', 'ths#'],
#  'window': ['*win', 'd', 'ow', '#'],
#  'winning': ['*win', 'ning#'],
#  'winter': ['*win', 'ter#'],
#  'wishes': ['*wishes#'],
#  'withdraw': ['*wi', 'thdra', 'w', '#'],
#  'withdrew': ['*wi', 'th', 'drew', '#'],
#  'within': ['*wi', 'th', 'in#'],
#  'without': ['*wi', 'th', 'out#'],
#  'withstand': ['*wi', 'th', 'stan', 'd#'],
#  'wonderful': ['*won', 'der', 'ful#'],
#  'worked': ['*wor', 'ked#'],
#  'working': ['*wor', 'king#'],
#  'worldwide': ['*wor', 'ld', 'wi', 'de#'],
#  'writer': ['*wri', 'ter#'],
#  'writers': ['*wri', 'ters#'],
#  'written': ['*writ', 'ten', '#'],
#  'youngest': ['*young', 'est', '#'],
#  'Æsthetic': ['*Æs', 'th', 'e', 'tic', '#'],
#  '戦場のヴァルキュリア3': ['*戦場のヴァルキュリア3', '#']}
