# %%
import pandas as pd
import numpy

# %%
import spacy

# %%
nlp = spacy.load("en")

# %%
def tokenize(x):
    return nlp(x, parse=False, tag=False, entity=False)

def load_file(file_name):
    with open(data_file) as d:
        for line in d:
            yield [x.text for x in tokenize(line)]

def get_tokens(file):
    tokens = {}
    for sent in file:
        for token in sent:
            try:
                tokens[token] += 1
            except:
                tokens[token] = 1
    return tokens

# %%
data_file = 'data/wikitext-2/train.txt'
#data_file = 'data/tel.wx.txt'

# %%
f = load_file(data_file)

# %%
# %%time 
tokens = get_tokens(f)
print(len(tokens))
# Out:
# 33242
# CPU times: user 5.29 s, sys: 6.04 ms, total: 5.29 s
# Wall time: 5.3 s

# %%
import math
def norm_probs(tokens):
    s = sum(tokens.values())
    return {k : round(math.log(v/float(s)),4) for k, v in tokens.items()}
def sort_probs(probs):
    return sorted(probs.items(), key=lambda x:x[1], reverse=True)

# %%
import nltk

# %%
def get_ngrams(tokens, min_length = 4, max_N=4):
    for token, count in tokens.items():
        token = f"{token}"
        if len(token) >= min_length:
            splits = []
            for i in range(1, max_N+1):
                splits += [list([''.join(x) for x in nltk.ngrams(list(token), i)])]
            yield token, count, splits

# %%
# %%time
from collections import Counter
pairs = Counter()

for x in get_ngrams(tokens):
    token, count, ngrams = x
    #print(x)
    for g, gram in enumerate(ngrams):
        #print(f"{g+1}-Gram")
        for gi in gram:
            pairs[(gi, '~')] += 1 * count
            
        for i, gi in enumerate(gram):
            for j in range(len(ngrams)):
                if i + g + 1 < len(ngrams[j]):
                    pair = gram[i], ngrams[j][i+g+1]
                    pairs[pair] += 1 * count
                    
#                    print(pair)
#pairs
# Out:
# CPU times: user 2.76 s, sys: 4.54 ms, total: 2.77 s
# Wall time: 2.77 s

# %%
pairs
# Out:
# Counter({('a', '~'): 1,
#          ('p', '~'): 2,
#          ('l', '~'): 1,
#          ('e', '~'): 1,
#          ('s', '~'): 1,
#          ('a', 'p'): 1,
#          ('a', 'pp'): 1,
#          ('a', 'ppl'): 1,
#          ('a', 'pple'): 1,
#          ('p', 'p'): 1,
#          ('p', 'pl'): 1,
#          ('p', 'ple'): 1,
#          ('p', 'ples'): 1,
#          ('p', 'l'): 1,
#          ('p', 'le'): 1,
#          ('p', 'les'): 1,
#          ('l', 'e'): 1,
#          ('l', 'es'): 1,
#          ('e', 's'): 1,
#          ('ap', '~'): 1,
#          ('pp', '~'): 1,
#          ('pl', '~'): 1,
#          ('le', '~'): 1,
#          ('es', '~'): 1,
#          ('ap', 'p'): 1,
#          ('ap', 'pl'): 1,
#          ('ap', 'ple'): 1,
#          ('ap', 'ples'): 1,
#          ('pp', 'l'): 1,
#          ('pp', 'le'): 1,
#          ('pp', 'les'): 1,
#          ('pl', 'e'): 1,
#          ('pl', 'es'): 1,
#          ('le', 's'): 1,
#          ('app', '~'): 1,
#          ('ppl', '~'): 1,
#          ('ple', '~'): 1,
#          ('les', '~'): 1,
#          ('app', 'l'): 1,
#          ('app', 'le'): 1,
#          ('app', 'les'): 1,
#          ('ppl', 'e'): 1,
#          ('ppl', 'es'): 1,
#          ('ple', 's'): 1,
#          ('appl', '~'): 1,
#          ('pple', '~'): 1,
#          ('ples', '~'): 1,
#          ('appl', 'e'): 1,
#          ('appl', 'es'): 1,
#          ('pple', 's'): 1})

# %%
pair_probs = norm_probs(pairs)

# %%
token = 'knives'
for i in range(len(token)):
    for j in range(i+1, len(token)):
        split = token[i:j], token[j:]
        
        if len(split[0]) < 5:
            #inside = pair_probs[(split[0], split[1][0])]
            inside = pair_probs[(split[0], '~')]
            outside = pair_probs[(split[0][-1], split[1][0])]
        else:
            #print(split)
            parts = split[0][:4], split[0][4]
            print(split, (parts[0][-1], parts[1]))
            inside = pair_probs[(split[0][:4], '~')] + pair_probs[(parts[0][-1], parts[1])]
            outside = pair_probs[(parts[1], split[1][0])]
            
            #outside = pair_probs[(split[0], split[1][0])]
            #for c in range(1, len(split[1])):
            #    pair = split[1][c-1], split[1][c]
            #    outside += pair_probs[pair]
                #print(pair)
        total = inside + outside
        print(split, (split[0][-1], split[1][0]), inside, outside, total)
# Out:
# ('k', 'nives') ('k', 'n') -7.2346 -10.1164 -17.351
# ('kn', 'ives') ('n', 'i') -10.1164 -7.9598 -18.0762
# ('kni', 'ves') ('i', 'v') -13.6668 -8.1667 -21.8335
# ('kniv', 'es') ('v', 'e') -16.3059 -7.1517 -23.4576
# ('knive', 's') ('v', 'e')
# ('knive', 's') ('e', 's') -23.4576 -6.6824 -30.14
# ('n', 'ives') ('n', 'i') -4.955 -7.9598 -12.9148
# ('ni', 'ves') ('i', 'v') -7.9598 -8.1667 -16.1265
# ('niv', 'es') ('v', 'e') -11.1331 -7.1517 -18.2848
# ('nive', 's') ('e', 's') -11.1784 -6.6824 -17.8608
# ('i', 'ves') ('i', 'v') -4.8425 -8.1667 -13.0092
# ('iv', 'es') ('v', 'e') -8.1667 -7.1517 -15.3184
# ('ive', 's') ('e', 's') -8.518 -6.6824 -15.200400000000002
# ('v', 'es') ('v', 'e') -6.6726 -7.1517 -13.824300000000001
# ('ve', 's') ('e', 's') -7.1517 -6.6824 -13.8341
# ('e', 's') ('e', 's') -4.3568 -6.6824 -11.039200000000001

# %%
v1 = pair_probs[('appl', 'e')] + pair_probs[('e', 's')]
v2 = pair_probs[('appl', 'es')]
v1, v2
# Out:
# (-20.5089, -14.6054)

# %%
token = '^apples$'

# %%
# %%time
all_splits = {}
for token, splits in get_ngrams(sorted_probs, max_N=4):
   # all_splits[token] = get_pos_encoded(len(token), splits)
    for split in splits:
        if split not in all_splits:
            all_splits[split] = {}
        if token in pruned_probs:
            if token not in all_splits[split]:
                all_splits[split][token] = 0
            all_splits[split][token] += 1
# Out:
# CPU times: user 3.21 s, sys: 41.2 ms, total: 3.25 s
# Wall time: 3.27 s

# %%
word_list = list(pruned_probs.keys())
word2index = lambda w : word_list.index(w)
index2word = lambda i : word_list[i]

# %%
list(all_splits.items())[:5]
# Out:
# [('ma',
#   {'mariyu': 1,
#    'maMxi': 1,
#    'maXya': 1,
#    'maMci': 1,
#    'samayaMlo': 1,
#    'maMwri': 1,
#    'manaM': 1,
#    'mariMwa': 1,
#    'muKyamaMwri': 1,
#    'samayaM': 1,
#    'manaku': 1,
#    'malYlYI': 1,
#    'amalu': 1,
#    'maniRi': 1,
#    'samasya': 1,
#    'malYlI': 1,
#    'samasyalu': 1,
#    'prema': 1,
#    'maMdalaM': 1,
#    'kAryakramaMlo': 1,
#    'wamaku': 1,
#    'maxxawu': 1,
#    'maroVka': 1,
#    'kAryakramaM': 1,
#    'manasu': 1,
#    'maXyalo': 1,
#    'maMcixi': 1,
#    'uxyamaM': 1,
#    'mahilYA': 1,
#    'marovEpu': 1,
#    'cAlAmaMxi': 1,
#    'paScima': 1,
#    'neVmmaxigA': 1,
#    'brahma': 1,
#    'somavAraM': 1,
#    'grAmaMlo': 1,
#    'maMxiki': 1,
#    'sAmarWyaM': 1,
#    'kramaMlo': 1,
#    'uwwama': 1,
#    'maXyAhnaM': 1,
#    'koVMwamaMxi': 1,
#    'maMxulu': 1,
#    'maMgalYavAraM': 1,
#    'maMjUru': 1,
#    'vimarSalu': 1,
#    'nammakaM': 1,
#    'mahilYalu': 1,
#    'maMdala': 1,
#    'maraNaM': 1,
#    'vimarSiMcAru': 1,
#    'samasyalanu': 1,
#    'margin': 1,
#    'XarmaM': 1,
#    'maMwrulu': 1,
#    'mimmalni': 1,
#    'KammaM': 1,
#    'mawaM': 1,
#    'marosAri': 1,
#    'anumawi': 1,
#    'pariSrama': 1,
#    'SrImawi': 1,
#    'grAma': 1,
#    'maxyaM': 1,
#    'jarmanI': 1,
#    'praWama': 1,
#    'gamanArhaM': 1,
#    'manamu': 1,
#    'samayAniki': 1,
#    'maMdalaMlo': 1,
#    'ceswAmani': 1,
#    'maharRi': 1,
#    'eVdama': 1,
#    'matti': 1,
#    'grAmaM': 1,
#    'carmaM': 1,
#    'mahilYala': 1,
#    'ummadi': 1,
#    'maMdalaMloni': 1,
#    'mahArARtra': 1,
#    'Awmahawya': 1,
#    'caMxamAma': 1,
#    'marinni': 1,
#    'kramaMgA': 1,
#    'mahilYalaku': 1,
#    'marikoVnni': 1,
#    'boVmma': 1,
#    'Sarma': 1,
#    'saMkRema': 1,
#    'samarpayAmi': 1,
#    'Srama': 1,
#    'samaswa': 1,
#    'amarAvawi': 1,
#    'uxyama': 1,
#    'akrama': 1,
#    'maMxu': 1,
#    'wirumala': 1,
#    'cErman': 1,
#    'samasyanu': 1,
#    'maMcu': 1,
#    'maMxini': 1,
#    'samasyala': 1,
#    'ramaNa': 1,
#    'manassu': 1,
#    'samagra': 1,
#    'kramaM': 1,
#    'maxrAsu': 1,
#    'mahilYa': 1,
#    'rAyalasIma': 1,
#    'namaswe': 1,
#    'Xarma': 1,
#    'grAmaMloni': 1,
#    'varma': 1,
#    'samasyalapE': 1,
#    'XarmarAju': 1,
#    'maniRini': 1,
#    'pariNAmaM': 1,
#    'wamanu': 1,
#    'rAjamaMdri': 1,
#    'manasulo': 1,
#    'maMtalu': 1,
#    'samakRaMlo': 1,
#    'manalni': 1,
#    'naduma': 1,
#    'kqwrima': 1,
#    'marikoVMxaru': 1,
#    'marala': 1,
#    'mammalni': 2,
#    'manuRulu': 1,
#    'viramaNa': 1,
#    'janma': 1,
#    'manaki': 1,
#    'namaH': 1,
#    'samayAnni': 1,
#    'brAhmaNa': 1,
#    'normal': 1,
#    'pariSramalu': 1,
#    'rAmakqRNa': 1,
#    'parama': 1,
#    'gamaniMci': 1,
#    'maMwrigA': 1,
#    'CErman\u200c': 1,
#    'maMxula': 1,
#    'CErman': 1,
#    'sakramaMgA': 1,
#    'paxma': 1,
#    'sAmarWyAnni': 1,
#    'karma': 1,
#    'malYlYi': 1,
#    'maMdali': 1,
#    'samayaMlone': 1,
#    'niyamaM': 1,
#    'amalulo': 1,
#    'vyAyAmaM': 1,
#    'eVMwamaMxi': 1,
#    'awyuwwama': 1,
#    'premawo': 1,
#    'samasyalaku': 1,
#    'bahumawi': 1,
#    'manuRula': 1,
#    'mahabUb': 1,
#    'premanu': 1,
#    'ammavAri': 1,
#    'malupu': 1,
#    'marri': 1,
#    'mana0': 1,
#    'gamaniswe': 1,
#    'uxyamaMlo': 1,
#    'mariMwagA': 1,
#    'carma': 1,
#    'paramAwma': 1,
#    'pariSramala': 1,
#    'maroVkaru': 1,
#    'bawukamma': 1,
#    'praXama': 1,
#    'marusati': 1,
#    'pimmata': 1,
#    'maMwrula': 1,
#    'maraNiMcAru': 1,
#    'anekamaMxi': 1,
#    'sUkRma': 1,
#    'rammani': 1,
#    'masIxu': 1,
#    'mawwu': 1,
#    'mahabUb\u200cnagar': 1,
#    'marginः0': 1,
#    'xigumawi': 1,
#    'sumawI': 1,
#    'maroVkati': 1,
#    'Xarmamu': 1,
#    'manalanu': 1,
#    'maMwriwva': 1,
#    'praXAnamaMwri': 1,
#    'maMcaM': 1,
#    'paximaMxi': 1,
#    'maMcixani': 1,
#    'samarWavaMwaMgA': 1,
#    'annamayya': 1,
#    'maralA': 1,
#    'maraNiMcAdu': 1,
#    'maXumehaM': 1,
#    'maxrAs': 1,
#    'manalo': 1,
#    'mahArAju': 1,
#    'anumawulu': 1,
#    'maraNa': 1,
#    'muKyamaMwrigA': 1,
#    'gamaniMcina': 1,
#    'maxxawugA': 1,
#    'jarman': 1,
#    'ahmax': 1,
#    'namaskAraM': 1,
#    'SrIrAmacaMxrA': 1,
#    'maraNiMcina': 1,
#    'maniRiki': 1,
#    'kAl\u200cmanI': 1,
#    'kamal': 1,
#    'samayamulo': 1,
#    'vimarSa': 1,
#    'mahAsaBa': 1,
#    'maMta': 1,
#    'vinuravema': 1,
#    'eVkkuvamaMxi': 1,
#    'marATI': 1,
#    'mattini': 1,
#    'maXyawaragawi': 1,
#    'ammakAlu': 1,
#    'mawaparamEna': 1,
#    'maraNamu': 1,
#    'makara': 1,
#    'samakAlIna': 1,
#    'mammulanu': 1,
#    'apramawwaMgA': 1,
#    'aMwima': 1,
#    'maXyAhna': 1,
#    'mahima': 2,
#    'lakRmayya': 1,
#    'maMxiraM': 1,
#    'ceyamani': 1,
#    'jIviwamaMwA': 1,
#    'vimarSakulu': 1,
#    'prawiRtAwmakaMgA': 1,
#    'namaskArAlu': 1,
#    'rAmanAXaM': 1,
#    'prAraMBamavuwuMxi': 1,
#    'maMxunu': 1,
#    'iswAmani': 1,
#    'maMxulanu': 1,
#    'mahABArawaM': 1,
#    'vAmapakRa': 1,
#    'mawsya': 1,
#    'akramaMgA': 1,
#    'maMgalYa': 1,
#    'mariyU': 1,
#    'prAraMBamayyAyi': 1,
#    'maheR': 1,
#    'maleriyA': 1,
#    'samasyalni': 1,
#    'xomalu': 1,
#    'kuMkuma': 1,
#    'samasyaku': 1,
#    'eVMwomaMxi': 1,
#    'maMxilo': 1,
#    'aMxiswAmani': 1,
#    'marnAdu': 1,
#    'mahAwmA': 1,
#    'maltI': 1,
#    'maMcinIti': 1,
#    'goXuma': 1,
#    'gamaniMcaMdi': 1,
#    'upaSamanaM': 1,
#    'anumawiswuMxi': 1,
#    'ASramaM': 1,
#    'manaxeSaMlo': 1,
#    'maXumAsaM': 1,
#    'sirimalleV': 1,
#    'marikoVMwa': 1,
#    'ceSAmannAru': 1,
#    'saMkRemaM': 1,
#    'maXyane': 1,
#    'avasaramani': 1,
#    'maXyA': 1,
#    'ceswAmannAru': 1,
#    'mariyA': 1,
#    'makkA': 1,
#    'amalloki': 1,
#    'pariSramalanu': 1,
#    'keMxramaMwri': 1,
#    'kamala': 1,
#    'ASrama': 1,
#    'maXura': 1,
#    'wirumalaku': 1,
#    'pariSramalo': 1,
#    'premagA': 1,
#    'mamawa': 2,
#    'miSrama': 1,
#    'samarpiMci': 1,
#    'maxya': 1,
#    'manuRyulu': 1,
#    'AwmaviSvAsaM': 1,
#    'cexxAmani': 1,
#    'Warmal': 1,
#    'mawwayi': 1,
#    'manavi': 1,
#    'niyAmakaM': 1,
#    'cAlAmaMxiki': 1,
#    'Awmahawyalu': 1,
#    'uwwamaM': 1,
#    'maXyalone': 1,
#    'vimarSalanu': 1,
#    'emaMte': 1,
#    'vAmapakRAlu': 1,
#    'marukRaNaM': 1,
#    'mAmayya': 1,
#    'samasyagA': 1,
#    'maruguna': 1,
#    'manasuku': 1,
#    'eVgumawi': 1,
#    'hemaMw\u200c': 1,
#    'boVmmalu': 1,
#    'samasyalawo': 1,
#    'mawAla': 1,
#    'avasaramayye': 1,
#    'gamaniMcAli': 1,
#    'maMdalAla': 1,
#    'maraNAlu': 1,
#    'ammamma': 2,
#    'samarpiMcAru': 1,
#    'maMgalYagiri': 1,
#    'sIwamma': 1,
#    'matuku': 1,
#    'brAhmaNudu': 1,
#    'wIsukuMtAmani': 1,
#    'nAmamu': 1,
#    'suRma': 1,
#    'manmaXa': 2,
#    'Awmaku': 1,
#    'hanumaMwuni': 1,
#    'kalpiswAmani': 1,
#    'viSvaxABirAma': 1,
#    'wamani': 1,
#    'maMdalAlu': 1,
#    'krama': 1,
#    'karmalu': 1,
#    'maXyana': 1,
#    'samaMgA': 1,
#    'Brama': 1,
#    'manasuwo': 1,
#    'maraci': 1,
#    'ceVppamani': 1,
#    'manaxeSaM': 1,
#    'amalApuraM': 1,
#    'virAmaM': 1,
#    'samAveSamayyAru': 1,
#    'makAM': 1,
#    'sAmarXyaM': 1,
#    'maropakka': 1,
#    'manaxi': 1,
#    'pariSramalaku': 1,
#    'SrImaMwudu': 1,
#    'manuvu': 1,
#    'mammI': 1,
#    'padamati': 1,
#    'samayamu': 1,
#    'amaluku': 1,
#    'mahmax\u200c': 2,
#    'miSramaM': 1,
#    'mahawwara': 1,
#    'maMwrAlu': 1,
#    'kAryakramaMgA': 1,
#    'manasulu': 1,
#    'maMwraM': 1,
#    'subrahmaNyaM': 1,
#    'arWamavuwoMxi': 1,
#    'maxxawunu': 1,
#    'kastamar': 1,
#    'mahilYallo': 1,
#    'manamU': 1,
#    'eVgumawulu': 1,
#    'maname': 1,
#    'gamanika': 1,
#    'maxiMpu': 1,
#    'mahArAjA': 1,
#    'samasyapE': 1,
#    'Axima': 1,
#    'amarika': 1,
#    'WAmas': 1,
#    'majlis': 1,
#    'mahAkavi': 1,
#    'sammakka': 1,
#    'maMgalYaM': 1,
#    'maruvaxxu': 1,
#    'maMxikipEgA': 1,
#    'arWamavuwuMxi': 1,
#    'rAmacaMxra': 1,
#    'maMdipaddAru': 1,
#    'samarpiMcina': 1,
#    'kAraNamani': 1,
#    'mawAniki': 1,
#    'emani': 1,
#    'parabrahma': 1,
#    'vemana': 1,
#    'bahumawulu': 1,
#    'wamaru': 1,
#    'mahAmuni': 1,
#    'hanumaMwarAvu': 1,
#    'wamannA': 1,
#    'viSvakarma': 1,
#    'maMxiwo': 1,
#    'mamawA': 2,
#    'mahammax': 2,
#    'dOnlodmariMwa': 1,
#    'manasuni': 1,
#    'maXyakAlaMlo': 1,
#    'maraNAnaMwaraM': 1,
#    'ceswunnAmani': 1,
#    'maMcixe': 1,
#    'ammaku': 1,
#    'xeSamaMwA': 1,
#    'gamaniMcavaccu': 1,
#    'homaM': 1,
#    'manugada': 1,
#    'Xarmapuri': 1,
#    'grAmamu': 1,
#    'manavadu': 1,
#    'iMxiramma': 1,
#    'manasArA': 1,
#    'maraNiswe': 1,
#    'macca': 1,
#    'apramawwaM': 1,
#    'nammakaMwo': 1,
#    'samanvaya': 1,
#    'magavAlYlYu': 1,
#    'neVmali': 1,
#    'maXyaMwara': 1,
#    'maMde': 1,
#    'maroVkariki': 1,
#    'gamanaM': 1,
#    'manuRulanu': 1,
#    'nirmala': 1,
#    'rAmarAju': 1,
#    'nammakamEna': 1,
#    'nixarSanamani': 1,
#    'prawima': 1,
#    'mareVnno': 1,
#    'mahilYalapE': 1,
#    'XUmapAnaM': 1,
#    'peVxxamma': 1,
#    'ruxramaxevi': 1,
#    'xAnimma': 1,
#    'amarci': 1,
#    'velAximaMxi': 1,
#    'maxyapAnaM': 1,
#    'manuRulni': 1,
#    'rAman': 1,
#    'rAmayya': 1,
#    'maMxulawo': 1,
#    'jarmanIlo': 1,
#    'ceSAmani': 1,
#    'mahammaxu': 2,
#    'wamawama': 2,
#    'maxuparulu': 1,
#    'ammakAla': 1,
#    'sawImaNi': 1,
#    'macilIpatnaM': 1,
#    'mahAlakRmi': 1,
#    'kamarRiyal': 1,
#    'mahAsaBalu': 1,
#    'maMdapaM': 1,
#    'maxar': 1,
#    'mak\u200cbeVw': 1,
#    'malli': 1,
#    'mahimanu': 2,
#    'vimarSalaku': 1,
#    'manasuloni': 1,
#    'mawAlu': 1,
#    'sqjanAwmaka': 1,
#    'samarWa': 1,
#    'marATA': 1,
#    'pUrvajanma': 1,
#    'wIsukuMtAmannAru': 1,
#    'premalo': 1,
#    'ImaXya': 1,
#    'praXAnamaMwrigA': 1,
#    'vyakwamavuwunnAyi': 1,
#    'BaMgimalo': 1,
#    'aMwarAwma': 1,
#    'lakRmaNudu': 1,
#    'namaskAramu': 1,
#    'Sramawo': 1,
#    'nirmalamEna': 1,
#    'manasA': 1,
#    'maMdelA': 1,
#    'kAman': 1,
#    'maXyapraxeS': 1,
#    'samarpiMcAli': 1,
#    'mariyalu': 1,
#    'lakRmaNarAvu': 1,
#    'lakRmaN': 1,
#    'sUryAswamayaM': 1,
#    'axesamayaMlo': 1,
#    'BIRma': 1,
#    'eVmarjeVnsI': 1,
#    'neVmaru': 1,
#    'sAmarXyAnni': 1,
#    'maheMxar\u200c': 1,
#    'narmaxa': 1,
#    'manassulo': 1,
#    'maXyanunna': 1,
#    'paxmanABaM': 1,
#    'grAmajyowi': 1,
#    'automatic': 1,
#    'ceVmata': 1,
#    'nAmaM': 1,
#    'maMxiraMlo': 1,
#    'mareVkkadA': 1,
#    'mananaM': 1,
#    'maxInA': 1,
#    'nirvahiswunnAmani': 1,
#    'Sramaku': 1,
#    'malYlYA': 1,
#    'anumawiMce': 1,
#    'maTaM': 1,
#    'vAmapakRAla': 1,
#    'punarjanma': 1,
#    'vyUhAwmaka': 1,
#    'niyAmakAla': 1,
#    'paramaM': 1,
#    'nijamani': 1,
#    'SrIrAma': 1,
#    'krismas': 1,
#    'vyUhAwmakaMgA': 1,
#    'saMkRemaSAKa': 1,
#    'maMdalAniki': 1,
#    'manakunna': 1,
#    'XarmanaMxanA': 1,
#    'amallo': 1,
#    'malupulu': 1,
#    'prapaMcamaMwatA': 1,
#    'bAmma': 1,
#    'samasyani': 1,
#    'iswAmannAru': 1,
#    'kAlakramaMlo': 1,
#    'paramaSivudu': 1,
#    'menamAma': 1,
#    'Xarmame': 1,
#    'SakwimaMwamEna': 1,
#    'niyama': 1,
#    'maMwrulanu': 1,
#    'pariSuxXAwma': 1,
#    'xomala': 1,
#    'brAhmaNewara': 1,
#    'maraNAniki': 1,
#    'maMdalAlanu': 1,
#    'mawAnni': 1,
#    'madda': 1,
#    'maxan': 1,
#    'hanuma': 1,
#    'maMxirAniki': 1,
#    'brAhmaNulu': 1,
#    'mahabUb\u200cnagar\u200c': 1,
#    'maMciryAla': 1,
#    'mummaraMgA': 1,
#    'mamekamE': 1,
#    '“mana': 1,
#    'sAmagri': 1,
#    'image': 1,
#    'veVyyimaMxi': 1,
#    'mahAviRNuvu': 1,
#    'nimma': 1,
#    'boVmmalanu': 1,
#    'samaMwa': 1,
#    'ma\u200cri': 1,
#    'prawiRtAwmaka': 1,
#    'maMwriki': 1,
#    'maXyamaXyalo': 2,
#    'manugadaku': 1,
#    'manuRyudu': 1,
#    'koVxximaMxi': 1,
#    'samaya': 1,
#    'mArgamani': 1,
#    'brAhmaNuni': 1,
#    'maracipoyi': 1,
#    'mawonmAxa': 1,
#    'nItimattaM': 1,
#    'manalAMti': 1,
#    'malleVllo': 1,
#    'Awmanu': 1,
#    'hanumaMwudu': 1,
#    'manavAlYlYu': 1,
#    'samagraMgA': 1,
#    'mahilYaku': 1,
#    'meVman': 1,
#    'kalYAwmaka': 1,
#    'maMga': 1,
#    'ammavAriki': 1,
#    'nammakAlu': 1,
#    'samayame': 1,
#    'vivaraNAwmaka': 1,
#    'maMjUrEna': 1,
#    'maXyayuga': 1,
#    'samayAllo': 1,
#    'marici': 1,
#    'laByamayye': 1,
#    'maMxa': 1,
#    'kaRtamani': 1,
#    'hemaMwa': 1,
#    'malaci': 1,
#    'mahASivarAwri': 1,
#    'rAmakqRNArAvu': 1,
#    'rAjamaMdrilo': 1,
#    'KammaMlo': 1,
#    'wamakU': 1,
#    'SrImaxvirAt': 1,
#    'samawa': 1,
#    'bAvamarixi': 1,
#    'paxmaSrI': 1,
#    'amarcina': 1,
#    'amara': 1,
#    'EkamawyaM': 1,
#    'uRNamaMdala': 1,
#    'marginः0px': 1,
#    'prawiRTAwmakaMgA': 1,
#    'punarAgamanaM': 1,
#    'brAhmaNulaku': 1,
#    'brahmaxevudu': 1,
#    'Almatti': 1,
#    'mawasaMbaMXamEna': 1,
#    'kramasUwra': 1,
#    'janagAma': 1,
#    'aSvawWAma': 1,
#    'maMxAra': 1,
#    'AwmarakRaNa': 1,
#    'SrIXarma': 1,
#    'maruguxoVddi': 1,
#    'kramaMlone': 1,
#    'maMwramu': 1,
#    'upagama': 1,
#    'aljImars\u200c': 1,
#    'uxyamakArulanu': 1,
#    'prAraMBamayiMxi': 1,
#    'rAmmadra': 1,
#    'kAraNamannAru': 1,
#    'rAmappa': 1,
#    'moVhammax': 1,
#    'karmala': 1,
#    'kramabaxXIkaraNa': 1,
#    'hiMxUmawaM': 1,
#    'AwmagOravAnni': 1,
#    'ammakaM': 1,
#    'mahAnu': 1,
#    'samasyA': 1,
#    'mahilYalanu': 1,
#    'samasyalannI': 1,
#    'brahmaku': 1,
#    'prayogAwmaka': 1,
#    'grAmaswulu': 1,
#    'SakwimaMwaMgA': 1,
#    'BUmaXya': 1,
#    'SAsanamaMdali': 1,
#    'malupula': 1,
#    'mariyoVka': 1,
#    'maraNAla': 1,
#    'samagramEna': 1,
#    'maMwrulaku': 1,
#    'gamanAlu': 1,
#    'BImadolu': 1,
#    'manmohan': 1,
#    'maMcivAdu': 1,
#    'samarXavaMwaMgA': 1,
#    'mAjImaMwri': 1,
#    'BImavaraM': 1,
#    'Awmala': 1,
#    'mahAgaNAXipawaye': 1,
#    'parAmarSiMcAru': 1,
#    'nirmal\u200c': 1,
#    'kastamarlu': 1,
#    'kAryakrama': 1,
#    'sqjanAwmakaMgA': 1,
#    'Tahoma': 1,
#    'marakalu': 1,
#    'boVmmalawo': 1,
#    'kammari': 1,
#    'jAwIyoxyama': 1,
#    'glAmar': 1,
#    'maMwra': 1,
#    'mahAnagaraM': 1,
#    'aRtama': 1,
#    'grAmasaBalu': 1,
#    'ceVxurumaxuru': 1,
#    'mahilYanu': 1,
#    'vyawirekamani': 1,
#    'manuRya': 1,
#    'cAlAma0xi': 1,
#    'maMdalAllo': 1,
#    'arWamayiMxi': 1,
#    'kAmans': 1,
#    'unnAmani': 1,
#    'xvArakAwirumala': 1,
#    'manuRulaku': 1,
#    'manasunu': 1,
#    'marexEnA': 1,
#    'jammalamadugu': 2,
#    'paramAwmanu': 1,
#    'mahAwmudu': 1,
#    'amarina': 1,
#    'matkA': 1,
#    'nIyamma': 1,
#    'SivarAmakqRNa': 1,
#    'manasuki': 1,
#    'maxanapalli': 1,
#    'sAmarWyAniki': 1,
#    'mummara': 1,
#    'janmawaH': 1,
#    'AwmagOravaM': 1,
#    'vimarSakudu': 1,
#    'maXyasWa': 1,
#    'qNAwmaka': 1,
#    'ImaXyane': 1,
#    'kamarRiyal\u200c': 1,
#    'kosamani': 1,
#    'amarcAru': 1,
#    'samAnamani': 1,
#    'nIwimaMwudu': 1,
#    'mayanmAr': 1,
#    'AwmavimarSa': 2,
#    'maMdalAlaku': 1,
#    'namaskariMci': 1,
#    'aMwimaMgA': 1,
#    'XarmarAjuku': 1,
#    'avasaramavuwuMxi': 1,
#    'viRamaMgA': 1,
#    'byAts\u200cman': 1,
#    'kqRNamma': 1,
#    'mahabUb\u200cnagar\u200clo': 1,
#    'marolA': 1,
#    'ceVyyamani': 1,
#    'gamaniMcagalaru': 1,
#    'malleV': 1,
#    'gamanAnni': 1,
#    'pariRkariswAmani': 1,
#    'maXupriya': 1,
#    'Xarmayya': 1,
#    'roman\u200c': 1,
#    'premaku': 1,
#    'manaswawvaM': 1,
#    'samasamAja': 1,
#    'boVmmanu': 1,
#    'SrIrAmarAjyaM': 1,
#    'nirvahiswAmani': 1,
#    'mahammaxIya': 2,
#    'nammaka': 1,
#    'mawasaMbaMXa': 1,
#    'maMxike': 1,
#    'masAj': 1,
#    'ivvamani': 1,
#    'roman': 1,
#    'sixXamavuwoMxi': 1,
#    'mahAnAdu': 1,
#    'maMcivi': 1,
#    'grAmaMlone': 1,
#    'maBya': 1,
#    'muhammax': 1,
#    'emaMdI': 1,
#    'samanvayakarwa': 1,
#    'kramaSikRaNA': 1,
#    'XarmarAjunu': 1,
#    'brahmapura': 1,
#    'SrImanmahABArawe': 2,
#    'xAnaXarmaparvaNi': 1,
#    'ammalu': 1,
#    'rugmawalu': 1,
#    'SrIrAmanavami': 1,
#    'mahonnawa': 1,
#    'maMxaMgA': 1,
#    'emaMtAru': 1,
#    'samayamuna': 1,
#    'malleSaM': 1,
#    'uwwamamEna': 1,
#    'sa\u200cma\u200cyaM': 1,
#    'wamawo': 1,
#    'sawIsahagamanaM': 1,
#    'xigumawulu': 1,
#    'kanumarugu': 1,
#    'maMgali': 1,
#    'cimma': 1,
#    'kamal\u200c': 1,
#    'kUrma': 1,
#    'BaMgimalu': 1,
#    'gummadi': 1,
#    'weightःnormal': 1,
#    'lakRmaN\u200c': 1,
#    'parimalYaM': 1,
#    'piwAmahA': 1,
#    'purugumaMxula': 1,
#    'wamalo': 1,
#    'Pemas': 1,
#    'sUkRmajIvulu': 1,
#    'sArvaBOma': 1,
#    'magavAdu': 1,
#    'sAmarasya': 1,
#    'mawaMlo': 1,
#    'paMcama': 1,
#    'manuXarmaM': 2,
#    'sammawiMcAru': 1,
#    'mallISvari': 1,
#    'niyAmakAlu': 1,
#    'maMte': 1,
#    'vaccAmani': 1,
#    'wamapE': 1,
#    'grAmasWAyilo': 1,
#    'marunAdu': 1,
#    'vAmana': 1,
#    'sWomawa': 1,
#    'spaRtamavuwuMxi': 1,
#    'maMdalini': 1,
#    'maryAxa': 1,
#    'camawkAraM': 1,
#    'mamekaM': 1,
#    'ciwrasImalo': 1,
#    'emavuwuMxo': 1,
#    'paramahaMsa': 1,
#    'manasEna': 1,
#    'kusuma': 1,
#    'samaswamunu': 1,
#    'meVmarI': 1,
#    'manoj': 1,
#    'rAmacaMxrAreVddi': 1,
#    'rAmacaMxrarAvu': 1,
#    'maxxi': 1,
#    'avasaramayina': 1,
#    'nAmarUpAlu': 1,
#    'lokamaMwA': 1,
#    'amaluloki': 1,
#    'nammakAnni': 1,
#    'mawaMgA': 1,
#    'BramarAMba': 1,
#    'maXurakavi': 1,
#    'ammavAru': 1,
#    'paScimagoxAvari': 1,
#    'kloma': 1,
#    'viSleRaNAwmaka': 1,
#    'keMxramaMwrulu': 1,
#    'marikAswa': 1,
#    'brahmamu': 1,
#    'wAmara': 1,
#    'sAmarlakota': 1,
#    'laByamavuwunnAyi': 1,
#    'mahAsamuxraM': 1,
#    'koVmma': 1,
#    'IkramaMlo': 1,
#    'aMxamayina': 1,
#    'samarpiMce': 1,
#    'nimmarasaM': 1,
#    'maruguxoVdla': 1,
#    'nirNayAwmaka': 1,
#    'ma\u200cna': 1,
#    'manuRyulanu': 1,
#    'manohar': 1,
#    'nAgamma': 1,
#    'manassunu': 1,
#    'praWamaM': 1,
#    'maheMxar': 1,
#    'amalupE': 1,
#    'vimarSala': 1,
#    'sixXamayyAru': 1,
#    'janmalo': 1,
#    'brahmaSrI': 1,
#    'gamaniMcAdu': 1,
#    'maroveVpu': 1,
#    'ceyamannAdu': 1,
#    'prAraMBamayina': 1,
#    'marikoVxxi': 1,
#    'prapaMcamaMwA': 1,
#    'manassuku': 1,
#    'maMjula': 1,
#    'gamaniswU': 1,
#    'malacadaM': 1,
#    'maxxawuni': 1,
#    'bAXAkaramannAru': 1,
#    'mahIMxrA': 1,
#    'kramamugA': 1,
#    'malaya': 1,
#    'manasPUrwigA': 1,
#    'mahAnuBAvulu': 1,
#    'pattumani': 1,
#    'maXurima': 2,
#    'ahmaxAbAx': 1,
#    'manassuki': 1,
#    'wamavaMwu': 1,
#    'brahmacaryaM': 1,
#    'maMtallo': 1,
#    'kammani': 1,
#    'BAnumawi': 1,
#    'maxilo': 1,
#    'manawo': 1,
#    'maMwrivarga': 1,
#    'mahAsaBala': 1,
#    'makkuva': 1,
#    'arWamavuwuMxani': 1,
#    'masAlA': 1,
#    'oVmar': 1,
#    'samakRaMlone': 1,
#    'kAmaw': 1,
#    'manoBAvAlanu': 1,
#    'maMcaMpE': 1,
#    'malayAlYaMlo': 1,
#    'xeSamaMwatA': 1,
#    'maXye': 1,
#    'samasye': 1,
#    'lakRmaNA': 1,
#    'vimarSiMcAdu': 1,
#    'Awmahawyaku': 1,
#    'mahammax\u200c': 2,
#    'ahmax\u200c': 1,
#    'mahawwaramEna': 1,
#    'mAXyamaM': 1,
#    'immarRan': 1,
#    'kamalA': 1,
#    'mahimalu': 2,
#    'marocota': 1,
#    'malinAlu': 1,
#    'amarula': 1,
#    'XarmaBikRaM': 1,
#    'Sarmanu': 1,
#    'bawukammalanu': 1,
#    'memaMwA': 1,
#    'malYliMpu': 1,
#    'mahABArawaMlo': 1,
#    'human': 1,
#    'axemaMte': 1,
#    'oVmahA': 1,
#    'samakUrciMxi': 1,
#    'saxASivabrahmaM': 1,
#    'hyUman': 1,
#    'mattaM': 1,
#    'marci': 1,
#    'Khammam': 1,
#    'mattAniki': 1,
#    'mahArAj': 1,
#    'mahimace': 2,
#    'magAlYlYu': 1,
#    'marugu': 1,
#    'maMwriwvaSAKa': 1,
#    'mbsprasad@gmail.com': 1,
#    'kAmanveVlw': 1,
#    'AwmakUru': 1,
#    'hiMsAwmaka': 1,
#    'mabbu': 1,
#    'rAyalasImalo': 1,
#    'svagrAmaM': 1,
#    'gamaniswAru': 1,
#    'kAraNamavuwunnAyi': 1,
#    'fontःnormal': 1,
#    'mAsamaMxu': 1,
#    'manassAkRi': 1,
#    'uMtAmani': 1,
#    'maTaMlo': 1,
#    'sIwArAma': 1,
#    'pasumarwi': 1,
#    'saMjIvarAyaSarma': 1,
#    'bahamanI': 1,
#    'cAriwrAwmaka': 1,
#    'rAmaM': 1,
#    'komatireVddi': 1,
#    'mayye': 1,
#    'maryAxalu': 1,
#    'mmagama': 2,
#    'kanuboVmalu': 1,
#    'samarXiMci': 1,
#    'manumarAlu': 2,
#    '18maMxi': 1,
#    'janmalu': 1,
#    'jayamma': 1,
#    'AkramaNala': 1,
#    'wulanAwmaka': 1,
#    'maxana': 1,
#    'balavanmaraNaM': 1,
#    'vimarSaku': 1,
#    'paramAwmawo': 1,
#    'premalu': 1,
#    'gamaniMcAnu': 1,
#    'maraNiMciMxi': 1,
#    'eVdamacewi': 1,
#    'barman': 1,
#    'ma\u200chilYa\u200cla\u200cku': 1,
#    'manaHsAkRi': 1,
#    'ceyabomani': 1,
#    'vimarSalo': 1,
#    'cAlAmaMxe': 1,
#    'manasse': 1,
#    '11maMxi': 1,
#    'sAXyamani': 1,
#    'pArvawamma': 1,
#    'cemakUra': 1,
#    'manaswawvAnni': 1,
#    'savawamma': 1,
#    'mawsyaSAKa': 1,
#    'paramapaxiMcAdu': 1,
#    'sawyaBAmagA': 1,
#    ...}),
#  ('ar',
#   {'mariyu': 1,
#    'warvAwa': 1,
#    'varaku': 1,
#    'waruvAwa': 1,
#    'iwara': 1,
#    'jarigina': 1,
#    'avasaraM': 1,
#    'saMxarBaMgA': 1,
#    'mariMwa': 1,
#    'jarigiMxi': 1,
#    'arWaM': 1,
#    'xaggara': 1,
#    'parisWiwi': 1,
#    'caryalu': 1,
#    'aMxarU': 1,
#    'hExarAbAx': 1,
#    'saMvawsaraM': 1,
#    'cariwra': 1,
#    'koVMxaru': 1,
#    'ixxaru': 1,
#    'eVvaru': 1,
#    'anaMwaraM': 1,
#    'varakU': 1,
#    'AKari': 1,
#    'civari': 1,
#    'aMwarjAwIya': 1,
#    'waxiwara': 1,
#    'jaruguwuMxi': 1,
#    'saMvawsarAla': 1,
#    'Pibravari': 1,
#    'aMxarikI': 1,
#    'vivarAlu': 1,
#    'uwwara': 1,
#    'carca': 1,
#    'hExarAbAx\u200c': 1,
#    'Barwa': 1,
#    'jarige': 1,
#    'dAktar': 1,
#    'kAryaxarSi': 1,
#    'eVvaro': 1,
#    'vivariMcAru': 1,
#    'maroVka': 1,
#    'jaruguwunna': 1,
#    'eVvarU': 1,
#    'janavari': 1,
#    'eVvari': 1,
#    'arXaM': 1,
#    'Karcu': 1,
#    'nagaraM': 1,
#    'nagara': 1,
#    'parIkRa': 1,
#    'oVkaru': 1,
#    'goxAvari': 1,
#    'sarEna': 1,
#    'waxiwarulu': 1,
#    'avasaramEna': 1,
#    'SarIraM': 1,
#    'uxAharaNaku': 1,
#    'sarve': 1,
#    'civariki': 1,
#    'marovEpu': 1,
#    'civaraku': 1,
#    'xaggaraku': 1,
#    'saraParA': 2,
#    'AXvaryaMlo': 1,
#    'pariXilo': 1,
#    'eVvarEnA': 1,
#    'saMvawsarAlu': 1,
#    'baruvu': 1,
#    'sarigA': 1,
#    'ixxarU': 1,
#    'paricayaM': 1,
#    'wvaragA': 1,
#    'diseVMbar': 1,
#    'sAmarWyaM': 1,
#    'hExarAbAx\u200clo': 1,
#    'nagaraMlo': 1,
#    'niyojakavargaM': 1,
#    'waragawi': 1,
#    'xarSakudu': 1,
#    'waracugA': 1,
#    'yUnivarsitI': 1,
#    'seVpteVMbar': 1,
#    'vimarSalu': 1,
#    'parisWiwulu': 1,
#    'saMvawsaraMlo': 1,
#    'Variable': 1,
#    'maraNaM': 1,
#    'vimarSiMcAru': 1,
#    'margin': 1,
#    'XarmaM': 1,
#    'sariggA': 1,
#    'varaMgal': 1,
#    'sIniyar': 1,
#    'saMxarBaMlo': 1,
#    'kaleVktar': 1,
#    'aktobar': 1,
#    'gavarnar': 2,
#    'carya': 1,
#    'waxupari': 1,
#    'janaral': 1,
#    'wvaralo': 1,
#    'marosAri': 1,
#    'parisWiwullo': 1,
#    'xaraKAswu': 1,
#    'cariwralo': 1,
#    'paryAvaraNa': 2,
#    'navaMbar': 1,
#    'vivarAlanu': 1,
#    'pariSrama': 1,
#    'eVvarikI': 1,
#    'carcalu': 1,
#    'kaMpyUtar': 1,
#    'parugulu': 1,
#    'Xaralu': 1,
#    'parIkRalu': 1,
#    'waracU': 1,
#    'eVvariki': 1,
#    'dEreVktar': 1,
#    'praxarSana': 1,
#    'kyAnsar': 1,
#    'jarmanI': 1,
#    'varRaM': 1,
#    'pariSoXana': 1,
#    'aMxari': 1,
#    'vargAla': 1,
#    'arhawa': 1,
#    'kAryakarwalu': 1,
#    'waravAwa': 1,
#    'pariRkAraM': 1,
#    'xaggariki': 1,
#    'eVMxaro': 1,
#    'jaruguwoMxi': 1,
#    'SarIra': 1,
#    'maharRi': 1,
#    'pariXiloni': 1,
#    'kaleVktar\u200c': 1,
#    'jarigAyi': 1,
#    'dAktar\u200c': 1,
#    'wappanisari': 1,
#    'SarIraMlo': 1,
#    'areVstu': 1,
#    'carmaM': 1,
#    'koVbbari': 1,
#    'jUniyar': 1,
#    'jarigiwe': 1,
#    'pavar': 1,
#    'diseVMbaru': 1,
#    'varusagA': 1,
#    'rakarakAla': 1,
#    'wappanisarigA': 1,
#    'jaruguwuMxani': 1,
#    'vargaM': 1,
#    'vAwAvaraNaM': 1,
#    'marinni': 1,
#    'proVPeVsar': 1,
#    'xarSanaM': 1,
#    'paraMgA': 1,
#    'vAwAvaraNa': 1,
#    'aMxaru': 1,
#    'xaggaragA': 1,
#    'saMxarBAllo': 1,
#    'uxAharaNa': 1,
#    'sOkaryaM': 1,
#    'marikoVnni': 1,
#    'parimiwaM': 1,
#    'aByarWulu': 1,
#    'niraMwaraM': 1,
#    'avasarAlaku': 1,
#    'spIkar': 1,
#    'Sarma': 1,
#    'xarSakawvaM': 1,
#    'iwarulu': 1,
#    'ippativaraku': 1,
#    'saxaru': 1,
#    'samarpayAmi': 1,
#    'kilomItarla': 1,
#    'parisWiwini': 1,
#    'paryatana': 1,
#    'amarAvawi': 1,
#    'xaraKAswulu': 1,
#    'xaryApwu': 1,
#    'sarva': 1,
#    'BarwI': 1,
#    'SrInivAsarAvu': 1,
#    'jaripina': 1,
#    'menejar': 1,
#    'vargAlu': 1,
#    'ixxari': 1,
#    'nareMxra': 1,
#    'saMxarBAlalo': 1,
#    'Ardar': 1,
#    'mItarla': 1,
#    'aByarWi': 1,
#    'parikarAlu': 2,
#    'nagar': 1,
#    'warvAwe': 1,
#    'iMtarneVt': 1,
#    'varRAlu': 1,
#    'parIkRala': 1,
#    'vivaraNa': 1,
#    'cakravarwi': 1,
#    'polavaraM': 1,
#    'karNAtaka': 1,
#    'warvAwi': 1,
#    'parimANaM': 1,
#    'pariSIlana': 1,
#    'varaMgal\u200c': 1,
#    'sekaraNa': 1,
#    'pariSIliMci': 1,
#    'niyojakavarga': 1,
#    'waraPuna': 1,
#    'karuvu': 1,
#    'jaruguwunnAyi': 1,
#    'seVMtar': 1,
#    'sUpar': 1,
#    'sidebar': 1,
#    'Xarma': 1,
#    'paripAlana': 1,
#    'hExarAbAxu': 1,
#    'parisWiwulanu': 1,
#    'warahA': 1,
#    'anusariMci': 1,
#    'saripowuMxi': 1,
#    'gujarAw': 1,
#    'woVMxaragA': 1,
#    'wvaralone': 1,
#    'saMvawsarAniki': 1,
#    'vAwAvaraNaMlo': 1,
#    'viparIwaMgA': 1,
#    'varma': 1,
#    'waruvAwi': 1,
#    'meyar': 1,
#    'AScaryaM': 1,
#    'XarmarAju': 2,
#    'vinara': 1,
#    'uwwaraM': 1,
#    'nixarSanaM': 1,
#    'cariwranu': 1,
#    'pariNAmaM': 1,
#    'parugu': 1,
#    'warapuna': 1,
#    'nagarAniki': 1,
#    'seVpteVMbaru': 1,
#    'sarihaxxu': 1,
#    'parijFAnaM': 1,
#    'byAtarI': 1,
#    'SarIrAniki': 1,
#    'eVkarAla': 1,
#    'eVkarAlu': 1,
#    'hExarAbAx\u200cku': 1,
#    'drEvar': 1,
#    'aMxariki': 1,
#    'karnUlu': 1,
#    'paramEna': 1,
#    'civara': 1,
#    'marikoVMxaru': 2,
#    'uxAharaNaki': 1,
#    'mistar': 1,
#    'marala': 1,
#    'kamiRanar': 1,
#    'sOkaryAlu': 1,
#    'aByarWula': 1,
#    'niraMwara': 1,
#    'pariSramalu': 1,
#    'garBaM': 1,
#    'oVkkarU': 1,
#    'paryAtaka': 1,
#    'kasarawwu': 1,
#    'jarigi': 1,
#    'gretar': 1,
#    'dAlarlu': 1,
#    'varusa': 1,
#    'parama': 1,
#    'AxarSaMgA': 1,
#    'varwiswuMxi': 1,
#    'areVst': 1,
#    'iwarula': 1,
#    'iwarulaku': 1,
#    'iMtarvyU': 1,
#    'pariSoXanalu': 1,
#    'heVccariMcAru': 1,
#    'karIMnagar': 2,
#    'oVkaroju': 1,
#    'narasiMha': 1,
#    'parisWiwula': 1,
#    'SrIhari': 1,
#    'parisWiwulalo': 1,
#    'niyojakavargaMlo': 1,
#    'arjunudu': 1,
#    'SeKar': 1,
#    'siMgareNi': 1,
#    'sAmarWyAnni': 1,
#    'iMtar': 1,
#    'SarIrAnni': 1,
#    'karma': 1,
#    'iMtar\u200c': 1,
#    'hAjaru': 1,
#    'iMwavaraku': 1,
#    'varga': 1,
#    'awyavasara': 1,
#    'praxarSiMcina': 1,
#    'jAwara': 1,
#    'pariNAmAlu': 1,
#    'varald': 1,
#    'SaMkar': 1,
#    'parisWiwilo': 1,
#    'soxarulu': 1,
#    'sarkAru': 1,
#    'carciMcAru': 1,
#    'XariMcina': 1,
#    'warabadi': 1,
#    'XariMci': 1,
#    'saripadA': 1,
#    'vivarAla': 1,
#    'neVMbaru': 1,
#    'oVMtarigA': 1,
#    'parvawa': 1,
#    'neVt\u200cvark': 1,
#    'pariSIliMcAru': 1,
#    'varaxa': 1,
#    'pravarwana': 1,
#    'rijarveRanlu': 1,
#    'parigaNanaloki': 1,
#    'waraM': 1,
#    'seVkratarI': 1,
#    'ixxaraM': 1,
#    'KarAru': 1,
#    'carci': 1,
#    'vAtar': 1,
#    'vivariMci': 1,
#    'otarlu': 1,
#    'caryalanu': 1,
#    'nAgeSvararAvu': 2,
#    'mItarlu': 1,
#    'viswaraNa': 1,
#    'vanarulu': 1,
#    'harilo': 1,
#    'avasaramA': 1,
#    'gretar\u200c': 1,
#    'kyAnsar\u200c': 1,
#    'waraliMcAru': 1,
#    'soxarudu': 1,
#    'aMbexkar\u200c': 1,
#    'vanarula': 1,
#    'arXarAwri': 2,
#    'viparIwamEna': 1,
#    'Karculu': 1,
#    'xaggaralo': 1,
#    'parIkRallo': 1,
#    'kAryaxarSigA': 1,
#    'pariSoXakulu': 1,
#    'sarkAr\u200c': 1,
#    'svargaM': 1,
#    'yuvarANi': 1,
#    'xarSakawvaMlo': 1,
#    'marri': 1,
#    'jarigiMxani': 1,
#    'lItarla': 1,
#    'vargAlaku': 1,
#    'parokRaMgA': 1,
#    'aruxEna': 1,
#    'AkarRaNa': 1,
#    'karuNa': 1,
#    'March': 1,
#    'mariMwagA': 1,
#    'AxaraNa': 1,
#    'aByaMwaraM': 1,
#    'vargIkaraNa': 2,
#    'carma': 1,
#    'paramAwma': 1,
#    'praxarSanalu': 1,
#    'paryatanalo': 1,
#    'pariSramala': 1,
#    'jaragadaM': 1,
#    'maroVkaru': 2,
#    'saMcariMcu': 1,
#    'marusati': 1,
#    'avasarAlu': 1,
#    'eVvarikEnA': 1,
#    'ApareRan': 1,
#    'kOMtar': 1,
#    'vEKari': 1,
#    'aruxugA': 1,
#    'sekariMci': 1,
#    'kaMpyUtar\u200c': 1,
#    'caryalaku': 1,
#    'karra': 1,
#    'aMwargawa': 1,
#    'maraNiMcAru': 1,
#    'uwwarvulu': 1,
#    'avasaramEwe': 1,
#    'gavarnar\u200c': 2,
#    'gariRta': 1,
#    'caxarapu': 1,
#    'nAgarikawa': 1,
#    'vivariMcAdu': 1,
#    'warAniki': 1,
#    'BayaMkaramEna': 1,
#    'oVkari': 1,
#    'eVkarAllo': 1,
#    'sariki': 1,
#    'mahabUb\u200cnagar': 1,
#    'sIniyar\u200c': 1,
#    'marginः0': 1,
#    'aktobaru': 1,
#    'warahAlo': 1,
#    'BarosA': 1,
#    'PyAktarI': 1,
#    'parIkRalo': 1,
#    'maroVkati': 1,
#    'Xarmamu': 1,
#    'hExarAbAxulo': 1,
#    'nikara': 1,
#    'Wiyetar': 1,
#    'svIkariMcina': 1,
#    'tEgar': 1,
#    'svIkariMci': 1,
#    'jaragalexu': 1,
#    'parugula': 1,
#    'Karcuwo': 1,
#    'parisara': 2,
#    'cOxari': 1,
#    'vijayanagara': 1,
#    'wyAgarAju': 1,
#    'parihAraM': 1,
#    'samarWavaMwaMgA': 1,
#    'carcaku': 1,
#    'maralA': 1,
#    'GarRaNa': 1,
#    'ippativarakU': 1,
#    'ABaraNAlu': 1,
#    'jarigiMxannAru': 1,
#    'maraNiMcAdu': 1,
#    'jaripAru': 1,
#    'barilo': 1,
#    'xaggari': 1,
#    'aMxarinI': 1,
#    'vilekarula': 1,
#    'neVtvark': 1,
#    'pariNAmAla': 1,
#    'rAbart': 1,
#    'varRapAwaM': 1,
#    'jaraganunna': 1,
#    'BUgarBa': 1,
#    'pariXi': 1,
#    'dAlarla': 1,
#    'uwwarAMXra': 1,
#    'janaral\u200c': 1,
#    'BarwIki': 1,
#    'carciMci': 1,
#    'nagarAllo': 1,
#    'maraNa': 1,
#    'viswariMci': 1,
#    'bOlar': 1,
#    'February': 1,
#    'pariSoXanA': 1,
#    'karnAtaka': 1,
#    'pariRaw': 1,
#    'veVMkateSvararAvu': 2,
#    'kutuMbarAvu': 1,
#    'jarman': 1,
#    'iwarulanu': 1,
#    'akRarAlu': 1,
#    'arati': 1,
#    'maraNiMcina': 1,
#    'lEbrarI': 1,
#    'AviRkaraNa': 1,
#    'jaripi': 1,
#    '“sare': 1,
#    'sarvIs': 1,
#    'vimarSa': 1,
#    'otaru': 1,
#    'gavarnameVMt': 1,
#    'pariRkArAniki': 1,
#    'muKarjI': 1,
#    'muMxara': 1,
#    'civaragA': 1,
#    'arban': 1,
#    'saMxarBaM': 1,
#    'eVvarini': 1,
#    'xarimilA': 1,
#    'avasarAlanu': 1,
#    'vijayanagaraM': 1,
#    'savaraNa': 1,
#    'jaruguwAyi': 1,
#    'jariginaxi': 1,
#    'histarI': 1,
#    'proVPeVsar\u200c': 1,
#    'sarAsari': 2,
#    'civarilo': 1,
#    'karwavyaM': 1,
#    'navaMbaru': 1,
#    'SrIXar': 1,
#    'akRara': 1,
#    'caraN': 1,
#    'vivaraMgA': 1,
#    'akRaraM': 1,
#    'mAstar': 1,
#    'parAjayaM': 1,
#    'marATI': 1,
#    'paraspara': 2,
#    'maXyawaragawi': 1,
#    'sarvelu': 1,
#    'eVkarAlaku': 1,
#    'cAlAvaraku': 1,
#    'waracu': 1,
#    'sarukulu': 1,
#    'prajAxaraNa': 1,
#    'carcA': 1,
#    'vaccesariki': 1,
#    'kalar': 1,
#    'mawaparamEna': 1,
#    'eVvvarU': 1,
#    'rUpAMwaraM': 1,
#    'nagaraMloni': 1,
#    'maraNamu': 1,
#    'makara': 1,
#    'arWaMlo': 1,
#    'karwa': 1,
#    'XarnA': 1,
#    'kaMdarAlu': 1,
#    'parvawaM': 1,
#    'aragaMta': 1,
#    'hExarAbAx\u200cloni': 1,
#    'dinnar': 1,
#    'sareVna': 1,
#    'xaraKAswula': 1,
#    'Earth': 1,
#    'xasarA': 1,
#    'carcallo': 1,
#    'aByarWigA': 1,
#    'parapawi': 1,
#    'parikarAla': 2,
#    'vimarSakulu': 1,
#    'parirakRaNa': 1,
#    'jaragAlani': 1,
#    'oVkkaru': 1,
#    'aravE': 1,
#    'sarikoVwwa': 1,
#    'iMtarneRanal': 1,
#    'vyavahariswAru': 1,
#    'sarkAr': 1,
#    'oVkariki': 1,
#    'jaragakuMdA': 1,
#    'oVkkarikI': 1,
#    'jUniyar\u200c': 1,
#    'dAktarlu': 1,
#    'naRtaparihAraM': 1,
#    'sarxubAtu': 1,
#    'aMbexkar': 1,
#    'caryala': 1,
#    'vIrixxari': 1,
#    'veVMkateSvarlu': 1,
#    'vanarulanu': 1,
#    'AparetiMg': 1,
#    'aMxaraM': 1,
#    'vargAniki': 1,
#    'pArlameVMtarI': 1,
#    'sAMbaSivarAvu': 1,
#    'SrInivAsareVddi': 1,
#    'rAjaSeKar': 1,
#    'xarSanamu': 1,
#    'parikarAlanu': 2,
#    'saMskaraNa': 1,
#    'mariyU': 1,
#    'mejar': 1,
#    'kavar': 1,
#    'punarAvqwaM': 1,
#    'varake': 1,
#    'ixxarikI': 1,
#    'vyavahariswunnAru': 1,
#    'waraliMci': 1,
#    'waragawulu': 1,
#    'karavu': 1,
#    'rijarveRanla': 1,
#    'xAsari': 1,
#    'jaragAli': 1,
#    'kAryaxarSulu': 1,
#    'haryAnA': 1,
#    'aruN\u200c': 1,
#    'prawyarWi': 1,
#    'avasarAla': 1,
#    'paripAlanA': 1,
#    'marnAdu': 1,
#    'praxarSiMce': 1,
#    'xarSana': 1,
#    'arjuna': 1,
#    'varsitI': 1,
#    'arWarAwri': 2,
#    'kAryakarwalaku': 1,
#    'niyojakavargAniki': 1,
#    'vivariMce': 1,
#    'narakaM': 1,
#    'deVlivarI': 1,
#    'hAjarayyAru': 1,
#    'xaggaraki': 1,
#    'uwwarapraxeS': 1,
#    'oVkarakaMgA': 1,
#    'saraxA': 1,
#    'iwarawrA': 1,
#    'APIsar': 1,
#    'AcaraNalo': 1,
#    'pepar': 1,
#    'nariki': 1,
#    'koVMxariki': 1,
#    'pramAxakara': 1,
#    'skAlar\u200cRip\u200c': 1,
#    'nArAyaNarAvu': 1,
#    'uxAharaNalu': 1,
#    'kAnsar': 1,
#    'marikoVMwa': 1,
#    'pariNAmAlanu': 1,
#    'SarIraMloni': 1,
#    'seVpteVMbar\u200c': 1,
#    'sarvar': 2,
#    'parIkRalaku': 1,
#    'jarnalistu': 1,
#    'kamiRanar\u200c': 1,
#    'sariyEna': 1,
#    'varNiMcAru': 1,
#    'parimiwa': 1,
#    'uxAharaNagA': 1,
#    'avasaramani': 1,
#    'saMvawsara': 1,
#    'xarSakudigA': 1,
#    'nAgarAju': 1,
#    'yUnivarSitI': 1,
#    'aByarWulaku': 1,
#    'kilomItarlu': 1,
#    'mariyA': 1,
#    'pexarikaM': 1,
#    'hAjarE': 1,
#    'jarigexi': 1,
#    'vivariMcina': 1,
#    'kareVMtu': 1,
#    'svarUpaM': 1,
#    'pariSramalanu': 1,
#    'xuraxqRtakaraM': 1,
#    'xaggarunna': 1,
#    'garBa': 1,
#    'parIkRA': 1,
#    'sartiPikeVtlu': 1,
#    'paripAlanalo': 1,
#    'jaruguwoMxani': 1,
#    'jaruguwuMxannAru': 1,
#    'waraMgAlu': 1,
#    'yUnivarsitIlo': 1,
#    'naMbar': 1,
#    'saMvawsaramulu': 1,
#    'nagarAlu': 1,
#    'paryavekRaNa': 1,
#    'pariSramalo': 1,
#    'garvaMgA': 1,
#    'beVnarjI': 1,
#    'barmA': 1,
#    'aMwarAyaM': 1,
#    'varuN': 1,
#    'parirakRaNaku': 1,
#    'suMxari': 1,
#    'jaragaxu': 1,
#    'samarpiMci': 1,
#    'viswariMcAyi': 1,
#    'harIS\u200crAvu': 1,
#    'deVvalapar': 1,
#    'harRaM': 1,
#    'caMxraSeKar': 1,
#    'jarupuwAru': 1,
#    'ixivaraku': 1,
#    'araku': 1,
#    'svIkariMcAru': 1,
#    'arhulu': 1,
#    'sarassu': 1,
#    'niraMwarAyaMgA': 1,
#    'pariRaw\u200c': 1,
#    'karNudu': 1,
#    'parikaraM': 2,
#    'Warmal': 1,
#    'parasparaM': 2,
#    'AvaraNalo': 1,
#    'mArgaxarSakAlu': 1,
#    'viswariMciMxi': 1,
#    'prapaMcIkaraNa': 1,
#    'areVst\u200c': 1,
#    'jariginappudu': 1,
#    'arjun': 1,
#    'warali': 1,
#    'EkyarAjyasamiwi': 1,
#    'vimarSalanu': 1,
#    'aMwarikRa': 1,
#    'marukRaNaM': 1,
#    'xaraKAswulanu': 1,
#    'AviRkariMcAru': 1,
#    'svarAjyaM': 1,
#    'maruguna': 1,
#    'karapawrAlu': 1,
#    'byAnar': 1,
#    'BaraNi': 1,
#    'oVkarini': 1,
#    'yiwara': 1,
#    'hitlar': 1,
#    'sarxubAtlu': 1,
#    'saMskaraNalu': 1,
#    'vyavahariMce': 1,
#    'jaragataM': 1,
#    'praxarSiMcAru': 1,
#    'appativaraku': 1,
#    'saMvawsaramu': 1,
#    'narsiMhAreVddi': 1,
#    'avasaramayye': 1,
#    'wUrpugoxAvari': 1,
#    'sarasvawi': 1,
#    'bariloki': 1,
#    'svaramu': 1,
#    'aByaMwarAlu': 1,
#    'eVvareVnA': 1,
#    'maraNAlu': 1,
#    'Xarala': 1,
#    'jvaraM': 1,
#    'AxarSa': 1,
#    'nAgArjunasAgar': 1,
#    'samarpiMcAru': 1,
#    'nagarapAlaka': 1,
#    'jarupukune': 1,
#    'varaxala': 1,
#    'article': 1,
#    'KarIxEna': 1,
#    'sixxavaraM': 1,
#    'varaxalu': 1,
#    'sarjarI': 2,
#    'vyavahariswunna': 1,
#    'carcilu': 1,
#    'veVtarnarI': 2,
#    'anusariMce': 1,
#    'saMxarBAlu': 1,
#    'sarvawrA': 1,
#    'reVgyular\u200c': 1,
#    'pariSoXanala': 1,
#    'sUpar\u200c': 1,
#    'nyUkliyar': 1,
#    'KarIxu': 1,
#    'arcana': 1,
#    'xaggare': 1,
#    'vark\u200c': 1,
#    'eVnarjI': 1,
#    'vilekarulawo': 1,
#    'xarSakulu': 1,
#    'jarigiMxo': 1,
#    'aMdar': 1,
#    'niyojakavargAllo': 1,
#    'eVvarEwe': 1,
#    'pariRkariMcAlani': 2,
#    'pavar\u200c': 1,
#    'neVMbar': 1,
#    'January': 1,
#    'rAjaSeKarareVddi': 2,
#    'cakkarlu': 1,
#    'varalakRmi': 1,
#    'jaruguwUne': 1,
#    'sarvIsu': 1,
#    'memixxaraM': 1,
#    'parAyi': 1,
#    'hArvard': 1,
#    'Xaralanu': 1,
#    'praBAkar': 1,
#    'sarvaM': 1,
#    'vivaraNalu': 1,
#    'sAgar': 1,
#    'waruNaMlo': 1,
#    'pramAxakaramEna': 1,
#    'kliyar': 1,
#    'karmalu': 1,
#    'koVMxarilo': 1,
#    'sarasana': 1,
#    'kAryakarwala': 1,
#    'eVMwavaraku': 1,
#    'paraloka': 1,
#    'maraci': 1,
#    'otarlanu': 1,
#    'sarkilYlu': 1,
#    'arWamu': 1,
#    'kareVnsI': 1,
#    'cillara': 1,
#    'paruvu': 1,
#    'karIMnagar\u200c': 2,
#    'Aks\u200cPard': 1,
#    'xASaraWi': 1,
#    'AsarA': 1,
#    'BaraxvAja': 1,
#    'parice': 1,
#    'varaM': 1,
#    'sekariMcina': 1,
#    'sAmarXyaM': 1,
#    'maropakka': 1,
#    'nivAlYularpiMcAru': 1,
#    'allari': 1,
#    'PeVdaral': 1,
#    'rijarvu': 1,
#    'aMgIkariMcina': 1,
#    'varasagA': 1,
#    'diseVMbar\u200c': 1,
#    'arhawalu': 1,
#    'uwwarapraxeS\u200c': 1,
#    'anuvarwanaM': 1,
#    'cattaparamEna': 1,
#    'pariSramalaku': 1,
#    'warAla': 1,
#    'Barwanu': 1,
#    'parijFAnAnni': 1,
#    'aMgIkariMci': 1,
#    'jarugu': 1,
#    'sOMxarya': 1,
#    'reVgyular': 1,
#    'eVvvaru': 1,
#    'aleVgjAMdar': 1,
#    'aMgIkariMcAru': 1,
#    'vArixxarU': 1,
#    'sarasvawI': 1,
#    'mahawwara': 1,
#    'Plavar': 1,
#    'pItar': 1,
#    'varNa': 1,
#    'puRkarAla': 1,
#    'saraParAlo': 2,
#    'xaggarnuMci': 1,
#    'civaralo': 1,
#    'sarvIseVs': 1,
#    'neVMbar\u200c': 1,
#    'varwaka': 1,
#    'anucarulu': 1,
#    'saMvawsaramula': 1,
#    'saMGarRaNa': 1,
#    'arWamavuwoMxi': 1,
#    'aruNAcal': 1,
#    'koVMwavaraku': 1,
#    'sAgar\u200c': 1,
#    'pariSIliMcina': 1,
#    'harikqRNa': 1,
#    'vivariswU': 1,
#    'kastamar': 1,
#    'aMxariwo': 1,
#    'parameSvarudu': 2,
#    'nagarAlaku': 1,
#    'pariSIliswe': 1,
#    'varwamAna': 1,
#    'sqRtikarwa': 1,
#    'carmAnni': 1,
#    'saMxarbaMgA': 1,
#    'seVMcarIlu': 1,
#    'aMwargawaMgA': 1,
#    'gaMxaragolYaM': 1,
#    'jaruguwuMxo': 1,
#    'rijarv': 1,
#    'parIkRaku': 1,
#    'oVMtari': 1,
#    'saraxAgA': 1,
#    'sarvasAXAraNaMgA': 1,
#    'eVdvard': 1,
#    'SrIrAMsAgar': 1,
#    'ceyagalaru': 1,
#    'amarika': 1,
#    'upasaMharaNa': 1,
#    'naraka': 1,
#    'vyAkaraNaM': 1,
#    'sarkil': 1,
#    'rivars': 1,
#    'yUjar': 1,
#    'carmAniki': 1,
#    'pariRkariMceMxuku': 2,
#    'sigareVt': 1,
#    'svarNa': 1,
#    'varks': 1,
#    'veVMkateSvara': 1,
#    'kAryAcaraNa': 1,
#    'SrIXar\u200c': 1,
#    'inParmeRan': 1,
#    'koVMxari': 1,
#    'aMwarjAwIyaMgA': 1,
#    'yuXiRtarudu': 1,
#    'karnUl': 1,
#    'Avaru': 1,
#    'maruvaxxu': 1,
#    'arWamavuwuMxi': 1,
#    'nagarAnni': 1,
#    'iMtarvyUlo': 1,
#    'varkarlu': 2,
#    'diseVMbar\u200clo': 1,
#    'anusariMcAli': 1,
#    'yuvawaraM': 1,
#    'parIkRanu': 1,
#    'savariMcu': 1,
#    'paxowaragawi': 1,
#    'jaraganunnAyi': 1,
#    'samarpiMcina': 1,
#    'visarjana': 1,
#    'anuvarwiwa': 1,
#    'jariginA': 1,
#    'nareR': 1,
#    'akRarAla': 1,
#    'sawvarame': 1,
#    'xarSaka': 1,
#    'waraliMcina': 1,
#    'cariwraku': 1,
#    'hAjarEna': 1,
#    'saripoye': 1,
#    'parabrahma': 1,
#    'xaggaralone': 1,
#    'parvaM': 1,
#    'parisWiwiki': 1,
#    'wamaru': 1,
#    'sekaraNaku': 1,
#    'menejarla': 1,
#    'civarlo': 1,
#    'liMdbarg': 1,
#    'hanumaMwarAvu': 1,
#    'ibbaMxikaraMgA': 1,
#    'paryatiMci': 1,
#    'janavarilo': 1,
#    'arXamu': 1,
#    'nAlugunnara': 1,
#    'karralu': 1,
#    'sawvaraM': 1,
#    'viSvakarma': 1,
#    'wiraskariMcAru': 1,
#    'SarIramu': 1,
#    'anusariMcina': 1,
#    'IsaMxarBaMgA': 1,
#    'sekariMcadAniki': 1,
#    'dOnlodmariMwa': 1,
#    'proVPeVsarlu': 1,
#    'maraNAnaMwaraM': 2,
#    'karmAgArAnni': 1,
#    'aMbedkar\u200c': 1,
#    'lahari': 1,
#    'niraMwaramu': 1,
#    'aracewilo': 1,
#    'AxarSaM': 1,
#    'narAla': 1,
#    'meVMbar\u200cgA': 1,
#    'parigaNiswAru': 1,
#    'iMwavarakU': 1,
#    'gujarAwI': 1,
#    'akkarlexu': 1,
#    'dEreVktar\u200c': 1,
#    'jaragaboye': 1,
#    'Xarmapuri': 1,
#    'parimiwulanu': 1,
#    'SiKaraM': 1,
#    'sOMxaryaM': 1,
#    'parakAla': 1,
#    'svaraM': 1,
#    'hExarAbAx\u200clone': 1,
#    'eVkarAku': 1,
#    'jarnal': 1,
#    'aMwarjAla': 1,
#    'rAjeSvararAvu': 2,
#    'aMxarini': 1,
#    'cUdagalaru': 1,
#    'sarvasvaM': 1,
#    'uwwarAKaMd': 1,
#    'niyojakavargAlaku': 1,
#    'Baraw': 1,
#    'maraNiswe': 1,
#    'nareMxramoxI': 1,
#    'waruvAwane': 1,
#    'puttinaroju': 1,
#    'pariXiloki': 1,
#    'veVluvariMcAru': 1,
#    'praxarSanaku': 1,
#    'varaMgal\u200clo': 1,
#    'sarpaMci': 1,
#    'parisWiwulaku': 1,
#    'SaMkar\u200c': 1,
#    'samAMwaraMgA': 1,
#    'Asakwikara': 1,
#    'aMgIkariMciMxi': 1,
#    'waraPu': 1,
#    'maXyaMwara': 1,
#    'parimiwamEMxi': 1,
#    'suMxar': 1,
#    'maroVkariki': 2,
#    'ricard': 1,
#    'libaral': 1,
#    'SaravegaMgA': 1,
#    'arjunudi': 1,
#    'kamiRanar\u200cgA': 1,
#    'rAmarAju': 1,
#    'sarikAxani': 1,
#    'dAktaru': 1,
#    'barniMg': 1,
#    'varkarla': 2,
#    'nixarSanamani': 1,
#    'sahacarulawo': 1,
#    'reVMdunnara': 1,
#    'jarapAlani': 1,
#    'vyavahariMcAli': 1,
#    'paryAvaraNaM': 2,
#    'kareVMt': 1,
#    'mareVnno': 1,
#    'kAnPareVns': 1,
#    ...}),
#  ('ri',
#   {'mariyu': 1,
#    'guriMci': 1,
#    'vAriki': 1,
#    'jarigina': 1,
#    'wirigi': 1,
#    'maMwri': 1,
#    'mariMwa': 1,
#    'jarigiMxi': 1,
#    'ameVrikA': 1,
#    'vArini': 1,
#    'parisWiwi': 1,
#    'rAwri': 1,
#    'muKyamaMwri': 1,
#    'cariwra': 1,
#    'waMdri': 1,
#    'AKari': 1,
#    'civari': 1,
#    'Pibravari': 1,
#    'Retrieved': 1,
#    'mAriMxi': 1,
#    'kriwaM': 1,
#    'aMxarikI': 1,
#    'vArilo': 1,
#    'oVkasAri': 1,
#    'jarige': 1,
#    'vivariMcAru': 1,
#    'janavari': 1,
#    'eVvari': 1,
#    'epril': 1,
#    'prakriya': 1,
#    'goxAvari': 1,
#    'aXikAri': 1,
#    'pAriSrAmika': 1,
#    'civariki': 1,
#    'pariXilo': 1,
#    'kriMxa': 1,
#    'pawrika': 1,
#    'sarigA': 1,
#    'paricayaM': 1,
#    'peVrigiMxi': 1,
#    'description': 1,
#    'parisWiwulu': 1,
#    'Variable': 1,
#    'korika': 1,
#    'sariggA': 1,
#    'krikeVt': 1,
#    'cAriwraka': 1,
#    'waxupari': 1,
#    'marosAri': 1,
#    'parisWiwullo': 1,
#    'cariwralo': 1,
#    'vAriwo': 1,
#    'pariSrama': 1,
#    'eVvarikI': 1,
#    'ameVrikAlo': 1,
#    'vIriki': 1,
#    'eVvariki': 1,
#    'pariSoXana': 1,
#    'oVkkasAri': 1,
#    'aMxari': 1,
#    'kriMxi': 1,
#    'pariRkAraM': 1,
#    'ceriMxi': 1,
#    'xaggariki': 1,
#    'IsAri': 1,
#    'rikArdu': 1,
#    'pariXiloni': 1,
#    'perita': 1,
#    'jarigAyi': 1,
#    'wappanisari': 1,
#    'peVrigi': 1,
#    'prins': 1,
#    'koVbbari': 1,
#    'jarigiwe': 1,
#    'vIrilo': 1,
#    'wappanisarigA': 1,
#    'oVkkasArigA': 1,
#    'marinni': 1,
#    'marikoVnni': 1,
#    'parimiwaM': 1,
#    'Asupawri': 1,
#    'guriMcina': 1,
#    'britiR': 1,
#    'parisWiwini': 1,
#    'SAswri': 1,
#    'jaripina': 1,
#    'ixxari': 1,
#    'rahaxAri': 1,
#    'parikarAlu': 1,
#    'gAriki': 1,
#    'oVkesAri': 1,
#    'APrikA': 1,
#    'mAxirigA': 1,
#    'parimANaM': 1,
#    'ameVrikan': 1,
#    'pariSIlana': 1,
#    'pariSIliMci': 1,
#    'girijana': 1,
#    'paripAlana': 1,
#    'parisWiwulanu': 1,
#    'anusariMci': 1,
#    'pawrikalu': 1,
#    'saripowuMxi': 1,
#    'aXikArikaMgA': 1,
#    'iMjinIriMg\u200c': 1,
#    'iMjanIriMg': 1,
#    'moVxatisAri': 1,
#    'epril\u200c': 1,
#    'peVrigina': 1,
#    'cariwranu': 1,
#    'pariNAmaM': 1,
#    'rAjamaMdri': 1,
#    'sarihaxxu': 1,
#    'right': 1,
#    'parijFAnaM': 1,
#    'cerina': 1,
#    'guriMcI': 1,
#    'aMxariki': 1,
#    'kqwrima': 1,
#    'ameVrikAloni': 1,
#    'marikoVMxaru': 1,
#    'mArina': 1,
#    'aXikArika': 1,
#    'pariSramalu': 1,
#    'jarigi': 1,
#    'Upiri': 1,
#    'pariSoXanalu': 1,
#    'heVccariMcAru': 1,
#    'woVlisArigA': 1,
#    'maMwrigA': 1,
#    'parisWiwula': 1,
#    'SrIhari': 1,
#    'parisWiwulalo': 1,
#    'priya': 1,
#    'woVlisAri': 1,
#    'meVjAritI': 1,
#    'pariNAmAlu': 1,
#    'ripablik': 1,
#    'parisWiwilo': 1,
#    'XariMcina': 1,
#    'weVrici': 1,
#    'XariMci': 1,
#    'saripadA': 1,
#    'oVMtarigA': 1,
#    'pariSIliMcAru': 1,
#    'rijarveRanlu': 1,
#    'parigaNanaloki': 1,
#    'vIrini': 1,
#    'vivariMci': 1,
#    'prakriyanu': 1,
#    'harilo': 1,
#    'ammavAri': 1,
#    'mAxiri': 1,
#    'naMxamUri': 1,
#    'arXarAwri': 1,
#    'koVriyA': 1,
#    'pariSoXakulu': 1,
#    'AXAriwa': 1,
#    'marri': 1,
#    'jarigiMxani': 1,
#    'mariMwagA': 1,
#    'mAxirigAne': 1,
#    'pariSramala': 1,
#    'bArina': 1,
#    'saMcariMcu': 1,
#    'eVvarikEnA': 1,
#    'vEKari': 1,
#    'rAwriki': 1,
#    'sekariMci': 1,
#    'peVrige': 1,
#    'pawrikalo': 1,
#    'sArigA': 1,
#    'eriyA': 1,
#    'vyApAri': 1,
#    'gariRta': 1,
#    'nAgarikawa': 1,
#    'vivariMcAdu': 1,
#    'vAripE': 1,
#    'oVkkosAri': 1,
#    'oVkari': 1,
#    'sariki': 1,
#    'britan': 1,
#    'prakriyalo': 1,
#    'gArini': 1,
#    'cinnAri': 1,
#    'moVxatisArigA': 1,
#    'maMwriwva': 1,
#    'praXAnamaMwri': 1,
#    'siriyA': 1,
#    'svIkariMcina': 1,
#    'svIkariMci': 1,
#    'parisara': 1,
#    'cOxari': 1,
#    'parihAraM': 1,
#    'serif': 1,
#    'jarigiMxannAru': 1,
#    'jaripAru': 1,
#    'xArilo': 1,
#    'barilo': 1,
#    'xaggari': 1,
#    'iMjinIriMg': 1,
#    'aMxarinI': 1,
#    'pariNAmAla': 1,
#    'osAri': 1,
#    'pariXi': 1,
#    'viswariMci': 1,
#    'pariSoXanA': 1,
#    'bayaluxeri': 1,
#    'muKyamaMwrigA': 1,
#    'pariRaw': 1,
#    'kriwame': 1,
#    'pracuriMcina': 1,
#    'jaripi': 1,
#    'Asupawrilo': 1,
#    'pariRkArAniki': 1,
#    'seVkyUritI': 1,
#    'Buvanagiri': 1,
#    'eVvarini': 1,
#    'xarimilA': 1,
#    'jariginaxi': 1,
#    'pracuriMcAru': 1,
#    'sarAsari': 1,
#    'civarilo': 1,
#    'kristiyan': 1,
#    'pawrikA': 1,
#    'rilIj': 1,
#    'waMdriki': 1,
#    'Asupawriki': 1,
#    'vaccesariki': 1,
#    'rikArd': 1,
#    'APrikan': 1,
#    'seMxriya': 1,
#    'koriMxi': 1,
#    'vArixi': 1,
#    'parikarAla': 1,
#    'waMdrini': 1,
#    'parirakRaNa': 1,
#    'guriMce': 1,
#    'sarikoVwwa': 1,
#    'cesiri': 1,
#    'vyavahariswAru': 1,
#    'oVkariki': 1,
#    'oVkkarikI': 1,
#    'palleVtUri': 1,
#    'naRtaparihAraM': 1,
#    'vIrixxari': 2,
#    'mArinA': 1,
#    'rikArdulu': 1,
#    'parikarAlanu': 1,
#    'mariyU': 1,
#    'mAripoyiMxi': 1,
#    'peVrigAyi': 1,
#    'maleriyA': 1,
#    'ameVrikAku': 1,
#    'Uriki': 1,
#    'rikArdunu': 1,
#    'ixxarikI': 1,
#    'rijistreRan': 1,
#    'vyavahariswunnAru': 1,
#    'rijarveRanla': 1,
#    'xAsari': 1,
#    'paripAlanA': 1,
#    'arWarAwri': 1,
#    'vivariMce': 1,
#    'eVleVktrik': 1,
#    'prinseVs': 1,
#    'yAMwrika': 1,
#    'irigeRan': 1,
#    'nariki': 1,
#    'koVMxariki': 1,
#    'sirimalleV': 1,
#    'marikoVMwa': 1,
#    'pariNAmAlanu': 1,
#    'sirikoVMda': 1,
#    'Serif': 1,
#    'sariyEna': 1,
#    'cakri': 1,
#    'parimiwa': 1,
#    'nivAriMcadAniki': 1,
#    'rikArds': 1,
#    'mariyA': 1,
#    'pexarikaM': 1,
#    'racayiwri': 1,
#    'jarigexi': 1,
#    'vivariMcina': 1,
#    'pariSramalanu': 1,
#    'keMxramaMwri': 1,
#    'paripAlanalo': 1,
#    'pariSramalo': 1,
#    'rijalyURan': 1,
#    'parirakRaNaku': 1,
#    'suMxari': 1,
#    'reVMdosAri': 1,
#    'viswariMcAyi': 1,
#    'svIkariMcAru': 1,
#    'pariRaw\u200c': 1,
#    'parikaraM': 1,
#    'korikalu': 1,
#    'viswariMciMxi': 1,
#    'svAmivAri': 1,
#    'rikArdulanu': 1,
#    'jariginappudu': 1,
#    'sArvawrika': 1,
#    'aMwarikRa': 1,
#    'AviRkariMcAru': 1,
#    'Upiriwiwwula': 1,
#    'xAriwIsiMxi': 1,
#    'oVkarini': 1,
#    'vArigA': 1,
#    'vyavahariMce': 1,
#    'eVdAri': 1,
#    'viktoriyA': 1,
#    'wUrpugoxAvari': 1,
#    'bariloki': 1,
#    'maMgalYagiri': 1,
#    'Aspawriki': 1,
#    'vyavahariswunna': 1,
#    'anusariMce': 1,
#    'virivigA': 1,
#    'pariSoXanala': 1,
#    'xoVrikina': 1,
#    'jarigiMxo': 1,
#    'pariRkariMcAlani': 2,
#    'korina': 1,
#    'girijanulu': 1,
#    'koVMxarilo': 1,
#    'aMwyakriyalu': 1,
#    'ciwriMcina': 1,
#    'rilayans': 1,
#    'parice': 1,
#    'sekariMcina': 1,
#    'pawrikala': 1,
#    'allari': 1,
#    'rijarvu': 1,
#    'britiR\u200c': 1,
#    'aMgIkariMcina': 1,
#    'iMjinIriMg\u200clo': 1,
#    'peVrigiwe': 1,
#    'pariSramalaku': 1,
#    'parijFAnAnni': 1,
#    'aMgIkariMci': 1,
#    'tUrijaM': 1,
#    'aMgIkariMcAru': 1,
#    'vArixxarU': 1,
#    'wirigina': 1,
#    'gAyawri': 1,
#    'pariSIliMcina': 1,
#    'Seshagirirao': 1,
#    'harikqRNa': 1,
#    'vivariswU': 1,
#    'aMxariwo': 1,
#    'pariSIliswe': 1,
#    'veriyabul': 1,
#    'rijarv': 1,
#    'oVMtari': 1,
#    'ameVrikanlu': 1,
#    'siMhAxri': 1,
#    'britIR': 1,
#    'amarika': 1,
#    'ameVrikan\u200c': 1,
#    'rivars': 1,
#    'riport': 1,
#    'pariRkariMceMxuku': 2,
#    'xakRiNAPrikA': 1,
#    'koVMxari': 1,
#    'britIR\u200c': 1,
#    'svAmivAriki': 1,
#    'anusariMcAli': 1,
#    'kUwuri': 1,
#    'Urike': 1,
#    'savariMcu': 1,
#    'bayaluxeriMxi': 1,
#    'jariginA': 1,
#    'kriya': 1,
#    'bridji': 1,
#    'xAriwIswuMxi': 1,
#    'oVrijinal': 1,
#    'gAriwo': 1,
#    'cariwraku': 1,
#    'mAriMxani': 1,
#    'saripoye': 1,
#    'parisWiwiki': 1,
#    'iMjanIriMg\u200c': 1,
#    'janavarilo': 1,
#    'vArikI': 1,
#    'Aspawri': 1,
#    'wripura': 1,
#    'guri0ci': 1,
#    'britiRu': 1,
#    'wiraskariMcAru': 1,
#    'koVriyAlo': 1,
#    'neVraveriMxi': 1,
#    'anusariMcina': 1,
#    'sekariMcadAniki': 1,
#    'dOnlodmariMwa': 1,
#    'mEnAritI': 1,
#    'lahari': 1,
#    'niyaMwriMce': 1,
#    'original': 1,
#    'parigaNiswAru': 1,
#    'bAktIriyA': 1,
#    'sirisilla': 1,
#    'Xarmapuri': 1,
#    'peVrigipovadaM': 1,
#    'wIrina': 1,
#    'parimiwulanu': 1,
#    'kuxiriMxi': 1,
#    'aMxarini': 1,
#    'pawrikalalo': 1,
#    'kurisina': 1,
#    'priMt': 1,
#    'iMxriya': 1,
#    'xakRiNAPrikAlo': 1,
#    'priyA': 1,
#    'pariXiloki': 1,
#    'veVluvariMcAru': 1,
#    'weVluguvAri': 1,
#    'parisWiwulaku': 1,
#    'pAriSrAmikaMgA': 1,
#    'pAriSuxXyaM': 1,
#    'aMgIkariMciMxi': 1,
#    'rAwripUta': 1,
#    'parimiwamEMxi': 1,
#    'kRawriya': 1,
#    'maroVkariki': 1,
#    'rijistreRanlu': 1,
#    'Prinzessin': 1,
#    'ricard': 1,
#    'korikagA': 1,
#    'muriki': 1,
#    'sarikAxani': 1,
#    'vyavahariMcAli': 1,
#    'riyal': 1,
#    'pracuriMciMxi': 1,
#    'parimANAnni': 1,
#    'oVrissA': 1,
#    'eVvariwo': 1,
#    'xArilone': 1,
#    'heVccariMciMxi': 1,
#    'sIriyas': 1,
#    'vEKarini': 1,
#    'vAraMxarikI': 1,
#    'puraskariMcukoVni': 1,
#    'Wrillar': 1,
#    'mIrixxarU': 1,
#    'parigaNaloki': 1,
#    'unnavArini': 1,
#    'spriMg': 1,
#    'jarigAyani': 1,
#    'pexarikAnni': 1,
#    'skript': 1,
#    'heVccarikalu': 1,
#    'sarikAxu': 1,
#    'civarigA': 1,
#    'unnavAriki': 1,
#    'veVnuxirigi': 1,
#    'cariwralu': 1,
#    'xoVrikiMxi': 1,
#    'SrIvAri': 1,
#    'keriMwalu': 1,
#    'parimiwulu': 1,
#    'heVccarika': 1,
#    'lEbreriyan': 1,
#    'sAriMcAru': 1,
#    'usiri': 1,
#    'rightः0px': 1,
#    'Princess': 1,
#    'mAsapawrika': 1,
#    'cariwrakArulu': 1,
#    'paMxiri': 1,
#    'mugguriwo': 1,
#    'praXAnamaMwrigA': 1,
#    'pracuriwamEna': 1,
#    'saMhariMci': 1,
#    'jariginatlu': 1,
#    'yAxagiri': 1,
#    'puwrika': 1,
#    'aNagArina': 1,
#    'wirigiMxi': 1,
#    'Aviri': 1,
#    'wIrika': 1,
#    'mariyalu': 1,
#    'moVttamoVxatisArigA': 1,
#    'eVriksan': 1,
#    'girijanula': 1,
#    'saripoxu': 1,
#    'nAnnagAri': 1,
#    'eVvarinI': 1,
#    'avvAri': 1,
#    'riportiMg': 1,
#    'xoVrike': 1,
#    'pAwrikeyudu': 1,
#    'eVdArilo': 1,
#    'vacciri': 1,
#    'Urilo': 1,
#    'parisWiwulapE': 1,
#    'aristAtil': 1,
#    'rijistrAr': 1,
#    'pariRkArAlu': 1,
#    'svAmivArini': 1,
#    'kArina': 1,
#    'nAnnagAriki': 1,
#    'rijarveRanlanu': 1,
#    'triMg': 1,
#    'krismas': 1,
#    'eVgiri': 1,
#    'aWAritI': 1,
#    'vyavahariMcadaM': 1,
#    'aMxarilo': 1,
#    'anusariswAru': 1,
#    'pexarika': 1,
#    'avawariMciMxi': 1,
#    'kRawriyulu': 1,
#    'pariSuxXAwma': 1,
#    'ukkiri': 1,
# ...
#    'tieVs\u200cyutieVP\u200c': 1,
#    'raMgAcAryulu': 1,
#    'upAXyAyulugA': 1,
#    'reVgyularEjeRan': 1,
#    'mahAyugaM': 1,
#    'saMyukwarARtrAla': 1,
#    'janyuvulanu': 1,
#    'ayyuMdoVccu': 1,
#    'vixyucCakwi': 1,
#    'priyurAli': 1,
#    'ceyucunnAru': 1,
#    'mUsiyu': 1,
#    'upayukwa': 1,
#    'kqpAcAryudu': 1,
#    'priyudani': 1,
#    'priyurAlu': 1,
#    'yuxxaM': 1,
#    'viXeyulE': 1,
#    'dAkyumeVMt\u200cnu': 1,
#    'yuvakudi': 1,
#    'upAXyAyule': 1,
#    'yureniyaM': 1,
#    'vExyulanu': 1,
#    'eVrrannAyudu': 1,
#    'SaMkarAcAryudu': 1,
#    'yuvanewa': 1,
#    'yuMdiri': 1,
#    'yuxxAlalo': 1,
#    'diRyuM': 1,
#    'mariyayu': 1,
#    'yuvawanu': 1,
#    'vallaBarAyudupAdu': 1,
#    'veVxyulu': 1,
#    'naMxyupAKyAnamu': 1,
#    'vExyudu': 1,
#    'sahajavAyuvu': 1,
#    'prAyudi': 1,
#    'viXeyulamagutanu': 1,
#    'hyuginslu': 1,
#    'nIyulunu': 1,
#    'gibiyonIyudEna': 1,
#    'meronowIyudEna': 1,
#    'yuvaBeri': 1,
#    'kuyukwulu': 1,
#    'dAkyumeVMtarIlu': 1,
#    'dipyuteRan\u200c': 1,
#    'badiyunnAzdu': 1,
#    'saByulanU': 1,
#    'cAlYukyulanu': 1,
#    'pravahiMpajeyuvAdu': 1,
#    'praXAnopAXyAyula': 1,
#    'bAhuleyuzdu': 1,
#    'Xanyulawo': 1,
#    'anyAnyupapurANAni': 1,
#    'waWApyupAsanAsakwEH': 1,
#    'xeVliyu': 1,
#    'yuxxAlu': 1,
#    'ceyuvAni': 1,
#    'viSvasanIyuleVna': 1,
#    'imyunAlajI': 1,
#    'saByudEna': 1,
#    'gurwuceyu': 1,
#    'KAlYIceyutaku': 1,
#    'maracipovalasiyuMdunu': 1,
#    'yuxXa0': 1,
#    'AcaraNalukAlikyuletar': 1,
#    'prajAsvAmyayuwamEnaxi': 1,
#    'saByullagA': 1,
#    'yuvakunipE': 1,
#    'yuvawimqwaxehaMgA': 1,
#    'vexaXaryudu': 1,
#    'AyurxAyaMwo': 1,
#    'Awmayu': 1,
#    'sAkRyulani': 1,
#    'muKyulaku': 1,
#    'wIyuviXAnaM': 1,
#    'wIyuxuru': 1,
#    'ceVppiyunnAdu': 1,
#    'pakRajatAyu': 1,
#    'SabaryupaxeSa': 1,
#    'XqRtaxyumnaM': 1,
#    'SrIpraxyumnaM': 1,
#    'sakalasAmrAjyasuKAcyuwaM': 1,
#    'SrImaxacyuwaM': 1,
#    'BrAwqBiryuwa': 1,
#    'manuRyulaku': 1,
#    'agaswyulawo': 1,
#    'manuRyulni': 1,
#    'mAnyuskriptsa': 1,
#    'tiyudablyUjeV': 1,
#    'EjeVyu': 1,
#    'xayAmayudu': 1,
#    'viRayAXipawiyu': 1,
#    'manuRyulanuMdi': 1,
#    'eVs\u200ctiyu': 1,
#    'liyureVn': 1,
#    'girinAyudiki': 1,
#    'asmaxIyulni': 1,
#    'drAyu': 1,
#    'dayal\u200cyuvar\u200ckaleVktar': 1,
#    'xawwAwreyudu': 1,
#    'uMdakapoyuMdexi…moVwwAniki': 1,
#    'nemiyu': 1,
#    'mqwyuvAwa': 1,
#    'pralYayanAyudu': 1,
#    'mroyuwummeVxa': 1,
#    'SrIkumArAByuxayamu': 1,
#    'praxyumnoxayamu': 1,
#    'eVgjikyutiv': 1,
#    'pApyular': 1,
#    'yukwavayassulo': 1,
#    'nIwimaMwulaniyu': 1,
#    'pApulaniyu': 1,
#    'sOrARtrIyudu': 1,
#    'SAsanasaByula': 1,
#    'vaMSIyudu': 1,
#    'avixyayu': 1,
#    'annamAcAryulu': 1,
#    'keralYIyulaku': 1,
#    'vAyuvulugAnu': 1,
#    'sAyuXulu': 1,
#    'padiyuMduta': 1,
#    'yuMdina': 1,
#    'AyuXAlane': 1,
#    'kramaSikRaNAyuwamEna': 1,
#    'neVheVlAmIyudEna': 1,
#    'jeyumu': 1,
#    'sEnyamulakaXipawiyu': 1,
#    'mAdyuleRan': 1,
#    'priyurAlugA': 1,
#    'yuvawani': 1,
#    'AyuReVMwo': 1,
#    'rEkyunakicci': 1,
#    'viRayAnniyu': 1,
#    'kRawriyudani': 1,
#    'aByuwxAnama': 1,
#    'hanyus': 1,
#    'paryuRiwaM': 1,
#    'yukwAhAravihArasya': 1,
#    'yukwaceRtasya': 1,
#    'yukwasvapnAvaboXasya': 1,
#    'yuXAmanyuSca': 2,
#    'praxyumnude': 1,
#    'vixvawsaByulugA': 1,
#    'yulisis': 1,
#    'sveccAyuwa': 1,
#    'SiRyudiki': 1,
#    'niyuwAyuvu': 2,
#    'aRRUrIyudu': 1,
#    'bAXyulni': 1,
#    'yugAnni': 1,
#    'upAXyAyurAligA': 1,
#    'yusiE': 1,
#    'wudiciveyucunnAnu': 1,
#    'kRawriyudinAnI': 1,
#    'PiliRwIyulawo': 1,
#    'praXAnAcAryulu': 1,
#    'acyuwarAma': 1,
#    'acyuwarAmarAyali': 1,
#    'yuxXakRewraM': 1,
#    'niryuxXa': 1,
#    'nAtyAcAryulugAnI': 1,
#    '.mahimayu': 1,
#    'Ganawayu': 1,
#    'yAwyulbaNaM': 1,
#    'gaviyuduM': 1,
#    'cariwraaMwaryuxXaM': 1,
#    'iMdividyuval\u200c': 1,
#    'yunna': 1,
#    'vAyuswaMBanaM': 1,
#    'ceyucunna': 1,
#    'sAhiwIpriyula': 1,
#    'goVppacesiyunnAvu': 1,
#    'AwmIyulawo': 1,
#    'kaliyugamunaku': 1,
#    'SiRyulEna': 1,
#    'vaxAnyulu': 1,
#    'AyuRyaM': 1,
#    'SAsanasaByulanu': 1,
#    'yeVmukalanniyu': 1,
#    'samApwiceyuxuvu': 1,
#    'yuMdumu': 1,
#    'yunnavAda': 1,
#    'cinnamanAyudi': 1,
#    'cinnamanAyudu': 1,
#    'yupivAru': 1,
#    'nasaByulu': 1,
#    'sixXamEyunnaxi': 1,
#    'poliyu0dunu': 1,
#    'axiyunu': 1,
#    'kalugajeyune': 1,
#    'yusiji': 1,
#    'xahiMciveyunu': 1,
#    'veVldiMguceyu': 1,
#    'AyuXAlawo': 1,
#    'eyulo': 1,
#    'vargIyulEna': 1,
#    'BOXxamawAcAryudu': 1,
#    'heVbrIyula': 1,
#    'prapaMcayuxXa': 1,
#    'poyiyuMdeVnu': 1,
#    'nannayAryuni': 1,
#    'xIyuxuru': 1,
#    'sAmAnyulame': 1,
#    'naSiMpaceyunatlunu': 1,
#    'EgupwIyulu': 1,
#    'muKyudanna': 1,
#    'seyuta': 1,
#    'praXAnopAXyAyulugA': 1,
#    'yugosleviyA': 1,
#    'yuvAn': 1,
#    'mAnyul': 1,
#    'hagrIyula': 1,
#    'saByule': 1,
#    'weVliyutaःrAmakqRuni': 1,
#    'dablyutio': 1,
#    'upayukwaMgA': 1,
#    'pAlaswanIyulanu': 1,
#    'yuxXonmAxi': 1,
#    'awyunnamExani': 1,
#    'eVdyukeRanal': 1,
#    'nAtyAcAryulu': 1,
#    'joSyula': 1,
#    'mArYiyu': 1,
#    'yuxxaraMgaMloki': 1,
#    'rAyulYla': 1,
#    'dablyuheVc\u200co': 1,
#    'wasmaxIyulu': 1,
#    'vexavexyudEna': 1,
#    'puNyudagune': 1,
#    'niliciyuMdagA': 1,
#    'aMxamEnaviyu': 1,
#    'balisinaviyunEna': 1,
#    'meyucuMdeVnu': 1,
#    'mahaxevanAyudu': 1,
#    'aByuxayavAxulanu': 1,
#    'acceVnnAyudu': 1,
#    'yuxXamalla': 1,
#    'pyugotlu': 1,
#    'AcAryulumAXyama': 1,
#    'Palyul': 1,
#    'yuvawi”': 1,
#    'cEnIyulu': 1,
#    'yu0dutavalana': 1,
#    'kaliyuga': 1,
#    'yuMdunaxi': 1,
#    'ivanniyunu': 1,
#    'PiliRwIyulamIxa': 1,
#    'pravarAKyuni': 1,
#    'yupiloni': 1,
#    'guruvaryudanI': 1,
#    'suBaxrAcAryula': 1,
#    'sAyuXaMgAnU': 1,
#    'uMdavaxxaniyu': 1,
#    'veVlYlipovudaniyu': 1,
#    'yugaMbulaMxunu': 1,
#    'yugAnukUla': 1,
#    'reVgyulargA': 1,
#    'caliMciyunnaxani': 1,
#    'yuvawulugA': 1,
#    'vExyudEnA': 1,
#    'yuvakulArA': 1,
#    'yuvawaloni': 1,
#    'SiRyulaki': 1,
#    'vuMdavalayunu': 1,
#    'gawAyuXaSramaH': 1,
#    'vExyulaku': 1,
#    'vixyuwSakwi': 1,
#    'kRawriyunaku': 1,
#    'prANamulanniyu': 1,
#    'AMgleyulace': 1,
#    'vixyuxAveSamu': 1,
#    'manuRyulamenane': 1,
#    'maroVyu': 1,
#    'prapaMcayuxXaM': 1,
#    'bAXyudu': 1,
#    'klatsayut': 1,
#    'voyuy': 1,
#    'vaMgunaniyu': 1,
#    'nAlukayu': 1,
#    'cesiyunnAnu': 1,
#    'bayaluxeriyunnaxi': 1,
#    'tAbyular': 1,
#    'puwrikayu': 1,
#    'kArakawvaMAyuHkArakudu': 1,
#    'mqwyuxevawArAXAna': 1,
#    'viRavAyuvulu': 1,
#    'saxxUkayyulu': 1,
#    'braxikiyuMdagA': 1,
#    'lokAyukwanu': 1,
#    'saByullonU': 1,
#    'iMdividyuvAlitI': 1,
#    'yunnavi': 1,
#    'valayu': 1,
#    'saByudni': 1,
#    'seyucun': 1,
#    'leyucuMda': 1,
#    'SiSyudu': 1,
#    'janiMpajeyucu': 1,
#    'mahanIyude': 1,
#    'vixyuw\u200cRAk\u200cku': 1,
#    'yullo': 1,
#    'CaMxoyukwa': 1,
#    'niMxyuzdu': 1,
#    'barjanyuz': 1,
#    'guriyu': 1,
#    'yukwavayaskulu': 1,
#    'yuMtini': 1,
#    'musalivAdanEyunnAnu': 1,
#    'gOravanIyulEna': 1,
#    'weVliyucunnaxi': 1,
#    'povalasinaxaniyu': 1,
#    'mugiyusariki': 1,
#    'saByulaMxarU': 1,
#    'wIrcunaniyu': 1,
#    'mAnyulu': 1,
#    'anyula': 1,
#    'AMjaneyunivigrahaM': 1,
#    'vixyuxIkaraNawo': 1,
#    'vixyuwwIgalu': 1,
#    'narasiMhAcAryulavAru': 1,
#    'hyuwwamaHSloke': 1,
#    'niliciyuMduno': 1,
#    'yuMxuno': 1,
#    'mIremiyu': 1,
#    'simyuletar': 1,
#    'cUdavalayu': 1,
#    'AcAryulugA': 1,
#    'mahAkAyudEna': 1,
#    'sureR\u200crAyudu': 1,
#    'yuxXAnaMwaraM': 1,
#    'navayuvawI': 1,
#    'yuvakulalo': 1,
#    'romIyulu': 1,
#    '“manuRyulaku': 1,
#    'vixeSIyudu': 1,
#    'saByulaM': 1,
#    'yuxXAlU': 1,
#    'yuvawIyuvakula': 2,
#    'yuxXaraMgamannanU': 1,
#    'prajAsvAmyayuwa': 1,
#    'appalAcAryula': 1,
#    'aBAgyulu': 1,
#    'simyuleRan': 1,
#    'simyuleRan\u200clanu': 1,
#    'aduguwunnAru…sityuyeRan': 1,
#    'tyunIRiyA': 1,
#    'vAyuparamANuvuna': 1,
#    'anyulani': 1,
#    'wyuwwamaBakwi': 1,
#    'briyaMbuzxAlmiyun': 1,
#    'sanmawiyu': 1,
#    'vrAyabadiyunnaxi': 1,
#    'prajvarillunattiyu': 1,
#    'saByulnI': 1,
#    'yuMcukoVneVdivAru': 1,
#    'brawikiyunnA': 1,
#    'vAyuvuwonU': 1,
#    'viXeyudugA': 1,
#    'uMdavaleVnaniyu': 1,
#    'unnAraniyu': 1,
#    'niMdukoVniyunnAnu': 1,
#    'awyuwwamaMgA': 1,
#    'heVd\u200creVgyuletar': 1,
#    'awyuwwamEna': 1,
#    'niyuxXaSIlosmi': 1,
#    'AyuHpramANAnni': 1,
#    'lokAyukwa': 1,
#    'raNAxiwyudi': 1,
#    'acyuwa': 1,
#    'prekRakAcAryulu': 1,
#    'yunilIvar': 1,
#    'ceyutakannA': 1,
#    'myAkyulA': 1,
#    'XanaMjayuni': 1,
#    'paniceyuvAdu': 1,
#    'siEtiyulo': 1,
#    'ayurveda': 1,
#    'saByulenani': 1,
#    'yuvarAnar': 1,
#    'BariMciyuMdu': 1,
#    'niMxalikaWaMxadaviyunnAdu': 1,
#    'paraxeSIyullA': 1,
#    'kutuMbasaByulane': 1,
#    'ayuWAya': 1,
#    'AppalanAyuduwo': 1,
#    'sOmyudu': 1,
#    'pAxayuga': 1,
#    'marcayuwuM': 1,
#    'upAXyAyulU': 1,
#    'grAdyuvet': 1,
#    'ammonIyula': 1,
#    'yunnAnani': 1,
#    'koVlassayulaku': 1,
#    'manuRyulaMxariki': 1,
#    'mAnyudu': 1,
#    'mahAyuxXamu': 1,
#    'muKyulawo': 1,
#    'yuvakumAr': 1,
#    'moyuvAru': 1,
#    'samUhAXipawiyunEna': 1,
#    'senAXipawiyunEna': 1,
#    'amASAyunu': 1,
#    'yogyulu': 1,
#    'manuRyulamIxa': 1,
#    'jeVeVn\u200cyuku': 1,
#    'rAmAnujAcAryuni': 1,
#    'jiweMxriyulEna': 1,
#    'vyuwpawwulawopAtu': 1,
#    'upAXyAyudigA': 1,
#    'reVgyularEj\u200c': 1,
#    'avixyuxvAhakaM': 1,
#    'veVMdiyu': 1,
#    'AyuRkArakudayina': 1,
#    'aBimanyuni': 1,
#    'veciyuMdataM': 1,
#    'nilayudu': 1,
#    'yuvakavulu': 1,
#    'prayukwa': 1,
#    'yullAnu': 1,
#    'SreRTamEnaxiyu': 1,
#    'sWiramEnaxiyunEna': 1,
#    'sAmAnyudukAdani': 1,
#    'acyuwanna': 1,
#    'dablyupiE': 1,
#    'kAvalasiyuMdeVnu': 1,
#    'asAXyurAlu': 1,
#    'upAyuM': 1,
#    'BIRmAcAryudu': 1,
#    'yuxXaraMgaMlo': 1,
#    'iwyukwvA': 1,
#    'yuyeVn': 1,
#    'sAmAnyudane': 1,
#    'yuxXamunakE': 1,
#    'yeVMwayu': 1,
#    'annamAcAryulavAru': 1,
#    '2.vixyuxayaskAMwa': 1,
#    'sUryudU': 1,
#    'waraMgamulanniyu': 1,
#    'janyuSAswraM': 1,
#    'jFAnahqxayulaku': 1,
#    'koVriMxIyulaku': 1,
#    'xahanabaliyu': 1,
#    'vixyuxuwpawwini': 1,
#    'padhAmbhOjayugaLI': 1,
#    'yugalYI': 1,
#    'yuvarEwulu': 1,
#    'prAwaHsmaraNIyule': 1,
#    'hqxayulu': 1,
#    'aBAgyulanU': 1,
#    'jatAyuvuni': 1,
#    'Aryudu': 1,
#    'laMkeyulu': 1,
#    'yunnAru': 1,
#    'yukwamEna': 1,
#    'peVrmyuteRans': 1,
#    'pAduceyunu': 1,
#    'puraMjayudiwo': 1,
#    'aByunnawe': 1,
#    'xInudEyunna': 1,
#    'yunikoM': 1,
#    'sveCCAyuwa': 1,
#    'ASviyuja': 1,
#    'xqRtivixyuxuwpawwi': 1,
#    'prAXAnyaMvixyuwwu': 1,
#    'xqRtivixyuxuwpawiki': 1,
#    'nIcameVânaxaniyu': 1,
#    'niMdalayuMdu': 1,
#    'yueVs\u200cjieVs\u200c': 1,
#    'heyudu': 1,
#    'BArawIyudi': 1,
#    'SrIXarAcAryulu': 1,
#    'yuvakulanI': 1,
#    'ceyucuMdeVnu': 1,
#    'vAyunaMxanudeVna': 1,
#    'priyudavu': 1,
#    'kURIyulanu': 1,
#    'yuxXAnaMwaramuna': 1,
#    'AyurvexaMlo': 1,
#    'vajrAyuXaM': 1,
#    'karikyulaM': 1,
#    'moyAbIyulanu': 1,
#    'cAvavaleVnaniyu': 1,
#    'brawukavaccunaniyu': 1,
#    'seVlyulAyid\u200cpE': 1,
#    'xIkRAyogyudu': 1,
#    'nijyu': 1,
#    'dAkyumeVMtarIni': 1,
#    'sAXyulu': 1,
#    'ceyurIwini': 1,
#    'ceyunatlumAku': 1,
#    'reVveVnyu': 1,
#    'SiRyuni': 1,
#    'iSrAyelIyulu': 1,
#    'yurIvnA': 1,
#    'yogyudeVna': 1,
#    'yuvauxyamakArudu': 1,
#    'PasiyuxxIn': 1,
#    'yuxXamulo': 1,
#    'anuyAyulawo': 1,
#    'vixyuw\u200cki': 1,
#    'veVMkatrAmAnAyudu': 1,
#    'praXAnopAXyAyurAlu': 1,
#    'yuvanewalu': 1,
#    'vIXulanniyu': 1,
#    'eVpiyudablyUjeV': 1,
#    'prAwaःsmaraNIyudugA': 1,
#    'mqwyubAMdlu': 1,
#    'vAyuvegaMwo': 1,
#    'AcAryulU': 1,
#    'yuxXAnikEnA': 1,
#    'nirASrayulu': 1,
#    'BArawIyule': 1,
#    'saByulaMxarikI': 1,
#    'nappudacyuwuMdu': 1,
#    'gqwayugaMbunan': 1,
#    'xEwyuMdu': 1,
#    'yaxiyunIku': 1,
#    'karmaMbuseyu': 1,
#    'saByulaMwA': 1,
#    'nissahAyudavE': 1,
#    'SalyuNNi': 1,
#    'yuteVras\u200cku': 1,
#    'svarNayugaMgA': 1,
#    'saMyukwo': 1,
#    'eVs\u200cyuijad': 1,
#    'yuMdeVno': 1,
#    'weVliyajeyucunnAmu': 1,
#    'hqxayudugA': 1,
#    'yulanu': 1,
#    'hawamuceyunu': 1,
#    'yuxXamunaku': 1,
#    'yukeVji': 1,
#    'acyuwAnaMxa': 1,
#    'vExyudiwo': 1,
#    'upAXyAyulni': 1,
#    'pAScAwyulu': 1,
#    'yuxXavIrulanu': 1,
#    'yuxXamuceya': 1,
#    'ceVppavalayunA': 1,
#    'iMkyubeRan': 1,
#    'SlokayukwaMgA': 1,
#    'BArawIyulapE': 1,
#    'marATIyulanu': 1,
#    'pimmatavixyuwwu': 1,
#    'seVkyularijaM': 1,
#    'sa\u200cByulugAnI': 1,
#    'sa\u200cByulu': 1,
#    'yuxXatyAMkulu': 1,
#    'yuxXatyAMkula': 1,
#    'vExyuwa': 1,
#    'vixyuwkaNaM': 1,
#    'vixyuw\u200cSAKa': 1,
#    'yuvarANini': 1,
#    'kamyunijaM': 1,
#    'kRawriyulanu': 1,
#    'jayunaku': 1,
#    'SilAyugaM': 1,
#    'yukwiwo': 1,
#    'jayavijayulixxarikI': 1,
#    'rAyulYlu': 1,
#    'grIkuvExyudu': 1,
#    'vikramAxiwyudu': 1,
#    'vikramAxiwyuni': 1,
#    'SiRyudigA': 1,
#    'yogyudu': 1,
#    'vyAKyAyuwa': 1,
#    'nAyudupE': 1,
#    'vixyuwwunu': 1,
#    'vixyuxayaskAMwawvaM': 1,
#    'nAyudolYla': 1,
#    'avyayudavu': 1,
#    'agrAhyudavu': 1,
#    'cinmayudavu': 1,
#    'asamAnyudu': 1,
#    'veyucuMdina': 1,
#    'yuMdavaleVnu': 1,
#    'praXAnopADyAyudu': 1,
#    'janAByuxayAniki': 1,
#    'ceyuxuro': 1,
#    'mAXavAcAryula': 1,
#    'jarugavalasiyunnavi': 1,
#    'sUryudini': 1,
#    'nArAcaMxrabAbunAyudu': 1,
#    'AxarSanIyudu': 1,
#    'pAwrudavEyuMxuvu': 1,
#    'varcyulEj': 1,
#    'pUryulalo': 1,
#    'aMjaneyulu': 1,
#    'vExyuluMdAlsi': 1,
#    'cawurvAyuvulu': 1,
#    'mahanIyula': 1,
#    'niravaxyudu': 1,
#    'pilipiMciiSrAyelIyula': 1,
#    'povalayunu': 1,
#    'xeSamaMwayu': 1,
#    'jatAyupAka': 1,
#    'jyowiRyulu': 1,
#    'EeVn\u200ctiyusi': 1,
#    'saByulayina': 1,
#    'saByudipE': 1,
#    'vAyuxevuniki': 1,
#    'nirASrayulayyAru': 1,
#    'sunnayu': 1,
#    'priyulanu': 1,
#    'mqwyukuharAlu': 1,
#    'saByudigAnU': 1,
#    'velAxiSiRyula': 1,
#    'iSrAyelIyudu': 1,
#    'saMjayuniki': 1,
#    'uxayunini': 1,
#    'yukwulaku': 1,
#    'gilAxIyu': 1,
#    'yukwaMgA': 1,
#    'yupilo': 1,
#    'aBayAMjaneyudi': 1,
#    'yuXyawaswaxA': 1,
#    'rAyulYlaku': 1,
#    'saByude': 1,
#    'SAKAmAwyulu': 1,
#    'rAjyaparipAlanaceyu': 1,
#    'levIyulagu': 1,
#    'xvAparayugaM': 1,
#    'drAkyulAgAllanu': 1,
#    'nerakayunnaxAnano': 1,
#    'yuMdutakemi': 1,
#    'upayukwamayyAyi': 1,
#    'BAwyuxaye': 1,
#    'yuvawe': 1,
#    'iSrAyelIyulaku': 1,
#    'sUryudivo': 1,
#    'yugAlu': 1,
#    'supriyuni': 1,
#    'supriyudu': 1,
#    'narasiMhAcAryulu': 1,
#    'praXAnopAXyAyulaku': 1,
#    'anAryula': 1,
#    'kalimiyu': 1,
#    'priyudu': 1,
#    'sAyuXulE': 1,
#    'xIpwAnalArkaxyuwimaprameyam': 1,
#    'SiRyuniki': 1,
#    'rAmmUrwinAyudu': 1,
#    'mahammaxIyula': 1,
#    'yuMxumu': 1,
#    'mAnyulaMxarikI': 1,
#    'vrAsiyuMdiri': 1,
#    'yuvarAj\u200c': 1,
#    'rasawanmAwrayu': 1,
#    'AwmIyulanu': 1,
#    'kalugajeyunani': 1,
#    'weVliyu': 1,
#    'yuvars': 1,
#    'yukwavayasu': 1,
#    'jarmanIyula': 1,
#    'SiRyudini': 1,
#    'aBAgyula': 1,
#    'sraviMpaceyu': 1,
#    'XanyulaM': 1,
#    'jeVeVn\u200cyu': 1,
#    'sAmAnyuduni': 1,
#    'IAyurvexamu': 1,
#    'ceyumu': 1,
#    'adugutayu': 1,
#    'xvAparayugaMlonU': 1,
#    'muKyulu': 1,
#    'SiRyula': 1,
#    'praSiRyulu': 1,
#    'grAdyuyet\u200c': 1,
#    'malayu': 1,
#    'nmarYiyuz': 1,
#    'jeyucuMdirata': 1,
#    'vAyubakRA': 1,
#    'cANakyudu': 1,
#    'vixyuw\u200cwagilina': 1,
#    'eVs\u200cyusiE': 1,
#    'myusiyaMlu': 1,
#    'agragaNyudu': 1,
#    'nArAyaNAcAryulu': 1,
#    'saByuniki': 1,
#    'manaRyulace': 1,
#    'sAyuXarEwAMga': 1,
#    'bayoAyuXAlanu': 1,
#    'waggiMcavalayunu': 1,
#    'yugeVn\u200c': 1,
#    'ryulu': 1,
#    'kOtilyudu': 1,
#    'vExyulaMwA': 1,
#    'SaMkarAcAryulu': 1,
#    'rAmAnujAcAryulu': 1,
#    'XarmayuxXa': 1,
#    'bAXyulEna': 1,
#    'hyuMxay': 1,
#    'jarAyuH': 1,
#    'vExyulaMtunnAru': 1,
#    'ceVppabadiyunnaxi': 1,
#    'saMyukwarAshtrAla': 1,
#    'mqwyuvuku': 1,
#    'tiyas\u200cyutiyaP\u200c': 1,
#    'prAyudu': 1,
#    'piAr\u200ctiyu': 1,
#    'yuxXakAlaMlo': 1,
#    'nAlYikAyuwa': 1,
#    'podgnivaniyu': 1,
#    'aNuvixyuw': 1,
#    'brahmayu': 1,
#    'yuvawulu': 1,
#    'AyurvuxXi': 1,
#    'AyukRINaM': 1,
#    'rivyu': 1,
#    'niliciyuMdunu': 1,
#    'aNvAyuXAlu': 1,
#    'kArwikeyudu': 1,
#    'upAXyAyudilo': 1,
#    'aBimAnyula': 1,
#    'svecCAvAyuvulu': 1,
#    'AMgleyulaku': 1,
#    'brahmanAyudu': 1,
#    'jadavAyuvukAxu': 1,
#    'AyurxAyAnni': 1,
#    'sUryude': 1,
#    'AyurvexaMlonEnA': 1,
#    'pAraveyunu': 1,
#    'xehamaMwayu': 1,
#    'awyuwsAhAnni': 1,
#    'uBayula': 1,
#    'wanmayuNni': 1,
#    'sAmAnyulakunna': 1,
#    'subbArAyudu': 1,
#    'gajAyuwasawwvavIryaHwenAhqwAH': 1,
#    'gajAyuwasawwvavIryaH': 1,
#    'heVc\u200csIyuku': 1,
#    'yuxXaniki': 1,
#    'veVxyula': 1,
#    'jayudu': 1,
#    'jAwIyullonU': 1,
#    'priyurAligA': 1,
#    'priyuni': 1,
#    'kenIyulu': 1,
#    'kanijjIyulu': 1,
#    ...})]

# %%
# %%time
#split_matrix = numpy.ndarray((len(all_splits), len(pruned_probs)))
split_matrix = numpy.memmap('split_matrix.en.dat', dtype='float32', mode='w+', shape=(len(all_splits), len(pruned_probs)))
for si, split in enumerate(all_splits):
    #print(split)
    split_matrix[si] = 0
    for word, count in all_splits[split].items():
        wi = word2index(word)
        #print(word, wi)
        split_matrix[si, wi] = count
# Out:
# CPU times: user 52min 56s, sys: 24.9 s, total: 53min 21s
# Wall time: 54min 40s

# %%
split_matrix = numpy.memmap('split_matrix.en.dat', dtype='float32', mode='r')

# %%
a, b = len(all_splits), len(pruned_probs)
a, b, a * b, split_matrix.shape, split_matrix.shape[0] / a
split_matrix = split_matrix.reshape(a, int(split_matrix.shape[0] / a ))

# %%
split_list = list(all_splits.keys())
split2index = lambda w : split_list.index(w)
index2split = lambda i : split_list[i]
split2vec = lambda s : split_matrix[split2index(s)]

# %%
split2vec('ma')
# Out:
# memmap([ 0.,  0.,  0., ...,  0.,  0.,  0.], dtype=float32)

# %%
def delta_p(x, y):
    try:
        xi, yi = split2index(x), split2index(y)
    except Exception as e:
        #print(e)
        return numpy.NINF
    xp, yp = split_matrix[xi], split_matrix[yi]
    xpne, ypne = xp > 0, yp > 0
    cyp = ypne.sum()
    cxpyp = ((xpne) & (ypne)).sum()
    if cyp != 0:
        del_p = cxpyp/float(cyp)
    else:
        del_p = 0
    
    #print(del_p, cyp, cxpyp)
    if del_p > 0:
        del_p = -math.log(del_p)
    else:
        del_p = numpy.NINF
    
    ype = (yp == 0)
    cype = ype.sum()
    cxpype = ((xpne) & (ype)).sum()
    if cype != 0:
        del_p2 = cxpype / float(cype)
        if del_p2 != 0:                  
            del_p = del_p + math.log(del_p2)
    #print(del_p)
    return del_p
    #return -math.log(abs(del_p))

# %%
def run_sequence(sequence):
    scores = []
    for s in range(1, len(sequence)):
        x, y = sequence[s - 1], sequence[s]
        try:
            scores.append(delta_p(x, y))
        except Exception as e:
            print(e.with_traceback())
            pass
    return scores, sum(scores) / len(sequence)

# %%
#sorted_probs[40000:45000]

# %%
def walk_paths(pos_dict, rem, pos = 0):
    if rem == 0:
        return None
    if pos not in pos_dict:
        return None
    paths = []
    for split, p in pos_dict[pos]:
        if p[1] + 1 not in pos_dict:
            path = []
            path.append((split,p))
            paths.append(path)
            
        else:
            rem_path = walk_paths(pos_dict, rem = rem - p[1], pos = p[1] + 1)
            if rem_path:
                for r in rem_path:
                    paths.append([(split, p)] + r)
        
        
    return paths

from pprint import pprint
def get_split_sequences(token, max_N=4):
    splits = []
    for i in range(2, max_N+1):
        splits += list([(''.join(x), (j, j+i-1)) for j, x in enumerate(nltk.ngrams(list(token), i))])
    s_pos_dict = {}
    
    for split, pos in splits:
        if pos[0] not in s_pos_dict:
            s_pos_dict[pos[0]] = []
        s_pos_dict[pos[0]].append((split, pos))
    
    all_paths  = walk_paths(s_pos_dict, len(token), 0)
    paths = []
    for path in all_paths:
        if path[-1][1][1] == len(token) - 1:
            paths.append([x[0] for x in path])
    
    return paths

# %%
def score_sequences(sequences):
    scores = []
    for seq in sequences:
        score_f = run_sequence(seq)
        score_r= run_sequence(seq[::-1])
        score = (score_f[1] + score_r[1])/2
        scores.append(score)
    return scores

# %%
sequences = get_split_sequences('samayAniki',max_N=4)
sequences
# Out:
# [['sa', 'ma', 'yA', 'ni', 'ki'],
#  ['sa', 'ma', 'yA', 'niki'],
#  ['sa', 'ma', 'yAni', 'ki'],
#  ['sa', 'may', 'An', 'iki'],
#  ['sa', 'may', 'Ani', 'ki'],
#  ['sa', 'mayA', 'ni', 'ki'],
#  ['sa', 'mayA', 'niki'],
#  ['sam', 'ay', 'An', 'iki'],
#  ['sam', 'ay', 'Ani', 'ki'],
#  ['sam', 'ayA', 'ni', 'ki'],
#  ['sam', 'ayA', 'niki'],
#  ['sam', 'ayAn', 'iki'],
#  ['sama', 'yA', 'ni', 'ki'],
#  ['sama', 'yA', 'niki'],
#  ['sama', 'yAn', 'iki']]

# %%
scores = score_sequences(sequences) 
#scores
scores.index(max(scores))
# Out:
# 1

# %%
sequences[1], scores[1]
# Out:
# (['sa', 'ma', 'yA', 'niki'], -0.4086928204830215)

# %%
import copy
vowels = ['a', 'A', 'e', 'E', 'i', 'I', 'o', 'O', 'u', 'U']
words = copy.deepcopy(word_list)
#mport random 
#andom.shuffle(words)

# %%
words = [w for w in words if len(w) > 6]

# %%
words
# Out:
# ['warvAwa',
#  'uMtuMxi',
#  'guriMci',
#  'weVlaMgANa',
#  'praBuwvaM',
#  'ceVMxina',
#  'waruvAwa',
#  'weVlugu',
#  'mAwrame',
#  'vaccina',
#  'praBuwva',
#  'weVlipAru',
#  'praXAna',
#  'moVxati',
#  'ceVppAru',
#  'viRayaM',
#  'eVkkuva',
#  'viXaMgA',
#  'jarigina',
#  'kAbatti',
#  'aBivqxXi',
#  'vacciMxi',
#  'avakASaM',
#  'avasaraM',
#  'samayaMlo',
#  'moVwwaM',
#  'cesiMxi',
#  'lekuMdA',
#  'prakAraM',
#  'prawyeka',
#  'rAjakIya',
#  'praswuwaM',
#  'kAkuMdA',
#  'prajalu',
#  'ceyadaM',
#  'saMxarBaMgA',
#  'kevalaM',
#  'eVMxuku',
#  'kAMgreVs',
#  'aXikArulu',
#  'mariMwa',
#  'eVkkuvagA',
#  'veVMtane',
#  'jarigiMxi',
#  'ameVrikA',
#  'viRayaMlo',
#  'mAtlAduwU',
#  'wakkuva',
#  'jillAlo',
#  'saMbaMXiMcina',
#  'prajala',
#  'samAcAraM',
#  'kAraNaM',
#  'pUrwigA',
#  'xaggara',
#  'kAlaMlo',
#  'parisWiwi',
#  'awaniki',
#  'caryalu',
#  'porAtaM',
#  'muKyamaMwri',
#  'prapaMca',
#  'awyaMwa',
#  'ceyAlani',
#  'samayaM',
#  'eVnnikala',
#  'muMxuku',
#  'viduxala',
#  'malYlYI',
#  'vAlYlYu',
#  'caMxrabAbu',
#  'muKyaMgA',
#  'polIsulu',
#  'sWAnika',
#  'hExarAbAx',
#  'lakRala',
#  'eVMxukaMte',
#  'saMvawsaraM',
#  'sAXAraNaMgA',
#  'cariwra',
#  'koVMxaru',
#  'ippatike',
#  'jIviwaM',
#  'BArawIya',
#  'pAlgoVnnAru',
#  'sAmAjika',
#  'nAyakulu',
#  'cikiwsa',
#  'ceswAru',
#  'perkoVnnAru',
#  'ceswunnAru',
#  'xeSaMlo',
#  'samasya',
#  'BAgaMgA',
#  'weVlusu',
#  'eVlAMti',
#  'kAraNaMgA',
#  'Ayanaku',
#  'anaMwaraM',
#  'ceyadAniki',
#  'viRayAnni',
#  'veVlYli',
#  'viXAnaM',
#  'samasyalu',
#  'keMxraM',
#  'veVlYlYi',
#  'prAMwaMlo',
#  'sAXAraNa',
#  'ceswunna',
#  'ceswuMxi',
#  'sWAyilo',
#  'vaswuMxi',
#  'prajalaku',
#  'saByulu',
#  'migilina',
#  'pracAraM',
#  'itIvala',
#  'avuwuMxi',
#  'kaligina',
#  'koVraku',
#  'kAMgreVs\u200c',
#  'pramuKa',
#  'wIsukuni',
#  'pillalu',
#  'ceVppAdu',
#  'vixyArWulu',
#  'saMbaMXiMci',
#  'muMxugA',
#  'maMdalaM',
#  'aMwarjAwIya',
#  'kanIsaM',
#  'cUdaMdi',
#  'waxiwara',
#  'kAryakramaMlo',
#  'kaMpeVnI',
#  'aseVMblI',
#  'nirNayaM',
#  'aXyakRudu',
#  'xakRiNa',
#  'vyakwaM',
#  'rARtraMlo',
#  'viBajana',
#  'jaruguwuMxi',
#  'saMvawsarAla',
#  'rojullo',
#  'Pibravari',
#  'rAjaXAni',
#  'nepaWyaMlo',
#  'bayataku',
#  'Retrieved',
#  'avagAhana',
#  'aMxubAtulo',
#  'nirvahiMcAru',
#  'mAriMxi',
#  'nijAniki',
#  'vyavasWa',
#  'aMxarikI',
#  'unnappudu',
#  'xUraMgA',
#  'gawaMlo',
#  'prAMwAllo',
#  'eVkkada',
#  'sAyaMwraM',
#  'vivarAlu',
#  'eVppudU',
#  'uwpawwi',
#  'ippatikI',
#  'eVMpika',
#  'poVMxina',
#  'vijayaM',
#  'eVnnikallo',
#  'hExarAbAx\u200c',
#  'AXunika',
#  'saMsWalu',
#  'ceVppina',
#  'vAlYlYa',
#  'reVMdava',
#  'AMxolYana',
#  'racayiwa',
#  'aBiprAyaM',
#  'yeVhovA',
#  'oVkasAri',
#  'nirmANaM',
#  'AXAraMgA',
#  'viRayAlu',
#  'saMgawi',
#  'buXavAraM',
#  'rARtraM',
#  'praXAni',
#  'kutuMba',
#  'kAryaxarSi',
#  'vyakwigawa',
#  'praswuwa',
#  'moVxalu',
#  'uMdataM',
#  'SanivAraM',
#  'rAvadaM',
#  'ceyaMdi',
#  'koVMceVM',
#  'mArpulu',
#  'vivariMcAru',
#  'maxxawu',
#  'maroVka',
#  'eVppudu',
#  'AxivAraM',
#  'praBAvaM',
#  'ceVbuwunnAru',
#  'ceseMxuku',
#  'jIviwaMlo',
#  'jaruguwunna',
#  'janavari',
#  'pramAxaM',
#  'baMgAru',
#  'vuMtuMxi',
#  'lakRaNAlu',
#  'vyawirekaMgA',
#  'kanipiswuMxi',
#  'koVduku',
#  'spaRtaM',
#  'paWakaM',
#  'pakkana',
#  'kAryakramaM',
#  'sAMkewika',
#  'bAXyawa',
#  'nagaraM',
#  'prawyekaMgA',
#  'weVlaMgANalo',
#  'svayaMgA',
#  'uMtuMxani',
#  'parIkRa',
#  'gaMtala',
#  'weVlaMgANA',
#  'mugguru',
#  'sibbaMxi',
#  'nirvahaNa',
#  'veVnuka',
#  'prakatana',
#  'pArtIlu',
#  'SikRaNa',
#  'maXyalo',
#  'maMcixi',
#  'vaccAyi',
#  'prayawnaM',
#  'gurwiMpu',
#  'prakriya',
#  'saMbaMXaM',
#  'goxAvari',
#  'oVkavelYa',
#  'rUpaMlo',
#  'pillala',
#  'weVlisina',
#  'raMgaMlo',
#  'erpAtlu',
#  'uxyamaM',
#  'Alocana',
#  'saMbaMXiwa',
#  'ceyavaccu',
#  'muKyamEna',
#  'eVmmeVlye',
#  'ituvaMti',
#  'eVtuvaMti',
#  'peVlYli',
#  'prAraMBiMcAru',
#  'peVxxagA',
#  'lekapowe',
#  'rakRaNa',
#  'aXikAri',
#  'prAjeVktu',
#  'vaMtivi',
#  'waxiwarulu',
#  'kutuMbaM',
#  'samAveSaMlo',
#  'aXikaMgA',
#  'prakatiMcAru',
#  'guruvAraM',
#  'prAMwaM',
#  'avasaramEna',
#  'SarIraM',
#  'koVnugolu',
#  'pAriSrAmika',
#  'grAmINa',
#  'oVppaMxaM',
#  'uxAharaNaku',
#  'mahilYA',
#  'poyiMxi',
#  'mAnasika',
#  'prEvetu',
#  'rEwulaku',
#  'sWAnaMlo',
#  'weVlisiMxi',
#  'cesukuni',
#  'jIviwAnni',
#  'aMtunnAru',
#  'prapaMcaMlo',
#  'civariki',
#  'jillAloni',
#  'marovEpu',
#  'kAvadaM',
#  'gattigA',
#  'civaraku',
#  'uxyogaM',
#  'xaggaraku',
#  'prajalanu',
#  'weVliyaxu',
#  'saraParA',
#  'nAyakudu',
#  'avakASAlu',
#  'sAhiwyaM',
#  'puttina',
#  'AXvaryaMlo',
#  'saMgIwa',
#  'prAraMBaM',
#  'SukravAraM',
#  'cAlAmaMxi',
#  'aXikAra',
#  'pariXilo',
#  'vyApAra',
#  'weVluswoMxi',
#  'wIsukoVni',
#  'sUciMcAru',
#  'prAWamika',
#  'vyavasAya',
#  'prayawnAlu',
#  'ivvadaM',
#  'samAXAnaM',
#  'paScima',
#  'weVluguxeSaM',
#  'koVwwagA',
#  'oVwwidi',
#  'PaliwAlu',
#  'wappakuMdA',
#  'nIlYlYu',
#  'moVxata',
#  'eVvarEnA',
#  'pawrika',
#  'veVnakki',
#  'sahAyaM',
#  'saMvawsarAlu',
#  'neVmmaxigA',
#  'guMtUru',
#  'weVlugulo',
#  'aXikAraM',
#  'atuvaMti',
#  'praBuwvAniki',
#  'sAhiwya',
#  'prakqwi',
#  'vaccAru',
#  'vicAraNa',
#  'AMXrapraxeS',
#  'eVnnikalu',
#  'puswakaM',
#  'bijeVpi',
#  'weVlisiMxe',
#  'PaliwaMgA',
#  'rUpAyalu',
#  'paricayaM',
#  'somavAraM',
#  'grAmaMlo',
#  'maMxiki',
#  'wvaragA',
#  'pArtIki',
#  'vixyArWula',
#  'awyaXika',
#  'xUraMlo',
#  'PiryAxu',
#  'moVttamoVxati',
#  'sinimAlu',
#  'diseVMbar',
#  'sAmarWyaM',
#  'vixyArWulaku',
#  'vyakwulu',
#  'paluvuru',
#  'vijayavAda',
#  'sinimAlo',
#  'jAgrawwagA',
#  'vixyArWi',
#  'saMgIwaM',
#  'ceVppiMxi',
#  'nirvahiMcina',
#  'vaswunna',
#  'aXyayanaM',
#  'pattaNa',
#  'padding',
#  'hExarAbAx\u200clo',
#  'nagaraMlo',
#  'pillalaku',
#  'samAjaMlo',
#  'vyAsAlu',
#  'kalYASAla',
#  'ibbaMxulu',
#  'kramaMlo',
#  'moVxalEna',
#  'weVliyani',
#  'niyojakavargaM',
#  'waragawi',
#  'wakkuvagA',
#  'xarSakudu',
#  'waracugA',
#  'BojanaM',
#  'mArkeVt',
#  'samAcArAnni',
#  'ceVppAli',
#  'vaswAyi',
#  'prawiniXi',
#  'Bakwulu',
#  'maXyAhnaM',
#  'prapaMcaM',
#  'vyawireka',
#  'praNAlYika',
#  'koVMwamaMxi',
#  'kAryakramAlu',
#  'kUrcuni',
#  'aMxuvalla',
#  'ceVppavaccu',
#  'yUnivarsitI',
#  'pArtIlo',
#  'bAXyawalu',
#  'axanapu',
#  'spaRtaMgA',
#  'seVpteVMbar',
#  'peVrigiMxi',
#  'padiMxi',
#  'mAtlAdAru',
#  'appatike',
#  'saMKyalo',
#  'sUryudu',
#  'BArawaxeSaM',
#  'kumArudu',
#  'maMxulu',
#  'description',
#  'maMgalYavAraM',
#  'sAMskqwika',
#  'maMjUru',
#  'vaMxala',
#  'adigAdu',
#  'vixyuw\u200c',
#  'vimarSalu',
#  'SAswraM',
#  'nammakaM',
#  'parisWiwulu',
#  'kaRtAlu',
#  'mahilYalu',
#  'vArwalu',
#  'vaccAdu',
#  'saMvawsaraMlo',
#  'nyUs\u200ctude',
#  'Variable',
#  'maMdala',
#  'viBAgaM',
#  'maraNaM',
#  'saMyukwa',
#  'naluguru',
#  'wIvraMgA',
#  'kanipiswAyi',
#  'samAjaM',
#  'Ayananu',
#  'kAvaccu',
#  'vimarSiMcAru',
#  'upayogiMce',
#  'sImAMXra',
#  'default',
#  'samasyalanu',
#  'lakRyaM',
#  'xqRtilo',
#  'peVlYlYi',
#  'woVmmixi',
#  'cesukunna',
#  'maMwrulu',
#  'uMdAlani',
#  'vaxxaku',
#  'nijaMgA',
#  'oVkkate',
#  'saMGatana',
#  'sariggA',
#  'prayANaM',
#  'varaMgal',
#  'kAryAlayaM',
#  'peVttina',
#  'aMxiMce',
#  'nirmANa',
#  'sIniyar',
#  'axBuwamEna',
#  'uMdadaM',
#  'vivAhaM',
#  'eVnimixi',
#  'yUniyan',
#  'saMxarBaMlo',
#  'wIsukovAli',
#  'kaleVktar',
#  'niyaMwraNa',
#  'ibbaMxi',
#  'mimmalni',
#  'ArogyaM',
#  'prAXAnyawa',
#  'paxXawi',
#  'samAveSaM',
#  'KacciwaMgA',
#  'coVppuna',
#  'neVlala',
#  'krikeVt',
#  'nirmiMcina',
#  'aktobar',
#  'aXikAraMloki',
#  'gavarnar',
#  'Alocanalu',
#  'kalYlYu',
#  'pArtIla',
#  'viSvavixyAlayaM',
#  'cesukovAli',
#  'pATaSAla',
#  'peVttAru',
#  'uMdavaccu',
#  'cAriwraka',
#  'waxupari',
#  'eVppatikappudu',
#  'sWiwilo',
#  'cesukunnAru',
#  'praXAnaMgA',
#  'rAjInAmA',
#  'wIsukovAlani',
#  'janaral',
#  'balaMgA',
#  'pravakwa',
#  'wvaralo',
#  'marosAri',
#  'kAvadaMwo',
#  'aBivqxXiki',
#  'parisWiwullo',
#  'anuguNaMgA',
#  'anumawi',
#  'aMSAlanu',
#  'saMsWala',
#  'xaraKAswu',
#  'AropiMcAru',
#  'viRayAlanu',
#  'cariwralo',
#  'paryAvaraNa',
#  'xeSAniki',
#  'rARtrAniki',
#  'aMxuvalana',
#  'reVveVnyU',
#  'navaMbar',
#  'saMskqwi',
#  'vivarAlanu',
#  'rARtrAla',
#  'pariSrama',
#  'praBuwvAlu',
#  'cesukoVni',
#  'eVvarikI',
#  'carcalu',
#  'viXAnAnni',
#  'xevawalu',
#  'kaMpyUtar',
#  'cakkagA',
#  'parugulu',
#  'sawyanArAyaNa',
#  'BArawaxeSaMlo',
#  'xeSaMloni',
#  'praBAviwaM',
#  'peVxxalu',
#  'vyApwaMgA',
#  'grAmAniki',
#  'racanalu',
#  'ceVppadaM',
#  'SrImawi',
#  'paMpiNI',
#  'praSnalu',
#  'ameVrikAlo',
#  'neVlalo',
#  'ceVppAlaMte',
#  'jAgrawwa',
#  'kanipiMce',
#  'anuBavaM',
#  'aXinewa',
#  'anumAnaM',
#  'parIkRalu',
#  'prAMwAla',
#  'wIsukunna',
#  'praSniMcAru',
#  'eVvariki',
#  'dEreVktar',
#  'upayogiswAru',
#  'praxarSana',
#  'kyAnsar',
#  'jarmanI',
#  'prAcIna',
#  'weVlisi',
#  'AXArapadi',
#  'axanaMgA',
#  'anukUlaMgA',
#  'pariSoXana',
#  'vayassu',
#  'PaliwaM',
#  'aMxamEna',
#  'dimAMd\u200c',
#  'oVkkasAri',
#  'praWama',
#  'meVllagA',
#  'rARtraMloni',
#  'keMxraMlo',
#  'sixXaMgA',
#  'kAryAlayaMlo',
#  'kAvalasina',
#  'gamanArhaM',
#  'vargAla',
#  'lopaliki',
#  'sUcanalu',
#  'vunnAyi',
#  'wIsukovadaM',
#  'gurwiMci',
#  'vaccinappudu',
#  'paxArWAlu',
#  'ayyiMxi',
#  'kAryakarwalu',
#  'BaxrawA',
#  'baMgAraM',
#  'upayogiMci',
#  'waravAwa',
#  'viSeRaM',
#  'pariRkAraM',
#  'ceriMxi',
#  'Baxrawa',
#  'prayojanaM',
#  'viXAnAlu',
#  'wapassu',
#  'xaggariki',
#  'weVluswuMxi',
#  'paduwuMxi',
#  'eVMxaro',
#  'lakRalu',
#  'nArAyaNa',
#  'prAMwIya',
#  'cepattina',
#  'erpadiMxi',
#  'Bakwula',
#  'vAswavaM',
#  'pattukuni',
#  'dipyUtI',
#  'jaruguwoMxi',
#  'ciwraMlo',
#  'weVlipiMxi',
#  'BaviRyawwulo',
#  'kArmikulu',
#  'prAMwAlalo',
#  'nyUDillI',
#  'poVMxiMxi',
#  'awanini',
#  'nASanaM',
#  'xeSAllo',
#  'paMtalu',
#  'unnAyani',
#  'avinIwi',
#  'puruRulu',
#  'rakamEna',
#  'wallixaMdrulu',
#  'samayAniki',
#  'emitaMte',
#  'wirupawi',
#  'jillAku',
#  'kAvAlani',
#  'vesiMxi',
#  'rikArdu',
#  'maMdalaMlo',
#  'rAvadaMwo',
#  'puswakAlu',
#  'sAXiMcina',
#  'ceswAmani',
#  'weVlIxu',
#  'vAraMwA',
#  'maharRi',
#  'AXyAwmika',
#  'pariXiloni',
#  'eVmmeVlyelu',
#  'grAmAllo',
#  'kaleVktar\u200c',
#  'keMxrAlu',
#  'akkadiki',
#  'BAgaMlo',
#  'rUpoVMxiMcina',
#  'mAtlAde',
#  'kaluguwuMxi',
#  'sevalanu',
#  'anipiswuMxi',
#  'nirlakRyaM',
#  'ciraMjIvi',
#  'vyApAraM',
#  'nirmANAniki',
#  'jarigAyi',
#  'dAktar\u200c',
#  'rAkuMdA',
#  'uxyogula',
#  'rARtrAllo',
#  'aMxubAtuloki',
#  'prAraMBa',
#  'wappanisari',
#  'gaMtalaku',
#  'uxyogulu',
#  'alavAtu',
#  'SarIraMlo',
#  'cesinatlu',
#  'areVstu',
#  'meVrugEna',
#  'ayinappatikI',
#  'emAwraM',
#  'pAlakulu',
#  'koVnnisArlu',
#  'ceyalexu',
#  'prAMwAlaku',
#  'janmiMcina',
#  'gOravaM',
#  'sWAyiki',
#  'weVlusA',
#  'samAnaMgA',
#  'kAvAlaMte',
#  'peVttubadi',
#  'cesukuMxi',
#  'ceswoMxi',
#  'nivexika',
#  'vayasulo',
#  'rARtrAlu',
#  'SAswravewwalu',
#  'waginaMwa',
#  'nilabadi',
#  'hakkula',
#  'peVrigi',
#  'mahilYala',
#  'neVlalu',
#  'prakatiMciMxi',
#  'prawyekawa',
#  'ciwrAlu',
#  'koVbbari',
#  'xalYiwa',
#  'jUniyar',
#  'jillAllo',
#  'BAviMci',
#  'AstreliyA',
#  'jarigiwe',
#  'prapaMcavyApwaMgA',
#  'kAraNAlu',
#  'dabbulu',
#  'tIAr\u200ceVs',
#  'AnaMxaM',
#  'muMxugAne',
#  'viluvEna',
#  'pattukoVni',
#  'eVwwuna',
#  'pAwralu',
#  'ceswAyi',
#  'rakaMgA',
#  'lakRyaMgA',
#  'vyavasWanu',
#  'cesukuMtU',
#  'ceyataM',
#  'wappulu',
#  'cUdagAne',
#  'paMduga',
#  'pakkane',
#  '.........',
#  'rAjyAMga',
#  'awipeVxxa',
#  'miMcina',
#  'veVlugu',
#  'diseVMbaru',
#  'cesukovadaM',
#  'panicesina',
#  'appatlo',
#  'varusagA',
#  'pArlameVMtu',
#  'bayatiki',
#  'saMskqwa',
#  'veVnaka',
#  'rakarakAla',
#  'wappanisarigA',
#  'sAMGika',
#  'vANijya',
#  'wamilYa',
#  'wIvramEna',
#  'svAXInaM',
#  'gurwiMcAru',
#  'mukkalu',
#  'maMdalaMloni',
#  'saMxehaM',
#  'AxeSiMcAru',
#  'soviyat',
#  'sAmAnya',
#  'samuxra',
#  'panulanu',
#  'mahArARtra',
#  'viSvAsaM',
#  'Awmahawya',
#  'kesIAr\u200c',
#  'iMglIRu',
#  'peVttiMxi',
#  'caMxamAma',
#  'jaruguwuMxani',
#  'vegaMgA',
#  'oVkkasArigA',
#  'unnatlu',
#  'poliswe',
#  'anipiMciMxi',
#  'cakkani',
#  'vAwAvaraNaM',
#  'marinni',
#  'pATaSAlalo',
#  'neRanal',
#  'prawyakRa',
#  'praBuwvAnni',
#  'proVPeVsar',
#  'kramaMgA',
#  'xarSanaM',
#  'prasixXi',
#  'mahilYalaku',
#  'svawaMwra',
#  'saMpUrNa',
#  'paraMgA',
#  'prANAlu',
#  'vAwAvaraNa',
#  'nipuNulu',
#  'nirmiMcAru',
#  'DillIlo',
#  'grAmAla',
#  'subbArAvu',
#  'xaggaragA',
#  'xqRtiki',
#  'erpadina',
#  'vaccexi',
#  'samIpaMlo',
#  'vyavasWalo',
#  'veVlYlYe',
#  'saMxarBAllo',
#  'wIsukunnAru',
#  'uxAharaNa',
#  'meVxadu',
#  'kutuMbAniki',
#  'saMpaxa',
#  'kArmika',
#  'sOkaryaM',
#  'marikoVnni',
#  'aMxiswuMxi',
#  'waxvArA',
#  'navvuwU',
#  'prAwiniXyaM',
#  'icciMxi',
#  'parimiwaM',
#  'limiteVd',
#  'kAryakalApAlu',
#  'kAkapowe',
#  'aByarWulu',
#  'iMdiyan',
#  'upAXyAyulu',
#  'vijayavaMwaM',
#  'niraMwaraM',
#  'sinimAllo',
#  'Asupawri',
#  'avasarAlaku',
#  'peVttAdu',
#  'Bakwulaku',
#  'xevAlayaM',
#  'wappaxu',
#  'prajallo',
#  'saMbaMXAlu',
#  'eVxurugA',
#  'peVdiwe',
#  'paxXawilo',
#  'pAwralo',
#  'xarSakawvaM',
#  'iwarulu',
#  'prAMwAniki',
#  'eVkkadA',
#  'saMGatanalu',
#  'poVMxAru',
#  'baxulugA',
#  'ippativaraku',
#  'jAbiwAlo',
#  'sahAyaMwo',
#  'ciwrAniki',
#  'samIkRa',
#  'polIsula',
#  'cUsiMxi',
#  'hIroyin',
#  'uMdataMwo',
#  'pAkiswAn',
#  'lekapovadaMwo',
#  'lok\u200csaBa',
#  'cakkati',
#  'saMkRema',
#  'veVlladiMcAru',
#  'woVluwa',
#  'oVkappudu',
#  'kalYASAlalo',
#  'vaswuvulu',
#  'samarpayAmi',
#  'muMxaswu',
#  'kilomItarla',
#  'cesevAru',
#  'saMpraxAya',
#  'vimukwi',
#  'kArpoVreRan',
#  'aMxaMgA',
#  'keralYa',
#  'kaWanaM',
#  'saMGAlu',
#  'paWakAnni',
#  'guriMcina',
#  'peVruguwuMxi',
#  'koVxxigA',
#  'parisWiwini',
#  'paryatana',
#  'panicese',
#  'pAwranu',
#  'vixyuwwu',
#  'unnappatikI',
#  'rAnunna',
#  'samaswa',
#  'amarAvawi',
#  'neVlaku',
#  'lexaMte',
#  'saByula',
#  'pattaNaMlo',
#  'viRayamE',
#  'cUdatAniki',
#  'BinnaMgA',
#  'nivAsaM',
#  'samAveSAlu',
#  'wIsukune',
#  'AropaNalu',
#  'weVccina',
#  'xaraKAswulu',
#  'wirumala',
#  'adigina',
#  'leVkkalu',
#  'xaryApwu',
#  'cUswAru',
#  'sinimAnu',
#  'nirvahiMce',
#  'adugulu',
#  'SawAbxaMlo',
#  'lekapovadaM',
#  'SawAbxaM',
#  'perkoVnnAdu',
#  'samasyanu',
#  'piluswAru',
#  'ceyabadina',
#  'kumArweV',
#  'peVttukuni',
#  'bahiraMga',
#  'aMwekAkuMdA',
#  'SrInivAsarAvu',
#  'samAcAra',
#  'jaripina',
#  'menejar',
#  'background',
#  'pillalanu',
#  'AxeSAlu',
#  'suprIMkortu',
#  'moVxatlo',
#  'purAwana',
#  'laBiswuMxi',
#  'SrInivAs',
#  'vargAlu',
#  'paMcAyawI',
#  'soVMwaM',
#  'ceVbuwAru',
#  'nareMxra',
#  'maMxini',
#  'vyAXulu',
#  'saMxarBAlalo',
#  'viRayAniki',
#  'polIsulaku',
#  'ceVMxiMxi',
#  'mItarla',
#  'mUlaMgA',
#  'samasyala',
#  'eVnnika',
#  'cerukunna',
#  'rahaxAri',
#  'aMxukani',
#  'nirasana',
#  'aByarWi',
#  'uxyogulaku',
#  'sulaBaMgA',
#  'parikarAlu',
#  'warvAwe',
#  'teVknAlajI',
#  'iMtarneVt',
#  'varRAlu',
#  'aXikArulanu',
#  'krEswava',
#  'gaMtalu',
#  'parIkRala',
#  'sWAnAnni',
#  'ceyakuMdA',
#  'prawyekiMci',
#  'anuvAxaM',
#  'aXikArula',
#  'prAmuKyawa',
#  'rAvataM',
#  'vivaraNa',
#  'yaMwrAMgaM',
#  'paviwra',
#  ...]

# %%
# %%time
patterns = {}
for w in words[:500]:
    splits = get_split_sequences(w)
    scores = score_sequences(splits)
    max_split = splits[scores.index(max(scores))]
    for s in max_split:
        pat = ''.join(['v' if x in vowels else 'c' for x in s])
        if pat not in patterns:
            patterns[pat] = 0
        patterns[pat] += 1
# Out:
# CPU times: user 21.4 s, sys: 725 ms, total: 22.1 s
# Wall time: 45 s

# %%
sorted(patterns.items(), key = lambda x : x[1], reverse=True)
# Out:
# [('cv', 760),
#  ('vc', 273),
#  ('cvc', 196),
#  ('cc', 132),
#  ('ccv', 104),
#  ('vcv', 97),
#  ('cvcc', 45),
#  ('cvcv', 39),
#  ('vcc', 27),
#  ('vccv', 21),
#  ('ccvc', 16),
#  ('vcvc', 9),
#  ('vccc', 5),
#  ('cccv', 3),
#  ('ccc', 3),
#  ('cccc', 2)]

# %%
def get_max_split(w):
    splits = get_split_sequences(w)
    scores = score_sequences(splits)
    max_split = splits[scores.index(max(scores))]
    return max_split

# %%
get_max_split('samayaM')
# Out:
# ['sa', 'ma', 'yaM']

# %%
import random
random.shuffle(words)
sample_words = words[:1000]

# %%
# %%time
max_splits = {}
for i, w in enumerate(sample_words):
    try:
        sp = get_max_split(w)
        max_splits[w] = sp
        if i % 100 == 0:
            print(f"{i} done")
    except:
        pass
# Out:
# 0 done
# 100 done
# 200 done
# 300 done
# 400 done
# 500 done
# 600 done
# 700 done
# 800 done
# 900 done
# CPU times: user 24min 2s, sys: 1.69 s, total: 24min 4s
# Wall time: 25min 33s

# %%
max_splits
# Out:
# {'nunnAru': ['nu', 'nn', 'Aru'],
#  'moyadaM': ['mo', 'ya', 'daM'],
#  'vaMgilekapovadaM': ['va', 'Mg', 'ile', 'ka', 'po', 'va', 'daM'],
#  'maguvalaku': ['ma', 'gu', 'vala', 'ku'],
#  'veVlYlYakuMdA': ['veV', 'lY', 'lY', 'ak', 'uM', 'dA'],
#  'kAmAMXurAligA': ['kAm', 'AM', 'Xu', 'rA', 'li', 'gA'],
#  'vIdkoVlipAdu': ['vId', 'koV', 'li', 'pA', 'du'],
#  'AnupAnulu': ['Anup', 'An', 'ulu'],
#  'gArdeVns': ['gA', 'rd', 'eV', 'ns'],
#  'sureR\u200cku': ['su', 're', 'R\u200c', 'ku'],
#  'vrawAnni': ['vra', 'wA', 'nni'],
#  'vaMSAniki': ['vaM', 'SA', 'niki'],
#  'bayograPI': ['bay', 'og', 'ra', 'PI'],
#  'galavAriwo': ['ga', 'la', 'vAri', 'wo'],
#  'guddipeVlYlAnni': ['gu', 'ddi', 'peV', 'lYl', 'Anni'],
#  'vismayAniki': ['vis', 'ma', 'yA', 'niki'],
#  'nyUjilAMd\u200cpE': ['ny', 'Ujil', 'AM', 'd\u200c', 'pE'],
#  'puwrudilA': ['puw', 'ru', 'di', 'lA'],
#  'adugupeVttabovadaM': ['ad', 'ug', 'up', 'eV', 'tta', 'bo', 'va', 'daM'],
#  'kodandaramuluswamitemple': ['ko',
#   'dand',
#   'ar',
#   'amu',
#   'lusw',
#   'am',
#   'ite',
#   'mp',
#   'le'],
#  'weVliyaMxe': ['weV', 'li', 'ya', 'Mxe'],
#  'ceVppukogaligina': ['ceVp', 'pu', 'ko', 'ga', 'li', 'gi', 'na'],
#  'ceyiMcAru': ['cey', 'iMcA', 'ru'],
#  'xarimilYA': ['xari', 'mi', 'lYA'],
#  'vicAriMcAlo': ['vi', 'cA', 'ri', 'McA', 'lo'],
#  'gAdpuwoz': ['gA', 'dpuw', 'oz'],
#  'teMdarlu': ['te', 'Md', 'ar', 'lu'],
#  'vqkRAla': ['vqkR', 'Ala'],
#  'koVdavalYlYa': ['ko', 'Vd', 'ava', 'lY', 'lYa'],
#  'samakUruswuMxi': ['sam', 'ak', 'Uru', 'swu', 'Mxi'],
#  'vAreVMt': ['vAr', 'eVMt'],
#  'wallilA': ['wa', 'll', 'ilA'],
#  'bijineVs\u200cnu': ['bij', 'in', 'eVs\u200c', 'nu'],
#  'parirakRakudigA': ['par', 'ir', 'ak', 'Raku', 'di', 'gA'],
#  'eVkkuvavuwuMxemo”': ['eVk', 'ku', 'va', 'vuwu', 'Mx', 'emo”'],
#  'koVttiMci': ['ko', 'Vtt', 'iMci'],
#  'byAtarI': ['byA', 'ta', 'rI'],
#  'cUpiMcatAniko': ['cUp', 'iMc', 'at', 'An', 'iko'],
#  'lobadinaxigA': ['lo', 'badi', 'na', 'xi', 'gA'],
#  'iMjanIrla': ['iMj', 'an', 'Ir', 'la'],
#  'maccuwunaka': ['ma', 'ccu', 'wun', 'aka'],
#  'kadagataM': ['kad', 'ag', 'ataM'],
#  'eVnnAlYlugAno': ['eVn', 'nA', 'lY', 'lu', 'gA', 'no'],
#  'uMdadaMsAmAjika': ['uMda', 'da', 'MsAm', 'Aj', 'ika'],
#  'sXApanaku': ['sX', 'Ap', 'ana', 'ku'],
#  'peVxavulAniMci': ['peV', 'xa', 'vul', 'Ani', 'Mci'],
#  'eVMpikaceyagA': ['eV', 'Mp', 'ika', 'ceya', 'gA'],
#  'baMwuleyAlaMtene': ['baM', 'wu', 'le', 'yAla', 'Mte', 'ne'],
#  'svAwaMwyra': ['sv', 'Aw', 'aM', 'wyra'],
#  'kidnAp\u200c': ['ki', 'dnA', 'p\u200c'],
#  'BojyeRu': ['Boj', 'ye', 'Ru'],
#  'sOBrAwqwva': ['sOBr', 'Aw', 'qw', 'va'],
#  'mAriRas\u200c': ['mA', 'ri', 'Ras\u200c'],
#  'pagetitlefont': ['pag', 'et', 'it', 'lefo', 'nt'],
#  'manasaMwA': ['ma', 'na', 'saM', 'wA'],
#  'Upiriwiwwulaku': ['Up', 'ir', 'iw', 'iw', 'wu', 'laku'],
#  'ceyaleka': ['ce', 'ya', 'le', 'ka'],
#  'samIpiswunnappudu': ['sam', 'Ipis', 'wu', 'nn', 'ap', 'pu', 'du'],
#  'aggiweVgulu': ['agg', 'iw', 'eV', 'gulu'],
#  'jilakaramma': ['ji', 'la', 'kar', 'amma'],
#  'wIsukonivaswAru': ['wIs', 'uk', 'on', 'iv', 'as', 'wAru'],
#  'xaSAbxAlunnAnu': ['xa', 'SA', 'bx', 'Al', 'unnA', 'nu'],
#  'nirasanalu': ['nir', 'as', 'an', 'alu'],
#  'eVkkadiko': ['eVk', 'ka', 'di', 'ko'],
#  'megnatik': ['me', 'gnat', 'ik'],
#  'koVlawalU': ['koV', 'la', 'walU'],
#  'guddivAdigA': ['gu', 'dd', 'iv', 'Ad', 'igA'],
#  'rameS\u200cwo': ['ra', 'meS\u200c', 'wo'],
#  'steRan\u200cbeVyil': ['st', 'eR', 'an', '\u200cb', 'eV', 'yil'],
#  'neVravercu': ['neVr', 'av', 'ercu'],
#  'vyarWaM': ['vy', 'ar', 'WaM'],
#  'aNuvulu': ['aN', 'uv', 'ulu'],
#  'vyAsaBagavAnudu': ['vyA', 'saB', 'ag', 'av', 'Anu', 'du'],
#  'brahmaraWaM': ['br', 'ah', 'mar', 'aW', 'aM'],
#  'prapaMcavyApwa': ['pr', 'ap', 'aM', 'cavy', 'Ap', 'wa'],
#  'oeVs\u200ceVs\u200c': ['oe', 'Vs\u200c', 'eV', 's\u200c'],
#  'vikasiMce': ['vik', 'as', 'iMce'],
#  'nItisaraParA': ['nIti', 'sa', 'ra', 'Pa', 'rA'],
#  'liMgamunakeVxurugA': ['liMg', 'am', 'un', 'ak', 'eV', 'xu', 'ru', 'gA'],
#  'pArtIlakU': ['pAr', 'tI', 'la', 'kU'],
#  'anipiMcukunna': ['an', 'ip', 'iMc', 'ukun', 'na'],
#  'koVmmukAswunnArani': ['koV', 'mm', 'uk', 'Asw', 'unnA', 'ra', 'ni'],
#  'sWirapadAlanukune': ['sWi', 'ra', 'pad', 'Ala', 'nu', 'ku', 'ne'],
#  'nirvANamu': ['nir', 'vA', 'Namu'],
#  'wanavigA': ['wa', 'na', 'vi', 'gA'],
#  'bildarlu': ['bil', 'da', 'rlu'],
#  'wIruwuMxA': ['wI', 'ru', 'wuM', 'xA'],
#  'yantIAr\u200c': ['yan', 'tI', 'Ar\u200c'],
#  'karmasWAnamaMxuMdi': ['kar', 'ma', 'sWAn', 'am', 'aM', 'xu', 'Mdi'],
#  'cIkiMxi': ['cI', 'ki', 'Mxi'],
#  'mabbula': ['ma', 'bbu', 'la'],
#  'braRiMg': ['braR', 'iMg'],
#  'peraMtAlu…ammavAri': ['pe', 'raMt', 'Al', 'u…am', 'ma', 'vAri'],
#  'nannaneVnA': ['nann', 'an', 'eVnA'],
#  'kUrcunnAru': ['kUrc', 'un', 'nA', 'ru'],
#  'yaSoxamma': ['yaSo', 'xa', 'mma'],
#  'eVMeVs\u200ckeV': ['eV', 'MeVs', '\u200ck', 'eV'],
#  'annaxAwaku': ['anna', 'xA', 'waku'],
#  'rAjarAjanareMvUxuni': ['rAja', 'rA', 'jan', 'ar', 'eMvU', 'xu', 'ni'],
#  'sAhiwIlokamuna': ['sA', 'hi', 'wI', 'lo', 'ka', 'mu', 'na'],
#  'ArtistugA': ['Ar', 'ti', 'stu', 'gA'],
#  'wArakAsura': ['wAra', 'kA', 'su', 'ra'],
#  '20maMxi': ['20m', 'aM', 'xi'],
#  'polIsolYlaM': ['pol', 'Isol', 'Yl', 'aM'],
#  'moVttikAya': ['mo', 'Vtt', 'ikA', 'ya'],
#  'kAtakAlawo': ['kAta', 'kA', 'lawo'],
#  'yawavrawaH': ['yaw', 'av', 'raw', 'aH'],
#  'avamAnavaruswU': ['av', 'am', 'An', 'ava', 'ru', 'swU'],
#  'uwwaraxiSa': ['uwwa', 'ra', 'xiSa'],
#  'xakRiNamaXya': ['xa', 'kRi', 'Na', 'maX', 'ya'],
#  'kewuxaSa': ['ke', 'wu', 'xaSa'],
#  'eVMeVs\u200cpIni': ['eVM', 'eV', 's\u200cpI', 'ni'],
#  'SikRaNA': ['Si', 'kR', 'aNA'],
#  'yerpadatAniki': ['yer', 'pa', 'da', 'tA', 'ni', 'ki'],
#  'kArpoVreRan\u200c': ['kA', 'rp', 'oV', 're', 'Ran\u200c'],
#  'polikanu': ['pol', 'ik', 'anu'],
#  'parimiwamayyAyi': ['pa', 'ri', 'mi', 'wa', 'ma', 'yy', 'Ayi'],
#  'raMgaMpE': ['ra', 'Mg', 'aMpE'],
#  'pAkiMxi': ['pA', 'ki', 'Mxi'],
#  'minappappunu': ['mi', 'nap', 'pa', 'ppu', 'nu'],
#  'mIveVnaka': ['mIve', 'Vn', 'aka'],
#  'awmahawyalu': ['aw', 'ma', 'ha', 'wy', 'alu'],
#  'vimuKudavE': ['vi', 'mu', 'Kuda', 'vE'],
#  'nAtakAllo': ['nA', 'ta', 'kAl', 'lo'],
#  'Bertrand': ['Be', 'rt', 'ra', 'nd'],
#  'mAsaMlonU': ['mA', 'saM', 'lo', 'nU'],
#  'ceswunnappudu': ['ce', 'sw', 'unn', 'ap', 'pu', 'du'],
#  'cUpiMcesariki': ['cUp', 'iMc', 'es', 'ar', 'iki'],
#  'caMxramohan': ['ca', 'Mx', 'ra', 'moh', 'an'],
#  'veVXavapani': ['veV', 'Xa', 'va', 'pani'],
#  'caMxrulu': ['ca', 'Mx', 'ru', 'lu'],
#  'sAhiwyavAxulu': ['sAh', 'iw', 'ya', 'vA', 'xu', 'lu'],
#  'xuswulane': ['xu', 'sw', 'ula', 'ne'],
#  'rajanIkAMw\u200c': ['raj', 'an', 'Ik', 'AM', 'w\u200c'],
#  'Sa\u200cwAXikaMgA': ['Sa\u200cw', 'AXi', 'ka', 'MgA'],
#  'saccciwsuKoxBoXakaM': ['sa', 'ccci', 'wsuK', 'oxBo', 'Xa', 'kaM'],
#  'mahABAgyaM': ['ma', 'hAB', 'Ag', 'yaM'],
#  'vunnalAti': ['vunn', 'al', 'Ati'],
#  'gurwoVcciMxi': ['gu', 'rwoV', 'cc', 'iMxi'],
#  'ixxAmanna': ['ixxA', 'ma', 'nna'],
#  'xuRtAmla': ['xu', 'RtAm', 'la'],
#  '00:10:29': ['00', ':10:', '29'],
#  'gqhAnirmANa': ['gqh', 'An', 'ir', 'mA', 'Na'],
#  'kummuwunnAdu…': ['kum', 'mu', 'wunn', 'Ad', 'u…'],
#  'mAdyUl\u200cwo': ['mA', 'dyU', 'l\u200c', 'wo'],
#  'cleaver': ['cle', 'av', 'er'],
#  'a0wyaxinAla': ['a0wy', 'ax', 'inA', 'la'],
#  'spaRtame': ['spa', 'Rt', 'ame'],
#  'vacciMxo': ['va', 'cc', 'iM', 'xo'],
#  'viXiswAru': ['viX', 'iswA', 'ru'],
#  'vaccinanu': ['vacc', 'in', 'anu'],
#  'sajjalapalleV': ['sa', 'jj', 'al', 'ap', 'all', 'eV'],
#  'vAralakopaMbunaMgUlaM': ['vAra',
#   'la',
#   'kop',
#   'aMb',
#   'un',
#   'aM',
#   'gUl',
#   'aM'],
#  'gaMXarvuNNi': ['gaM', 'Xa', 'rvuN', 'Ni'],
#  'mosaMlo': ['mo', 'saM', 'lo'],
#  'pepar\u200c1': ['pe', 'pa', 'r\u200c1'],
#  '“miwrulu': ['“miw', 'rulu'],
#  'rAkapovaccu': ['rA', 'ka', 'po', 'va', 'ccu'],
#  'nAtakAlloni': ['nA', 'ta', 'kA', 'llo', 'ni'],
#  'kAyalanu': ['kAya', 'lanu'],
#  'leVkkaki': ['le', 'Vkka', 'ki'],
#  'viMtimo': ['vi', 'Mti', 'mo'],
#  'varjasvaramunu': ['va', 'rjas', 'va', 'ra', 'munu'],
#  'kaligiMcani': ['kal', 'ig', 'iMc', 'ani'],
#  'ketAyiMcanunnattu': ['ketA', 'yi', 'Mc', 'anu', 'nn', 'attu'],
#  'eVrresu': ['eVr', 're', 'su'],
#  'AMwrAknos\u200c': ['AM', 'wr', 'Ak', 'nos\u200c'],
#  'AxaraNaSIli': ['Ax', 'ar', 'aNa', 'SIli'],
#  'pUrvIkulu': ['pUr', 'vI', 'ku', 'lu'],
#  'Worldwide': ['Wor', 'ld', 'wi', 'de'],
#  'prAmANikaM': ['pr', 'Am', 'AN', 'ik', 'aM'],
#  'vaccinave': ['vacc', 'in', 'ave'],
#  'pracuraNakarwa': ['pra', 'cu', 'raN', 'ak', 'ar', 'wa'],
#  'XyAniMci': ['Xy', 'An', 'iMci'],
#  'kutuMbAlawo': ['ku', 'tu', 'Mb', 'Ala', 'wo'],
#  'UxAraMgugA': ['Ux', 'Ara', 'Mgu', 'gA'],
#  'mUdu.1.': ['mU', 'du', '.1.'],
#  'eVluguku': ['eV', 'lug', 'uku'],
#  'xEvavAkyaM': ['xEv', 'av', 'Ak', 'yaM'],
#  'sixXamavuwoMxi': ['si', 'xXa', 'ma', 'vu', 'wo', 'Mxi'],
#  'imitet\u200c': ['im', 'it', 'et\u200c'],
#  'annAgAri': ['ann', 'AgA', 'ri'],
#  'BArgavi': ['BAr', 'ga', 'vi'],
#  'nAcarenmEWunaM': ['nA', 'ca', 're', 'nmEW', 'un', 'aM'],
#  'areVstulaku': ['ar', 'eV', 'st', 'ula', 'ku'],
#  'nAgaddaMkUdA': ['nA', 'gadd', 'aM', 'kUdA'],
#  'wAgAvukaxA”': ['wA', 'gA', 'vu', 'ka', 'xA”'],
#  'instityut': ['ins', 'ti', 'ty', 'ut'],
#  'paMtegAni': ['paM', 'te', 'gA', 'ni'],
#  'praswAvicadaM': ['pra', 'sw', 'Av', 'ica', 'daM'],
#  'vAl\u200cloni': ['vAl', '\u200clo', 'ni'],
#  'subject': ['subj', 'ect'],
#  'Pijik\u200c\u200csa': ['Pi', 'ji', 'k\u200c\u200c', 'sa'],
#  'pAvanaM': ['pA', 'va', 'naM'],
#  'suxarSanAniki': ['sux', 'ar', 'Sa', 'nA', 'niki'],
#  'reVn\u200cmin\u200c': ['reV', 'n\u200cmi', 'n\u200c'],
#  'vyAleVt\u200c': ['vy', 'Al', 'eVt\u200c'],
#  'anipiswAyi': ['an', 'ip', 'iswA', 'yi'],
#  'oVwwasAgiMxi…': ['oVww', 'as', 'Ag', 'iM', 'xi…'],
#  '3racayiwaःkarakoswana': ['3ra',
#   'ca',
#   'yi',
#   'wa',
#   'ःka',
#   'ra',
#   'ko',
#   'swa',
#   'na'],
#  'yeVMxuku': ['yeV', 'Mx', 'uku'],
#  'caMxramma': ['caMx', 'ra', 'mma'],
#  'xunnuwunnav\u200c': ['xunn', 'uw', 'un', 'nav\u200c'],
#  'weVlisiMxallA': ['weVl', 'is', 'iM', 'xa', 'llA'],
#  'svarUpamanarAxu': ['sv', 'ar', 'Up', 'ama', 'na', 'rA', 'xu'],
#  'aXyAyanAlani': ['aX', 'yA', 'yanA', 'la', 'ni'],
#  'wiMtuMxi': ['wi', 'Mt', 'uMxi'],
#  'jIvanaporAtaM': ['jIv', 'an', 'ap', 'or', 'At', 'aM'],
#  'nApkin\u200clanu': ['nA', 'pkin', '\u200cl', 'anu'],
#  'niMxiMcakuMdA': ['ni', 'Mx', 'iMc', 'ak', 'uM', 'dA'],
#  'eVvarayina': ['eV', 'va', 'rayi', 'na'],
#  'heVccariswunnAdu': ['heV', 'cc', 'ar', 'isw', 'un', 'nA', 'du'],
#  'pattaleka': ['patt', 'al', 'eka'],
#  'prAraMBiMcagA': ['pr', 'Ar', 'aM', 'Bi', 'Mca', 'gA'],
#  'pariSramanu': ['pa', 'ri', 'Sr', 'am', 'anu'],
#  'mugiMcAlo': ['mug', 'iMcA', 'lo'],
#  'rEtaps\u200clo': ['rEt', 'ap', 's\u200clo'],
#  'allAxurgaM': ['all', 'Ax', 'ur', 'gaM'],
#  'munagadameti': ['mu', 'nag', 'ad', 'am', 'eti'],
#  'vadaboyadaM': ['vad', 'ab', 'oy', 'adaM'],
#  'weVranuvaxili': ['weV', 'ra', 'nu', 'va', 'xi', 'li'],
#  'haxxulanu': ['ha', 'xx', 'ula', 'nu'],
#  'oVsvaldo': ['oV', 'sv', 'al', 'do'],
#  'appatixAka': ['app', 'at', 'ix', 'Aka'],
#  'nirNayiMcukogala': ['nir', 'Na', 'yi', 'Mc', 'uko', 'ga', 'la'],
#  'uxvegAwmaka': ['uxv', 'egAw', 'ma', 'ka'],
#  'rAyAlsi': ['rAy', 'Alsi'],
#  'pArtIlu': ['pAr', 'tI', 'lu'],
#  'mUdadugula': ['mUd', 'ad', 'ug', 'ula'],
#  'ceVruvulU': ['ceV', 'ru', 'vu', 'lU'],
#  'pariRkAramArgAnni': ['pa', 'riRk', 'Ar', 'amAr', 'gA', 'nni'],
#  'waMdrixe': ['wa', 'Md', 'ri', 'xe'],
#  'mahapaxmanaMxudu': ['ma', 'ha', 'pax', 'man', 'aMxu', 'du'],
#  'civaraki': ['ci', 'vara', 'ki'],
#  'miMcani': ['miMc', 'ani'],
#  'prayawniMcinA': ['pra', 'ya', 'wniM', 'ci', 'nA'],
#  'mArkeVtlake': ['mArk', 'eV', 'tl', 'ake'],
#  'edipiswU': ['ed', 'ip', 'iswU'],
#  'keVmeVrAlo': ['keVm', 'eV', 'rAlo'],
#  'vaccinappudallA': ['vacc', 'in', 'appu', 'da', 'llA'],
#  'mixxamEna': ['mi', 'xxa', 'mEna'],
#  'manuRulawone': ['ma', 'nu', 'Ru', 'la', 'wone'],
#  'robot\u200cla': ['ro', 'bot\u200c', 'la'],
#  'AkattukoVne': ['Ak', 'att', 'ukoV', 'ne'],
#  'xamayaMwI': ['xa', 'may', 'aM', 'wI'],
#  'sarvasva': ['sar', 'va', 'sva'],
#  'baliswAru': ['ba', 'li', 'swA', 'ru'],
#  'Sawakame': ['Sa', 'wa', 'ka', 'me'],
#  'rahaxArullo': ['ra', 'haxA', 'ru', 'llo'],
#  '————————': ['——', '——', '——', '——'],
#  'gAreVlu': ['gA', 're', 'Vlu'],
#  'mqgamunu': ['mq', 'ga', 'mu', 'nu'],
#  'nijAmuxxIn': ['ni', 'jA', 'mu', 'xxIn'],
#  'dabbulivvAli': ['da', 'bb', 'ul', 'iv', 'vA', 'li'],
#  'poVMxagalamu': ['po', 'VM', 'xa', 'gal', 'amu'],
#  'mahArAj': ['mah', 'Ar', 'Aj'],
#  'grahi0cinA': ['gr', 'ah', 'i0', 'ci', 'nA'],
#  'iMtarvyUlani': ['iM', 'ta', 'rvyU', 'la', 'ni'],
#  'payaniswunna': ['pa', 'ya', 'ni', 'swun', 'na'],
#  'koVnnavAriki': ['koV', 'nna', 'vA', 'ri', 'ki'],
#  'upaxeSiMcutasavariMcu': ['up',
#   'ax',
#   'eS',
#   'iMcu',
#   'ta',
#   'sa',
#   'va',
#   'ri',
#   'Mcu'],
#  'oVmeVgA': ['oV', 'meV', 'gA'],
#  'asamarXa': ['as', 'am', 'ar', 'Xa'],
#  'yuxxAniki': ['yu', 'xxA', 'niki'],
#  'boVrnavitA': ['boVr', 'na', 'vitA'],
#  'asamarWa': ['as', 'am', 'ar', 'Wa'],
#  'viMtUMdagA': ['vi', 'MtU', 'Md', 'agA'],
#  'aMkAnAm': ['aM', 'kA', 'nAm'],
#  'AnaMxaxAyakamani': ['An', 'aMx', 'ax', 'Aya', 'kam', 'ani'],
#  'uMdaMdaMwo': ['uMd', 'aMd', 'aMwo'],
#  'searchbox': ['se', 'ar', 'chb', 'ox'],
#  'koVxxikRaNAllo': ['koV', 'xx', 'ik', 'RaN', 'Al', 'lo'],
#  'kAnannAru': ['kAn', 'an', 'nAru'],
#  'nirvahiMcabadina': ['nir', 'va', 'hi', 'Mca', 'ba', 'di', 'na'],
#  'veVnakkilAgadaMvalla': ['veV', 'na', 'kk', 'ilA', 'ga', 'daMv', 'al', 'la'],
#  'vinnAvA': ['vi', 'nnA', 'vA'],
#  'miwavAxulaku': ['miwa', 'vA', 'xu', 'laku'],
#  'walapeVttinapanulalo': ['wa', 'lap', 'eV', 'tt', 'inap', 'anu', 'lalo'],
#  'niSciwArWaM': ['niS', 'ci', 'wA', 'rW', 'aM'],
#  'ciMwiMca': ['ci', 'Mw', 'iMca'],
#  'hewubaxXa': ['he', 'wu', 'bax', 'Xa'],
#  'GatiMcAru': ['Gat', 'iMc', 'Aru'],
#  'SrIrAmanavami': ['Sr', 'Ir', 'Aman', 'av', 'ami'],
#  'cesinappatikI': ['ces', 'in', 'ap', 'pa', 'ti', 'kI'],
#  'wIramunaku': ['wIr', 'am', 'un', 'aku'],
#  'gumikUdavaxxani': ['gu', 'mi', 'kUda', 'va', 'xxa', 'ni'],
#  'vaxalani': ['va', 'xa', 'lani'],
#  'porAtaMgA': ['po', 'rA', 'taM', 'gA'],
#  'canipovunu': ['ca', 'ni', 'po', 'vu', 'nu'],
#  'maMwrAlu…aRtAxaSavarNAwviyakaM': ['maMw',
#   'rA',
#   'lu',
#   '…aR',
#   'tA',
#   'xaS',
#   'av',
#   'ar',
#   'NAwv',
#   'iya',
#   'kaM'],
#  'padeyAlani': ['pa', 'deyA', 'la', 'ni'],
#  'rAjAyyAdu': ['rA', 'jAyy', 'Adu'],
#  'paxabaMXAlu': ['pax', 'ab', 'aM', 'XAlu'],
#  'speVktroskopIki': ['sp', 'eV', 'ktro', 'sk', 'op', 'Iki'],
#  'reVMtinI': ['re', 'VMt', 'inI'],
#  'agnihowrAvuXAnluni': ['ag', 'niho', 'wr', 'Avu', 'XAnl', 'uni'],
#  'hqxayakavAtAnni': ['hqxa', 'yak', 'avA', 'tA', 'nni'],
#  'xvArAweVlusukovaccu': ['xv', 'Ar', 'Aw', 'eV', 'lu', 'suko', 'va', 'ccu'],
#  'xakkelA': ['xa', 'kk', 'elA'],
#  'kesIAr\u200cwo': ['ke', 'sI', 'Ar\u200c', 'wo'],
#  'pilcuwU': ['pil', 'cu', 'wU'],
#  'SaMKamu': ['SaMK', 'amu'],
#  'prAMgaNaMloni': ['prA', 'Mg', 'aN', 'aMlo', 'ni'],
#  'xIkRalaku': ['xIkR', 'al', 'aku'],
#  'anerisams': ['ane', 'ri', 'sams'],
#  'weVllapoyAru': ['weVl', 'la', 'poyA', 'ru'],
#  'saMkarRaNa': ['saMk', 'ar', 'RaNa'],
#  'XaraNilo': ['Xa', 'ra', 'Ni', 'lo'],
#  'addukunnAdu': ['ad', 'du', 'ku', 'nn', 'Adu'],
#  'mAwqBARa': ['mA', 'wqBA', 'Ra'],
#  'avunurA': ['avu', 'nu', 'rA'],
#  'saMvawsaramulaku': ['sa', 'Mvaw', 'sa', 'ramu', 'laku'],
#  'harRanIyaM': ['har', 'Ran', 'Iy', 'aM'],
#  'vidawalo': ['vid', 'aw', 'alo'],
#  'jeVnnaruwo': ['jeV', 'nn', 'ar', 'uwo'],
#  'mUrcanalu': ['mU', 'rc', 'ana', 'lu'],
#  'bawikiMcAli': ['baw', 'ik', 'iMcA', 'li'],
#  '2.lAlAjalamu': ['2.l', 'Al', 'Aja', 'la', 'mu'],
#  'Anukuni': ['An', 'uku', 'ni'],
#  'kristet': ['kr', 'is', 'tet'],
#  'moVkkuwunna': ['moVk', 'ku', 'wun', 'na'],
#  'beVxirina': ['beVx', 'ir', 'ina'],
#  'cAr\u200cXAm\u200clu': ['cA', 'r\u200c', 'XAm\u200c', 'lu'],
#  'paraMbulagunavu': ['par', 'aM', 'bul', 'ag', 'un', 'avu'],
#  'wAkiMxeVvaru': ['wA', 'kiMx', 'eV', 'va', 'ru'],
#  'familyःGeorgia': ['fami', 'ly', 'ःGe', 'or', 'gia'],
#  'narasamma': ['na', 'ras', 'amma'],
#  'bAxukuMtunnAru': ['bA', 'xuku', 'Mt', 'unn', 'Aru'],
#  'vrAswunnavAru': ['vr', 'As', 'wunn', 'avA', 'ru'],
#  'avvadaMwo': ['avv', 'ad', 'aM', 'wo'],
#  'iMtikoVccinappudu': ['iM', 'tik', 'oV', 'cc', 'in', 'ap', 'pu', 'du'],
#  'vexikalayyAyi': ['ve', 'xi', 'kala', 'yy', 'Ayi'],
#  'purugulu': ['pu', 'rug', 'ulu'],
#  'muhUrwaM': ['mu', 'hU', 'rw', 'aM'],
#  'svAmivArini': ['sv', 'Amiv', 'Ar', 'ini'],
#  'SrAmikulu': ['Sr', 'Ami', 'ku', 'lu'],
#  'agniparvawaMloMci': ['ag', 'ni', 'par', 'va', 'wa', 'MloM', 'ci'],
#  'kAryavarga': ['kAry', 'av', 'ar', 'ga'],
#  'va\u200cra\u200cku': ['va', '\u200cra\u200c', 'ku'],
#  'bAlyamuna': ['bAl', 'ya', 'muna'],
#  'cAlArojulayiMxi': ['cAl', 'Ar', 'oj', 'ula', 'yi', 'Mxi'],
#  'kalavanunna': ['kala', 'van', 'unna'],
#  'samayamlo': ['sam', 'ay', 'am', 'lo'],
#  'caxuvarulu': ['caxu', 'va', 'ru', 'lu'],
#  'samaMjasame': ['sam', 'aM', 'ja', 'sa', 'me'],
#  'wappiMceVnu': ['wa', 'pp', 'iMc', 'eV', 'nu'],
#  'AMXraprAMwaMlo': ['AMXr', 'ap', 'rA', 'Mw', 'aMlo'],
#  'veVllAla': ['veV', 'llA', 'la'],
#  'ugravAxi': ['ug', 'rav', 'Axi'],
#  'prAjuktulu': ['pr', 'Aj', 'uktu', 'lu'],
#  'planned': ['pl', 'ann', 'ed'],
#  'sokiMxaMte': ['so', 'ki', 'Mx', 'aMte'],
#  'Sakwulu-': ['Sa', 'kw', 'ulu-'],
#  'jAripoyiMxi': ['jA', 'ri', 'po', 'yi', 'Mxi'],
#  'parameSvarI': ['par', 'am', 'eS', 'va', 'rI'],
#  'pattiMcukoxu': ['pa', 'tt', 'iMc', 'uk', 'oxu'],
#  'mugiMcukunna': ['mug', 'iMc', 'ukun', 'na'],
#  '1871–1918': ['18', '71–', '19', '18'],
#  'vaxilAnu': ['va', 'xi', 'lA', 'nu'],
#  'SabxAlanu': ['Sabx', 'Al', 'anu'],
#  'wawwvameVlA': ['waww', 'va', 'meV', 'lA'],
#  'bAxyawalu': ['bAx', 'ya', 'walu'],
#  'KaMdanao': ['Ka', 'Md', 'an', 'ao'],
#  'paryAyapaxaMgA': ['par', 'yA', 'ya', 'pa', 'xa', 'MgA'],
#  'eVppudo': ['eV', 'ppu', 'do'],
#  'karuNAkaran': ['kar', 'uNAk', 'ar', 'an'],
#  'poVraMboku': ['poVr', 'aM', 'boku'],
#  'vaxilipeVdiwene': ['va', 'xi', 'li', 'peV', 'di', 'we', 'ne'],
#  'peVxxavAdu': ['peV', 'xx', 'av', 'Adu'],
#  'avaroXAlugA': ['av', 'ar', 'oX', 'Al', 'ugA'],
#  'amAnuRaMgA': ['am', 'Anu', 'Ra', 'MgA'],
#  'PArmulAnu': ['PArm', 'ul', 'Anu'],
#  'mAMsAla': ['mAM', 'sA', 'la'],
#  'eVtucUsinA': ['eV', 'tucU', 'si', 'nA'],
#  'waggani': ['wa', 'gga', 'ni'],
#  'vimarSalawo': ['vi', 'ma', 'rS', 'al', 'awo'],
#  'alAMtixe': ['al', 'AM', 'ti', 'xe'],
#  'xikukalA': ['xik', 'uk', 'alA'],
#  'SrImahAviRNuM': ['SrI', 'ma', 'hA', 'vi', 'RN', 'uM'],
#  'Sakunwala': ['Sa', 'kun', 'wa', 'la'],
#  'vArasurAlavutuMxi': ['vAr', 'as', 'urA', 'la', 'vutu', 'Mxi'],
#  'SAKalunnAyi': ['SAKa', 'lu', 'nn', 'Ayi'],
#  'xqSyarUpakaM': ['xqSy', 'ar', 'Up', 'ak', 'aM'],
#  'naduswuMdagA': ['na', 'du', 'swuM', 'da', 'gA'],
#  'aMxiMcAmani': ['aM', 'xi', 'McA', 'ma', 'ni'],
#  'SvAsaku': ['SvAs', 'aku'],
#  'malayAlYasvAmi': ['mal', 'ay', 'Al', 'Yasv', 'Ami'],
#  'payaHpArAvArapAraxa': ['pa', 'yaHp', 'Ar', 'AvAr', 'ap', 'Ar', 'axa'],
#  'PaliwAlanu': ['Pa', 'li', 'wA', 'lanu'],
#  'pariNAmame': ['pa', 'riNA', 'ma', 'me'],
#  'veVnakAduwunnAM': ['veV', 'na', 'kA', 'duwu', 'nn', 'AM'],
#  'mEkupattukunnavAri': ['mE', 'ku', 'pa', 'ttu', 'ku', 'nna', 'vA', 'ri'],
#  'maroveVpu': ['ma', 'ro', 'veV', 'pu'],
#  'vyakwiwvAniki': ['vy', 'ak', 'wiw', 'vA', 'niki'],
#  'virupaNNa': ['vir', 'upaN', 'Na'],
#  'velaMlo': ['vel', 'aMlo'],
#  'rabbar\u200cnu': ['ra', 'bb', 'ar\u200c', 'nu'],
#  'moVwwamu': ['mo', 'Vww', 'amu'],
#  'haswAlalo': ['ha', 'swA', 'la', 'lo'],
#  'sannaxXamayyeMxuku': ['sa', 'nna', 'xX', 'am', 'ayye', 'Mx', 'uku'],
#  'muKyapAwrawo': ['muKy', 'ap', 'Aw', 'ra', 'wo'],
#  '2013-12-16T18:50:07': ['20', '13-1', '2-', '16T', '18', ':50:', '07'],
#  'kanAnulo': ['ka', 'nAn', 'ulo'],
#  'baMXuroxbaMXura': ['baM', 'Xuro', 'xbaM', 'Xu', 'ra'],
#  'prAya\u200crtI': ['prA', 'ya', '\u200crtI'],
#  'prEjuloVswe': ['prEj', 'ul', 'oV', 'swe'],
#  'uMdevAru': ['uM', 'de', 'vA', 'ru'],
#  'javaxekar': ['ja', 'vax', 'ek', 'ar'],
#  'rAwaprawulni': ['rA', 'wap', 'ra', 'wul', 'ni'],
#  'paramANaM': ['par', 'am', 'ANaM'],
#  'gurwuleka': ['gurw', 'ul', 'eka'],
#  'korinappudu': ['kor', 'in', 'ap', 'pu', 'du'],
#  'svAmivArika': ['sv', 'Amiv', 'Ar', 'ika'],
#  'koVmmapE': ['koV', 'mma', 'pE'],
#  'viXiMcAru': ['viX', 'iMc', 'Aru'],
#  'kalisinattu': ['kal', 'is', 'in', 'attu'],
#  'nammina': ['na', 'mm', 'ina'],
#  'veVxyaraMgaM': ['ve', 'Vx', 'yar', 'aM', 'gaM'],
#  'karajjA': ['ka', 'ra', 'jjA'],
#  'sinimAkannA': ['si', 'ni', 'mAk', 'an', 'nA'],
#  'namaskariswunnAro': ['na', 'ma', 'sk', 'ar', 'isw', 'unnA', 'ro'],
#  'anipiMcani': ['an', 'ip', 'iMca', 'ni'],
#  'koVdukki': ['koV', 'du', 'kki'],
#  'kArucavakagA': ['kAr', 'ucav', 'ak', 'agA'],
#  'Krueger': ['Kr', 'ueg', 'er'],
#  'cewabadi': ['ce', 'wa', 'badi'],
#  'adigAru': ['adig', 'Aru'],
#  'panararara': ['pa', 'nara', 'ra', 'ra'],
#  'saMsWalugA': ['sa', 'MsWa', 'lu', 'gA'],
#  'katteVlanu': ['katt', 'eV', 'lanu'],
#  'vaMweVnapE': ['vaMw', 'eV', 'napE'],
#  'cAvavaccu': ['cAva', 'va', 'ccu'],
#  'eVkkuvavadamo': ['eVk', 'ku', 'va', 'vada', 'mo'],
#  'prinispAl': ['pri', 'ni', 'spAl'],
#  'karuvavuwoMxi': ['ka', 'ru', 'va', 'vu', 'wo', 'Mxi'],
#  'pariSrama': ['par', 'iS', 'ra', 'ma'],
#  'kalapavakuMdA': ['ka', 'la', 'pa', 'vak', 'uM', 'dA'],
#  'mukkeVra': ['muk', 'keV', 'ra'],
#  'lotas\u200cpAMd\u200cloni': ['lot', 'as\u200cp', 'AM', 'd\u200clo', 'ni'],
#  'wIruloniki': ['wI', 'ru', 'lo', 'niki'],
#  'aMbAlikawo': ['aMb', 'Al', 'ik', 'awo'],
#  'xayArXra': ['xay', 'Ar', 'Xra'],
#  'muMceVwwAdu': ['mu', 'Mc', 'eV', 'ww', 'Adu'],
#  'AmeVloV': ['Am', 'eVl', 'oV'],
#  'ceVppukuMtene': ['ceVp', 'pu', 'ku', 'Mte', 'ne'],
#  'yAjFavalkya': ['yA', 'jFav', 'al', 'kya'],
#  'prAblams\u200c': ['prA', 'bl', 'am', 's\u200c'],
#  'mAraNahiMsa': ['mAr', 'aNa', 'hiM', 'sa'],
#  'tiMpumuxrohinivagu': ['ti', 'Mp', 'um', 'uxr', 'oh', 'in', 'iva', 'gu'],
#  'iSrAyelU': ['iS', 'rA', 'ye', 'lU'],
#  'yupayogamEnavi': ['yu', 'pa', 'yo', 'gamE', 'na', 'vi'],
#  'iRtasaKi': ['iR', 'ta', 'saKi'],
#  'viSAraxaH': ['viS', 'Ar', 'ax', 'aH'],
#  'vaMcana”': ['va', 'Mc', 'ana”'],
#  'avamAniMcinappudu': ['av', 'am', 'Ani', 'Mcin', 'ap', 'pu', 'du'],
#  'xIpakuni': ['xI', 'pa', 'ku', 'ni'],
#  'viSleRiMciMxAmeV': ['viS', 'le', 'RiMc', 'iM', 'xA', 'meV'],
#  'vUregiMpullo': ['vUre', 'gi', 'Mp', 'ullo'],
#  'iccceMxuku': ['iccc', 'eM', 'xu', 'ku'],
#  'krismas': ['kr', 'is', 'mas'],
#  'naBavewpApa': ['naB', 'av', 'ewpA', 'pa'],
#  'prawioVkkarU': ['pr', 'aw', 'ioVk', 'ka', 'rU'],
#  'poRiMcutaku': ['po', 'Ri', 'Mcu', 'ta', 'ku'],
#  'uxASInawa': ['uxAS', 'In', 'awa'],
#  'affiliate': ['affi', 'li', 'ate'],
#  'pUjiMcinaMxuku': ['pU', 'ji', 'Mc', 'in', 'aM', 'xuku'],
#  'BojanaMlA': ['Boj', 'an', 'aM', 'lA'],
#  'samAjAlu': ['sa', 'mAjA', 'lu'],
#  'kaviwvasexyapu': ['ka', 'vi', 'wv', 'asex', 'ya', 'pu'],
#  'avixyuxvAhakaM': ['avix', 'yu', 'xvAh', 'ak', 'aM'],
#  'sAXiMcinA': ['sAX', 'iMci', 'nA'],
#  'pArkulo': ['pAr', 'ku', 'lo'],
#  '1969-70': ['19', '69', '-70'],
#  'hAravajramEna': ['hA', 'ra', 'va', 'jram', 'Ena'],
#  'xuswulalo': ['xu', 'swu', 'lalo'],
#  'AtagAlYlaMwA': ['Ata', 'gA', 'lYl', 'aM', 'wA'],
#  'caxuvuwunna': ['ca', 'xu', 'vu', 'wun', 'na'],
#  'plAneriyA': ['plA', 'ne', 'ri', 'yA'],
#  'nyUtrAsyUtikals': ['nyUt', 'rA', 'syUt', 'ik', 'als'],
#  'boVllAraMloni': ['boV', 'll', 'AraM', 'loni'],
#  'nilupukoVneMxuku': ['ni', 'lu', 'pu', 'koV', 'ne', 'Mx', 'uku'],
#  'prawiBApAtavAlu': ['pr', 'aw', 'iBAp', 'At', 'av', 'Alu'],
#  '1416-1489': ['14', '16-', '1489'],
#  'vAkyamulu': ['vAk', 'ya', 'mu', 'lu'],
#  'sUPIwawwvAnni': ['sUPI', 'wa', 'wwvA', 'nni'],
#  'viSvaviKyAwa': ['viSv', 'aviK', 'yA', 'wa'],
#  'vArasula': ['vA', 'ra', 'su', 'la'],
#  'wiriginattanipiMciMxi': ['wi',
#   'ri',
#   'gi',
#   'na',
#   'tt',
#   'an',
#   'ip',
#   'iMc',
#   'iMxi'],
#  'ravANAnu': ['ra', 'vANA', 'nu'],
#  'vyavahariMcAlani': ['vya', 'va', 'ha', 'ri', 'McA', 'la', 'ni'],
#  'paxxawule': ['pa', 'xxa', 'wu', 'le'],
#  'gomayaMlo': ['goma', 'ya', 'Mlo'],
#  'hAhAhUhU': ['hA', 'hA', 'hUhU'],
#  'avalakRaNAlu': ['ava', 'lakR', 'aN', 'Alu'],
#  'kalmaRaM': ['ka', 'lmaR', 'aM'],
#  'koVttukunnArani': ['koV', 'ttu', 'ku', 'nnA', 'ra', 'ni'],
#  'maMgoliyan\u200c': ['maM', 'go', 'li', 'ya', 'n\u200c'],
#  'annaxAniki': ['ann', 'axA', 'niki'],
#  'upayogiMcukuMte': ['up', 'ay', 'og', 'iM', 'cu', 'ku', 'Mte'],
#  'odiMcadaM': ['od', 'iMc', 'ad', 'aM'],
#  'PEnals\u200c': ['PEn', 'al', 's\u200c'],
#  'pAlEMxi': ['pAl', 'EMxi'],
#  'bahaxUr\u200cRAku': ['bah', 'ax', 'Ur\u200cR', 'Aku'],
#  'addukuni': ['add', 'uku', 'ni'],
#  'meVyiMteVneVns': ['meV', 'yiM', 'teV', 'ne', 'Vns'],
#  'nadapAlani': ['na', 'da', 'pAla', 'ni'],
#  'AryaBatuni': ['Arya', 'Ba', 'tu', 'ni'],
#  'ceswunnanepaXyaMlo': ['cesw', 'unn', 'anep', 'aX', 'yaM', 'lo'],
#  'jAwipiwa': ['jAw', 'ip', 'iwa'],
#  'vinadame': ['vi', 'na', 'da', 'me'],
#  '2vapejI': ['2v', 'ap', 'ejI'],
#  'vIrabrahmeMxrasvAmi': ['vI', 'ra', 'brah', 'me', 'Mx', 'ras', 'vA', 'mi'],
#  'SarIrAniki': ['Sa', 'rI', 'rA', 'niki'],
#  'hEkortulo': ['hEko', 'rt', 'ulo'],
#  'prAraMBiMcAdu': ['pr', 'Ar', 'aM', 'Bi', 'Mc', 'Adu'],
#  'saMpraxAyamu': ['sa', 'Mp', 'ra', 'xA', 'ya', 'mu'],
#  'punarjanma': ['pu', 'na', 'rj', 'an', 'ma'],
#  'pajjUrulo': ['pajj', 'Ur', 'ulo'],
#  'AptimeVj': ['Ap', 'ti', 'me', 'Vj'],
#  'veiMbeVrg': ['ve', 'iM', 'beV', 'rg'],
#  'anugrahiMcabaduxuru': ['an',
#   'ug',
#   'ra',
#   'hiM',
#   'ca',
#   'ba',
#   'du',
#   'xu',
#   'ru'],
#  'muKyanagarAlEna': ['muKy', 'ana', 'ga', 'rAl', 'Ena'],
#  'jeVMdAlanu': ['jeV', 'Md', 'Ala', 'nu'],
#  'patAn\u200cceVru': ['pa', 'tA', 'n\u200c', 'ceV', 'ru'],
#  'cAMbar\u200cloki': ['cA', 'Mb', 'ar', '\u200clo', 'ki'],
#  'pAwramavuwU': ['pAwr', 'am', 'av', 'uwU'],
#  'swaMBiMce': ['sw', 'aM', 'BiM', 'ce'],
#  'nappudu': ['na', 'pp', 'udu'],
#  'mUluguwunnAdu…': ['mU', 'lu', 'gu', 'wunn', 'Ad', 'u…'],
#  'aMcanAveswunna': ['aM', 'ca', 'nA', 've', 'swun', 'na'],
#  'gummamuvaraku': ['gumm', 'am', 'uv', 'ara', 'ku'],
#  'cAliMcinaxi': ['cAl', 'iMci', 'naxi'],
#  'sare…iMkA': ['sa', 're…i', 'MkA'],
#  'swuwi”ni': ['sw', 'uwi”', 'ni'],
#  'Asa\u200ckwika\u200craMgA': ['Asa',
#   '\u200ck',
#   'wi',
#   'ka\u200c',
#   'ra',
#   'MgA'],
#  'jaraggA': ['ja', 'ra', 'ggA'],
#  'aMwaamAyakaMgA': ['aM', 'waam', 'Ay', 'ak', 'aMgA'],
#  'saMparkula': ['saMp', 'ar', 'kula'],
#  'mahApApaharaM': ['mahA', 'pA', 'pa', 'ha', 'raM'],
#  'jammalamadugu': ['jamm', 'al', 'am', 'adu', 'gu'],
#  'irakvAyi': ['ir', 'ak', 'vA', 'yi'],
#  'saraMjAmA': ['sa', 'raM', 'jA', 'mA'],
#  'sAguwoMxi': ['sAgu', 'wo', 'Mxi'],
#  'wamaloni': ['wa', 'mal', 'oni'],
#  'wAralawo': ['wAra', 'lawo'],
#  'aXigacCawi': ['aX', 'ig', 'ac', 'Cawi'],
#  'Prem\u200cvark': ['Pr', 'em\u200cv', 'ark'],
#  'anukoVne': ['anu', 'koV', 'ne'],
#  'CAMpiyans': ['CAM', 'pi', 'ya', 'ns'],
#  'bassulo': ['ba', 'ss', 'ulo'],
#  'mahArAjugA': ['mah', 'Ar', 'Aj', 'ugA'],
#  'BAgyaMwo': ['BAg', 'ya', 'Mwo'],
#  'jaruguwAyannaxi': ['ja', 'ru', 'gu', 'wA', 'ya', 'nna', 'xi'],
#  'wiMtAru': ['wi', 'Mt', 'Aru'],
#  'praxAnowsavaM': ['pra', 'xAno', 'ws', 'av', 'aM'],
#  'sixxamma': ['six', 'xa', 'mma'],
#  'laMcAvawAraM': ['la', 'McAv', 'aw', 'AraM'],
#  'premaku': ['pr', 'em', 'aku'],
#  'praveSapeVdawAru': ['pra', 've', 'Sa', 'pe', 'Vd', 'aw', 'Aru'],
#  'cirAkupadeVdu': ['ci', 'rAk', 'upa', 'deV', 'du'],
#  'plAMt\u200clu': ['pl', 'AM', 't\u200c', 'lu'],
#  'cUsevANni': ['cU', 'se', 'vAN', 'ni'],
#  'praxarSiMcukune': ['pr', 'ax', 'ar', 'Si', 'Mcu', 'ku', 'ne'],
#  'sieVMni': ['si', 'eVM', 'ni'],
#  'vyavahariMcagalarani': ['vy', 'av', 'ah', 'ar', 'iMca', 'ga', 'la', 'rani'],
#  'sApekRaMgA': ['sApe', 'kR', 'aMgA'],
#  'aByarXigA': ['aBy', 'ar', 'Xi', 'gA'],
#  'aBiprAyAnni': ['aBip', 'rA', 'yA', 'nni'],
#  'xevawala': ['xe', 'va', 'wa', 'la'],
#  'kAxanalemu': ['kA', 'xa', 'na', 'le', 'mu'],
#  'kroneVnbarg': ['kro', 'ne', 'Vnba', 'rg'],
#  'veVwukuwUne': ['veV', 'wu', 'ku', 'wUne'],
#  'ArWikewara': ['Ar', 'Wike', 'wa', 'ra'],
#  'kaRtakAlaMlonU': ['ka', 'Rtak', 'Al', 'aMlo', 'nU'],
#  'kuxurcadAniki': ['ku', 'xur', 'ca', 'dA', 'ni', 'ki'],
#  'vyavahArAlu': ['vya', 'va', 'hA', 'rA', 'lu'],
#  'prapaMcakap': ['pra', 'pa', 'Mc', 'ak', 'ap'],
#  'kanapadiwe': ['ka', 'na', 'pa', 'di', 'we'],
#  'GorAlaku': ['Gor', 'Al', 'aku'],
#  'saMxehiMcAlsina': ['sa', 'Mx', 'eh', 'iMc', 'Al', 'si', 'na'],
#  'kqwajfawalu': ['kq', 'wajf', 'aw', 'alu'],
#  'pakkawadupuwuMte': ['pa', 'kk', 'aw', 'adu', 'pu', 'wu', 'Mte'],
#  'ravIMxraBArawi': ['ra', 'vI', 'Mx', 'raB', 'Ar', 'awi'],
#  'awyAScaryaM': ['aw', 'yA', 'Sc', 'ar', 'yaM'],
#  'mAMdalikaMloki': ['mAMd', 'al', 'ikaM', 'lo', 'ki'],
#  'billiMg\u200c': ['bi', 'll', 'iMg\u200c'],
#  'saMvawsaramula': ['sa', 'Mvaw', 'sa', 'ramu', 'la'],
#  'rogaBayaMpikkalu': ['ro', 'ga', 'Baya', 'Mp', 'ikk', 'alu'],
#  'BaviRyawwu': ['Bav', 'iR', 'ya', 'wwu'],
#  'rAkuMte': ['rA', 'ku', 'Mte'],
#  'clicksor_layer_ad_link_color': ['cl',
#   'ic',
#   'ks',
#   'or_l',
#   'ay',
#   'er',
#   '_ad_',
#   'li',
#   'nk_c',
#   'ol',
#   'or'],
#  'pUrwEna': ['pU', 'rwE', 'na'],
#  'blAk\u200cnu': ['bl', 'Ak', '\u200cnu'],
#  'araNyame': ['ar', 'aN', 'ya', 'me'],
#  'niwyamE': ['ni', 'wya', 'mE'],
#  'mawAnni': ['ma', 'wA', 'nni'],
#  'uxyamaMcina': ['ux', 'ya', 'maM', 'cina'],
#  'mahAiRtaM': ['mah', 'AiRt', 'aM'],
#  'peVduwunnatlu': ['peV', 'du', 'wunn', 'at', 'lu'],
#  '53.5lakRala': ['53.5', 'la', 'kRa', 'la'],
#  'klarkulaku': ['kl', 'ar', 'kula', 'ku'],
#  'winipiswAdu': ['win', 'ip', 'iswA', 'du'],
#  'nAkitti': ['nA', 'ki', 'tti'],
#  'unnAru”': ['unn', 'Ar', 'u”'],
#  'rAjapuruRo': ['rAja', 'pu', 'ruRo'],
#  'anumawiMcarAxannAru': ['an', 'um', 'aw', 'iMca', 'rA', 'xa', 'nn', 'Aru'],
#  'RAjiyaM': ['RA', 'ji', 'yaM'],
#  'vinipiMcAdu': ['vi', 'ni', 'pi', 'Mc', 'Adu'],
#  'aswamAnU': ['asw', 'am', 'AnU'],
#  'aMdar\u200c19-': ['aMd', 'ar', '\u200c19-'],
#  'nirUpiMcukovataM': ['ni', 'rU', 'piMc', 'ukov', 'at', 'aM'],
#  'kUtamini': ['kUt', 'am', 'ini'],
#  'lAlAjalAnni': ['lA', 'lAja', 'lA', 'nni'],
#  'aruxEna': ['ar', 'ux', 'Ena'],
#  'vaswini': ['va', 'swi', 'ni'],
#  'xAriwIse': ['xA', 'ri', 'wI', 'se'],
#  'kaMcikacarlagA': ['ka', 'Mc', 'ik', 'ac', 'arla', 'gA'],
#  'varinAru': ['va', 'rin', 'Aru'],
#  'walliwraMdrula': ['wal', 'liwr', 'aM', 'dr', 'ula'],
#  'AwraMgA': ['Awr', 'aM', 'gA'],
#  'boVddUdani': ['bo', 'Vd', 'dUda', 'ni'],
#  'pariXiloniki': ['pa', 'riXi', 'lo', 'niki'],
#  'ceVbuwunnAnaMte': ['ceV', 'bu', 'wunn', 'An', 'aMte'],
#  'mattiwo': ['ma', 'tti', 'wo'],
#  'magAlYlYa': ['ma', 'gAl', 'YlYa'],
#  'poVyyAru': ['po', 'VyyA', 'ru'],
#  'moVxaleVnavAti': ['moVx', 'al', 'eVn', 'avA', 'ti'],
#  'waggiMcaleka': ['wa', 'gg', 'iMc', 'al', 'eka'],
#  'mAnukoleni': ['mA', 'nu', 'ko', 'le', 'ni'],
#  'sahajamEnavI': ['sa', 'ha', 'ja', 'mEna', 'vI'],
#  'kaMxipappu': ['kaM', 'xi', 'pa', 'ppu'],
#  'meVyins': ['meV', 'yi', 'ns'],
#  'prakatanalo': ['pr', 'ak', 'at', 'an', 'alo'],
#  'prabAvaM': ['pra', 'bA', 'vaM'],
#  'paryAyapaxamo': ['par', 'yA', 'ya', 'paxa', 'mo'],
#  'wappavu': ['wapp', 'avu'],
#  'naccAka': ['na', 'ccA', 'ka'],
#  'vAlmIki': ['vAl', 'mI', 'ki'],
#  'peRIloni': ['pe', 'RIlo', 'ni'],
#  'nArAyaNarAvu': ['nA', 'rA', 'ya', 'Na', 'rAvu'],
#  'rEwAMgAnni': ['rEwA', 'Mg', 'Anni'],
#  'jamiMxArla': ['jam', 'iMx', 'Ar', 'la'],
#  'paxXawi': ['pa', 'xX', 'awi'],
#  'AliyarAma': ['Al', 'iya', 'rA', 'ma'],
#  'marixiki': ['ma', 'ri', 'xi', 'ki'],
#  'srAvaka': ['sr', 'Av', 'aka'],
#  'mawimarupunaku': ['mawi', 'ma', 'rup', 'un', 'aku'],
#  'anupama': ['an', 'up', 'ama'],
#  'gaNAMkAlU': ['gaN', 'AM', 'kA', 'lU'],
#  'Sivakavi': ['Siv', 'aka', 'vi'],
#  'svapnakesi': ['sva', 'pnak', 'esi'],
#  'maraNasWalaM': ['ma', 'raNa', 'sW', 'al', 'aM'],
#  'mArmoguwU': ['mAr', 'mo', 'guwU'],
#  'xUramOwU': ['xU', 'ra', 'mOwU'],
#  'vIrixxariwo': ['vI', 'ri', 'xx', 'ar', 'iwo'],
#  'SrISElakReVwra': ['SrIS', 'El', 'ak', 'ReVw', 'ra'],
#  'kunArilli': ['kun', 'Ari', 'lli'],
#  'vikAramE': ['vi', 'kA', 'ramE'],
#  'xravAlu': ['xr', 'avA', 'lu'],
#  'புறந்தொழா': ['புற', 'ந்தொ', 'ழா'],
#  'praxarSanalawo': ['pr', 'ax', 'ar', 'Sa', 'na', 'lawo'],
#  'yUnivarsitIki': ['yU', 'ni', 'var', 'si', 'tI', 'ki'],
#  'yUxArAjEna': ['yU', 'xAr', 'Aj', 'Ena'],
#  'weVccukuMxani': ['weV', 'cc', 'ukuM', 'xa', 'ni'],
#  'AnaMxaM': ['An', 'aM', 'xaM'],
#  'eVMpIki': ['eV', 'Mp', 'Iki'],
#  'paMcAyaw': ['pa', 'Mc', 'Ay', 'aw'],
#  'ayipoye': ['ayi', 'po', 'ye'],
#  'punAxikosaM': ['pu', 'nA', 'xi', 'ko', 'saM'],
#  'siMharASilo': ['siM', 'ha', 'rA', 'Si', 'lo'],
#  'appanna': ['app', 'an', 'na'],
#  'cariwalu': ['ca', 'ri', 'walu'],
#  'doi:10.1016/0300-5712': ['do', 'i:', '10', '.10', '16/0', '300-', '5712'],
#  'resworiMg': ['re', 'sw', 'ori', 'Mg'],
#  'Exuguru': ['Ex', 'ug', 'uru'],
#  'paMpiswonaMtnuMxi': ['paMp', 'is', 'wo', 'na', 'Mtnu', 'Mxi'],
#  'manasuloMci': ['ma', 'na', 'su', 'lo', 'Mci'],
#  'axemitaMte': ['axe', 'mi', 'ta', 'Mte'],
#  'nittUrpulu': ['ni', 'tt', 'Ur', 'pulu'],
#  'graMWAlayaM': ['gr', 'aM', 'WA', 'la', 'yaM'],
#  'aniwanu': ['ani', 'wanu'],
#  'katakatAlloki': ['kata', 'ka', 'tA', 'llo', 'ki'],
#  'rAnIyaxu': ['rA', 'nI', 'ya', 'xu'],
#  'rijistreRanu': ['ri', 'ji', 'st', 're', 'Ra', 'nu'],
#  'jElupAlE': ['jE', 'lu', 'pAlE'],
#  'palleVlu': ['pall', 'eVlu'],
#  'SmaSAnavAtika': ['SmaS', 'An', 'av', 'Ati', 'ka'],
#  'axyakRudu–baxruxxIn': ['ax', 'ya', 'kR', 'ud', 'u–b', 'ax', 'ru', 'xxIn'],
#  'AropaNa': ['Aro', 'pa', 'Na'],
#  'kaligivuMdunu': ['kal', 'ig', 'ivuM', 'du', 'nu'],
#  'lakRawo': ['lakR', 'awo'],
#  'walaluxanni': ['wala', 'lu', 'xa', 'nni'],
#  'kAnaMtAdu': ['kAn', 'aM', 'tAdu'],
#  'priyulu': ['pr', 'iy', 'ulu'],
#  'yogavixiwi': ['yo', 'ga', 'vi', 'xiwi'],
#  'xoVrikiwe': ['xoV', 'ri', 'ki', 'we'],
#  'anuBavaM': ['an', 'uB', 'av', 'aM'],
#  'paruswuMxi': ['pa', 'ru', 'sw', 'uM', 'xi'],
#  'ciMwapaMdu': ['ci', 'Mw', 'ap', 'aM', 'du'],
#  'ceVppagalaM': ['ceVp', 'pa', 'ga', 'laM'],
#  'koVMxariki': ['koV', 'Mx', 'ar', 'iki'],
#  'spaMxiMcAlannAru': ['sp', 'aM', 'xi', 'McA', 'la', 'nnA', 'ru'],
#  'maheSvarareVddi': ['ma', 'heSv', 'ar', 'ar', 'eV', 'ddi'],
#  'koVttukoVnipoyiri': ['koV', 'tt', 'uk', 'oV', 'ni', 'poyi', 'ri'],
#  'carcallo': ['car', 'ca', 'llo'],
#  'kaxiliMxi': ['ka', 'xi', 'liM', 'xi'],
#  'rugmawa': ['rug', 'ma', 'wa'],
#  'suraXenu': ['su', 'raXe', 'nu'],
#  'irigeRan': ['ir', 'igeR', 'an'],
#  'eVnIver': ['eVn', 'Iver'],
#  'niyaMvUwiMci': ['ni', 'ya', 'Mv', 'UwiM', 'ci'],
#  'ivvAlsina': ['ivv', 'Al', 'si', 'na'],
#  'kuMtAdu': ['ku', 'Mt', 'Adu'],
#  'EsIdIeVs\u200c': ['EsI', 'dI', 'eV', 's\u200c'],
#  'jillAlakU': ['ji', 'll', 'Ala', 'kU'],
#  'gadupuwunnAdu': ['ga', 'du', 'pu', 'wunn', 'Adu'],
#  'nannayAryuni': ['na', 'nnay', 'Ar', 'yuni'],
#  'pAduwuMdagA': ['pAdu', 'wuM', 'da', 'gA'],
#  'vargAlalo': ['var', 'gA', 'lalo'],
#  'bareMxar': ['ba', 're', 'Mx', 'ar'],
#  'emavuwuMxannattu': ['emav', 'uw', 'uM', 'xa', 'nn', 'attu'],
#  'yUniyanlo': ['yUni', 'ya', 'nlo'],
#  'wanamanamunaMxuz': ['wana', 'ma', 'namu', 'na', 'Mxuz'],
#  'eVgumawilo': ['eV', 'gu', 'ma', 'wilo'],
#  'prajalalo': ['pra', 'ja', 'la', 'lo'],
#  'muKaSAla': ['muK', 'aS', 'Ala'],
#  'svasWawa': ['sv', 'as', 'Wa', 'wa'],
#  'watAkamulU': ['wa', 'tA', 'ka', 'mu', 'lU'],
#  'Strengthening': ['Str', 'en', 'gthe', 'ni', 'ng'],
#  'uMdiwIrAli': ['uM', 'diwI', 'rA', 'li'],
#  'pattikalanu': ['patt', 'ik', 'al', 'anu'],
#  'karwavyAlanu': ['kar', 'wa', 'vyA', 'lanu'],
#  'pramANa': ['pra', 'mA', 'Na'],
#  'pAkudurAlYlYu': ['pAk', 'udur', 'Al', 'YlYu'],
#  'sarvIseVs\u200c': ['sar', 'vI', 'se', 'Vs\u200c'],
#  'rAGavarAvu': ['rAG', 'av', 'ar', 'Avu'],
#  'varNiMcatAniki': ['varN', 'iM', 'ca', 'tA', 'ni', 'ki'],
#  'uxyoginulakU': ['ux', 'yogi', 'nu', 'lakU'],
#  'nadavadaM': ['nad', 'av', 'adaM'],
#  'xeSaBARalaMxu': ['xeS', 'aBA', 'Ra', 'laM', 'xu'],
#  'weVlusA': ['weV', 'lu', 'sA'],
#  'viMtiwo': ['vi', 'Mt', 'iwo'],
#  'sujiw\u200ckumAr\u200c': ['su', 'ji', 'w\u200c', 'ku', 'mA', 'r\u200c'],
#  'miMcinaxi': ['mi', 'Mci', 'naxi'],
#  'veVlYlYAlsi': ['veV', 'lY', 'lYAl', 'si'],
#  'vyavahariMcadAnni': ['vy', 'av', 'ah', 'ar', 'iMc', 'ad', 'Anni'],
#  'ceyagaligiMxi': ['ce', 'ya', 'ga', 'li', 'giM', 'xi'],
#  'eVrranelalu': ['eVrr', 'an', 'el', 'alu'],
#  '22nAmineRan\u200claku': ['22n', 'Am', 'in', 'eR', 'an', '\u200cl', 'aku'],
#  'peRaMtla': ['pe', 'Ra', 'Mt', 'la'],
#  'mUdumAtlu': ['mUdu', 'mA', 'tlu'],
#  'sepatlo': ['se', 'pa', 'tlo'],
#  'xAKalEna': ['xA', 'KalE', 'na'],
#  'wqwIyASvAsa': ['wq', 'wI', 'yA', 'SvA', 'sa'],
#  'oVppukoni': ['oVpp', 'uk', 'oni'],
#  'gaMtakriwame': ['gaM', 'takr', 'iw', 'ame'],
#  'riMgavvagAne': ['ri', 'Mga', 'vv', 'agA', 'ne'],
#  'ekAraNamuwo': ['ek', 'Ara', 'Namu', 'wo'],
#  'vicceVnu': ['vi', 'cc', 'eV', 'nu'],
#  'putamuni': ['pu', 'tamu', 'ni'],
#  'sinimAwo': ['si', 'ni', 'mAwo'],
#  'jatAyupAka': ['ja', 'tA', 'yu', 'pA', 'ka'],
#  'kAswAneda': ['kA', 'swA', 'neda'],
#  'kAyalanniMtikI': ['kA', 'ya', 'la', 'nn', 'iM', 'tikI'],
#  'avivekAnni': ['av', 'ive', 'kA', 'nni'],
#  'asAXAraNaM': ['as', 'AX', 'Ar', 'aN', 'aM'],
#  'seVkratarIgAne': ['seV', 'kr', 'at', 'ar', 'IgA', 'ne'],
#  'itAliksulo': ['it', 'Al', 'iksu', 'lo'],
#  'oVkkaxAnike': ['oV', 'kk', 'axA', 'ni', 'ke'],
#  'trEniMg': ['tr', 'En', 'iMg'],
#  'enuguke': ['en', 'ugu', 'ke'],
#  'weVlusukovAlsiMxi': ['weV', 'lu', 'suk', 'ov', 'Al', 'si', 'Mxi'],
#  'xvAropari': ['xvA', 'ro', 'pari'],
#  'moVxalagu': ['moV', 'xa', 'la', 'gu'],
#  'kotaloki': ['ko', 'ta', 'loki'],
#  'cinnapillalu': ['ci', 'nn', 'ap', 'il', 'la', 'lu'],
#  'caMxraSeKarAvu': ['ca', 'Mx', 'ra', 'SeK', 'ar', 'Avu'],
#  'vaxilipeVtti': ['va', 'xi', 'li', 'peVt', 'ti'],
#  'saripovani': ['sa', 'ri', 'po', 'vani'],
#  'rAwriMcara': ['rAwr', 'iMc', 'ara'],
#  'veVnniccinaco': ['veV', 'nni', 'cc', 'ina', 'co'],
#  'Srikakulam': ['Sr', 'ika', 'kul', 'am'],
#  'pAlavuwunnAru': ['pA', 'la', 'vu', 'wunn', 'Aru'],
#  'japAnulo': ['ja', 'pA', 'nu', 'lo'],
#  'eVrracaMxanaM': ['eVr', 'rac', 'aMx', 'an', 'aM'],
#  'aMbaxevudu': ['aM', 'bax', 'ev', 'udu'],
#  'lopaMvalla': ['lo', 'paM', 'va', 'lla'],
#  'weVllagoVdugukiMxa': ['weV', 'll', 'ag', 'oV', 'dug', 'uk', 'iMxa'],
#  'rAhuxaSalo': ['rA', 'hu', 'xa', 'Sa', 'lo'],
#  'uMdetappati': ['uMd', 'etap', 'pa', 'ti'],
#  'o0tAriyoloni': ['o0tA', 'ri', 'yo', 'loni'],
#  'eVMjeVmu': ['eV', 'MjeV', 'mu'],
#  'saMskqwini': ['saMs', 'kq', 'wi', 'ni'],
#  'AkASalo': ['AkAS', 'alo'],
#  'abaxxamu': ['aba', 'xx', 'amu'],
#  'kanipiMcunu': ['ka', 'ni', 'pi', 'Mc', 'unu'],
#  'weVlaMgANawo': ['weVl', 'aM', 'gA', 'Nawo'],
#  'solipowU': ['so', 'li', 'po', 'wU'],
#  'wAj\u200ckqRNa': ['wA', 'j\u200ckq', 'RNa'],
#  'vixyakosaM': ['vix', 'yak', 'os', 'aM'],
#  'pravahiMciMxi': ['pra', 'va', 'hiMc', 'iM', 'xi'],
#  'SreNulanu': ['SreN', 'ul', 'anu'],
#  'poVgapIlci': ['po', 'Vg', 'ap', 'Il', 'ci'],
#  'bAXyawAyuwaMgA': ['bAX', 'ya', 'wA', 'yu', 'wa', 'MgA'],
#  'muxralounna': ['mux', 'ra', 'lo', 'unna'],
#  'wirucirapalli': ['wiru', 'ci', 'rap', 'al', 'li'],
#  'mAnasasarovarAniki': ['mAn', 'as', 'asar', 'ov', 'arA', 'niki'],
#  'peVttiswuMxi': ['peVt', 'ti', 'sw', 'uM', 'xi'],
#  'cAlakapowe': ['cA', 'la', 'ka', 'po', 'we'],
#  'SibUSoreVn': ['Si', 'bUS', 'or', 'eVn'],
#  'AveSAniki': ['Av', 'eSA', 'niki'],
#  'CAritabul\u200c': ['CA', 'ri', 'ta', 'bu', 'l\u200c'],
#  'nirmiMcAlanI': ['ni', 'rm', 'iMc', 'Al', 'anI'],
#  'wappulu': ['wa', 'ppu', 'lu'],
#  'dimAMd\u200cpE': ['di', 'mA', 'Md\u200c', 'pE'],
#  'yAMtibayAtiks\u200c': ['yA', 'Mti', 'ba', 'yA', 'ti', 'ks\u200c'],
#  'sIriyas\u200cgAne': ['sIri', 'ya', 's\u200c', 'gAne'],
#  'parugeVwwedu': ['pa', 'rug', 'eV', 'ww', 'edu'],
#  'yiccAru': ['yi', 'cc', 'Aru'],
#  'majilIlu': ['ma', 'jilI', 'lu'],
#  'reVccipoyi': ['reVc', 'ci', 'poyi'],
#  'pravahiMcexi': ['pr', 'av', 'ahiM', 'ce', 'xi'],
#  'mIranukoVMxurA': ['mIr', 'anu', 'koV', 'Mxu', 'rA'],
#  'beriyAtrik': ['ber', 'iy', 'At', 'rik'],
#  'pArabosi': ['pA', 'ra', 'bo', 'si'],
#  'wAralannI': ['wA', 'ral', 'annI'],
#  'breVjil': ['br', 'eV', 'jil'],
#  'Bajiswe': ['Ba', 'ji', 'swe'],
#  'aMtarAniwanaM': ['aM', 'tar', 'An', 'iw', 'an', 'aM'],
#  'viBajiMcavaccu': ['vi', 'Ba', 'ji', 'Mca', 'va', 'ccu'],
#  'xqDawvaM': ['xqD', 'aw', 'vaM'],
#  'vyUhaMgA': ['vyU', 'ha', 'MgA'],
#  'prapaMcaMlo': ['pr', 'ap', 'aM', 'caM', 'lo'],
#  'pAriSrAmikaMgA': ['pA', 'riS', 'rA', 'mi', 'ka', 'MgA'],
#  'pUrNamma': ['pUr', 'Na', 'mma'],
#  'nAtikalannI': ['nA', 'ti', 'kal', 'annI'],
#  'ceyavaccani': ['ce', 'ya', 'va', 'cca', 'ni'],
#  'prowsahiMci': ['pr', 'ow', 'sa', 'hi', 'Mci'],
#  'gurwuMtAnani': ['gur', 'wuMt', 'An', 'ani'],
#  'saMxeSAlni': ['sa', 'Mx', 'eS', 'Al', 'ni'],
#  'nyAyaMwo': ['nyAy', 'aMwo'],
#  'jillAnuMdi': ['jill', 'An', 'uMdi'],
#  'AgiMxemI': ['Ag', 'iM', 'xemI'],
#  'mammalnaMxarnI': ['ma', 'mma', 'lnaM', 'xa', 'rnI'],
#  'rARtraMloni': ['rA', 'Rt', 'ra', 'Mlo', 'ni'],
#  'maMdana': ['ma', 'Md', 'ana'],
#  'viRNurUpAya': ['viR', 'NurU', 'pA', 'ya'],
#  'nirvahiMcabadunu': ['nir', 'va', 'hi', 'Mca', 'ba', 'du', 'nu'],
#  'Agipoyexi': ['Ag', 'ipoy', 'exi'],
#  'marripAlu': ['ma', 'rrip', 'Alu'],
#  'xuswulawo': ['xu', 'swu', 'lawo'],
#  'karaMbu': ['ka', 'raM', 'bu'],
#  'vAnigaddaM': ['vAn', 'ig', 'add', 'aM'],
#  '2013-12-15T10:47:33': ['20', '13-1', '2-', '15T', '10', ':4', '7:33'],
#  'mallamma': ['ma', 'll', 'amma'],
#  'maliMganu': ['mal', 'iM', 'ganu'],
#  '155-172.': ['155-', '172.'],
#  'mahAsaBa': ['ma', 'hA', 'sa', 'Ba'],
#  'kaxilipoyAyi': ['ka', 'xi', 'li', 'po', 'yA', 'yi'],
#  'vAyiMcu': ['vA', 'yi', 'Mcu'],
#  'xalElAmAwo': ['xal', 'El', 'Am', 'Awo'],
#  'niruxyogiwa': ['ni', 'ruxy', 'ogi', 'wa'],
#  'sAhiwyamu': ['sAh', 'iw', 'ya', 'mu'],
#  'riMcataM': ['ri', 'Mc', 'at', 'aM'],
#  'jEtlIwo': ['jEt', 'lI', 'wo'],
#  'oxArcAru': ['ox', 'Ar', 'cAru'],
#  'kummari0cu': ['ku', 'mm', 'ar', 'i0cu'],
#  'neVttesiMxi': ['neV', 'tt', 'es', 'iM', 'xi'],
#  'iä¢xujiw': ['iä', '¢xuj', 'iw'],
#  'polcinatlayiwe': ['polc', 'in', 'at', 'la', 'yi', 'we'],
#  'rODlanee': ['rOD', 'la', 'nee'],
#  'nalaBESAwaM': ['nal', 'aB', 'ESAw', 'aM'],
#  'akROhiNula': ['akRO', 'hi', 'Nu', 'la'],
#  '1994-10-31': ['19', '94-1', '0-', '31'],
#  'kqwrimaMgA': ['kqwr', 'im', 'aMgA'],
#  'krikeVtarlu': ['kr', 'ik', 'eVt', 'ar', 'lu'],
#  'arikAlYlYa': ['ar', 'ik', 'Al', 'YlYa'],
#  'meVrugani': ['meV', 'ru', 'ga', 'ni'],
#  'saMwoRiMcAdu': ['saM', 'wo', 'RiMc', 'Adu'],
#  'biddawo': ['bi', 'dd', 'awo'],
#  'areVreV': ['ar', 'eVr', 'eV'],
#  'XanahAnimaNikattunaMxu': ['Xan',
#   'ah',
#   'Ani',
#   'maN',
#   'ik',
#   'attu',
#   'naM',
#   'xu'],
#  'meVmoVrAMdam': ['meV', 'moV', 'rA', 'Md', 'am'],
#  'WOjaMdu': ['WOj', 'aM', 'du'],
#  'siggugA': ['si', 'gg', 'ugA'],
#  'pattukovoy\u200c': ['pat', 'tu', 'ko', 'voy\u200c'],
#  'karapawra0': ['kara', 'pa', 'wra0'],
#  'patamatalaMkaku': ['pata', 'ma', 'tal', 'aMk', 'aku'],
#  '16.puxicceri': ['16.p', 'uxic', 'ce', 'ri'],
#  'garibAld': ['ga', 'ri', 'bAld'],
#  'rAmAyaNa': ['rA', 'mA', 'ya', 'Na'],
#  'BUpariveRtiwa': ['BU', 'par', 'iv', 'eR', 'ti', 'wa'],
#  'Xarmamane': ['Xar', 'ma', 'mane'],
#  'EdApsin': ['EdAp', 'sin'],
#  'Population': ['Popu', 'la', 'tion'],
#  'mqgamulu': ['mq', 'ga', 'mu', 'lu'],
#  'sadeVn\u200cgA': ['sa', 'deV', 'n\u200c', 'gA'],
#  'paviwravqwwigA': ['pa', 'vi', 'wr', 'av', 'qwwi', 'gA'],
#  'palYlYulevugA': ['pal', 'Yl', 'Yule', 'vu', 'gA'],
#  'vakwalu': ['va', 'kw', 'alu'],
#  '__weblink__101BC8Qafnu': ['__we', 'bl', 'ink', '__1', '01BC', '8Qaf', 'nu'],
#  'visuruwU': ['vi', 'su', 'ru', 'wU'],
#  'caxvulu': ['ca', 'xvu', 'lu'],
#  'eVvarikivAru': ['eV', 'va', 'ri', 'ki', 'vAru'],
#  'SrInivAs\u200cyAxav': ['Sr', 'In', 'iv', 'As\u200cy', 'Ax', 'av'],
#  'aBivqxWi': ['aB', 'iv', 'qxWi'],
#  'teVligrAPku': ['te', 'Vl', 'ig', 'rA', 'Pku'],
#  'dIlApadipoyinA': ['dI', 'lA', 'pa', 'di', 'poyi', 'nA'],
#  'cuttupakkalaku': ['cu', 'ttu', 'pa', 'kk', 'al', 'aku'],
#  'peVttuna': ['peV', 'tt', 'una'],
#  'sOBaxro': ['sOB', 'ax', 'ro'],
#  'cejikkiMcukovAlani': ['ceji', 'kk', 'iMc', 'uko', 'vA', 'la', 'ni'],
#  'bIdijEn': ['bI', 'di', 'jEn'],
#  'paMpiswAM': ['pa', 'Mp', 'isw', 'AM'],
#  'Romronu': ['Rom', 'ro', 'nu'],
#  'cinnaviRayamU': ['ci', 'nn', 'avi', 'Ra', 'ya', 'mU'],
#  'eVksarsEjes': ['eVk', 'sa', 'rs', 'Ejes'],
#  'araviMxa': ['ara', 'vi', 'Mxa'],
#  'stArtayiMxi': ['st', 'Ar', 'ta', 'yi', 'Mxi'],
#  'peVMdiMg\u200clounnAyi': ['peV', 'Mdi', 'Mg', '\u200clou', 'nn', 'Ayi'],
#  'likkar\u200c': ['li', 'kka', 'r\u200c'],
#  'awikramamu': ['aw', 'ik', 'ra', 'ma', 'mu'],
#  'veVlYuwuMdevArani': ['veV', 'lY', 'uwuM', 'de', 'vA', 'ra', 'ni'],
#  'BAraw\u200cwo': ['BA', 'ra', 'w\u200c', 'wo'],
#  'rAniyAn': ['rAn', 'iy', 'An'],
#  'jarigivuMdexi': ['ja', 'ri', 'gi', 'vu', 'Md', 'exi'],
#  'savariMcalekapoyAyi': ['sa', 'va', 'ri', 'Mc', 'alek', 'ap', 'oy', 'Ayi'],
#  'saMbaMXiMcinave': ['saMb', 'aM', 'XiMc', 'in', 'ave'],
#  'xigaMbarAya': ['xig', 'aM', 'bar', 'Aya'],
#  'byAlast': ['by', 'Al', 'ast'],
#  'Baje2haM–': ['Ba', 'je2', 'ha', 'M–'],
#  'priyamugA': ['pr', 'iy', 'amu', 'gA'],
#  'xvAxaSAxiwyulunu': ['xv', 'Ax', 'aSAx', 'iw', 'yul', 'unu'],
#  'mAtalAdukovataM': ['mA', 'ta', 'lA', 'du', 'ko', 'va', 'taM'],
#  'SivarAman\u200c': ['Si', 'var', 'Ama', 'n\u200c'],
#  'viswqwaparacAli': ['vi', 'swqw', 'ap', 'ar', 'ac', 'Ali'],
#  'engineering': ['eng', 'in', 'eeri', 'ng'],
#  'AduwunnatlugA': ['Adu', 'wunn', 'at', 'lu', 'gA'],
#  'ceVsukoVni': ['ceV', 'su', 'koV', 'ni'],
#  'cinnappuxu': ['ci', 'nn', 'appu', 'xu'],
#  'nilaxISAru': ['ni', 'la', 'xI', 'SA', 'ru'],
#  'viBajiswAru': ['vi', 'Ba', 'ji', 'sw', 'Aru'],
#  'PyAkRanist\u200c': ['PyA', 'kR', 'ani', 'st\u200c'],
#  'wappiMcukuneMxuku': ['wa', 'pp', 'iMc', 'uku', 'ne', 'Mx', 'uku'],
#  'DIkoVnadAnikI': ['DIk', 'oV', 'na', 'dAni', 'kI'],
#  'bIeVMIsI': ['bI', 'eV', 'MIsI'],
#  'buraKAlo': ['bu', 'ra', 'KA', 'lo'],
#  'limiteVd\u200cki': ['li', 'mi', 'teV', 'd\u200c', 'ki'],
#  'eVrukaloki': ['eVr', 'uk', 'alo', 'ki'],
#  'padipokuMdA': ['pad', 'ip', 'ok', 'uM', 'dA'],
#  'sawyanArAyaNasvAmi': ['sawy', 'an', 'Ar', 'Ay', 'aN', 'as', 'vA', 'mi'],
#  'goVppagoVppa': ['go', 'Vp', 'pago', 'Vp', 'pa'],
#  'BUmmIxa': ['BU', 'mm', 'Ixa'],
#  'neVwwikeVkkiMcukuMte': ['ne', 'Vww', 'ik', 'eVkk', 'iMcu', 'ku', 'Mte'],
#  'xeVlpabadutaye': ['xeVl', 'pa', 'ba', 'du', 'ta', 'ye'],
#  'paMdiMxani': ['paM', 'diMx', 'ani'],
#  'nAmineteVd\u200c': ['nAm', 'in', 'et', 'eV', 'd\u200c'],
#  'xuRpraBAvAlaku': ['xu', 'Rp', 'ra', 'BA', 'vA', 'laku'],
#  'pariRkAriMcAli': ['par', 'iR', 'kAr', 'iMc', 'Ali'],
#  'pAlpaddaxani': ['pAl', 'pa', 'dda', 'xa', 'ni'],
#  'ArAXiMcucuMdeVnu': ['ArAX', 'iM', 'cu', 'cu', 'Md', 'eV', 'nu'],
#  '2009-06-04.': ['20', '09-0', '6-0', '4.'],
#  'SrIxurgA': ['SrI', 'xu', 'rgA'],
#  'vakwagA': ['va', 'kw', 'agA'],
#  'ceVk\u200cpostupE': ['ceV', 'k\u200cpo', 'st', 'upE'],
#  'nAnnagAru': ['nA', 'nna', 'gA', 'ru'],
#  'AtagAlYlYu': ['Ata', 'gA', 'lY', 'lYu'],
#  'Visakhapatnam': ['Vis', 'ak', 'ha', 'pa', 'tnam'],
#  'badjeVtlo': ['bad', 'je', 'Vt', 'lo'],
#  'ceswunnAnaMte': ['ce', 'sw', 'unnA', 'na', 'Mte'],
#  'baravasaMgAvaddiswuMte': ['bar', 'ava', 'saMg', 'Ava', 'dd', 'isw', 'uMte'],
#  'Feelings': ['Fee', 'li', 'ngs'],
#  'AviRkaraNagOrava': ['AviR', 'ka', 'ra', 'NagO', 'ra', 'va'],
#  'nyAyasWAnAlu': ['nyA', 'ya', 'sWA', 'nA', 'lu'],
#  'jIeVseVP': ['jI', 'eV', 'seVP'],
#  'jaMwuvayinA': ['jaM', 'wu', 'vay', 'inA'],
#  'objectives': ['obj', 'ec', 'ti', 'ves'],
#  'varmagAri': ['var', 'ma', 'gA', 'ri'],
#  'fontःnormal': ['fo', 'ntःn', 'or', 'mal'],
#  'hiRtarikal': ['hi', 'Rt', 'arik', 'al'],
#  'natiMceru': ['nat', 'iMce', 'ru'],
#  'progrAm\u200cllo': ['pr', 'og', 'rA', 'm\u200cl', 'lo'],
#  'janmaBUmilo': ['jan', 'ma', 'BU', 'mi', 'lo'],
#  'Googlece': ['Go', 'og', 'le', 'ce'],
#  'vIlYlYaMxarU': ['vIlY', 'lY', 'aM', 'xa', 'rU'],
#  '7,8,9wexIllo': ['7,', '8,9w', 'ex', 'Il', 'lo'],
#  'SaMkar\u200cpalli': ['SaM', 'ka', 'r\u200cp', 'al', 'li'],
#  'rAmakuppaM': ['rAm', 'aku', 'pp', 'aM'],
#  'beVMdli': ['beV', 'Md', 'li'],
#  'bayomAs': ['ba', 'yo', 'mAs'],
#  'koVnasAgiswunnAnu': ['koV', 'na', 'sA', 'gi', 'sw', 'unnA', 'nu'],
#  'anuBaviswunnAru': ['anu', 'Ba', 'vi', 'sw', 'un', 'nA', 'ru'],
#  'sOlaByAnni': ['sO', 'la', 'ByAn', 'ni'],
#  'Berleburg': ['Ber', 'le', 'bu', 'rg'],
#  'xomalakeVM': ['xo', 'ma', 'la', 'keVM'],
#  'praXAnopAXyAyurAlu': ['pr', 'aX', 'An', 'op', 'AX', 'yA', 'yu', 'rA', 'lu'],
#  'jabbuwo': ['ja', 'bb', 'uwo'],
#  'srIlaMxarU': ['srIl', 'aM', 'xarU'],
#  'sAyaMkAlAllo': ['sA', 'ya', 'Mk', 'Al', 'Allo'],
#  'asaMpUrNamEnaxigA': ['as', 'aMp', 'Ur', 'Na', 'mEna', 'xi', 'gA']}

# %%
# %%time
sorted_probs = sort_probs(probs)
pruned_probs = dict(sorted_probs)
word_list = list(pruned_probs.keys())
word_list_len = len(word_list)
index_array = numpy.array(list(range(len(word_list))))
ratios = {}
for index, split in enumerate(split_list):
    split_vec = split2vec(split)
    select_w = split_vec.nonzero()
    in_deg = len(select_w[0])
    #print(split_vec.nonzero())
    #print(split, in_deg, select_w)
    out_deg = 0
    for wi in select_w[0]:
        w = word_list[wi]        
        if w in max_splits:
            wsplit = max_splits[w]
            if split in wsplit:
                out_deg += 1

        
#        print(split, w, wsplit, split in wsplit)
    #ratio = float(in_deg)/out_deg if out_deg > 0 else 0
    #ratio = 1 - (out_deg/float(in_deg))
    ratio = out_deg * (in_deg/float(word_list_len))
    ratios[split] = ratio
    if index % 1000 == 0:
        print(f"{index} done")
# Out:
# 0 done
# 1000 done
# 2000 done
# 3000 done
# 4000 done
# 5000 done
# 6000 done
# 7000 done
# 8000 done
# 9000 done
# 10000 done
# 11000 done
# 12000 done
# 13000 done
# 14000 done
# 15000 done
# 16000 done
# 17000 done
# 18000 done
# 19000 done
# 20000 done
# 21000 done
# 22000 done
# 23000 done
# 24000 done
# 25000 done
# 26000 done
# 27000 done
# 28000 done
# 29000 done
# 30000 done
# 31000 done
# 32000 done
# 33000 done
# 34000 done
# 35000 done
# 36000 done
# 37000 done
# 38000 done
# 39000 done
# 40000 done
# 41000 done
# 42000 done
# 43000 done
# 44000 done
# 45000 done
# 46000 done
# 47000 done
# 48000 done
# 49000 done
# 50000 done
# 51000 done
# 52000 done
# 53000 done
# 54000 done
# 55000 done
# 56000 done
# 57000 done
# 58000 done
# 59000 done
# 60000 done
# 61000 done
# 62000 done
# 63000 done
# 64000 done
# 65000 done
# 66000 done
# 67000 done
# 68000 done
# 69000 done
# 70000 done
# 71000 done
# 72000 done
# 73000 done
# 74000 done
# 75000 done
# 76000 done
# 77000 done
# 78000 done
# 79000 done
# 80000 done
# 81000 done
# 82000 done
# 83000 done
# 84000 done
# 85000 done
# 86000 done
# 87000 done
# 88000 done
# 89000 done
# 90000 done
# 91000 done
# 92000 done
# 93000 done
# 94000 done
# 95000 done
# 96000 done
# 97000 done
# 98000 done
# 99000 done
# 100000 done
# 101000 done
# 102000 done
# 103000 done
# 104000 done
# 105000 done
# 106000 done
# CPU times: user 4min 22s, sys: 13.9 s, total: 4min 36s
# Wall time: 7min 57s

# %%
ratios = pd.Series(ratios)

# %%
ratios.count()
# Out:
# 106630

# %%
ratios[ratios > 0].count()
# Out:
# 226

# %%
p_ratios = ratios[ratios > 0].sort_values()

# %%
#p_ratios['es'],p_ratios['ies']
p_glens = p_ratios.index.str.len()

# %%
p_glens.value_counts()
# Out:
# 2    139
# 3     65
# 4     22
# dtype: int64

# %%
# %matplotlib inline
p_ratios.plot()

# %%
w = 'samayAniki'
sequences = get_split_sequences(w)
sequences
# Out:
# [['sa', 'ma', 'yA', 'ni', 'ki'],
#  ['sa', 'ma', 'yA', 'niki'],
#  ['sa', 'ma', 'yAni', 'ki'],
#  ['sa', 'may', 'An', 'iki'],
#  ['sa', 'may', 'Ani', 'ki'],
#  ['sa', 'mayA', 'ni', 'ki'],
#  ['sa', 'mayA', 'niki'],
#  ['sam', 'ay', 'An', 'iki'],
#  ['sam', 'ay', 'Ani', 'ki'],
#  ['sam', 'ayA', 'ni', 'ki'],
#  ['sam', 'ayA', 'niki'],
#  ['sam', 'ayAn', 'iki'],
#  ['sama', 'yA', 'ni', 'ki'],
#  ['sama', 'yA', 'niki'],
#  ['sama', 'yAn', 'iki']]

# %%
get_max_split(w)
# Out:
# ['sa', 'ma', 'yA', 'niki']

# %%
def run_sequence_f(sequence, good_splits):
    scores = []
    new_sequence = []
    #print(sequence)
    for s in range(1, len(sequence)):
        x, y = sequence[s - 1], sequence[s]
        #print(x, y)
        if (x in good_splits) and (y in good_splits):
            #print(x, y)
            try:
                scores.append(delta_p(x, y))
            except Exception as e:
                print(e.with_traceback())
                
            new_sequence.append(x)
        else:
            #print((x in good_splits), (y in good_splits), x, y, new_sequence)
            
            if y not in good_splits:
                if len(new_sequence) == 0:                
                    new_sequence.append(x + y)
                elif (x in good_splits):
                    if new_sequence[-1].endswith(x):
                        new_sequence[-1] += y
                    else:
                        new_sequence.append(x + y)
                    
                else:
                    new_sequence[-1] += y
                    
            elif x not in good_splits:                         
                if len(new_sequence) == 0:
                    new_sequence.append(x + y)
                else:
                    new_sequence.append(y)
                
                split_vec = split2vec(y)
                select_w = split_vec.nonzero()
                in_deg = len(select_w[0])
                scores.append(good_splits[y]/in_deg)
                
    #print(new_sequence)
    if not new_sequence[-1].endswith(sequence[-1]):
        new_sequence.append(sequence[-1])
        
    return new_sequence, scores, sum(scores) / len(sequence)


def score_sequences_f(sequences,good_splits):
    scores = []
    new_seqs = []
    for seq in sequences:
        new_seq_f, _, score_f = run_sequence_f(seq, good_splits)
        new_seq_r, _, score_r= run_sequence_f(seq[::-1], good_splits)
        new_seq_r = new_seq_r[::-1]
        new_seq = new_seq_f if score_f > score_r else new_seq_r
        new_seqs.append(new_seq_f)
#        score = score_f
        score = (score_f + score_r)/2
        scores.append(score)
    return new_seqs, scores

def get_max_split_f(w, good_splits):
    splits = get_split_sequences(w)
    new_splits, scores = score_sequences_f(splits, good_splits)
    max_index = scores.index(max(scores))
    #print(max_index)
    max_split = new_splits[max_index]
    return max_split, max(scores)

# %%
#score_sequences_f(sequences, p_ratios)
get_max_split_f('nirNayiMcukogala', p_ratios)
# for k in sequences:
#     print('-'*5)
#     print(k)
#     print(run_sequence_f(k, p_ratios))
# Out:
# (['nirNay', 'iMcukoga', 'la'], 2.2524995706172695e-05)

# %%
run_sequence_f(['in', 'it', 'iali', 'zati', 'on'], p_ratios)
# Out:
# in it
# it iali
# True False it iali ['in']
# iali zati
# False False iali zati ['in', 'itiali']
# zati on
# False True zati on ['in', 'itializati']
# (['in', 'itializati', 'on'],
#  [0.03913968974847393, 0.020425967149990978],
#  0.011913131379692982)

# %%
# %%time
max_splits = {}
for i, w in enumerate(sample_words):
    try:
        sp = get_max_split_f(w, p_ratios)
        max_splits[w] = sp
        if i % 1000 == 0:
            print(f"{i} done")
    except:
        pass
# Out:
# 0 done
# CPU times: user 5min 5s, sys: 167 ms, total: 5min 5s
# Wall time: 5min 14s

# %%
max_splits
# Out:
# {'nunnAru': (['nunnA', 'ru'], 1.267031008472214e-05),
#  'moyadaM': (['mo', 'yadaM'], 0.11386912407101377),
#  'vaMgilekapovadaM': (['va', 'Mgilekapov', 'adaM'], 0.016998523027387503),
#  'maguvalaku': (['ma', 'gu', 'valaku'], 0.18124513300621076),
#  'veVlYlYakuMdA': (['veVlYlYa', 'kuMdA'], 1.4782028432175829e-05),
#  'kAmAMXurAligA': (['kAmAMXu', 'rA', 'rA', 'li', 'gA'], 0.022514482363229692),
#  'vIdkoVlipAdu': (['vIdkoV', 'koV', 'lipAdu'], 0.014902992249798942),
#  'AnupAnulu': (['AnupAn', 'An', 'ulu'], 0.15906712299221093),
#  'gArdeVns': (['gArd', 'eVns'], 1.9005465127083213e-05),
#  'sureR\u200cku': (['sureR\u200c', 'ku'], 1.1262497853086346e-05),
#  'vrawAnni': (['vrawAn', 'ni'], 1.4078122316357932e-05),
#  'vaMSAniki': (['vaMSA', 'niki'], 2.9564056864351657e-05),
#  'bayograPI': (['bayog', 'raPI'], 2.0061324300810052e-05),
#  'galavAriwo': (['galavA', 'ri', 'ri', 'wo'], 0.044113975449023006),
#  'guddipeVlYlAnni': (['guddip', 'eVlYlA', 'nni'], 1.4359684762685095e-05),
#  'vismayAniki': (['vismayA', 'niki'], 2.1117183474536899e-05),
#  'nyUjilAMd\u200cpE': (['nyUjilAMd\u200cpE'], 2.1117183474536901e-06),
#  'puwrudilA': (['puwrudilA'], 1.9709371242901106e-05),
#  'adugupeVttabovadaM': (['adugup', 'eVttabovad', 'aM'],
#   2.3228901821990591e-05),
#  'kodandaramuluswamitemple': (['kodandaram', 'ulu', 'ulu', 'sw', 'amitemple'],
#   0.083022414999729829),
#  'weVliyaMxe': (['weVli', 'yaMxe'], 2.1117183474536899e-05),
#  'ceVppukogaligina': (['ceVppukogaligi', 'na'], 1.9427808796573947e-05),
#  'ceyiMcAru': (['ceyiMcA', 'ru'], 1.1614450910995295e-05),
#  'xarimilYA': (['xarimilYA'], 7.0390611581789671e-06),
#  'vicAriMcAlo': (['vicAriMcA', 'lo'], 1.1614450910995295e-05),
#  'gAdpuwoz': (['gAdpuwoz'], 1.1262497853086347e-05),
#  'teMdarlu': (['teMd', 'ar', 'ar', 'lu'], 0.013855606705794915),
#  'vqkRAla': (['vqkRA', 'la'], 1.9709371242901106e-05),
#  'koVdavalYlYa': (['koVda', 'va', 'va', 'lYlYa'], 0.12297924080550854),
#  'samakUruswuMxi': (['samakU', 'ruswuM', 'xi'], 1.5204372101666567e-05),
#  'vAreVMt': (['vAreVMt'], 1.9709371242901109e-05),
#  'wallilA': (['wallilA'], 8.4468733898147605e-06),
#  'bijineVs\u200cnu': (['bijineVs\u200c', 'nu'], 6.3351550423610699e-06),
#  'parirakRakudigA': (['par', 'irakRa', 'kudigA'], 0.018192311599118917),
#  'eVkkuvavuwuMxemo”': (['eVkku', 'ku', 'va', 'vuwuMxemo”'],
#   0.039279489067886503),
#  'koVttiMci': (['koVttiM', 'ci'], 7.0390611581789671e-06),
#  'byAtarI': (['byAta', 'rI'], 2.8156244632715868e-06),
#  'cUpiMcatAniko': (['cUpiMcatA', 'niko'], 2.0272496135555424e-05),
#  'lobadinaxigA': (['lo', 'badina', 'xi', 'xi', 'gA'], 0.084157733749496547),
#  'iMjanIrla': (['iMjan', 'Ir', 'Ir', 'la'], 0.098992997638560037),
#  'maccuwunaka': (['maccuw', 'un', 'un', 'aka'], 0.14179880617262036),
#  'kadagataM': (['kadagat', 'aM'], 2.534062016944428e-05),
#  'eVnnAlYlugAno': (['eVnnAlYlu', 'gAno'], 1.8583121457592473e-05),
#  'uMdadaMsAmAjika': (['uMdadaM', 'adaM', 'sAmAji', 'ka'],
#   0.039150880250163396),
#  'sXApanaku': (['sXApan', 'an', 'aku'], 0.054754644881539749),
#  'peVxavulAniMci': (['peVxavulA', 'niMci'], 2.534062016944428e-05),
#  'eVMpikaceyagA': (['eVMpi', 'kaceya', 'gA'], 1.7738434118610998e-05),
#  'baMwuleyAlaMtene': (['ba', 'Mwuley', 'Al', 'Al', 'aMtene'],
#   0.048343672387266431),
#  'svAwaMwyra': (['svAwaM', 'aM', 'wyra'], 1.0068154986105331),
#  'kidnAp\u200c': (['kidnAp\u200c'], 1.9709371242901106e-05),
#  'BojyeRu': (['BojyeRu'], 0.0),
#  'sOBrAwqwva': (['sOBrAwqw', 'va'], 2.534062016944428e-05),
#  'mAriRas\u200c': (['mA', 'ri', 'Ras\u200c'], 1.0112096034962839),
#  'pagetitlefont': (['pagetitlefont'], 1.3726169258448984e-05),
#  'manasaMwA': (['manasaMwA'], 1.1262497853086347e-05),
#  'Upiriwiwwulaku': (['Upiriwiwwula', 'ku'], 9.2915607287962363e-06),
#  'ceyaleka': (['ceyaleka'], 2.8156244632715865e-05),
#  'samIpiswunnappudu': (['samIpi', 'swunn', 'appudu'], 1.1262497853086347e-05),
#  'aggiweVgulu': (['aggiw', 'iw', 'eVgulu'], 0.1632677018722978),
#  'jilakaramma': (['jil', 'akaram', 'ma'], 0.16491932568971429),
#  'wIsukonivaswAru': (['wIsukoni', 'vaswA', 'ru'], 1.9427808796573947e-05),
#  'xaSAbxAlunnAnu': (['xaSAbx', 'Al', 'Al', 'unnAnu'], 0.099082934322582611),
#  'nirasanalu': (['niras', 'analu'], 2.9564056864351664e-05),
#  'eVkkadiko': (['eVkkadiko'], 1.4078122316357934e-05),
#  'megnatik': (['megnatik'], 4.2234366949073797e-05),
#  'koVlawalU': (['koV', 'lawalU'], 0.0067547153505776412),
#  'guddivAdigA': (['guddi', 'vAdi', 'gA'], 8.4468733898147605e-06),
#  'rameS\u200cwo': (['rameS\u200c', 'wo'], 1.5485934547993725e-05),
#  'steRan\u200cbeVyil': (['steRan\u200cb', 'eVyil'], 2.7029994847407238e-05),
#  'neVravercu': (['neVravercu'], 1.900546512708321e-05),
#  'vyarWaM': (['vyarWaM'], 3.097186909598745e-05),
#  'aNuvulu': (['aNuvu', 'lu'], 1.1262497853086346e-05),
#  'vyAsaBagavAnudu': (['vyAsaBagav', 'An', 'An', 'udu'], 0.10501970445927403),
#  'brahmaraWaM': (['brahmaraW', 'aM'], 3.5899211906712734e-05),
#  'prapaMcavyApwa': (['prapaMc', 'av', 'av', 'yApwa'], 0.0013619803349313598),
#  'oeVs\u200ceVs\u200c': (['oeVs\u200c', 'eVs\u200c'], 1.4782028432175832e-05),
#  'vikasiMce': (['vi', 'kasiMce'], 0.031436763434828985),
#  'nItisaraParA': (['nIti', 'ti', 'saraPa', 'rA'], 0.16228154800411423),
#  'liMgamunakeVxurugA': (['liMgam', 'un', 'un', 'ak', 'eVxuru', 'gA'],
#   0.072339704355531248),
#  'pArtIlakU': (['pArtI', 'lakU'], 3.0619916038078507e-05),
#  'anipiMcukunna': (['anipiMcukun', 'na'], 2.4284760995717437e-05),
#  'koVmmukAswunnArani': (['koVmmukAsw', 'unnAra', 'ni'],
#   1.6893746779629524e-05),
#  'sWirapadAlanukune': (['sWirap', 'ad', 'ad', 'Alanukune'],
#   0.12209285594219735),
#  'nirvANamu': (['nirvANamu'], 1.4078122316357932e-05),
#  'wanavigA': (['wanavi', 'gA'], 1.4078122316357934e-05),
#  'bildarlu': (['bild', 'ar', 'ar', 'lu'], 0.013855606705794915),
#  'wIruwuMxA': (['wIruwuMxA'], 1.478202843217583e-05),
#  'yantIAr\u200c': (['yantI', 'Ar\u200c'], 1.5485934547993725e-05),
#  'karmasWAnamaMxuMdi': (['karmasWA', 'namaMxuMdi'], 3.2379681327623249e-05),
#  'cIkiMxi': (['cIkiM', 'xi'], 2.8156244632715868e-06),
#  'mabbula': (['mabbu', 'la'], 3.097186909598745e-05),
#  'braRiMg': (['braR', 'iMg'], 2.8156244632715868e-06),
#  'peraMtAlu…ammavAri': (['peraM', 'aM', 'tAlu…a', 'mm', 'mm', 'avAri'],
#   0.10635700219113664),
#  'nannaneVnA': (['nannan', 'an', 'eV', 'nA'], 0.061406512772052536),
#  'kUrcunnAru': (['kUrc', 'unnAru'], 8.4468733898147605e-06),
#  'yaSoxamma': (['yaSoxam', 'ma'], 1.900546512708321e-05),
#  'eVMeVs\u200ckeV': (['eVMeVs\u200ck', 'eV'], 2.2173042648263748e-05),
#  'annaxAwaku': (['annaxA', 'wa', 'wa', 'ku'], 0.015909358260050251),
#  'rAjarAjanareMvUxuni': (['rAjarAja', 'na', 'na', 'reMvU', 'xu', 'xu', 'ni'],
#   0.083400211561872134),
#  'sAhiwIlokamuna': (['sAhiwI', 'lo', 'lo', 'kamuna'], 0.014622691368875328),
#  'ArtistugA': (['Ar', 'tistu', 'gA'], 0.095826758975543269),
#  'wArakAsura': (['wArakA', 'su', 'su', 'ra'], 0.018040902408219362),
#  '20maMxi': (['20maM', 'xi'], 2.8156244632715868e-06),
#  'polIsolYlaM': (['polIso', 'lYl', 'lYl', 'aM'], 0.11898539591405033),
#  'moVttikAya': (['moVttikA', 'ya'], 1.2670310084722138e-05),
#  'kAtakAlawo': (['kAtakAla', 'wo'], 1.0558591737268451e-05),
#  'yawavrawaH': (['yawav', 'rawaH'], 2.9564056864351657e-05),
#  'avamAnavaruswU': (['avamAna', 'va', 'va', 'ruswU'], 0.0012298875521493942),
#  'uwwaraxiSa': (['uwwara', 'ra', 'xi', 'Sa'], 0.13011480421330274),
#  'xakRiNamaXya': (['xakRiN', 'amaX', 'ya'], 1.9427808796573947e-05),
#  'kewuxaSa': (['ke', 'wuxaSa'], 0.17254241643803739),
#  'eVMeVs\u200cpIni': (['eVMeVs\u200cpI', 'ni'], 2.5340620169444283e-05),
#  'SikRaNA': (['SikRaNA'], 2.8156244632715868e-06),
#  'yerpadatAniki': (['yerpadatA', 'niki'], 3.8855617593147894e-05),
#  'kArpoVreRan\u200c': (['kArpoV', 'reRan\u200c'], 4.2234366949073794e-06),
#  'polikanu': (['polik', 'ik', 'anu'], 0.084233480281043632),
#  'parimiwamayyAyi': (['parimiwa', 'mayyA', 'yi'], 2.1821089590354798e-05),
#  'raMgaMpE': (['raMgaMpE'], 1.267031008472214e-05),
#  'pAkiMxi': (['pAkiM', 'xi'], 4.2234366949073802e-06),
#  'minappappunu': (['minappa', 'ppu', 'ppu', 'nu'], 0.11689758113612794),
#  'mIveVnaka': (['mIveV', 'eV', 'na', 'ka'], 0.038943888971399214),
#  'awmahawyalu': (['awmahaw', 'ya', 'ya', 'lu'], 0.045927852008192716),
#  'vimuKudavE': (['vimuKudavE'], 2.8156244632715868e-06),
#  'nAtakAllo': (['nA', 'takAl', 'lo'], 0.094299985894337912),
#  'Bertrand': (['Bert', 'rand'], 1.900546512708321e-05),
#  'mAsaMlonU': (['mAsaMlonU'], 5.0681240338888559e-05),
#  'ceswunnappudu': (['ceswunn', 'appudu'], 1.1825622745740664e-05),
#  'cUpiMcesariki': (['cUpiM', 'ces', 'ces', 'ar', 'iki'], 0.20293045577285238),
#  'caMxramohan': (['caMxra', 'ra', 'mohan'], 0.098319592029291636),
#  'veVXavapani': (['veVXav', 'av', 'apani'], 0.0068228091038160339),
#  'caMxrulu': (['caMxru', 'lu'], 1.4078122316357932e-05),
#  'sAhiwyavAxulu': (['sAhiw', 'yavAxu', 'lu'], 2.4495932830462802e-05),
#  'xuswulane': (['xu', 'swulane'], 0.16833942152629311),
#  'rajanIkAMw\u200c': (['rajanIkAMw\u200c'], 1.9005465127083213e-05),
#  'Sa\u200cwAXikaMgA': (['Sa\u200cwAXi', 'kaMgA'], 1.0558591737268451e-05),
#  'saccciwsuKoxBoXakaM': (['saccc', 'iw', 'iw', 'suKoxBoXak', 'aM'],
#   0.018793905546810059),
#  'mahABAgyaM': (['mahABAgy', 'aM'], 2.7452338516897972e-05),
#  'vunnalAti': (['vunnalAti'], 4.2234366949073797e-05),
#  'gurwoVcciMxi': (['gurwoVcci', 'Mxi'], 5.2792958686342255e-06),
#  'ixxAmanna': (['ixxAma', 'ma', 'nna'], 0.017663359119054277),
#  'xuRtAmla': (['xu', 'Rt', 'Am', 'la'], 0.019649996117334534),
#  '00:10:29': (['00:10:29'], 0.0),
#  'gqhAnirmANa': (['gqhAn', 'An', 'irmANa'], 0.022292559428617666),
#  'kummuwunnAdu…': (['kummu', 'mu', 'wunnAdu…'], 0.18352673844383227),
#  'mAdyUl\u200cwo': (['mAdyUl\u200c', 'wo'], 4.2234366949073802e-06),
#  'cleaver': (['cleav', 'er'], 2.8156244632715868e-06),
#  'a0wyaxinAla': (['a0wya', 'ya', 'xi', 'nA', 'la'], 0.20296907080801127),
#  'spaRtame': (['spaR', 'tame'], 4.2234366949073802e-06),
#  'vacciMxo': (['vacciMxo'], 1.1262497853086346e-05),
#  'viXiswAru': (['viXiswA', 'ru'], 9.854685621450553e-06),
#  'vaccinanu': (['vaccin', 'in', 'anu'], 0.27020514334589474),
#  'sajjalapalleV': (['sajja', 'lapall', 'eV'], 3.1253431542314613e-05),
#  'vAralakopaMbunaMgUlaM': (['vA', 'ra', 'lakopaMbu', 'na', 'na', 'MgUlaM'],
#   0.075959707462793624),
#  'gaMXarvuNNi': (['gaMXarvuNNi'], 2.3228901821990587e-05),
#  'mosaMlo': (['mosaM', 'lo'], 8.4468733898147605e-06),
#  'pepar\u200c1': (['pepar\u200c1'], 3.6603118022530627e-05),
#  '“miwrulu': (['“miw', 'iw', 'ru', 'lu'], 0.017978121742008291),
#  'rAkapovaccu': (['rA', 'kapovaccu'], 0.064535951635687594),
#  'nAtakAlloni': (['nA', 'takAlloni'], 0.09429470659846928),
#  'kAyalanu': (['kAyalanu'], 2.8156244632715865e-05),
#  'leVkkaki': (['leVk', 'kaki'], 1.0558591737268451e-05),
#  'viMtimo': (['viMti', 'mo'], 4.2234366949073802e-06),
#  'varjasvaramunu': (['varjasv', 'aramu', 'nu'], 2.2524995706172691e-05),
#  'kaligiMcani': (['kalig', 'iMcani'], 1.3726169258448986e-05),
#  'ketAyiMcanunnattu': (['ketAy', 'iMcanun', 'nattu'], 2.7452338516897972e-05),
#  'eVrresu': (['eVrre', 'su'], 1.1262497853086347e-05),
#  'AMwrAknos\u200c': (['AMwrAknos\u200c'], 1.6893746779629521e-05),
#  'AxaraNaSIli': (['AxaraNaSI', 'li'], 2.1117183474536899e-05),
#  'pUrvIkulu': (['pUrvIku', 'lu'], 1.267031008472214e-05),
#  'Worldwide': (['Worldwi', 'de'], 1.4078122316357934e-06),
#  'prAmANikaM': (['prAmAN', 'ik', 'ik', 'aM'], 0.073782749301430611),
#  'vaccinave': (['vacci', 'nave'], 4.0122648601620105e-05),
#  'pracuraNakarwa': (['pracu', 'raNakarwa'], 1.9427808796573947e-05),
#  'XyAniMci': (['XyAniMci'], 2.8156244632715865e-05),
#  'kutuMbAlawo': (['kutuMbAla', 'wo'], 9.5027325635416049e-06),
#  'UxAraMgugA': (['UxAraM', 'aM', 'gu', 'gA'], 0.14328277079515142),
#  'mUdu.1.': (['mUdu.1.'], 5.6312489265431736e-06),
#  'eVluguku': (['eVlugu', 'ku'], 1.9709371242901109e-05),
#  'xEvavAkyaM': (['xEva', 'va', 'vAkyaM'], 0.085836861302439477),
#  'sixXamavuwoMxi': (['sixXa', 'mavuwo', 'Mxi'], 1.5204372101666567e-05),
#  'imitet\u200c': (['imitet\u200c'], 0.0),
#  'annAgAri': (['annAgA', 'ri'], 1.4078122316357936e-05),
#  'BArgavi': (['BArga', 'ga', 'vi'], 0.046338700847749853),
#  'nAcarenmEWunaM': (['nA', 'ca', 'renmEW', 'un', 'un', 'aM'],
#   0.19368463588647622),
#  'areVstulaku': (['ar', 'eVstulaku'], 0.063758355200805861),
#  'nAgaddaMkUdA': (['nAgadd', 'aMkUdA'], 4.5401944470254332e-05),
#  'wAgAvukaxA”': (['wA', 'gAvukaxA”'], 0.15192710037805945),
#  'instityut': (['instityut'], 2.8156244632715868e-06),
#  'paMtegAni': (['pa', 'Mte', 'gA', 'ni'], 0.24888579233329688),
#  'praswAvicadaM': (['praswAvicad', 'aM'], 2.2173042648263745e-05),
#  'vAl\u200cloni': (['vAl\u200clo', 'ni'], 1.8301559011265313e-05),
#  'subject': (['subject'], 1.4078122316357932e-06),
#  'Pijik\u200c\u200csa': (['Pijik\u200c\u200c', 'sa'], 4.2234366949073794e-06),
#  'pAvanaM': (['pA', 'vanaM'], 0.10813885869952461),
#  'suxarSanAniki': (['suxarSanA', 'niki'], 3.547686823722199e-05),
#  'reVn\u200cmin\u200c': (['reVn\u200cmi', 'n\u200c'], 3.1675775211805345e-06),
#  'vyAleVt\u200c': (['vyAl', 'Al', 'eVt\u200c'], 0.13171319244756796),
#  'anipiswAyi': (['anipi', 'swAyi'], 1.5837887605902675e-05),
#  'oVwwasAgiMxi…': (['oVwwa', 'wa', 'sAgiMxi…'], 0.065794014904770215),
#  '3racayiwaःkarakoswana': (['3raca', 'yi', 'yi', 'waःkarakoswana'],
#   0.01905983583660549),
#  'yeVMxuku': (['yeVMxu', 'ku'], 9.854685621450553e-06),
#  'caMxramma': (['caMxramma'], 2.534062016944428e-05),
#  'xunnuwunnav\u200c': (['xunnuwun', 'nav\u200c'], 3.167577521180535e-05),
#  'weVlisiMxallA': (['weVlisi', 'Mx', 'Mx', 'allA'], 0.042689262108018912),
#  'svarUpamanarAxu': (['svarUpama', 'na', 'na', 'rA', 'xu'],
#   0.069669947048751582),
#  'aXyAyanAlani': (['aXyAya', 'nA', 'nA', 'lani'], 0.074414799704641821),
#  'wiMtuMxi': (['wiMtuM', 'xi'], 2.8156244632715868e-06),
#  'jIvanaporAtaM': (['jIvan', 'an', 'ap', 'orAtaM'], 0.16725257449828621),
#  'nApkin\u200clanu': (['nApkin', 'in', '\u200cl', 'anu'],
#   0.011005004617377738),
#  'niMxiMcakuMdA': (['niMxiMca', 'iMca', 'kuMdA'], 0.1720687647875056),
#  'eVvarayina': (['eV', 'varayi', 'na'], 0.041454039038769229),
#  'heVccariswunnAdu': (['heVcc', 'arisw', 'unnAdu'], 2.1117183474536899e-05),
#  'pattaleka': (['pattale', 'ka'], 1.900546512708321e-05),
#  'prAraMBiMcagA': (['prAraMBi', 'Mca', 'Mca', 'gA'], 0.01544049127700311),
#  'pariSramanu': (['pariSr', 'am', 'am', 'anu'], 0.035789732230938398),
#  'mugiMcAlo': (['mugiMcAlo'], 1.1262497853086347e-05),
#  'rEtaps\u200clo': (['rEtaps\u200c', 'lo'], 1.3726169258448986e-05),
#  'allAxurgaM': (['allAxurg', 'aM'], 2.3228901821990587e-05),
#  'munagadameti': (['munag', 'ad', 'ad', 'ameti'], 0.031008904618785506),
#  'vadaboyadaM': (['vadabo', 'yadaM'], 2.9564056864351657e-05),
#  'weVranuvaxili': (['weV', 'ra', 'nu', 'vaxili'], 0.089193758974157572),
#  'haxxulanu': (['haxxulanu'], 5.6312489265431736e-06),
#  'oVsvaldo': (['oVsv', 'sv', 'aldo'], 0.14080205038154198),
#  'appatixAka': (['appatixA', 'ka'], 9.5027325635416066e-06),
#  'nirNayiMcukogala': (['nirNay', 'iMcukoga', 'la'], 2.2524995706172695e-05),
#  'uxvegAwmaka': (['uxvegAwma', 'ka'], 1.3726169258448986e-05),
#  'rAyAlsi': (['rAyAl', 'si'], 1.267031008472214e-05),
#  'pArtIlu': (['pArtI', 'lu'], 1.267031008472214e-05),
#  'mUdadugula': (['mUdadugu', 'la'], 1.6893746779629521e-05),
#  'ceVruvulU': (['ceVru', 'vulU'], 4.2234366949073794e-06),
#  'pariRkAramArgAnni': (['pariRkA', 'ramArgAn', 'ni'], 2.4737272070171795e-05),
#  'waMdrixe': (['waMd', 'ri', 'ri', 'xe'], 0.11920677301265875),
#  'mahapaxmanaMxudu': (['mah', 'apaxmana', 'Mx', 'Mx', 'udu'],
#   0.14011193023918195),
#  'civaraki': (['civaraki'], 3.097186909598745e-05),
#  'miMcani': (['miMcani'], 5.6312489265431728e-06),
#  'prayawniMcinA': (['pra', 'ya', 'wniMcinA'], 0.21997077911884633),
#  'mArkeVtlake': (['mArkeVtla', 'ke'], 1.5837887605902675e-05),
#  'edipiswU': (['edipiswU'], 2.8156244632715868e-06),
#  'keVmeVrAlo': (['keVmeV', 'eV', 'rA', 'lo'], 0.12191871866248093),
#  'vaccinappudallA': (['vacci', 'nappudallA'], 3.2098118881296087e-05),
#  'mixxamEna': (['mixxamE', 'na'], 2.6396479343171129e-05),
#  'manuRulawone': (['manuRu', 'lawone'], 3.801093025416642e-05),
#  'robot\u200cla': (['robot\u200c', 'la'], 2.1117183474536899e-05),
#  'AkattukoVne': (['Akattu', 'koVne'], 6.7574987118518087e-06),
#  'xamayaMwI': (['xamay', 'aMwI'], 4.3290226122800647e-05),
#  'sarvasva': (['sarvasva'], 2.2524995706172691e-05),
#  'baliswAru': (['ba', 'liswA', 'ru'], 0.014656179827357157),
#  'Sawakame': (['Sawakame'], 1.1262497853086347e-05),
#  'rahaxArullo': (['rahaxA', 'rullo'], 2.4284760995717437e-05),
#  '————————': (['————————'], 0.0),
#  'gAreVlu': (['gA', 're', 'Vlu'], 0.3118612254227143),
#  'mqgamunu': (['mqgamunu'], 1.1262497853086347e-05),
#  'nijAmuxxIn': (['nijA', 'muxxIn'], 1.6893746779629521e-05),
#  'dabbulivvAli': (['dabbu', 'livvA', 'li'], 5.0681240338888553e-06),
#  'poVMxagalamu': (['poVMxagala', 'mu'], 1.3726169258448986e-05),
#  'mahArAj': (['mahAr', 'Aj'], 1.267031008472214e-05),
#  'grahi0cinA': (['grahi0ci', 'nA'], 7.3910142160879152e-06),
#  'iMtarvyUlani': (['iMtarvyU', 'la', 'la', 'ni'], 0.021780438330311833),
#  'payaniswunna': (['payaniswun', 'na'], 3.695507108043957e-05),
#  'koVnnavAriki': (['koVnnavAr', 'iki'], 3.2731634385532192e-05),
#  'upaxeSiMcutasavariMcu': (['upaxeSiMcu', 'ta', 'ta', 'savariMcu'],
#   0.085919985121354292),
#  'oVmeVgA': (['oVmeV', 'eV', 'gA'], 0.069103727454975422),
#  'asamarXa': (['asamarXa'], 2.2524995706172695e-05),
#  'yuxxAniki': (['yuxxA', 'niki'], 2.1117183474536899e-05),
#  'boVrnavitA': (['boVrna', 'vi', 'vi', 'tA'], 0.083106715481211735),
#  'asamarWa': (['asamarWa'], 2.2524995706172695e-05),
#  'viMtUMdagA': (['viMtUMda', 'gA'], 6.3351550423610699e-06),
#  'aMkAnAm': (['aMkAn', 'An', 'Am'], 0.0048608595751535762),
#  'AnaMxaxAyakamani': (['AnaMxaxA', 'ya', 'ya', 'kamani'], 0.03046368043591699),
#  'uMdaMdaMwo': (['uMdaMdaM', 'wo'], 4.0122648601620105e-05),
#  'searchbox': (['searchbox'], 2.3228901821990587e-05),
#  'koVxxikRaNAllo': (['koVxxi', 'xi', 'kRaNAl', 'lo'], 0.14213100602341192),
#  'kAnannAru': (['kAnannA', 'ru'], 3.9066789427893262e-05),
#  'nirvahiMcabadina': (['nirvahiM', 'cabadi', 'na'], 2.463671405362638e-05),
#  'veVnakkilAgadaMvalla': (['veVnakkilAgad', 'aMval', 'la'],
#   3.4994189757804004e-05),
#  'vinnAvA': (['vinnA', 'nA', 'vA'], 0.10143558313124124),
#  'miwavAxulaku': (['miwavAxula', 'ku'], 1.6049059440648043e-05),
#  'walapeVttinapanulalo': (['walapeVttin', 'ap', 'ap', 'anulalo'],
#   0.071028227833452626),
#  'niSciwArWaM': (['niSciw', 'iw', 'ArWaM'], 0.0717902316491148),
#  'ciMwiMca': (['ciMwiM', 'ca'], 7.0390611581789662e-06),
#  'hewubaxXa': (['hewubaxXa'], 2.1117183474536897e-06),
#  'GatiMcAru': (['GatiMcA', 'ru'], 9.854685621450553e-06),
#  'SrIrAmanavami': (['SrIrAman', 'Aman', 'av', 'ami'], 0.41434993071290971),
#  'cesinappatikI': (['cesinappatikI'], 3.167577521180535e-05),
#  'wIramunaku': (['wIramuna', 'ku'], 2.6396479343171122e-05),
#  'gumikUdavaxxani': (['gumikUda', 'vaxxa', 'ni'], 2.1961870813518376e-05),
#  'vaxalani': (['va', 'xa', 'lani'], 0.03195130438934883),
#  'porAtaMgA': (['po', 'rAtaM', 'gA'], 0.089835284131665305),
#  'canipovunu': (['canipovu', 'nu'], 4.2234366949073802e-06),
#  'maMwrAlu…aRtAxaSavarNAwviyakaM': (['maMwrAlu…aR',
#    'tA',
#    'tA',
#    'xaSavarNAwviyakaM'],
#   0.0264563485823084),
#  'padeyAlani': (['padeyA', 'la', 'la', 'ni'], 0.021794164499570279),
#  'rAjAyyAdu': (['rAjAy', 'yA', 'yA', 'du'], 0.051512842052350238),
#  'paxabaMXAlu': (['paxab', 'aMXAlu'], 3.801093025416642e-05),
#  'speVktroskopIki': (['speVktroskopIki'], 1.1825622745740666e-05),
#  'reVMtinI': (['reVM', 'tinI'], 4.2234366949073794e-06),
#  'agnihowrAvuXAnluni': (['agnihowrAvuX', 'An', 'An', 'lu', 'ni'],
#   0.18739290357910199),
#  'hqxayakavAtAnni': (['hqxa', 'xa', 'ya', 'ka', 'vAtAn', 'ni'],
#   0.091684178597184043),
#  'xvArAweVlusukovaccu': (['xvAr', 'Ar', 'Aw', 'eVlusukovaccu'],
#   0.34847598374647221),
#  'xakkelA': (['xakkelA'], 7.0390611581789671e-06),
#  'kesIAr\u200cwo': (['kesIAr\u200cwo'], 8.4468733898147605e-06),
#  'pilcuwU': (['pilcuwU'], 0.0),
#  'SaMKamu': (['SaMKa', 'mu'], 5.6312489265431736e-06),
#  'prAMgaNaMloni': (['prAMgaN', 'aMloni'], 3.801093025416642e-05),
#  'xIkRalaku': (['xIkRala', 'ku'], 9.854685621450553e-06),
#  'anerisams': (['an', 'erisams'], 0.046006697708897454),
#  'weVllapoyAru': (['weVlla', 'la', 'poyAru'], 0.11165748002460857),
#  'saMkarRaNa': (['saMkarRaNa'], 3.097186909598745e-05),
#  'XaraNilo': (['XaraNilo'], 2.534062016944428e-05),
#  'addukunnAdu': (['addukunnA', 'du'], 1.6893746779629518e-05),
#  'mAwqBARa': (['mAwqBA', 'Ra'], 4.2234366949073802e-06),
#  'avunurA': (['avunu', 'rA'], 1.8301559011265313e-05),
#  'saMvawsaramulaku': (['sa', 'Mvaw', 'saramula', 'ku'], 0.29907325657700856),
#  'harRanIyaM': (['harRanIy', 'aM'], 3.801093025416642e-05),
#  'vidawalo': (['vidaw', 'aw', 'alo'], 0.10361692068612426),
#  'jeVnnaruwo': (['jeVnna', 'na', 'ru', 'wo'], 0.082633146461387474),
#  'mUrcanalu': (['mUrcanalu'], 2.5340620169444283e-05),
#  'bawikiMcAli': (['bawik', 'iMcAli'], 9.5027325635416049e-06),
#  '2.lAlAjalamu': (['2.lAl', 'Aj', 'Aj', 'alamu'], 0.096121187474575528),
#  'Anukuni': (['Anuku', 'ku', 'ni'], 0.047683929060164415),
#  'kristet': (['kristet'], 0.0),
#  'moVkkuwunna': (['moVkkuwun', 'na'], 1.6893746779629521e-05),
#  'beVxirina': (['beVxiri', 'na'], 2.1117183474536899e-05),
#  'cAr\u200cXAm\u200clu': (['cAr\u200cXAm\u200c', 'lu'],
#   1.0558591737268448e-05),
#  'paraMbulagunavu': (['paraMbu', 'laguna', 'vu'], 3.0267962980169557e-05),
#  'wAkiMxeVvaru': (['wAkiMx', 'eV', 'eV', 'va', 'ru'], 0.034367778162995334),
#  'familyःGeorgia': (['familyःGe', 'orgia'], 3.3787493559259044e-06),
#  'narasamma': (['narasamma'], 2.1117183474536899e-05),
#  'bAxukuMtunnAru': (['bAxukuMt', 'unnAru'], 1.8583121457592469e-05),
#  'vrAswunnavAru': (['vrAswun', 'navAru'], 3.167577521180535e-05),
#  'avvadaMwo': (['avvadaMwo'], 7.0390611581789662e-06),
#  'iMtikoVccinappudu': (['iMtikoVccin', 'appudu'], 1.0136248067777712e-05),
#  'vexikalayyAyi': (['vexi', 'xi', 'kalayyAyi'], 0.0048431431340952118),
#  'purugulu': (['purugu', 'lu'], 1.6893746779629518e-05),
#  'muhUrwaM': (['muhUrw', 'aM'], 2.9564056864351661e-05),
#  'svAmivArini': (['svAmivA', 'ri', 'ri', 'ni'], 0.027701979494174155),
#  'SrAmikulu': (['SrAmik', 'ik', 'ulu'], 0.059222305914487072),
#  'agniparvawaMloMci': (['agni', 'ni', 'parvawaMloM', 'ci'],
#   0.019873056948553076),
#  'kAryavarga': (['kAryavar', 'ga'], 2.2173042648263745e-05),
#  'va\u200cra\u200cku': (['va\u200cra\u200cku'], 2.534062016944428e-05),
#  'bAlyamuna': (['bAlyamuna'], 2.8156244632715865e-05),
#  'cAlArojulayiMxi': (['cAlAroju', 'layiM', 'xi'], 2.5340620169444283e-05),
#  'kalavanunna': (['kalavanun', 'na'], 3.2731634385532192e-05),
#  'samayamlo': (['samay', 'am', 'am', 'lo'], 0.030596872844913605),
#  'caxuvarulu': (['caxuvarulu'], 2.2524995706172691e-05),
#  'samaMjasame': (['samaMjasame'], 3.801093025416642e-05),
#  'wappiMceVnu': (['wappiMc', 'iMc', 'eV', 'nu'], 0.15775906962488173),
#  'AMXraprAMwaMlo': (['AMXraprAMwaM', 'lo'], 1.9427808796573947e-05),
#  'veVllAla': (['veVllA', 'la'], 2.1117183474536899e-05),
#  'ugravAxi': (['ugravAxi'], 2.534062016944428e-05),
#  'prAjuktulu': (['prAjuktu', 'lu'], 1.3726169258448983e-05),
#  'planned': (['planned'], 2.5340620169444283e-05),
#  'sokiMxaMte': (['sokiMx', 'aMte'], 3.801093025416642e-05),
#  'Sakwulu-': (['Sakwulu-'], 2.8156244632715864e-06),
#  'jAripoyiMxi': (['jAripoyiM', 'xi'], 4.2234366949073802e-06),
#  'parameSvarI': (['parameS', 'va', 'va', 'rI'], 0.064559958133262402),
#  'pattiMcukoxu': (['patt', 'iMcuko', 'xu'], 1.9427808796573947e-05),
#  'mugiMcukunna': (['mugiMcukun', 'na'], 2.4284760995717437e-05),
#  '1871–1918': (['1871–19', '18'], 2.1117183474536901e-06),
#  'vaxilAnu': (['vaxilA', 'nu'], 1.4078122316357932e-05),
#  'SabxAlanu': (['SabxAl', 'anu'], 4.2234366949073802e-06),
#  'wawwvameVlA': (['wawwv', 'am', 'am', 'eVlA'], 0.15663524767505393),
#  'bAxyawalu': (['bAxya', 'wa', 'wa', 'lu'], 0.018948343619564403),
#  'KaMdanao': (['KaMd', 'anao'], 1.9005465127083213e-05),
#  'paryAyapaxaMgA': (['paryA', 'yapaxaMgA'], 2.7874682186388706e-05),
#  'eVppudo': (['eVppudo'], 1.1262497853086347e-05),
#  'karuNAkaran': (['ka', 'ruNAk', 'ar', 'ar', 'an'], 0.0484274752128665),
#  'poVraMboku': (['poVraMboku'], 5.0681240338888559e-05),
#  'vaxilipeVdiwene': (['vaxilip', 'eVdiwene'], 1.1825622745740666e-05),
#  'peVxxavAdu': (['peVxxavAdu'], 1.4078122316357934e-05),
#  'avaroXAlugA': (['avaroXAlu', 'gA'], 9.5027325635416049e-06),
#  'amAnuRaMgA': (['amAnuRaM', 'gA'], 8.4468733898147605e-06),
#  'PArmulAnu': (['PArmulA', 'nu'], 8.4468733898147605e-06),
#  'mAMsAla': (['mAMsA', 'sA', 'la'], 0.059559826054247401),
#  'eVtucUsinA': (['eVtucU', 'si', 'si', 'nA'], 0.062998062049772555),
#  'waggani': (['wagga', 'ni'], 2.2524995706172695e-05),
#  'vimarSalawo': (['vi', 'marSalawo'], 0.023367514080705434),
#  'alAMtixe': (['alAM', 'ti', 'ti', 'xe'], 0.046081326963052553),
#  'xikukalA': (['xi', 'ku', 'kalA'], 0.030167525943383733),
#  'SrImahAviRNuM': (['SrImahAviRNuM'], 1.6893746779629521e-05),
#  'Sakunwala': (['Sakun', 'un', 'wa', 'la'], 0.049004740837687306),
#  'vArasurAlavutuMxi': (['vArasurA', 'lavutu', 'Mxi'], 2.4495932830462806e-05),
#  'SAKalunnAyi': (['SAKal', 'al', 'unnAyi'], 0.12486699585083505),
#  'xqSyarUpakaM': (['xqSyarUpak', 'aM'], 4.2234366949073804e-05),
#  'naduswuMdagA': (['nadusw', 'uMdagA'], 2.2173042648263745e-05),
#  'aMxiMcAmani': (['aMxiMc', 'iMc', 'Amani'], 0.067153228693957068),
#  'SvAsaku': (['SvAsa', 'sa', 'ku'], 0.058350300852719666),
#  'malayAlYasvAmi': (['malayA', 'yA', 'lYasvAmi'], 0.064950754897444674),
#  'payaHpArAvArapAraxa': (['payaH', 'pA', 'pA', 'rA', 'vArapAraxa'],
#   0.041787605152567145),
#  'PaliwAlanu': (['PaliwAla', 'nu'], 6.3351550423610699e-06),
#  'pariNAmame': (['pariNA', 'mame'], 3.0619916038078507e-05),
#  'veVnakAduwunnAM': (['veVnak', 'ak', 'AduwunnAM'], 0.18516819322368178),
#  'mEkupattukunnavAri': (['mEku', 'ku', 'pattukun', 'navAri'],
#   0.0017690355822839302),
#  'maroveVpu': (['ma', 'ro', 'veV', 'pu'], 0.10872384176980227),
#  'vyakwiwvAniki': (['vyakwiwvA', 'niki'], 1.9709371242901106e-05),
#  'virupaNNa': (['vi', 'rupaN', 'Na'], 0.028328503332429956),
#  'velaMlo': (['vela', 'la', 'Mlo'], 0.050186574660868483),
#  'rabbar\u200cnu': (['rabbar\u200cnu'], 3.097186909598745e-05),
#  'moVwwamu': (['moVwwa', 'mu'], 5.6312489265431736e-06),
#  'haswAlalo': (['haswAla', 'lo'], 7.0390611581789671e-06),
#  'sannaxXamayyeMxuku': (['sa', 'nna', 'xXamayyeMxuku'], 0.025867611709344353),
#  'muKyapAwrawo': (['muKyapAw', 'ra', 'ra', 'wo'], 0.021050948590912923),
#  '2013-12-16T18:50:07': (['2013-12-16T', '18:50:07'], 1.4078122316357934e-06),
#  'kanAnulo': (['ka', 'nA', 'nu', 'lo'], 0.08164016823452952),
#  'baMXuroxbaMXura': (['baMXuroxb', 'aMXu', 'ra'], 3.2379681327623249e-05),
#  'prAya\u200crtI': (['prAya\u200crtI'], 2.8156244632715865e-05),
#  'prEjuloVswe': (['prEju', 'loVswe'], 1.0558591737268451e-05),
#  'uMdevAru': (['uMdevA', 'ru'], 1.4078122316357932e-05),
#  'javaxekar': (['ja', 'vaxek', 'ar'], 0.045534275741250227),
#  'rAwaprawulni': (['rAwap', 'ra', 'ra', 'wulni'], 0.0076187443401161724),
#  'paramANaM': (['paramAN', 'aM'], 3.2731634385532192e-05),
#  'gurwuleka': (['gurwule', 'ka'], 7.391014216087916e-06),
#  'korinappudu': (['korinappu', 'du'], 6.3351550423610699e-06),
#  'svAmivArika': (['svAmiv', 'Arika'], 7.3910142160879152e-06),
#  'koVmmapE': (['koVm', 'mapE'], 1.6893746779629521e-05),
#  'viXiMcAru': (['viXiMcA', 'ru'], 9.854685621450553e-06),
#  'kalisinattu': (['kalisi', 'nattu'], 3.6955071080439577e-05),
#  'nammina': (['nammi', 'na'], 4.2234366949073797e-05),
#  'veVxyaraMgaM': (['veVxyaraMg', 'aM'], 4.0122648601620105e-05),
#  'karajjA': (['karajjA'], 7.0390611581789671e-06),
#  'sinimAkannA': (['sinimA', 'mA', 'kannA'], 0.050943821784291458),
#  'namaskariswunnAro': (['namaskariswun', 'nA', 'nA', 'ro'],
#   0.010293329584284638),
#  'anipiMcani': (['anipi', 'Mcani'], 1.3726169258448986e-05),
#  'koVdukki': (['koVdukki'], 2.8156244632715868e-06),
#  'kArucavakagA': (['kArucav', 'akagA'], 1.8583121457592473e-05),
#  'Krueger': (['Krueg', 'er'], 1.4078122316357934e-06),
#  'cewabadi': (['cewa', 'wa', 'badi'], 0.062922320782276095),
#  'adigAru': (['adigA', 'ru'], 1.1262497853086347e-05),
#  'panararara': (['panar', 'arara'], 3.6955071080439577e-05),
#  'saMsWalugA': (['saMsWalu', 'gA'], 6.3351550423610699e-06),
#  'katteVlanu': (['katt', 'eVlanu'], 2.0061324300810059e-05),
#  'vaMweVnapE': (['vaMweV', 'eV', 'napE'], 0.047243251442991963),
#  'cAvavaccu': (['cAvavaccu'], 2.2524995706172691e-05),
#  'eVkkuvavadamo': (['eVkku', 'ku', 'vavada', 'mo'], 0.013272697794421327),
#  'prinispAl': (['pr', 'inisp', 'Al'], 0.003708997081839539),
#  'karuvavuwoMxi': (['ka', 'ru', 'va', 'vuwoM', 'xi'], 0.060806133144927582),
#  'pariSrama': (['pariSrama'], 1.8301559011265313e-05),
#  'kalapavakuMdA': (['kalapa', 'pa', 'va', 'kuMdA'], 0.038337305478017711),
#  'mukkeVra': (['mukk', 'eV', 'eV', 'ra'], 0.18639344567028732),
#  'lotas\u200cpAMd\u200cloni': (['lotas\u200cpAMd\u200clo', 'ni'],
#   1.267031008472214e-05),
#  'wIruloniki': (['wIru', 'ru', 'lo', 'niki'], 0.38338149503979818),
#  'aMbAlikawo': (['aMbAl', 'Al', 'ikawo'], 0.088059908987921362),
#  'xayArXra': (['xa', 'yArXra'], 0.013897253141049563),
#  'muMceVwwAdu': (['mu', 'Mc', 'eVww', 'Adu'], 0.16606705736292449),
#  'AmeVloV': (['Am', 'eVloV'], 0.096093352178714175),
#  'ceVppukuMtene': (['ceVppukuMtene'], 8.4468733898147605e-06),
#  'yAjFavalkya': (['yAjFa', 'valk', 'ya'], 2.1961870813518376e-05),
#  'prAblams\u200c': (['prAblams\u200c'], 3.9418742485802212e-05),
#  'mAraNahiMsa': (['mAraNahiM', 'sa'], 6.3351550423610699e-06),
#  'tiMpumuxrohinivagu': (['tiMpum', 'ux', 'ux', 'rohini', 'va', 'va', 'gu'],
#   0.2787016800002633),
#  'iSrAyelU': (['iSrAyelU'], 1.4078122316357934e-06),
#  'yupayogamEnavi': (['yupayogamEna', 'vi'], 2.3651245491481328e-05),
#  'iRtasaKi': (['iRtasaKi'], 1.4078122316357934e-06),
#  'viSAraxaH': (['viSAraxaH'], 2.534062016944428e-05),
#  'vaMcana”': (['vaMcana”'], 1.1262497853086346e-05),
#  'avamAniMcinappudu': (['avamA', 'niMcin', 'appudu'], 2.3228901821990587e-05),
#  'xIpakuni': (['xIpaku', 'aku', 'ni'], 0.24118705337781188),
#  'viSleRiMciMxAmeV': (['viSl', 'eR', 'eR', 'iMciMx', 'Am', 'Am', 'eV'],
#   0.09337400441328228),
#  'vUregiMpullo': (['vUregiM', 'pullo'], 1.0136248067777712e-05),
#  'iccceMxuku': (['iccceMxu', 'ku'], 8.4468733898147588e-06),
#  'krismas': (['krismas'], 0.0),
#  'naBavewpApa': (['naBavewpA', 'pa'], 2.9564056864351657e-05),
#  'prawioVkkarU': (['prawioVk', 'ka', 'ka', 'rU'], 0.13324316537642467),
#  'poRiMcutaku': (['poRiMcuta', 'ku'], 1.5837887605902675e-05),
#  'uxASInawa': (['uxASIna', 'wa'], 8.4468733898147605e-06),
#  'affiliate': (['affiliate'], 5.6312489265431728e-06),
#  'pUjiMcinaMxuku': (['pUjiMc', 'in', 'in', 'aMxuku'], 0.081107636813681022),
#  'BojanaMlA': (['Bojan', 'an', 'aMlA'], 0.023883535868097383),
#  'samAjAlu': (['samAjA', 'lu'], 1.4078122316357932e-05),
#  'kaviwvasexyapu': (['ka', 'viwvasex', 'ya', 'ya', 'pu'],
#   0.061482109243158362),
#  'avixyuxvAhakaM': (['avixy', 'ux', 'ux', 'vAhak', 'aM'],
#   0.098213380064622477),
#  'sAXiMcinA': (['sAXiMcinA'], 1.1262497853086347e-05),
#  'pArkulo': (['pAr', 'ku', 'lo'], 0.3348223397197332),
#  '1969-70': (['1969-70'], 0.0),
#  'hAravajramEna': (['hAravaj', 'ramE', 'na'], 3.0267962980169557e-05),
#  'xuswulalo': (['xu', 'swula', 'lo'], 0.16834470082216174),
#  'AtagAlYlaMwA': (['AtagA', 'gA', 'lYl', 'aM', 'wA'], 0.062788539413084613),
#  'caxuvuwunna': (['caxuvuwun', 'na'], 1.7949605953356364e-05),
#  'plAneriyA': (['plAneri', 'yA'], 1.6893746779629521e-05),
#  'nyUtrAsyUtikals': (['nyUt', 'rAsyUti', 'kals'], 1.5687050581084555e-05),
#  'boVllAraMloni': (['boVllAr', 'aMloni'], 3.801093025416642e-05),
#  'nilupukoVneMxuku': (['ni', 'lupukoVneMxuku'], 0.12628701903542255),
#  'prawiBApAtavAlu': (['prawiBApA', 'ta', 'ta', 'vA', 'lu'],
#   0.060262520950752893),
#  '1416-1489': (['1416-1489'], 0.0),
#  'vAkyamulu': (['vAkyamulu'], 2.8156244632715865e-05),
#  'sUPIwawwvAnni': (['sUPIwawwvAn', 'ni'], 1.8583121457592473e-05),
#  'viSvaviKyAwa': (['viSvaviKyA', 'wa'], 1.6893746779629521e-05),
#  'vArasula': (['vA', 'ra', 'su', 'la'], 0.01958679516902534),
#  'wiriginattanipiMciMxi': (['wiriginat', 'ta', 'ta', 'nipiMciMxi'],
#   0.04960710531009755),
#  'ravANAnu': (['ravANA', 'nu'], 1.5485934547993725e-05),
#  'vyavahariMcAlani': (['vyavahariMcA', 'la', 'la', 'ni'],
#   0.017424350664249466),
#  'paxxawule': (['paxxawule'], 1.8301559011265313e-05),
#  'gomayaMlo': (['gomayaM', 'lo'], 2.2173042648263745e-05),
#  'hAhAhUhU': (['hAhAhU', 'hU'], 2.8156244632715868e-06),
#  'avalakRaNAlu': (['avalakRaNA', 'lu'], 3.0408744203333132e-05),
#  'kalmaRaM': (['kalmaR', 'aM'], 3.2379681327623249e-05),
#  'koVttukunnArani': (['koVttuk', 'unnAra', 'ni'], 1.6893746779629518e-05),
#  'maMgoliyan\u200c': (['maMgoli', 'ya', 'ya', 'n\u200c'],
#   0.066856817608271335),
#  'annaxAniki': (['annaxA', 'niki'], 3.0619916038078507e-05),
#  'upayogiMcukuMte': (['upayog', 'iMcuk', 'uMte'], 9.854685621450553e-06),
#  'odiMcadaM': (['odiMcad', 'aM'], 2.534062016944428e-05),
#  'PEnals\u200c': (['PEnals\u200c'], 4.2234366949073797e-05),
#  'pAlEMxi': (['pAlEM', 'xi'], 4.2234366949073802e-06),
#  'bahaxUr\u200cRAku': (['ba', 'haxUr\u200cRAku'], 0.18624506927584647),
#  'addukuni': (['adduku', 'ni'], 1.5485934547993725e-05),
#  'meVyiMteVneVns': (['meVyi', 'yi', 'MteVneVns'], 0.090348459114312579),
#  'nadapAlani': (['nadapA', 'la', 'la', 'ni'], 0.021796276217917736),
#  'AryaBatuni': (['AryaBatu', 'ni'], 1.6893746779629518e-05),
#  'ceswunnanepaXyaMlo': (['ceswun', 'nane', 'paXyaM', 'lo'],
#   3.6804234055621451e-05),
#  'jAwipiwa': (['jAwipi', 'wa'], 8.4468733898147605e-06),
#  'vinadame': (['vi', 'nadame'], 0.18927062512345996),
#  '2vapejI': (['2vapejI'], 1.1262497853086347e-05),
#  'vIrabrahmeMxrasvAmi': (['vIrab', 'rahmeMx', 'rasvAmi'],
#   1.900546512708321e-05),
#  'SarIrAniki': (['SarIrA', 'niki'], 2.2173042648263745e-05),
#  'hEkortulo': (['hEkortu', 'lo'], 9.5027325635416066e-06),
#  'prAraMBiMcAdu': (['prAraMBiMc', 'Adu'], 4.0122648601620105e-05),
#  'saMpraxAyamu': (['saMpraxAya', 'mu'], 2.2173042648263745e-05),
#  'punarjanma': (['punarjan', 'ma'], 3.167577521180535e-05),
#  'pajjUrulo': (['pajjU', 'ru', 'ru', 'lo'], 0.19838365770684718),
#  'AptimeVj': (['AptimeVj'], 2.8156244632715864e-06),
#  'veiMbeVrg': (['veiMb', 'eVrg'], 1.4782028432175832e-05),
#  'anugrahiMcabaduxuru': (['anugrahiMcab', 'ad', 'ad', 'uxuru'],
#   0.0073495152463225397),
#  'muKyanagarAlEna': (['muKyanag', 'ar', 'ar', 'Al', 'Ena'],
#   0.13104079037999242),
#  'jeVMdAlanu': (['jeVMdAl', 'anu'], 2.8156244632715868e-06),
#  'patAn\u200cceVru': (['patAn\u200c', 'n\u200c', 'ceV', 'ru'],
#   0.035135683595892336),
#  'cAMbar\u200cloki': (['cAMbar\u200cloki'], 2.3228901821990587e-05),
#  'pAwramavuwU': (['pAwramavuwU'], 1.900546512708321e-05),
#  'swaMBiMce': (['sw', 'aMBiMce'], 0.0536857199662613),
#  'nappudu': (['nappudu'], 2.1117183474536897e-06),
#  'mUluguwunnAdu…': (['mUluguw', 'unnAdu…'], 1.6893746779629521e-05),
#  'aMcanAveswunna': (['aMcanAveswun', 'na'], 2.7874682186388709e-05),
#  'gummamuvaraku': (['gummamuva', 'ra', 'ra', 'ku'], 0.0002044046281885678),
#  'cAliMcinaxi': (['cAliM', 'cinaxi'], 6.3351550423610708e-06),
#  'sare…iMkA': (['sa', 're…iMkA'], 0.14831698714827418),
#  'swuwi”ni': (['sw', 'uwi”ni'], 0.2743201696996469),
#  'Asa\u200ckwika\u200craMgA': (['Asa\u200ckwika\u200c', 'raMgA'],
#   1.5204372101666567e-05),
#  'jaraggA': (['jarag', 'gA'], 7.0390611581789671e-06),
#  'aMwaamAyakaMgA': (['aMwaamA', 'ya', 'ya', 'kaMgA'], 0.03046368043591699),
#  'saMparkula': (['saMparku', 'la'], 4.2234366949073797e-05),
#  'mahApApaharaM': (['mahApA', 'pa', 'pa', 'haraM'], 0.071800842667898296),
#  'jammalamadugu': (['jamm', 'al', 'am', 'adugu'], 0.11306488079210915),
#  'irakvAyi': (['ir', 'ak', 'vA', 'yi'], 0.044064710011323616),
#  'saraMjAmA': (['saraMjAmA'], 5.0681240338888559e-05),
#  'sAguwoMxi': (['sAguwoM', 'xi'], 6.3351550423610699e-06),
#  'wamaloni': (['wa', 'maloni'], 0.38095926799916913),
#  'wAralawo': (['wArala', 'wo'], 4.2234366949073802e-06),
#  'aXigacCawi': (['aXigacC', 'awi'], 3.1675775211805345e-06),
#  'Prem\u200cvark': (['Prem\u200c', 'vark'], 1.6893746779629518e-05),
#  'anukoVne': (['anukoVne'], 1.2670310084722142e-05),
#  'CAMpiyans': (['CAMpi', 'yans'], 2.1117183474536899e-05),
#  'bassulo': (['bassu', 'su', 'lo'], 0.048997152601202479),
#  'mahArAjugA': (['mahArAjugA'], 2.2524995706172695e-05),
#  'BAgyaMwo': (['BAgyaMwo'], 2.8156244632715865e-05),
#  'jaruguwAyannaxi': (['jaruguwA', 'ya', 'ya', 'nnaxi'], 0.024272784095216847),
#  'wiMtAru': (['wiMtA', 'ru'], 9.854685621450553e-06),
#  'praxAnowsavaM': (['praxAnowsav', 'aM'], 2.7029994847407235e-05),
#  'sixxamma': (['sixxam', 'ma'], 1.267031008472214e-05),
#  'laMcAvawAraM': (['la', 'McAvawAraM'], 0.051005665934794206),
#  'premaku': (['prema', 'ma', 'ku'], 0.080920966928365728),
#  'praveSapeVdawAru': (['praveSapeVd', 'aw', 'aw', 'Aru'],
#   0.050643147003918476),
#  'cirAkupadeVdu': (['ci', 'rA', 'ku', 'pad', 'eV', 'du'], 0.21172680373479102),
#  'plAMt\u200clu': (['plAMt\u200c', 'lu'], 1.1262497853086346e-05),
#  'cUsevANni': (['cUsevAN', 'ni'], 1.4078122316357932e-05),
#  'praxarSiMcukune': (['praxarSiMcu', 'kune'], 2.534062016944428e-05),
#  'sieVMni': (['sieVM', 'ni'], 1.5485934547993725e-05),
#  'vyavahariMcagalarani': (['vyavahariMcaga', 'la', 'la', 'ra', 'ni'],
#   0.02069246413737498),
#  'sApekRaMgA': (['sApekRaM', 'gA'], 5.2792958686342255e-06),
#  'aByarXigA': (['aByarXigA'], 3.097186909598745e-05),
#  'aBiprAyAnni': (['aBip', 'rAyAn', 'ni'], 0.28567478030277033),
#  'xevawala': (['xevawa', 'la'], 2.1117183474536899e-05),
#  'kAxanalemu': (['kAxanalemu'], 4.2234366949073797e-05),
#  'kroneVnbarg': (['kroneVnbarg'], 1.4782028432175832e-05),
#  'veVwukuwUne': (['veVwuk', 'uwUne'], 5.2792958686342255e-06),
#  'ArWikewara': (['ArWikewa', 'ra'], 1.267031008472214e-05),
#  'kaRtakAlaMlonU': (['kaRtakA', 'la', 'la', 'MlonU'], 0.030112789483860074),
#  'kuxurcadAniki': (['kuxurcadA', 'niki'], 2.280655815249985e-05),
#  'vyavahArAlu': (['vyavahArA', 'lu'], 1.5204372101666566e-05),
#  'prapaMcakap': (['pra', 'paMcak', 'ap'], 0.015954749840293155),
#  'kanapadiwe': (['kanapadiwe'], 3.6603118022530627e-05),
#  'GorAlaku': (['GorAlaku'], 2.2524995706172695e-05),
#  'saMxehiMcAlsina': (['sa', 'MxehiMcAls', 'ina'], 0.0022355356925282443),
#  'kqwajfawalu': (['kqwajfa', 'wa', 'wa', 'lu'], 0.018948343619564403),
#  'pakkawadupuwuMte': (['pa', 'kka', 'wa', 'dupuwu', 'Mte'],
#   0.17937587348051687),
#  'ravIMxraBArawi': (['ravIMxraB', 'Ar', 'Ar', 'awi'], 0.056707754530137759),
#  'awyAScaryaM': (['awyASc', 'aryaM'], 2.428476099571743e-05),
#  'mAMdalikaMloki': (['mAMdal', 'ik', 'ik', 'aMloki'], 0.059038869751229212),
#  'billiMg\u200c': (['billiMg\u200c'], 5.6312489265431728e-06),
#  'saMvawsaramula': (['sa', 'Mvaw', 'saramula'], 0.35888199508103741),
#  'rogaBayaMpikkalu': (['ro', 'gaBayaMpi', 'kka', 'kka', 'lu'],
#   0.065659381676556786),
#  'BaviRyawwu': (['BaviRyawwu'], 4.2234366949073802e-06),
#  'rAkuMte': (['rAkuMte'], 1.1262497853086347e-05),
#  'clicksor_layer_ad_link_color': (['clicksor_layer_ad_',
#    'li',
#    'li',
#    'nk_color'],
#   0.2372859600659061),
#  'pUrwEna': (['pUrw', 'rw', 'Ena'], 0.11387988180943281),
#  'blAk\u200cnu': (['blAk\u200c', 'nu'], 2.8156244632715868e-06),
#  'araNyame': (['araN', 'yame'], 3.2731634385532192e-05),
#  'niwyamE': (['niwyamE'], 2.8156244632715865e-05),
#  'mawAnni': (['mawAn', 'ni'], 2.534062016944428e-05),
#  'uxyamaMcina': (['uxyamaMci', 'na'], 3.2731634385532199e-05),
#  'mahAiRtaM': (['mahAiRt', 'aM'], 2.6748432401080072e-05),
#  'peVduwunnatlu': (['peVduwun', 'natlu'], 3.167577521180535e-05),
#  '53.5lakRala': (['53.5lakRa', 'la'], 4.4346085296527489e-05),
#  'klarkulaku': (['klar', 'ar', 'kulaku'], 0.033688729106220471),
#  'winipiswAdu': (['winipiswAdu'], 2.1117183474536899e-05),
#  'nAkitti': (['nAkit', 'ti'], 1.1262497853086346e-05),
#  'unnAru”': (['unnAru”'], 8.4468733898147605e-06),
#  'rAjapuruRo': (['rAjapu', 'ruRo'], 2.3228901821990591e-05),
#  'anumawiMcarAxannAru': (['anumaw', 'aw', 'iMca', 'rA', 'xannA', 'ru'],
#   0.11658327916929279),
#  'RAjiyaM': (['RAjiy', 'iy', 'aM'], 0.035427613920057208),
#  'vinipiMcAdu': (['vinipiMcA', 'du'], 4.2234366949073802e-06),
#  'aswamAnU': (['aswa', 'wa', 'mAnU'], 0.056773555193588246),
#  'aMdar\u200c19-': (['aMdar\u200c19-'], 3.097186909598745e-05),
#  'nirUpiMcukovataM': (['ni', 'rUpiMcukovataM'], 0.047822583283266537),
#  'kUtamini': (['kUtami', 'ni'], 1.478202843217583e-05),
#  'lAlAjalAnni': (['lAlAj', 'Aj', 'alAnni'], 0.12015148434321941),
#  'aruxEna': (['aruxE', 'na'], 3.660311802253062e-05),
#  'vaswini': (['vaswi', 'ni'], 2.534062016944428e-05),
#  'xAriwIse': (['xAriwIse'], 5.6312489265431736e-06),
#  'kaMcikacarlagA': (['kaMcikacar', 'la', 'la', 'gA'], 0.014933563317567022),
#  'varinAru': (['varin', 'in', 'Aru'], 0.10791858757104665),
#  'walliwraMdrula': (['walliwr', 'aMdru', 'la'], 4.2234366949073804e-05),
#  'AwraMgA': (['AwraM', 'gA'], 7.0390611581789671e-06),
#  'boVddUdani': (['boVddUda', 'ni'], 1.0558591737268449e-05),
#  'pariXiloniki': (['pariXi', 'lo', 'lo', 'niki'], 0.1850305689673365),
#  'ceVbuwunnAnaMte': (['ceVbuw', 'unnA', 'unnA', 'na', 'Mte'],
#   0.18403458821977026),
#  'mattiwo': (['matti', 'ti', 'wo'], 0.07267517305755429),
#  'magAlYlYa': (['ma', 'gA', 'lYlYa'], 0.056883897133008086),
#  'poVyyAru': (['poVy', 'yA', 'yA', 'ru'], 0.022794151004128918),
#  'moVxaleVnavAti': (['moVxal', 'al', 'eV', 'navAti'], 0.052034805255453759),
#  'waggiMcaleka': (['waggiMc', 'iMc', 'aleka'], 5.6852973883749703e-05),
#  'mAnukoleni': (['mAnukole', 'ni'], 1.267031008472214e-05),
#  'sahajamEnavI': (['sahajamE', 'na', 'na', 'vI'], 0.0250707978517224),
#  'kaMxipappu': (['ka', 'Mxipap', 'pu'], 0.0237227070281005),
#  'meVyins': (['meVyins'], 5.6312489265431736e-06),
#  'prakatanalo': (['prakat', 'at', 'an', 'alo'], 0.11266825956754677),
#  'prabAvaM': (['prabAv', 'aM'], 3.2379681327623249e-05),
#  'paryAyapaxamo': (['paryAyap', 'axa', 'axa', 'mo'], 0.11161057902015722),
#  'wappavu': (['wappa', 'pa', 'vu'], 0.09450618708389355),
#  'naccAka': (['naccA', 'ka'], 2.8156244632715865e-05),
#  'vAlmIki': (['vAlmIki'], 4.2234366949073802e-06),
#  'peRIloni': (['peRIlo', 'ni'], 1.4078122316357932e-05),
#  'nArAyaNarAvu': (['nA', 'rAyaNa', 'rAvu'], 0.0257999438228683),
#  'rEwAMgAnni': (['rEwA', 'wA', 'MgAnni'], 0.14070426052223095),
#  'jamiMxArla': (['jamiMx', 'Mx', 'Ar', 'la'], 0.12107850227308642),
#  'paxXawi': (['paxXawi'], 2.1117183474536901e-06),
#  'AliyarAma': (['AliyarAma'], 3.097186909598745e-05),
#  'marixiki': (['marix', 'iki'], 1.267031008472214e-05),
#  'srAvaka': (['srAva', 'va', 'ka'], 0.0029486518464026767),
#  'mawimarupunaku': (['mawim', 'arupun', 'aku'], 2.7029994847407231e-05),
#  'anupama': (['anu', 'pa', 'ma'], 0.03396567832761106),
#  'gaNAMkAlU': (['gaNAMkAlU'], 1.4078122316357932e-06),
#  'Sivakavi': (['Siv', 'aka', 'vi'], 0.15916402421185838),
#  'svapnakesi': (['svapna', 'na', 'ke', 'si'], 0.03221849063442029),
#  'maraNasWalaM': (['maraNasW', 'al', 'al', 'aM'], 0.025248313239635688),
#  'mArmoguwU': (['mArmo', 'guwU'], 6.3351550423610699e-06),
#  'xUramOwU': (['xUramOwU'], 2.534062016944428e-05),
#  'vIrixxariwo': (['vIrixxa', 'ri', 'ri', 'wo'], 0.044112919589849281),
#  'SrISElakReVwra': (['SrISEla', 'kR', 'kR', 'eVwra'], 0.19581809322702093),
#  'kunArilli': (['kunArilli'], 9.854685621450553e-06),
#  'vikAramE': (['vikA', 'ramE'], 2.1117183474536902e-05),
#  'xravAlu': (['xravAlu'], 1.4078122316357932e-05),
#  'புறந்தொழா': (['புறந்தொழா'], 0.0),
#  'praxarSanalawo': (['praxarSa', 'nalawo'], 3.167577521180535e-05),
#  'yUnivarsitIki': (['yUniv', 'ar', 'ar', 'sitIki'], 0.083070728344538436),
#  'yUxArAjEna': (['yUxArAjE', 'na'], 3.2731634385532199e-05),
#  'weVccukuMxani': (['weVccu', 'kuMxa', 'ni'], 2.1961870813518376e-05),
#  'AnaMxaM': (['An', 'aM', 'xaM'], 0.2424261903626605),
#  'eVMpIki': (['eVMpIki'], 9.8546856214505547e-06),
#  'paMcAyaw': (['paMcAy', 'aw'], 1.9709371242901106e-05),
#  'ayipoye': (['ayipoye'], 2.8156244632715868e-06),
#  'punAxikosaM': (['pu', 'nA', 'xikos', 'aM'], 0.10731290001215693),
#  'siMharASilo': (['siMharA', 'Si', 'Si', 'lo'], 0.13102366217604414),
#  'appanna': (['appan', 'na'], 2.6748432401080072e-05),
#  'cariwalu': (['cariwa', 'lu'], 1.4078122316357932e-05),
#  'doi:10.1016/0300-5712': (['doi:10.1016/0300-5712'], 0.0),
#  'resworiMg': (['re', 'swori', 'Mg'], 0.070294199656222772),
#  'Exuguru': (['Exugu', 'ru'], 9.854685621450553e-06),
#  'paMpiswonaMtnuMxi': (['paMpis', 'wo', 'wo', 'naMt', 'nu', 'nu', 'Mxi'],
#   0.14863958837610833),
#  'manasuloMci': (['manasu', 'su', 'loMci'], 0.036753143746770495),
#  'axemitaMte': (['axemit', 'aMte'], 3.801093025416642e-05),
#  'nittUrpulu': (['nittUrpu', 'lu'], 1.900546512708321e-05),
#  'graMWAlayaM': (['graMWA', 'layaM'], 5.405998969481447e-05),
#  'aniwanu': (['an', 'iw', 'anu'], 0.07497100924275209),
#  'katakatAlloki': (['katak', 'ak', 'at', 'Alloki'], 0.13159276785415314),
#  'rAnIyaxu': (['rAnI', 'ya', 'ya', 'xu'], 0.0070577589391322051),
#  'rijistreRanu': (['rijistr', 'eR', 'eR', 'anu'], 0.053397300983908408),
#  'jElupAlE': (['jElupAlE'], 2.2524995706172691e-05),
#  'palleVlu': (['palleV', 'lu'], 2.9564056864351657e-05),
#  'SmaSAnavAtika': (['SmaSA', 'navAti', 'ka'], 2.9564056864351661e-05),
#  'axyakRudu–baxruxxIn': (['axyakRu', 'du–bax', 'ruxxIn'],
#   2.2927227772354349e-05),
#  'AropaNa': (['Aropa', 'Na'], 7.0390611581789671e-06),
#  'kaligivuMdunu': (['kaligiv', 'uMdunu'], 9.2915607287962363e-06),
#  'lakRawo': (['lakRa', 'wo'], 2.2524995706172695e-05),
#  'walaluxanni': (['wa', 'la', 'lu', 'xa', 'nni'], 0.25626161623460575),
#  'kAnaMtAdu': (['kAnaMtAdu'], 5.0681240338888559e-05),
#  'priyulu': (['pr', 'iy', 'ulu'], 0.27832123541352816),
#  'yogavixiwi': (['yoga', 'ga', 'vixiwi'], 0.034756137354159847),
#  'xoVrikiwe': (['xoVrikiwe'], 2.8156244632715868e-06),
#  'anuBavaM': (['anuBav', 'aM'], 3.801093025416642e-05),
#  'paruswuMxi': (['paruswuMxi'], 1.8301559011265313e-05),
#  'ciMwapaMdu': (['ciMwap', 'aM', 'aM', 'du'], 0.16149560501833943),
#  'ceVppagalaM': (['ceVppag', 'al', 'al', 'aM'], 0.025249369098809416),
#  'koVMxariki': (['koVMxariki'], 1.4078122316357934e-05),
#  'spaMxiMcAlannAru': (['spaMxiMcA', 'lannA', 'ru'], 4.2837715048346282e-05),
#  'maheSvarareVddi': (['maheSva', 'ra', 'ra', 'reVddi'], 0.15224913561762471),
#  'koVttukoVnipoyiri': (['koVttukoV', 'nipoyi', 'ri'], 1.6189840663811625e-05),
#  'carcallo': (['carcal', 'lo'], 9.854685621450553e-06),
#  'kaxiliMxi': (['ka', 'xiliM', 'xi'], 0.0060507613400978336),
#  'rugmawa': (['rugma', 'wa'], 1.8301559011265313e-05),
#  'suraXenu': (['su', 'raXenu'], 0.024064391229913933),
#  'irigeRan': (['irigeR', 'an'], 1.2670310084722142e-05),
#  'eVnIver': (['eVnIv', 'er'], 1.1262497853086347e-05),
#  'niyaMvUwiMci': (['niyaMvUwiMci'], 3.801093025416642e-05),
#  'ivvAlsina': (['ivvAlsi', 'na'], 2.2173042648263745e-05),
#  'kuMtAdu': (['kuMt', 'Adu'], 1.267031008472214e-05),
#  'EsIdIeVs\u200c': (['EsIdI', 'eVs\u200c'], 1.4782028432175832e-05),
#  'jillAlakU': (['jillA', 'lakU'], 3.0619916038078507e-05),
#  'gadupuwunnAdu': (['gadupuwunn', 'Adu'], 1.0558591737268451e-05),
#  'nannayAryuni': (['na', 'nna', 'yAryu', 'ni'], 0.07917502710525734),
#  'pAduwuMdagA': (['pAduwuMda', 'gA'], 8.4468733898147605e-06),
#  'vargAlalo': (['vargAla', 'lo'], 1.3726169258448984e-05),
#  'bareMxar': (['ba', 'reMxar'], 0.23914661649371999),
#  'emavuwuMxannattu': (['em', 'avuwuMxannattu'], 0.11559888554750505),
#  'yUniyanlo': (['yUniy', 'an', 'an', 'lo'], 0.12770353963533479),
#  'wanamanamunaMxuz': (['wanamanam', 'un', 'un', 'aMxuz'], 0.07619071016674607),
#  'eVgumawilo': (['eVgum', 'awi', 'awi', 'lo'], 0.074484772320107598),
#  'prajalalo': (['prajala', 'lo'], 1.1262497853086347e-05),
#  'muKaSAla': (['muKaSA', 'la'], 2.3932807937808487e-05),
#  'svasWawa': (['svasWa', 'wa'], 9.8546856214505547e-06),
#  'watAkamulU': (['wa', 'tAkamulU'], 0.17542550712519947),
#  'Strengthening': (['Strengthe', 'ning'], 1.6893746779629521e-05),
#  'uMdiwIrAli': (['uMdiwI', 'rA', 'rA', 'li'], 0.12265752128946586),
#  'pattikalanu': (['pattikal', 'anu'], 1.5837887605902675e-05),
#  'karwavyAlanu': (['karwav', 'av', 'yAlanu'], 0.0016993078411430193),
#  'pramANa': (['pramA', 'Na'], 9.854685621450553e-06),
#  'pAkudurAlYlYu': (['pAkudu', 'du', 'rA', 'lYlYu'], 0.15809498811694017),
#  'sarvIseVs\u200c': (['sarvIs', 'eVs\u200c'], 1.6893746779629524e-05),
#  'rAGavarAvu': (['rAGav', 'arAvu'], 3.167577521180535e-05),
#  'varNiMcatAniki': (['varN', 'iMcatA', 'niki'], 2.534062016944428e-05),
#  'uxyoginulakU': (['uxyoginu', 'lakU'], 2.9564056864351661e-05),
#  'nadavadaM': (['nadavad', 'aM'], 3.4843352732985885e-05),
#  'xeSaBARalaMxu': (['xeSaBARa', 'laMxu'], 2.9564056864351661e-05),
#  'weVlusA': (['weVlu', 'Vlu', 'sA'], 0.1085868658317341),
#  'viMtiwo': (['viMti', 'ti', 'wo'], 0.07267517305755429),
#  'sujiw\u200ckumAr\u200c': (['sujiw\u200c', 'kumAr\u200c'],
#   1.5837887605902675e-05),
#  'miMcinaxi': (['miMcinaxi'], 8.4468733898147605e-06),
# ...
#  'sepatlo': (['sepat', 'at', 'lo'], 0.15347353458809243),
#  'xAKalEna': (['xAKal', 'al', 'Ena'], 0.091766856395927104),
#  'wqwIyASvAsa': (['wqwIyASvA', 'sa'], 6.3351550423610699e-06),
#  'oVppukoni': (['oVppuko', 'ni'], 1.900546512708321e-05),
#  'gaMtakriwame': (['gaMtak', 'ak', 'riwame'], 0.05269244473028728),
#  'riMgavvagAne': (['ri', 'Mg', 'avvagAne'], 0.058319699516742138),
#  'ekAraNamuwo': (['ekAraNamu', 'wo'], 2.1117183474536902e-05),
#  'vicceVnu': (['vicceV', 'nu'], 5.6312489265431736e-06),
#  'putamuni': (['pu', 'ta', 'mu', 'ni'], 0.1176470630959458),
#  'sinimAwo': (['si', 'nimAwo'], 0.021658740412624063),
#  'jatAyupAka': (['ja', 'tAyupA', 'ka'], 0.16759822985425057),
#  'kAswAneda': (['kAswAneda'], 1.9709371242901106e-05),
#  'kAyalanniMtikI': (['kAyala', 'la', 'nniMti', 'kI'], 0.044675651950134052),
#  'avivekAnni': (['avivekAn', 'ni'], 1.5837887605902675e-05),
#  'asAXAraNaM': (['asAXAraN', 'aM'], 2.534062016944428e-05),
#  'seVkratarIgAne': (['seVkra', 'ra', 'tarIgAne'], 0.20044755076415616),
#  'itAliksulo': (['itAl', 'Al', 'ik', 'su', 'lo'], 0.23320549343712996),
#  'oVkkaxAnike': (['oVkkaxA', 'ni', 'ni', 'ke'], 0.0032243419916510628),
#  'trEniMg': (['trEni', 'ni', 'Mg'], 0.086719368480661835),
#  'enuguke': (['enugu', 'gu', 'ke'], 0.41288894282160082),
#  'weVlusukovAlsiMxi': (['weVlusuko', 'vAlsiM', 'xi'], 7.0390611581789671e-06),
#  'xvAropari': (['xvAropa', 'ri'], 7.3910142160879152e-06),
#  'moVxalagu': (['moVxala', 'gu'], 4.2234366949073802e-06),
#  'kotaloki': (['kotaloki'], 5.6312489265431736e-06),
#  'cinnapillalu': (['cinnapil', 'la', 'la', 'lu'], 0.17809784283928981),
#  'caMxraSeKarAvu': (['caMxraSeK', 'arAvu'], 3.3787493559259035e-05),
#  'vaxilipeVtti': (['vaxilip', 'eVtti'], 1.4782028432175832e-05),
#  'saripovani': (['saripova', 'ni'], 1.267031008472214e-05),
#  'rAwriMcara': (['rAwri', 'Mcara'], 1.267031008472214e-05),
#  'veVnniccinaco': (['veV', 'nniccinaco'], 0.38813470500387848),
#  'Srikakulam': (['Srika', 'ka', 'kulam'], 0.066339482500792468),
#  'pAlavuwunnAru': (['pAlavuwunnAru'], 1.0558591737268449e-05),
#  'japAnulo': (['ja', 'pA', 'nu', 'lo'], 0.20145725835188721),
#  'eVrracaMxanaM': (['eVrracaMx', 'an', 'an', 'aM'], 0.019106828694477905),
#  'aMbaxevudu': (['aMbaxevudu'], 2.534062016944428e-05),
#  'lopaMvalla': (['lopaMval', 'la'], 5.2792958686342252e-05),
#  'weVllagoVdugukiMxa': (['weVllagoVdugukiMxa'], 2.3651245491481328e-05),
#  'rAhuxaSalo': (['rAhu', 'xaSalo'], 1.900546512708321e-05),
#  'uMdetappati': (['uMdet', 'appati'], 8.4468733898147605e-06),
#  'o0tAriyoloni': (['o0tA', 'tA', 'riyolo', 'ni'], 0.067279021195845473),
#  'eVMjeVmu': (['eVMj', 'eV', 'eV', 'mu'], 0.22724929765034493),
#  'saMskqwini': (['saMskqwi', 'ni'], 1.267031008472214e-05),
#  'AkASalo': (['AkASa', 'lo'], 7.0390611581789671e-06),
#  'abaxxamu': (['abaxxa', 'mu'], 4.2234366949073802e-06),
#  'kanipiMcunu': (['kanip', 'iMcunu'], 1.3726169258448986e-05),
#  'weVlaMgANawo': (['weVlaMgANa', 'wo'], 4.0122648601620105e-05),
#  'solipowU': (['solipowU'], 5.6312489265431728e-06),
#  'wAj\u200ckqRNa': (['wAj\u200ckqR', 'Na'], 3.167577521180535e-06),
#  'vixyakosaM': (['vixyakos', 'aM'], 4.0122648601620105e-05),
#  'pravahiMciMxi': (['pravah', 'iMciMxi'], 1.3726169258448986e-05),
#  'SreNulanu': (['SreNul', 'anu'], 4.2234366949073802e-06),
#  'poVgapIlci': (['poVgapIl', 'ci'], 1.1614450910995297e-05),
#  'bAXyawAyuwaMgA': (['bAXyawAy', 'uwaMgA'], 2.0272496135555424e-05),
#  'muxralounna': (['muxralo', 'alo', 'un', 'na'], 0.013880487029909794),
#  'wirucirapalli': (['wirucira', 'palli'], 3.3787493559259035e-05),
#  'mAnasasarovarAniki': (['mAnasa', 'sa', 'sa', 'ro', 'varAn', 'iki'],
#   0.098231069120161885),
#  'peVttiswuMxi': (['peVtti', 'ti', 'swuMxi'], 0.048194710280509631),
#  'cAlakapowe': (['cAlakapowe'], 2.9564056864351661e-05),
#  'SibUSoreVn': (['SibUS', 'oreVn'], 5.2792958686342255e-06),
#  'AveSAniki': (['AveSA', 'niki'], 2.1117183474536899e-05),
#  'CAritabul\u200c': (['CAri', 'ri', 'tabul\u200c'], 0.033015051244378937),
#  'nirmiMcAlanI': (['nirmiMcA', 'lanI'], 3.2098118881296087e-05),
#  'wappulu': (['wappulu'], 4.2234366949073802e-06),
#  'dimAMd\u200cpE': (['dimAMd\u200cpE'], 4.2234366949073802e-06),
#  'yAMtibayAtiks\u200c': (['yAMti', 'ba', 'ba', 'yA', 'tiks\u200c'],
#   0.17582079966463976),
#  'sIriyas\u200cgAne': (['sI', 'riyas\u200cgAne'], 0.048449721244457428),
#  'parugeVwwedu': (['parugeVwwe', 'du'], 1.5837887605902675e-05),
#  'yiccAru': (['yiccA', 'ru'], 1.267031008472214e-05),
#  'majilIlu': (['ma', 'jilIlu'], 0.066230730279402766),
#  'reVccipoyi': (['reVc', 'cipoyi'], 8.4468733898147605e-06),
#  'pravahiMcexi': (['pravah', 'iMcexi'], 1.3726169258448986e-05),
#  'mIranukoVMxurA': (['mIra', 'ra', 'nukoVM', 'xu', 'xu', 'rA'],
#   0.034408569621448941),
#  'beriyAtrik': (['beriyAtrik'], 5.6312489265431736e-06),
#  'pArabosi': (['pArabo', 'si'], 4.2234366949073802e-06),
#  'wAralannI': (['wAralannI'], 3.9418742485802212e-05),
#  'breVjil': (['breVjil'], 2.1117183474536901e-06),
#  'Bajiswe': (['Bajiswe'], 4.2234366949073802e-06),
#  'aMtarAniwanaM': (['aM', 'tar', 'Aniwan', 'aM'], 0.26597331860921014),
#  'viBajiMcavaccu': (['viBajiMc', 'avaccu'], 1.0558591737268449e-05),
#  'xqDawvaM': (['xqDawv', 'aM'], 2.534062016944428e-05),
#  'vyUhaMgA': (['vyUhaM', 'gA'], 5.6312489265431736e-06),
#  'prapaMcaMlo': (['prapaM', 'aM', 'caM', 'lo'], 0.33072561761716879),
#  'pAriSrAmikaMgA': (['pAriS', 'rAmi', 'kaMgA'], 1.900546512708321e-05),
#  'pUrNamma': (['pUrNam', 'ma'], 1.267031008472214e-05),
#  'nAtikalannI': (['nAtika', 'lannI'], 3.6955071080439577e-05),
#  'ceyavaccani': (['ceyavacca', 'ni'], 2.7452338516897969e-05),
#  'prowsahiMci': (['prow', 'sahiM', 'ci'], 1.0136248067777711e-05),
#  'gurwuMtAnani': (['gurwuM', 'tA', 'tA', 'na', 'ni'], 0.1225499537636444),
#  'saMxeSAlni': (['sa', 'MxeSAl', 'ni'], 0.0028039223482238468),
#  'nyAyaMwo': (['nyAyaMwo'], 2.8156244632715865e-05),
#  'jillAnuMdi': (['jillAn', 'An', 'uMdi'], 0.047680902635706186),
#  'AgiMxemI': (['AgiMxemI'], 5.6312489265431728e-06),
#  'mammalnaMxarnI': (['mammaln', 'aMxarnI'], 3.6603118022530627e-05),
#  'rARtraMloni': (['rARtr', 'tr', 'aMloni'], 0.16875442869425161),
#  'maMdana': (['maMda', 'na'], 3.2379681327623249e-05),
#  'viRNurUpAya': (['viRNurUpA', 'ya'], 1.267031008472214e-05),
#  'nirvahiMcabadunu': (['nirvahiM', 'cabadu', 'nu'], 1.5485934547993725e-05),
#  'Agipoyexi': (['Agipoye', 'xi'], 4.2234366949073802e-06),
#  'marripAlu': (['marripA', 'lu'], 1.6893746779629518e-05),
#  'xuswulawo': (['xu', 'swula', 'wo'], 0.16834153324464057),
#  'karaMbu': (['karaMbu'], 5.0681240338888559e-05),
#  'vAnigaddaM': (['vAnigadd', 'aM'], 2.2173042648263745e-05),
#  '2013-12-15T10:47:33': (['2013-12-15T10:47:33'], 0.0),
#  'mallamma': (['mallam', 'ma'], 2.2524995706172695e-05),
#  'maliMganu': (['maliMg', 'Mg', 'anu'], 0.13047604230587434),
#  '155-172.': (['155-172.'], 0.0),
#  'mahAsaBa': (['mahAsa', 'Ba'], 1.5485934547993728e-05),
#  'kaxilipoyAyi': (['ka', 'xilipoyAyi'], 0.00604864962175038),
#  'vAyiMcu': (['vA', 'yiMcu'], 0.05730794417703617),
#  'xalElAmAwo': (['xalElAmA', 'wo'], 7.391014216087916e-06),
#  'niruxyogiwa': (['ni', 'ruxyogiwa'], 0.056706966128213236),
#  'sAhiwyamu': (['sAhiwya', 'mu'], 5.6312489265431736e-06),
#  'riMcataM': (['riMcat', 'aM'], 2.6748432401080072e-05),
#  'jEtlIwo': (['jEtlI', 'wo'], 2.8156244632715868e-06),
#  'oxArcAru': (['oxArcA', 'ru'], 1.3726169258448986e-05),
#  'kummari0cu': (['ku', 'mm', 'ari0cu'], 0.18284655869149039),
#  'neVttesiMxi': (['neVttesiM', 'xi'], 2.1117183474536901e-06),
#  'iä¢xujiw': (['iä¢xujiw'], 5.6312489265431736e-06),
#  'polcinatlayiwe': (['polcin', 'at', 'at', 'la', 'yiwe'], 0.06392673603201178),
#  'rODlanee': (['rODlanee'], 3.9418742485802212e-05),
#  'nalaBESAwaM': (['na', 'laBESAwaM'], 0.054509795912486655),
#  'akROhiNula': (['akROhiNu', 'la'], 1.900546512708321e-05),
#  '1994-10-31': (['1994-10-31'], 0.0),
#  'kqwrimaMgA': (['kqwri', 'maMgA'], 1.6893746779629521e-05),
#  'krikeVtarlu': (['krikeVt', 'ar', 'ar', 'lu'], 0.013855606705794915),
#  'arikAlYlYa': (['ar', 'ik', 'AlYlYa'], 0.068262454332572997),
#  'meVrugani': (['meVrugani'], 1.9709371242901106e-05),
#  'saMwoRiMcAdu': (['saMwoRiMc', 'Adu'], 6.3351550423610699e-06),
#  'biddawo': (['bidda', 'wo'], 2.8156244632715868e-06),
#  'areVreV': (['ar', 'eVreV'], 0.085011140267741134),
#  'XanahAnimaNikattunaMxu': (['Xana',
#    'na',
#    'hAnimaNikatt',
#    'un',
#    'un',
#    'aM',
#    'xu'],
#   0.03207242100182249),
#  'meVmoVrAMdam': (['meVmoV', 'moV', 'rAMdam'], 0.22241864495580677),
#  'WOjaMdu': (['WOjaM', 'aM', 'du'], 0.21532324992109098),
#  'siggugA': (['siggu', 'gu', 'gA'], 0.087836510301307902),
#  'pattukovoy\u200c': (['pattukovoy\u200c'], 1.3726169258448984e-05),
#  'karapawra0': (['karapawra0'], 3.6603118022530627e-05),
#  'patamatalaMkaku': (['pa', 'ta', 'ma', 'talaM', 'ka', 'ka', 'ku'],
#   0.10384567166689049),
#  '16.puxicceri': (['16.pux', 'ux', 'icceri'], 0.051679739524810912),
#  'garibAld': (['ga', 'ribAld'], 0.098739765987531924),
#  'rAmAyaNa': (['rAmAya', 'Na'], 1.4078122316357934e-05),
#  'BUpariveRtiwa': (['BUpariveR', 'ti', 'ti', 'wa'], 0.10876059828473672),
#  'Xarmamane': (['Xarmamane'], 2.2524995706172695e-05),
#  'EdApsin': (['EdAps', 'in'], 2.8156244632715868e-06),
#  'Population': (['Popula', 'la', 'tion'], 0.14296748665208098),
#  'mqgamulu': (['mqgamu', 'lu'], 1.1262497853086346e-05),
#  'sadeVn\u200cgA': (['sa', 'deVn\u200c', 'gA'], 0.17746906066489743),
#  'paviwravqwwigA': (['pa', 'viwravqwwi', 'gA'], 0.068428828900997579),
#  'palYlYulevugA': (['pa', 'lYlYulevu', 'gA'], 0.036237431409341575),
#  'vakwalu': (['vakwa', 'wa', 'lu'], 0.025264458159419204),
#  '__weblink__101BC8Qafnu': (['__webl', 'ink__101BC8Qaf', 'nu'],
#   3.6200885956348975e-06),
#  'visuruwU': (['vi', 'suruwU'], 0.14884276337659166),
#  'caxvulu': (['caxvu', 'lu'], 1.4078122316357932e-05),
#  'eVvarikivAru': (['eV', 'varikivAru'], 0.041438201151163326),
#  'SrInivAs\u200cyAxav': (['SrInivAs\u200cyAx', 'av'], 2.1117183474536899e-05),
#  'aBivqxWi': (['aBivqxWi'], 0.0),
#  'teVligrAPku': (['teVlig', 'rAPku'], 1.6893746779629521e-05),
#  'dIlApadipoyinA': (['dIlApadipoyi', 'nA'], 2.7874682186388706e-05),
#  'cuttupakkalaku': (['cuttu', 'pakkal', 'aku'], 2.3651245491481328e-05),
#  'peVttuna': (['peVttu', 'na'], 2.1117183474536899e-05),
#  'sOBaxro': (['sOBaxro'], 8.4468733898147605e-06),
#  'cejikkiMcukovAlani': (['cejikkiMcukovA', 'la', 'la', 'ni'],
#   0.014520292220207887),
#  'bIdijEn': (['bIdij', 'En'], 1.4078122316357934e-06),
#  'paMpiswAM': (['paMpi', 'swAM'], 2.0061324300810052e-05),
#  'Romronu': (['Romro', 'ro', 'nu'], 0.072009228592691099),
#  'cinnaviRayamU': (['cinnaviRa', 'yamU'], 4.2234366949073797e-05),
#  'eVksarsEjes': (['eVksarsEjes'], 2.3228901821990587e-05),
#  'araviMxa': (['araviM', 'xa'], 2.2524995706172691e-05),
#  'stArtayiMxi': (['stAr', 'Ar', 'tayiM', 'xi'], 0.093405648487988685),
#  'peVMdiMg\u200clounnAyi': (['peVMdiMg\u200c', 'lo', 'lo', 'unnAyi'],
#   0.24410495075983851),
#  'likkar\u200c': (['li', 'kka', 'r\u200c'], 0.27169403440241224),
#  'awikramamu': (['awikramamu'], 2.534062016944428e-05),
#  'veVlYuwuMdevArani': (['veVlYuw', 'uMdevAra', 'ni'], 1.1966403968904244e-05),
#  'BAraw\u200cwo': (['BAraw\u200cwo'], 2.534062016944428e-05),
#  'rAniyAn': (['rAniy', 'An'], 2.1117183474536902e-05),
#  'jarigivuMdexi': (['jarigiv', 'uMdexi'], 6.3351550423610699e-06),
#  'savariMcalekapoyAyi': (['savar', 'iMc', 'iMc', 'aleka', 'poyAyi'],
#   3.4900806044946901e-05),
#  'saMbaMXiMcinave': (['saMb', 'aMXiMci', 'nave'], 4.1027670750528835e-05),
#  'xigaMbarAya': (['xigaMbarA', 'ya'], 4.8569521991434867e-05),
#  'byAlast': (['byAlast'], 2.8156244632715868e-06),
#  'Baje2haM–': (['Baje2haM–'], 4.2234366949073802e-06),
#  'priyamugA': (['priyamugA'], 2.8156244632715865e-05),
#  'xvAxaSAxiwyulunu': (['xvAxaSAxiwyu', 'lu', 'lu', 'nu'],
#   0.060268569847085035),
#  'mAtalAdukovataM': (['mAtal', 'al', 'AdukovataM'], 0.086612722446970158),
#  'SivarAman\u200c': (['SivarA', 'ma', 'ma', 'n\u200c'], 0.094017034901808766),
#  'viswqwaparacAli': (['viswq', 'wa', 'wa', 'paracA', 'li'],
#   0.0099903157554374952),
#  'engineering': (['enginee', 'ring'], 5.0681240338888561e-06),
#  'AduwunnatlugA': (['AduwunnatlugA'], 8.4468733898147605e-06),
#  'ceVsukoVni': (['ceV', 'sukoVni'], 0.40800848841528559),
#  'cinnappuxu': (['cinnappuxu'], 1.1262497853086347e-05),
#  'nilaxISAru': (['ni', 'laxISA', 'ru'], 0.021787829344527918),
#  'viBajiswAru': (['viBajiswA', 'ru'], 9.5027325635416049e-06),
#  'PyAkRanist\u200c': (['PyAkRa', 'Ra', 'nist\u200c'], 0.13670392708108445),
#  'wappiMcukuneMxuku': (['wappiMcu', 'kuneMxu', 'ku'], 1.6290398680357036e-05),
#  'DIkoVnadAnikI': (['DIkoV', 'na', 'na', 'dAnikI'], 0.11375778063181403),
#  'bIeVMIsI': (['bIeVMIsI'], 1.9709371242901109e-05),
#  'buraKAlo': (['buraKAlo'], 2.534062016944428e-05),
#  'limiteVd\u200cki': (['limit', 'eVd\u200cki'], 1.4782028432175832e-05),
#  'eVrukaloki': (['eV', 'ru', 'ka', 'loki'], 0.029881783599451553),
#  'padipokuMdA': (['padipo', 'kuMdA'], 2.8508197690624815e-05),
#  'sawyanArAyaNasvAmi': (['sawya', 'nA', 'nA', 'rAyaNa', 'svAmi'],
#   0.014748858522631754),
#  'goVppagoVppa': (['goVppagoVp', 'pa'], 4.1178507775346954e-05),
#  'BUmmIxa': (['BUmmI', 'xa'], 7.0390611581789671e-06),
#  'neVwwikeVkkiMcukuMte': (['neVwwik', 'eVkk', 'iMcuk', 'uMte'],
#   1.4782028432175832e-05),
#  'xeVlpabadutaye': (['xeVlpabadutaye'], 2.7452338516897969e-05),
#  'paMdiMxani': (['paMdiMxa', 'ni'], 2.4284760995717434e-05),
#  'nAmineteVd\u200c': (['nAminet', 'eVd\u200c'], 1.7738434118610998e-05),
#  'xuRpraBAvAlaku': (['xuRpraBAvAla', 'ku'], 2.1117183474536899e-05),
#  'pariRkAriMcAli': (['pariRkAr', 'iMcAli'], 1.7738434118610995e-05),
#  'pAlpaddaxani': (['pAlpaddaxani'], 2.7452338516897969e-05),
#  'ArAXiMcucuMdeVnu': (['ArAX', 'iMcuc', 'uMdeV', 'nu'],
#   1.1463613886177174e-05),
#  '2009-06-04.': (['2009-06-04.'], 0.0),
#  'SrIxurgA': (['SrIxur', 'gA'], 7.0390611581789671e-06),
#  'vakwagA': (['vakwa', 'gA'], 1.6893746779629518e-05),
#  'ceVk\u200cpostupE': (['ceVk\u200c', 'postupE'], 1.6893746779629522e-06),
#  'nAnnagAru': (['nA', 'nnagAru'], 0.10584158302895944),
#  'AtagAlYlYu': (['AtagA', 'gA', 'lYlYu'], 0.0050020345948475504),
#  'Visakhapatnam': (['Visak', 'ha', 'ha', 'patnam'], 0.071799997980559319),
#  'badjeVtlo': (['badjeVtlo'], 1.9709371242901109e-05),
#  'ceswunnAnaMte': (['ceswunnA', 'unnA', 'na', 'Mte'], 0.23004217941553909),
#  'baravasaMgAvaddiswuMte': (['ba', 'ravasa', 'MgAvaddiswuMte'],
#   0.01652105737241135),
#  'Feelings': (['Feelings'], 5.6312489265431728e-06),
#  'AviRkaraNagOrava': (['AviRk', 'araNagOra', 'va'], 2.1117183474536895e-05),
#  'nyAyasWAnAlu': (['nyAyasWAnAlu'], 2.1117183474536899e-05),
#  'jIeVseVP': (['jIeVseVP'], 1.9709371242901109e-05),
#  'jaMwuvayinA': (['jaMwuvayi', 'nA'], 9.5027325635416049e-06),
#  'objectives': (['objec', 'tives'], 2.1117183474536897e-06),
#  'varmagAri': (['varma', 'ma', 'gA', 'ri'], 0.024111955626771056),
#  'fontःnormal': (['fontःnor', 'mal'], 2.1117183474536897e-06),
#  'hiRtarikal': (['hiRtar', 'tar', 'ik', 'al'], 0.056706002140876365),
#  'natiMceru': (['natiMce', 'ru'], 2.3228901821990591e-05),
#  'progrAm\u200cllo': (['progrAm\u200cl', 'lo'], 2.2173042648263745e-05),
#  'janmaBUmilo': (['janmaBUmi', 'lo'], 2.2173042648263745e-05),
#  'Googlece': (['Googlece'], 0.0),
#  'vIlYlYaMxarU': (['vIlY', 'lY', 'aMxarU'], 0.088352198037014329),
#  '7,8,9wexIllo': (['7,8,9wexIl', 'lo'], 5.2792958686342255e-06),
#  'SaMkar\u200cpalli': (['SaMka', 'r\u200c', 'r\u200c', 'palli'],
#   0.06808154454257509),
#  'rAmakuppaM': (['rAmaku', 'aku', 'pp', 'aM'], 0.23017684351615569),
#  'beVMdli': (['beVMd', 'li'], 2.8156244632715864e-06),
#  'bayomAs': (['bayomAs'], 1.4078122316357934e-06),
#  'koVnasAgiswunnAnu': (['koVnasAgisw', 'unnAnu'], 8.4468733898147605e-06),
#  'anuBaviswunnAru': (['anuBavisw', 'unnAru'], 1.5204372101666567e-05),
#  'sOlaByAnni': (['sOlaByAn', 'ni'], 4.0122648601620112e-05),
#  'Berleburg': (['Berleburg'], 0.0),
#  'xomalakeVM': (['xoma', 'ma', 'lakeVM'], 0.011617359352474153),
#  'praXAnopAXyAyurAlu': (['praXAnopAX', 'yAyurA', 'lu'], 1.830155901126531e-05),
#  'jabbuwo': (['jabbu', 'wo'], 4.2234366949073802e-06),
#  'srIlaMxarU': (['srIla', 'la', 'MxarU'], 0.066268922226513455),
#  'sAyaMkAlAllo': (['sAyaMkAlAllo'], 3.801093025416642e-05),
#  'asaMpUrNamEnaxigA': (['asaMpUr', 'NamEna', 'xi', 'xi', 'gA'],
#   0.033749841899862354)}
