# %%
import pandas as pd
import numpy

# %%
def tokenize(x):
    return x.strip().split(' ')

# %%
def load_file(file_name):
    with open(data_file) as d:
        for line in d:
            yield tokenize(line)

# %%
data_file = 'data/wikitext-2/train.txt'
f = load_file(data_file)

# %%
def get_tokens(file):
    tokens = {}
    for sent in file:
        for token in sent:
            try:
                tokens[token] += 1
            except:
                tokens[token] = 1
    return tokens

# %%
# %%time 
tokens = get_tokens(f)
print(len(tokens))
# Out:
# 33278
# CPU times: user 356 ms, sys: 3.6 ms, total: 360 ms
# Wall time: 450 ms

# %%
import math
def norm_probs(tokens):
    s = sum(tokens.values())
    return {k : round(math.log(v/float(s)),4) for k, v in tokens.items()}
def sort_probs(probs):
    return sorted(probs.items(), key=lambda x:x[1], reverse=True)

# %%
probs = norm_probs(tokens)
sorted_probs = sort_probs(probs)

# %%
sorted_probs[100:130]
# Out:
# [('000', -7.2633),
#  ('song', -7.2654),
#  ('before', -7.2675),
#  ('being', -7.2793),
#  ('years', -7.2892),
#  ('5', -7.3246),
#  ('series', -7.3491),
#  ('album', -7.3491),
#  ('second', -7.3705),
#  ('through', -7.372),
#  ('can', -7.3759),
#  ('both', -7.3774),
#  ('4', -7.3867),
#  ('part', -7.3883),
#  ('then', -7.3922),
#  ('including', -7.3938),
#  ('New', -7.397),
#  ('/', -7.4009),
#  ('against', -7.4017),
#  ('number', -7.4025),
#  ('became', -7.4057),
#  ('film', -7.4073),
#  ('known', -7.4105),
#  ('well', -7.4153),
#  ('—', -7.4177),
#  ('many', -7.4439),
#  ('there', -7.4463),
#  ('no', -7.4513),
#  ('United', -7.4555),
#  ('century', -7.4853)]

# %%
a = "Hello"
a[3:10]
# Out:
# 'lo'

# %%
# def is_stack_completed(stack, token):
#     return all([len(''.join(x)) == len(token) for x in stack]) and len(stack) > 0


def is_stack_completed(stack, token):
    new_stack = []
    for s in stack:
        new_s = [x if i == 0 else x[1:] for i, x in enumerate(s)]
        new_stack.append(new_s)
    #print(stack, '/', new_stack)
    return all([len(''.join(x)) == len(token) for x in new_stack]) and len(new_stack) > 0

def get_grams(token, position, start_from=2, max_gram = 4):
    return list(set([token[position:position+x] for x in range(start_from, max_gram + 1)]))


def print_stack(stack, level = 0):
    cleaved = {}
    
    for x in stack:
        if x[0] not in cleaved:
            cleaved[x[0]] = []
        if len(x) > 1:
            cleaved[x[0]].append(x[1:])
    
    for k, v in cleaved.items():
        print(level*"-", k)
        if len(v) > 0:
            print_stack(v, level+1)
    
 
def process_token(token, max_gram = 4):
    stack = []
    counter = 0
    pairs = {}
    while is_stack_completed(stack, token) == False:
        #print(counter, stack)
        if len(stack) == 0:
            stack += [[x] for x in get_grams(token, 0)]
        p_stack = []
        for i, element in enumerate(stack):
            position = len(''.join( [x if i == 0 else x[1:] for i, x in enumerate(element)])) - 1
            grams = get_grams(token, position)
            #print(i, '/', element, '/', stack, '/', p_stack, grams)
            for g in grams:
                if len(g) > 0:
                    p = element[-1]
                    if len(p)> 1 and len(g) > 1:
                        p_stack.append(element + [g])
                        pair = (p, g)
                        if counter > 15:
                            print(token, "Something wrong here", stack,  p_stack, grams)
                            return None
                        #yield pair
                        if pair not in pairs:
                            yield pair
                            pairs[pair] = 0
    #                     if pair not in pairs:
#                         pairs[pair] = 0
#                     pairs[pair] += 1
        stack = p_stack
        #print_stack(stack)
        counter += 1
       
    #return pairs

# %%
list(process_token('apple'))
# Out:
# [('ap', 'pple'),
#  ('ap', 'ppl'),
#  ('ap', 'pp'),
#  ('appl', 'le'),
#  ('app', 'pl'),
#  ('app', 'ple'),
#  ('ppl', 'le'),
#  ('pp', 'pl'),
#  ('pp', 'ple'),
#  ('pl', 'le')]

# %%
words = [x[0] for x in sorted_probs if len(x[0]) > 6]

# %%
sample_words = words[:15000]

# %%
# %time
# token = 'insurmountable'
# #pairs = process_token(token)


pairs = {}
unigrams = {}

for t, token in enumerate(sample_words):
    for pair in process_token(token):
        if pair != None:
            if pair not in pairs:
                pairs[pair] = 0
            pairs[pair] += 1

            for k in pair:
                kp = (k, )
                if kp not in pairs:
                    pairs[kp] = 0
                pairs[kp] += 1
    if t % 1000 == 0:
        print(t, "Done !!")
# Out:
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 3.58 µs
# 0 Done !!
# 1000 Done !!
# 2000 Done !!
# 3000 Done !!
# 4000 Done !!
# 5000 Done !!
# 6000 Done !!
# 7000 Done !!
# 8000 Done !!
# 9000 Done !!
# 10000 Done !!
# 11000 Done !!
# 12000 Done !!
# 13000 Done !!
# 14000 Done !!

# %%
pairs, sum(pairs.values())
# Out:
# ({('be', 'etw'): 1,
#   ('be',): 981,
#   ('etw',): 34,
#   ('be', 'etwe'): 1,
#   ('etwe',): 6,
#   ('be', 'et'): 14,
#   ('et',): 2455,
#   ('bet', 'twe'): 1,
#   ('bet',): 50,
#   ('twe',): 30,
#   ('bet', 'twee'): 1,
#   ('twee',): 9,
#   ('bet', 'tw'): 1,
#   ('tw',): 205,
#   ('betw', 'ween'): 1,
#   ('betw',): 3,
#   ('ween',): 9,
#   ('betw', 'wee'): 1,
#   ('wee',): 37,
#   ('betw', 'we'): 1,
#   ('we',): 654,
#   ('etw', 'ween'): 2,
#   ('etw', 'wee'): 2,
#   ('etw', 'we'): 2,
#   ('etwe', 'een'): 2,
#   ('een',): 222,
#   ('etwe', 'ee'): 2,
#   ('ee',): 1198,
#   ('et', 'twe'): 2,
#   ('et', 'twee'): 2,
#   ('et', 'tw'): 8,
#   ('twe', 'een'): 2,
#   ('twe', 'ee'): 3,
#   ('twee', 'en'): 2,
#   ('en',): 8258,
#   ('tw', 'ween'): 2,
#   ('tw', 'wee'): 3,
#   ('tw', 'we'): 8,
#   ('wee', 'en'): 3,
#   ('we', 'een'): 3,
#   ('we', 'ee'): 10,
#   ('ee', 'en'): 55,
#   ('thr', 'roug'): 4,
#   ('thr',): 135,
#   ('roug',): 84,
#   ('thr', 'rou'): 4,
#   ('rou',): 370,
#   ('thr', 'ro'): 16,
#   ('ro',): 4051,
#   ('th', 'hr'): 33,
#   ('th',): 2374,
#   ('hr',): 437,
#   ('th', 'hro'): 16,
#   ('hro',): 187,
#   ('th', 'hrou'): 4,
#   ('hrou',): 24,
#   ('thro', 'oug'): 4,
#   ('thro',): 71,
#   ('oug',): 183,
#   ('thro', 'ough'): 4,
#   ('ough',): 130,
#   ('thro', 'ou'): 4,
#   ('ou',): 2857,
#   ('roug', 'gh'): 22,
#   ('gh',): 995,
#   ('rou', 'ugh'): 22,
#   ('ugh',): 202,
#   ('rou', 'ug'): 22,
#   ('ug',): 481,
#   ('ro', 'oug'): 22,
#   ('ro', 'ough'): 22,
#   ('ro', 'ou'): 83,
#   ('hr', 'roug'): 6,
#   ('hr', 'rou'): 6,
#   ('hr', 'ro'): 40,
#   ('hro', 'oug'): 6,
#   ('hro', 'ough'): 6,
#   ('hro', 'ou'): 6,
#   ('hrou', 'ugh'): 6,
#   ('hrou', 'ug'): 6,
#   ('oug', 'gh'): 35,
#   ('ou', 'ugh'): 35,
#   ('ou', 'ug'): 41,
#   ('ug', 'gh'): 47,
#   ('in', 'nclu'): 6,
#   ('in',): 12575,
#   ('nclu',): 72,
#   ('in', 'ncl'): 9,
#   ('ncl',): 135,
#   ('in', 'nc'): 102,
#   ('nc',): 2664,
#   ('inc', 'cl'): 9,
#   ('inc',): 402,
#   ('cl',): 885,
#   ('inc', 'clu'): 6,
#   ('clu',): 157,
#   ('inc', 'clud'): 4,
#   ('clud',): 62,
#   ('incl', 'ludi'): 1,
#   ('incl',): 28,
#   ('ludi',): 19,
#   ('incl', 'lud'): 4,
#   ('lud',): 101,
#   ('incl', 'lu'): 6,
#   ('lu',): 904,
#   ('nclu', 'ud'): 9,
#   ('ud',): 504,
#   ('nclu', 'udi'): 2,
#   ('udi',): 127,
#   ('nclu', 'udin'): 2,
#   ('udin',): 31,
#   ('ncl', 'ludi'): 2,
#   ('ncl', 'lud'): 9,
#   ('ncl', 'lu'): 16,
#   ('nc', 'cl'): 29,
#   ('nc', 'clu'): 16,
#   ('nc', 'clud'): 9,
#   ('cl', 'ludi'): 3,
#   ('cl', 'lud'): 14,
#   ('cl', 'lu'): 32,
#   ('clu', 'ud'): 14,
#   ('clu', 'udi'): 3,
#   ('clu', 'udin'): 3,
#   ('clud', 'ding'): 3,
#   ('ding',): 500,
#   ('clud', 'di'): 3,
#   ('di',): 3484,
#   ('clud', 'din'): 3,
#   ('din',): 811,
#   ('ludi', 'in'): 4,
#   ('ludi', 'ing'): 4,
#   ('ing',): 4888,
#   ('lud', 'ding'): 4,
#   ('lud', 'di'): 4,
#   ('lud', 'din'): 4,
#   ('lu', 'ud'): 21,
#   ('lu', 'udi'): 4,
#   ('lu', 'udin'): 4,
#   ('ud', 'ding'): 5,
#   ('ud', 'di'): 29,
#   ('ud', 'din'): 7,
#   ('udi', 'in'): 7,
#   ('udi', 'ing'): 5,
#   ('udin', 'ng'): 5,
#   ('ng',): 6096,
#   ('di', 'in'): 187,
#   ('di', 'ing'): 158,
#   ('din', 'ng'): 158,
#   ('in', 'ng'): 1515,
#   ('agai', 'in'): 1,
#   ('agai',): 3,
#   ('agai', 'inst'): 1,
#   ('inst',): 172,
#   ('agai', 'ins'): 1,
#   ('ins',): 501,
#   ('ag', 'gain'): 1,
#   ('ag',): 1404,
#   ('gain',): 18,
#   ('ag', 'gai'): 1,
#   ('gai',): 21,
#   ('ag', 'ga'): 26,
#   ('ga',): 1219,
#   ('aga', 'ai'): 1,
#   ('aga',): 114,
#   ('ai',): 1580,
#   ('aga', 'ains'): 1,
#   ('ains',): 67,
#   ('aga', 'ain'): 1,
#   ('ain',): 667,
#   ('in', 'nst'): 51,
#   ('nst',): 552,
#   ('in', 'ns'): 149,
#   ('ns',): 3829,
#   ('ins', 'st'): 51,
#   ('st',): 6544,
#   ('gain', 'nst'): 2,
#   ('gain', 'ns'): 2,
#   ('gai', 'in'): 5,
#   ('gai', 'inst'): 2,
#   ('gai', 'ins'): 2,
#   ('ga', 'ai'): 5,
#   ('ga', 'ains'): 2,
#   ('ga', 'ain'): 5,
#   ('ai', 'in'): 149,
#   ('ai', 'inst'): 5,
#   ('ai', 'ins'): 21,
#   ('ains', 'st'): 5,
#   ('ain', 'nst'): 5,
#   ('ain', 'ns'): 21,
#   ('ns', 'st'): 116,
#   ('cen', 'ntu'): 2,
#   ('cen',): 384,
#   ('ntu',): 130,
#   ('cen', 'nt'): 45,
#   ('nt',): 6484,
#   ('cen', 'ntur'): 2,
#   ('ntur',): 69,
#   ('ce', 'en'): 85,
#   ('ce',): 3049,
#   ('ce', 'ent'): 45,
#   ('ent',): 2987,
#   ('ce', 'entu'): 2,
#   ('entu',): 97,
#   ('cent', 'tur'): 2,
#   ('cent',): 171,
#   ('tur',): 818,
#   ('cent', 'tu'): 2,
#   ('tu',): 1704,
#   ('cent', 'tury'): 1,
#   ('tury',): 6,
#   ('ntu', 'ury'): 2,
#   ('ury',): 57,
#   ('ntu', 'ur'): 16,
#   ('ur',): 3236,
#   ('nt', 'tur'): 16,
#   ('nt', 'tu'): 26,
#   ('nt', 'tury'): 2,
#   ('ntur', 'ry'): 2,
#   ('ry',): 1002,
#   ('en', 'ntu'): 21,
#   ('en', 'nt'): 713,
#   ('en', 'ntur'): 16,
#   ('ent', 'tur'): 16,
#   ('ent', 'tu'): 21,
#   ('ent', 'tury'): 2,
#   ('entu', 'ury'): 2,
#   ('entu', 'ur'): 16,
#   ('tur', 'ry'): 2,
#   ('tu', 'ury'): 2,
#   ('tu', 'ur'): 180,
#   ('ur', 'ry'): 18,
#   ('sev', 've'): 9,
#   ('sev',): 48,
#   ('ve',): 3250,
#   ('sev', 'ver'): 4,
#   ('ver',): 1154,
#   ('sev', 'vera'): 1,
#   ('vera',): 42,
#   ('se', 'ever'): 4,
#   ('se',): 3443,
#   ('ever',): 135,
#   ('se', 'eve'): 9,
#   ('eve',): 466,
#   ('se', 'ev'): 12,
#   ('ev',): 1067,
#   ('seve', 'eral'): 1,
#   ('seve',): 29,
#   ('eral',): 101,
#   ('seve', 'er'): 4,
#   ('er',): 11736,
#   ('seve', 'era'): 1,
#   ('era',): 1018,
#   ('ve', 'eral'): 4,
#   ('ve', 'er'): 264,
#   ('ve', 'era'): 12,
#   ('ver', 'ra'): 12,
#   ('ra',): 6729,
#   ('ver', 'ral'): 4,
#   ('ral',): 381,
#   ('vera', 'al'): 4,
#   ('al',): 5535,
#   ('ever', 'ra'): 3,
#   ('ever', 'ral'): 2,
#   ('eve', 'eral'): 2,
#   ('eve', 'er'): 40,
#   ('eve', 'era'): 3,
#   ('ev', 've'): 114,
#   ('ev', 'ver'): 40,
#   ('ev', 'vera'): 3,
#   ('er', 'ra'): 198,
#   ('er', 'ral'): 29,
#   ('era', 'al'): 29,
#   ('ra', 'al'): 99,
#   ('epis', 'sode'): 2,
#   ('epis',): 15,
#   ('sode',): 17,
#   ('epis', 'sod'): 3,
#   ('sod',): 27,
#   ('epis', 'so'): 3,
#   ('so',): 1419,
#   ('epi', 'iso'): 3,
#   ('epi',): 99,
#   ('iso',): 204,
#   ('epi', 'isod'): 3,
#   ('isod',): 22,
#   ('epi', 'is'): 5,
#   ('is',): 5373,
#   ('ep', 'pis'): 5,
#   ('ep',): 1207,
#   ('pis',): 55,
#   ('ep', 'piso'): 3,
#   ('piso',): 18,
#   ('ep', 'pi'): 26,
#   ('pi',): 1221,
#   ('sod', 'de'): 5,
#   ('de',): 3953,
#   ('so', 'od'): 6,
#   ('od',): 982,
#   ('so', 'ode'): 5,
#   ('ode',): 122,
#   ('iso', 'od'): 6,
#   ('iso', 'ode'): 5,
#   ('isod', 'de'): 5,
#   ('is', 'sode'): 5,
#   ('is', 'sod'): 6,
#   ('is', 'so'): 46,
#   ('pis', 'sode'): 4,
#   ('pis', 'sod'): 5,
#   ('pis', 'so'): 5,
#   ('piso', 'od'): 5,
#   ('piso', 'ode'): 4,
#   ('pi', 'iso'): 5,
#   ('pi', 'isod'): 5,
#   ('pi', 'is'): 14,
#   ('od', 'de'): 30,
#   ('Am', 'mer'): 4,
#   ('Am',): 66,
#   ('mer',): 338,
#   ('Am', 'meri'): 4,
#   ('meri',): 34,
#   ('Am', 'me'): 6,
#   ('me',): 3429,
#   ('Amer', 'rica'): 4,
#   ('Amer',): 12,
#   ('rica',): 172,
#   ('Amer', 'ric'): 4,
#   ('ric',): 488,
#   ('Amer', 'ri'): 4,
#   ('ri',): 6474,
#   ('Ame', 'eri'): 4,
#   ('Ame',): 18,
#   ('eri',): 1078,
#   ('Ame', 'er'): 4,
#   ('Ame', 'eric'): 4,
#   ('eric',): 69,
#   ('mer', 'rica'): 5,
#   ('mer', 'ric'): 6,
#   ('mer', 'ri'): 8,
#   ('meri', 'ican'): 2,
#   ('ican',): 108,
#   ('meri', 'ic'): 6,
#   ('ic',): 4770,
#   ('meri', 'ica'): 5,
#   ('ica',): 1541,
#   ('me', 'eri'): 8,
#   ('me', 'er'): 81,
#   ('me', 'eric'): 6,
#   ('rica', 'an'): 9,
#   ('an',): 7317,
#   ('ric', 'can'): 9,
#   ('can',): 207,
#   ('ric', 'ca'): 37,
#   ('ca',): 2918,
#   ('ri', 'ican'): 9,
#   ('ri', 'ic'): 109,
#   ('ri', 'ica'): 37,
#   ('eri', 'ican'): 2,
#   ('eri', 'ic'): 17,
#   ('eri', 'ica'): 7,
#   ('er', 'rica'): 7,
#   ('er', 'ric'): 17,
#   ('er', 'ri'): 216,
#   ('eric', 'can'): 2,
#   ('eric', 'ca'): 7,
#   ('ic', 'can'): 28,
#   ('ic', 'ca'): 317,
#   ('ica', 'an'): 28,
#   ('ca', 'an'): 56,
#   ('Brit', 'tis'): 1,
#   ('Brit',): 18,
#   ('tis',): 239,
#   ('Brit', 'ti'): 1,
#   ('ti',): 11861,
#   ('Brit', 'tish'): 1,
#   ('tish',): 17,
#   ('Bri', 'it'): 6,
#   ('Bri',): 72,
#   ('it',): 4751,
#   ('Bri', 'iti'): 1,
#   ('iti',): 1272,
#   ('Bri', 'itis'): 1,
#   ('itis',): 10,
#   ('Br', 'riti'): 1,
#   ('Br',): 204,
#   ('riti',): 139,
#   ('Br', 'ri'): 24,
#   ('Br', 'rit'): 6,
#   ('rit',): 598,
#   ('tis', 'sh'): 5,
#   ('sh',): 1721,
#   ('ti', 'ish'): 5,
#   ('ish',): 547,
#   ('ti', 'is'): 49,
#   ('it', 'tis'): 3,
#   ('it', 'ti'): 249,
#   ('it', 'tish'): 2,
#   ('iti', 'ish'): 2,
#   ('iti', 'is'): 3,
#   ('itis', 'sh'): 2,
#   ('riti', 'ish'): 1,
#   ('riti', 'is'): 1,
#   ('ri', 'it'): 129,
#   ('ri', 'iti'): 33,
#   ('ri', 'itis'): 1,
#   ('rit', 'tis'): 1,
#   ('rit', 'ti'): 33,
#   ('rit', 'tish'): 1,
#   ('is', 'sh'): 122,
#   ('rel', 'leas'): 5,
#   ('rel',): 320,
#   ('leas',): 69,
#   ('rel', 'le'): 15,
#   ('le',): 4811,
#   ('rel', 'lea'): 5,
#   ('lea',): 242,
#   ('rele', 'ease'): 4,
#   ('rele',): 52,
#   ('ease',): 72,
#   ('rele', 'ea'): 5,
#   ('ea',): 2845,
#   ('rele', 'eas'): 5,
#   ('eas',): 421,
#   ('re', 'elea'): 5,
#   ('re',): 8017,
#   ('elea',): 28,
#   ('re', 'el'): 87,
#   ('el',): 3325,
#   ('re', 'ele'): 15,
#   ('ele',): 523,
#   ('leas', 'se'): 7,
#   ('leas', 'sed'): 4,
#   ('sed',): 397,
#   ('le', 'ease'): 7,
#   ('le', 'ea'): 59,
#   ('le', 'eas'): 17,
#   ('lea', 'ase'): 7,
#   ('ase',): 168,
#   ('lea', 'ased'): 4,
#   ('ased',): 30,
#   ('lea', 'as'): 17,
#   ('as',): 2615,
#   ('ease', 'ed'): 8,
#   ('ed',): 5972,
#   ('ea', 'ase'): 20,
#   ('ea', 'ased'): 8,
#   ('ea', 'as'): 95,
#   ('eas', 'se'): 20,
#   ('eas', 'sed'): 8,
#   ('elea', 'ase'): 6,
#   ('elea', 'ased'): 3,
#   ('elea', 'as'): 7,
#   ('el', 'leas'): 7,
#   ('el', 'le'): 131,
#   ('el', 'lea'): 7,
#   ('ele', 'ease'): 6,
#   ('ele', 'ea'): 7,
#   ('ele', 'eas'): 7,
#   ('se', 'ed'): 131,
#   ('ase', 'ed'): 10,
#   ('as', 'se'): 46,
#   ('as', 'sed'): 10,
#   ('be', 'ec'): 5,
#   ('ec',): 3098,
#   ('be', 'ecau'): 1,
#   ('ecau',): 11,
#   ('be', 'eca'): 1,
#   ('eca',): 93,
#   ('beca', 'ause'): 1,
#   ('beca',): 3,
#   ('ause',): 23,
#   ('beca', 'aus'): 1,
#   ('aus',): 74,
#   ('beca', 'au'): 1,
#   ('au',): 876,
#   ('bec', 'caus'): 1,
#   ('bec',): 17,
#   ('caus',): 16,
#   ('bec', 'cau'): 1,
#   ('cau',): 37,
#   ('bec', 'ca'): 1,
#   ('ec', 'caus'): 2,
#   ('ec', 'cau'): 3,
#   ('ec', 'ca'): 20,
#   ('ecau', 'use'): 2,
#   ('use',): 215,
#   ('ecau', 'us'): 2,
#   ('us',): 2178,
#   ('eca', 'ause'): 2,
#   ('eca', 'aus'): 2,
#   ('eca', 'au'): 3,
#   ('aus', 'se'): 7,
#   ('au', 'use'): 7,
#   ('au', 'us'): 17,
#   ('caus', 'se'): 3,
#   ('cau', 'use'): 3,
#   ('cau', 'us'): 5,
#   ('ca', 'ause'): 3,
#   ('ca', 'aus'): 5,
#   ('ca', 'au'): 10,
#   ('us', 'se'): 56,
#   ('mil', 'll'): 14,
#   ('mil',): 182,
#   ('ll',): 3431,
#   ('mil', 'llio'): 3,
#   ('llio',): 65,
#   ('mil', 'lli'): 7,
#   ('lli',): 630,
#   ('mi', 'illi'): 7,
#   ('mi',): 2470,
#   ('illi',): 172,
#   ('mi', 'il'): 43,
#   ('il',): 2635,
#   ('mi', 'ill'): 14,
#   ('ill',): 718,
#   ('mill', 'lion'): 3,
#   ('mill',): 47,
#   ('lion',): 76,
#   ('mill', 'lio'): 3,
#   ('lio',): 114,
#   ('mill', 'li'): 7,
#   ('li',): 5430,
#   ('ll', 'lion'): 14,
#   ('ll', 'lio'): 16,
#   ('ll', 'li'): 132,
#   ('llio', 'on'): 14,
#   ('on',): 9256,
#   ('lli', 'io'): 16,
#   ('io',): 6023,
#   ('lli', 'ion'): 14,
#   ('ion',): 4123,
#   ('illi', 'io'): 9,
#   ('illi', 'ion'): 9,
#   ('il', 'll'): 169,
#   ('il', 'llio'): 9,
#   ('il', 'lli'): 44,
#   ('ill', 'lion'): 9,
#   ('ill', 'lio'): 9,
#   ('ill', 'li'): 44,
#   ('lio', 'on'): 21,
#   ('li', 'io'): 26,
#   ('li', 'ion'): 21,
#   ('io', 'on'): 1139,
#   ('How', 'wev'): 1,
#   ('How',): 9,
#   ('wev',): 8,
#   ('How', 'weve'): 1,
#   ('weve',): 6,
#   ('How', 'we'): 1,
#   ('Howe', 'ever'): 1,
#   ('Howe',): 3,
#   ('Howe', 'eve'): 1,
#   ('Howe', 'ev'): 1,
#   ('Ho', 'ow'): 3,
#   ('Ho',): 150,
#   ('ow',): 877,
#   ('Ho', 'owe'): 1,
#   ('owe',): 158,
#   ('Ho', 'owev'): 1,
#   ('owev',): 6,
#   ('wev', 've'): 2,
#   ('wev', 'ver'): 2,
#   ('weve', 'er'): 2,
#   ('we', 'ever'): 2,
#   ('we', 'eve'): 2,
#   ('we', 'ev'): 2,
#   ('ow', 'wev'): 2,
#   ('ow', 'weve'): 2,
#   ('ow', 'we'): 38,
#   ('owe', 'ever'): 2,
#   ('owe', 'eve'): 2,
#   ('owe', 'ev'): 2,
#   ('owev', 've'): 2,
#   ('owev', 'ver'): 2,
#   ('Se', 'epte'): 1,
#   ('Se',): 180,
#   ('epte',): 12,
#   ('Se', 'ep'): 4,
#   ('Se', 'ept'): 2,
#   ('ept',): 244,
#   ('Sep', 'pte'): 1,
#   ('Sep',): 12,
#   ('pte',): 114,
#   ('Sep', 'pt'): 2,
#   ('pt',): 949,
#   ('Sep', 'ptem'): 1,
#   ('ptem',): 8,
#   ('Sept', 'temb'): 1,
#   ('Sept',): 6,
#   ('temb',): 5,
#   ('Sept', 'tem'): 1,
#   ('tem',): 181,
#   ('Sept', 'te'): 1,
#   ('te',): 8353,
#   ('epte', 'emb'): 1,
#   ('emb',): 253,
#   ('epte', 'embe'): 1,
#   ('embe',): 60,
#   ('epte', 'em'): 1,
#   ('em',): 2253,
#   ('ep', 'pte'): 3,
#   ('ep', 'pt'): 47,
#   ('ep', 'ptem'): 1,
#   ('ept', 'temb'): 1,
#   ('ept', 'tem'): 1,
#   ('ept', 'te'): 3,
#   ('pte', 'emb'): 1,
#   ('pte', 'embe'): 1,
#   ('pte', 'em'): 2,
#   ('pt', 'temb'): 1,
#   ('pt', 'tem'): 2,
#   ('pt', 'te'): 26,
#   ('ptem', 'mbe'): 1,
#   ('mbe',): 204,
#   ('ptem', 'mber'): 1,
#   ('mber',): 142,
#   ('ptem', 'mb'): 1,
#   ('mb',): 845,
#   ('temb', 'be'): 1,
#   ('temb', 'ber'): 1,
#   ('ber',): 413,
#   ('tem', 'mbe'): 1,
#   ('tem', 'mber'): 1,
#   ('tem', 'mb'): 1,
#   ('te', 'emb'): 1,
#   ('te', 'embe'): 1,
#   ('te', 'em'): 40,
#   ('emb', 'be'): 14,
#   ('emb', 'ber'): 13,
#   ('embe', 'er'): 13,
#   ('em', 'mbe'): 14,
#   ('em', 'mber'): 13,
#   ('em', 'mb'): 58,
#   ('mbe', 'er'): 34,
#   ('mb', 'be'): 43,
#   ('mb', 'ber'): 34,
#   ('be', 'er'): 92,
#   ('fo', 'ollo'): 5,
#   ('fo',): 933,
#   ('ollo',): 39,
#   ('fo', 'oll'): 5,
#   ('oll',): 348,
#   ('fo', 'ol'): 14,
#   ('ol',): 2744,
#   ('foll', 'low'): 5,
#   ('foll',): 15,
#   ('low',): 173,
#   ('foll', 'lowi'): 1,
#   ('lowi',): 36,
#   ('foll', 'lo'): 5,
#   ('lo',): 2485,
#   ('fol', 'll'): 5,
#   ('fol',): 51,
#   ('fol', 'llo'): 5,
#   ('llo',): 263,
#   ('fol', 'llow'): 5,
#   ('llow',): 97,
#   ('ollo', 'ow'): 7,
#   ('ollo', 'owin'): 2,
#   ('owin',): 65,
#   ('ollo', 'owi'): 2,
#   ('owi',): 116,
#   ('oll', 'low'): 7,
#   ('oll', 'lowi'): 2,
#   ('oll', 'lo'): 10,
#   ('ol', 'll'): 83,
#   ('ol', 'llo'): 10,
#   ('ol', 'llow'): 7,
#   ('low', 'wing'): 8,
#   ('wing',): 98,
#   ('low', 'win'): 8,
#   ('win',): 168,
#   ('low', 'wi'): 9,
#   ('wi',): 545,
#   ('lowi', 'in'): 8,
#   ('lowi', 'ing'): 8,
#   ('lo', 'ow'): 39,
#   ('lo', 'owin'): 8,
#   ('lo', 'owi'): 9,
#   ('ll', 'low'): 23,
#   ('ll', 'lowi'): 5,
#   ('ll', 'lo'): 59,
#   ('llo', 'ow'): 23,
#   ('llo', 'owin'): 4,
#   ('llo', 'owi'): 5,
#   ('llow', 'wing'): 4,
#   ('llow', 'win'): 4,
#   ('llow', 'wi'): 5,
#   ('ow', 'wing'): 18,
#   ('ow', 'win'): 18,
#   ('ow', 'wi'): 25,
#   ('owin', 'ng'): 18,
#   ('owi', 'in'): 18,
#   ('owi', 'ing'): 18,
#   ('win', 'ng'): 31,
#   ('wi', 'in'): 43,
#   ('wi', 'ing'): 31,
#   ('rece', 'ei'): 7,
#   ('rece',): 75,
#   ('ei',): 655,
#   ('rece', 'eiv'): 6,
#   ('eiv',): 55,
#   ('rece', 'eive'): 5,
#   ('eive',): 39,
#   ('rec', 'ceiv'): 6,
#   ('rec',): 613,
#   ('ceiv',): 48,
#   ('rec', 'ce'): 22,
#   ('rec', 'cei'): 7,
#   ('cei',): 68,
#   ('re', 'ec'): 161,
#   ('re', 'ece'): 22,
#   ('ece',): 189,
#   ('re', 'ecei'): 7,
#   ('ecei',): 31,
#   ('ei', 'ive'): 10,
#   ('ive',): 902,
#   ('ei', 'ived'): 4,
#   ('ived',): 33,
#   ('ei', 'iv'): 11,
#   ('iv',): 1776,
#   ('eiv', 'ved'): 4,
#   ('ved',): 104,
#   ('eiv', 've'): 10,
#   ('eive', 'ed'): 4,
#   ('ceiv', 'ved'): 4,
#   ('ceiv', 've'): 10,
#   ('ce', 'ei'): 14,
#   ('ce', 'eiv'): 11,
#   ('ce', 'eive'): 10,
#   ('cei', 'ive'): 10,
#   ('cei', 'ived'): 4,
#   ('cei', 'iv'): 11,
#   ('ec', 'ceiv'): 7,
#   ('ec', 'ce'): 44,
#   ('ec', 'cei'): 8,
#   ('ece', 'ei'): 8,
#   ('ece', 'eiv'): 7,
#   ('ece', 'eive'): 6,
#   ('ecei', 'ive'): 6,
#   ('ecei', 'ived'): 2,
#   ('ecei', 'iv'): 7,
#   ('ive', 'ed'): 11,
#   ('iv', 'ved'): 11,
#   ('iv', 've'): 247,
#   ('ve', 'ed'): 34,
#   ('de', 'es'): 115,
#   ('es',): 7410,
#   ('de', 'escr'): 9,
#   ('escr',): 62,
#   ('de', 'esc'): 16,
#   ('esc',): 230,
#   ('des', 'scr'): 9,
#   ('des',): 384,
#   ('scr',): 255,
#   ('des', 'sc'): 16,
#   ('sc',): 1234,
#   ('des', 'scri'): 8,
#   ('scri',): 164,
#   ('desc', 'crib'): 5,
#   ('desc',): 52,
#   ('crib',): 69,
#   ('desc', 'cri'): 8,
#   ('cri',): 305,
#   ('desc', 'cr'): 9,
#   ('cr',): 1143,
#   ('es', 'scr'): 14,
#   ('es', 'sc'): 51,
#   ('es', 'scri'): 13,
#   ('escr', 'ribe'): 6,
#   ('ribe',): 46,
#   ('escr', 'ri'): 13,
#   ('escr', 'rib'): 9,
#   ('rib',): 283,
#   ('esc', 'crib'): 9,
#   ('esc', 'cri'): 13,
#   ('esc', 'cr'): 14,
#   ('scr', 'ribe'): 11,
#   ('scr', 'ri'): 33,
#   ('scr', 'rib'): 14,
#   ('sc', 'crib'): 14,
#   ('sc', 'cri'): 33,
#   ('sc', 'cr'): 56,
#   ('scri', 'ib'): 14,
#   ('ib',): 914,
#   ('scri', 'ibe'): 11,
#   ('ibe',): 125,
#   ('scri', 'ibed'): 6,
#   ('ibed',): 18,
#   ('crib', 'be'): 11,
#   ('crib', 'bed'): 6,
#   ('bed',): 62,
#   ('cri', 'ib'): 14,
#   ('cri', 'ibe'): 11,
#   ('cri', 'ibed'): 6,
#   ('cr', 'ribe'): 11,
#   ('cr', 'ri'): 65,
#   ('cr', 'rib'): 14,
#   ('ribe', 'ed'): 6,
#   ('ri', 'ib'): 56,
#   ('ri', 'ibe'): 12,
#   ('ri', 'ibed'): 6,
#   ('rib', 'be'): 12,
#   ('rib', 'bed'): 6,
#   ('ib', 'be'): 30,
#   ('ib', 'bed'): 6,
#   ('ibe', 'ed'): 6,
#   ('be', 'ed'): 18,
#   ('Oct', 'tobe'): 1,
#   ('Oct',): 15,
#   ('tobe',): 3,
#   ('Oct', 'tob'): 1,
#   ('tob',): 26,
#   ('Oct', 'to'): 1,
#   ('to',): 2889,
#   ('Octo', 'obe'): 1,
#   ('Octo',): 3,
#   ('obe',): 36,
#   ('Octo', 'ob'): 1,
#   ('ob',): 442,
#   ('Octo', 'ober'): 1,
#   ('ober',): 13,
#   ('Oc', 'ct'): 4,
#   ('Oc',): 36,
#   ('ct',): 3199,
#   ('Oc', 'cto'): 1,
#   ('cto',): 276,
#   ('Oc', 'ctob'): 1,
#   ('ctob',): 3,
#   ('tobe', 'er'): 1,
#   ('tob', 'be'): 1,
#   ('tob', 'ber'): 1,
#   ('to', 'obe'): 1,
#   ('to', 'ob'): 6,
#   ('to', 'ober'): 1,
#   ('obe', 'er'): 4,
#   ('ob', 'be'): 9,
#   ('ob', 'ber'): 4,
#   ('ct', 'tobe'): 1,
#   ('ct', 'tob'): 1,
#   ('ct', 'to'): 60,
#   ('cto', 'obe'): 1,
#   ('cto', 'ob'): 1,
#   ('cto', 'ober'): 1,
#   ('ctob', 'be'): 1,
#   ('ctob', 'ber'): 1,
#   ('spec', 'cie'): 3,
#   ('spec',): 249,
#   ('cie',): 216,
#   ('spec', 'ci'): 21,
#   ('ci',): 2014,
#   ('spec', 'cies'): 3,
#   ('cies',): 33,
#   ('sp', 'peci'): 21,
#   ('sp',): 1305,
#   ('peci',): 113,
#   ('sp', 'pec'): 64,
#   ('pec',): 400,
#   ('sp', 'pe'): 94,
#   ('pe',): 2463,
#   ('spe', 'ecie'): 3,
#   ('spe',): 396,
#   ('ecie',): 14,
#   ('spe', 'ec'): 64,
#   ('spe', 'eci'): 21,
#   ('eci',): 282,
#   ('cie', 'es'): 11,
#   ('ci', 'ie'): 46,
#   ('ie',): 2611,
#   ('ci', 'ies'): 11,
#   ('ies',): 668,
#   ('peci', 'ie'): 4,
#   ('peci', 'ies'): 4,
#   ('pec', 'cie'): 4,
#   ('pec', 'ci'): 28,
#   ('pec', 'cies'): 4,
#   ('pe', 'ecie'): 4,
#   ('pe', 'ec'): 87,
#   ('pe', 'eci'): 28,
#   ('ecie', 'es'): 4,
#   ('ec', 'cie'): 4,
#   ('ec', 'ci'): 60,
#   ('ec', 'cies'): 4,
#   ('eci', 'ie'): 4,
#   ('eci', 'ies'): 4,
#   ('ie', 'es'): 217,
#   ('ano', 'oth'): 1,
#   ('ano',): 141,
#   ('oth',): 194,
#   ('ano', 'othe'): 1,
#   ('othe',): 97,
#   ('ano', 'ot'): 1,
#   ('ot',): 1463,
#   ('anot', 'the'): 1,
#   ('anot',): 3,
#   ('the',): 768,
#   ('anot', 'th'): 1,
#   ('anot', 'ther'): 1,
#   ('ther',): 291,
#   ('an', 'no'): 32,
#   ('no',): 1442,
#   ('an', 'noth'): 1,
#   ('noth',): 14,
#   ('an', 'not'): 1,
#   ('not',): 102,
#   ('oth', 'he'): 24,
#   ('he',): 2802,
#   ('oth', 'her'): 17,
#   ('her',): 774,
#   ('othe', 'er'): 17,
#   ('ot', 'the'): 24,
#   ('ot', 'th'): 43,
#   ('ot', 'ther'): 17,
#   ('the', 'er'): 76,
#   ('th', 'he'): 167,
#   ('th', 'her'): 76,
#   ('no', 'oth'): 4,
#   ('no', 'othe'): 3,
#   ('no', 'ot'): 28,
#   ('noth', 'he'): 3,
#   ('noth', 'her'): 2,
#   ('not', 'the'): 3,
#   ('not', 'th'): 4,
#   ('not', 'ther'): 2,
#   ('he', 'er'): 187,
#   ('incl', 'lude'): 3,
#   ('lude',): 61,
#   ('nclu', 'ude'): 7,
#   ('ude',): 167,
#   ('nclu', 'uded'): 3,
#   ('uded',): 24,
#   ('ncl', 'lude'): 7,
#   ('cl', 'lude'): 11,
#   ('clu', 'ude'): 11,
#   ('clu', 'uded'): 6,
#   ('clud', 'de'): 11,
#   ('clud', 'ded'): 6,
#   ('ded',): 330,
#   ('lud', 'de'): 17,
#   ('lud', 'ded'): 7,
#   ('lude', 'ed'): 7,
#   ('lu', 'ude'): 17,
#   ('lu', 'uded'): 7,
#   ('ud', 'de'): 44,
#   ('ud', 'ded'): 8,
#   ('ude', 'ed'): 8,
#   ('de', 'ed'): 110,
#   ('Jan', 'nu'): 1,
#   ('Jan',): 12,
#   ('nu',): 486,
#   ('Jan', 'nua'): 1,
#   ('nua',): 34,
#   ('Jan', 'nuar'): 1,
#   ('nuar',): 3,
#   ('Ja', 'anua'): 1,
#   ('Ja',): 81,
#   ('anua',): 10,
#   ('Ja', 'anu'): 1,
#   ('anu',): 92,
#   ('Ja', 'an'): 4,
#   ('Janu', 'uar'): 1,
#   ('Janu',): 3,
#   ('uar',): 181,
#   ('Janu', 'ua'): 1,
#   ('ua',): 977,
#   ('Janu', 'uary'): 1,
#   ('uary',): 18,
#   ('nu', 'uar'): 1,
#   ('nu', 'ua'): 7,
#   ('nu', 'uary'): 1,
#   ('nua', 'ar'): 1,
#   ('ar',): 5915,
#   ('nua', 'ary'): 1,
#   ('ary',): 332,
#   ('nuar', 'ry'): 1,
#   ('anua', 'ar'): 1,
#   ('anua', 'ary'): 1,
#   ('anu', 'uar'): 1,
#   ('anu', 'ua'): 3,
#   ('anu', 'uary'): 1,
#   ('an', 'nu'): 22,
#   ('an', 'nua'): 3,
#   ('an', 'nuar'): 1,
#   ('uar', 'ry'): 6,
#   ('ua', 'ar'): 42,
#   ('ua', 'ary'): 6,
#   ('ar', 'ry'): 106,
#   ('Engl', 'land'): 1,
#   ('Engl',): 9,
#   ('land',): 314,
#   ('Engl', 'lan'): 1,
#   ('lan',): 731,
#   ('Engl', 'la'): 1,
#   ('la',): 3737,
#   ('En', 'ngla'): 1,
#   ('En',): 70,
#   ('ngla',): 8,
#   ('En', 'ng'): 6,
#   ('En', 'ngl'): 3,
#   ('ngl',): 159,
#   ('Eng', 'gla'): 1,
#   ...},
#  1956396)

# %%
sorted_pairs = sorted(pairs.items(), key = lambda x : x[1], reverse=True)

# %%
sorted_pairs[:10]
# Out:
# [(('in',), 12575),
#  (('ti',), 11861),
#  (('er',), 11736),
#  (('on',), 9256),
#  (('at',), 9246),
#  (('te',), 8353),
#  (('en',), 8258),
#  (('re',), 8017),
#  (('es',), 7410),
#  (('an',), 7317)]

# %%
import math
def calc_assocs(pairs):
    
    total = sum(pairs.values())
    assocs = {}
    for p in pairs:
        if len(p) > 1:
            x, y = p
            cXY = pairs[(x, y)]
            cX = pairs[(x,)]
            cY = pairs[(y,)]

            p_x_given_y = float(cXY) / cY 
            p_x_and_not_y = float(cX - cXY)
            p_not_y = total - cY
            p_x_given_not_y = p_x_and_not_y / float(p_not_y)       


            p_y_given_x = float(cXY) / cX 
            p_y_and_not_x = float(cY - cXY)
            p_not_x = total - cX
            p_y_given_not_x = p_y_and_not_x / float(p_not_x)

            delta_p = p_x_given_y - p_x_given_not_y
            delta_p_r = p_y_given_x - p_y_given_not_x
            #delta_p = delta_p / 2.0
#             delta_p, delta_p_r = 0, 0
#             try:
#                 delta_p = -math.log(p_x_given_y) + math.log(p_x_given_not_y)
#                 delta_p_r = -math.log(p_y_given_x) + math.log(p_y_given_not_x)
#             except:
#                 pass
            #p_x_y = float(cXY) / total
            #p_x, p_y = float(cX)/total, float(cY)/total
            #pmi_x_y = math.log(p_x_y/(p_x*p_y))
            #delta_p = pmi_x_y + math.log(p_x_y)
            #delta_p_r = delta_p
            assocs[(x,y)] = (delta_p, delta_p_r)
    return assocs

# %%
assocs  = calc_assocs(pairs)

# %%
sorted_assocs = sorted(assocs.items(), key = lambda x : sum(x[1]), reverse=True)

# %%
sorted_assocs[-30:]
# Out:
# [(('er', 'rib'), (-0.0024655732717530233, -5.980458846381629e-05)),
#  (('min', 'nt'), (-0.00031194909723811606, -0.0022163872744239976)),
#  (('li', 'ir'), (-0.002042719412083729, -0.0005134410734723548)),
#  (('ati', 'it'), (-0.001155873839178435, -0.0014063980364033644)),
#  (('ene', 'en'), (-0.00016687258347305954, -0.0024423689982903123)),
#  (('er', 'rep'), (-0.0025508877824370075, -6.340418942233859e-05)),
#  (('es', 'sio'), (-0.0024569619773144747, -0.0002498627221377789)),
#  (('ci', 'ic'), (-0.0008218040178037772, -0.0019436332239488427)),
#  (('fo', 'on'), (-0.00026206110650561765, -0.0025887603500479696)),
#  (('er', 'ret'), (-0.0027941029117358965, -7.471722100626587e-05)),
#  (('er', 'rec'), (-0.002737000369070692, -0.0001437779262205681)),
#  (('ti', 'isc'), (-0.0028163686577827455, -7.356843838690121e-05)),
#  (('ple', 'er'), (-7.831682196478817e-05, -0.002864456347415457)),
#  (('ai', 'io'), (-0.000643558512451045, -0.0024476854514922652)),
#  (('cha', 'at'), (-0.00017687709201703026, -0.0029283081224810723)),
#  (('ato', 'on'), (-0.0001769954042650627, -0.0029334210151512295)),
#  (('ti', 'id'), (-0.0028117971084049348, -0.000366299406641364)),
#  (('di', 'ion'), (-0.0015415324175411173, -0.0018236677774355241)),
#  (('ti', 'iss'), (-0.0033751482434478996, -0.00010648119130726522)),
#  (('re', 'era'), (-0.003117144850588594, -0.0003972374295428725)),
#  (('at', 'tat'), (-0.00332472419705308, -0.000257507757348412)),
#  (('ti', 'ight'), (-0.0035188561212692376, -0.00011728068835925965)),
#  (('pre', 'er'), (-0.00023325372147526557, -0.003458880865991742)),
#  (('re', 'er'), (-0.0015509074748600526, -0.002266023177245994)),
#  (('io', 'om'), (-0.002698782139878637, -0.0011706371789420187)),
#  (('ri', 'ion'), (-0.002586972391756045, -0.0016495129993645836)),
#  (('ss', 'st'), (-0.001273450359848514, -0.0029897238426527385)),
#  (('la', 'al'), (-0.0017343833934909839, -0.002566489862814749)),
#  (('ti', 'igh'), (-0.004324819180238398, -0.00021087632947654477)),
#  (('ti', 'ita'), (-0.004363309649192224, -0.0002175617324134937))]

# %%
new_sample = words[13000:13500]

# %%
def is_stack_completed2(stack, token):
    r = True
    if len(stack) == 0:
        return False
    for element in stack:
        l = len(''.join([x[0] if i==0 else x[0][1:] for i,x in enumerate(element)]))
        if l != len(token):
            return False
    return r
    #return all([len(''.join(x)) == len(token) for x in stack]) and len(stack) > 0


def split_token(token, max_gram = 4, thresh=0.001):
    stack = []
    counter = 0
    pairs = {}
    while is_stack_completed2(stack, token) == False:
        #print(counter, stack)
        if len(stack) == 0:
            stack += [[(x, x)] for x in get_grams(token, 0)]
        p_stack = []
        #print(stack)
        for i, element in enumerate(stack):
            position = len(''.join([x[0] if i==0 else x[0][1:] for i,x in enumerate(element)])) - 1
            if position == len(token) - 1:
                #print('~~@@', element, position)
                p_stack.append(element)
            grams = get_grams(token, position)
            for g in grams:
                if len(g) > 1:
                    #print(element, g, '//', p_stack)
                    #p_stack.append(element + [g])
                    pair = (element[-1][0], g)
                    if pair in assocs  and assocs[pair][0] > thresh and assocs[pair][1] > thresh:
                        #print(pair, assocs[pair])
                        p_stack.append(element + [(g, element[-1][1] + g[1:])])
                    else:
                        p_stack.append(element + [(g, g[1:])])
#                 elif len(g) > 0:
#                     p_stack.append(element + [(g, element[-1][1] + g)])
                        #yield pair
        stack = p_stack
        #print('~~', stack)
        #print(p_stack)
        #print_stack(stack)
        
        counter += 1
        #break
    return stack
    #return pairs
        
def get_scores(stack):
    scores = []
    joins = []
    for split in stack:
        score = 0 
        join = []
        
        for a, b in zip(split, split[1:]):            
            if b[1].startswith(a[1]) == False:
                join.append(a[1])
            if (a[0], b[0]) in assocs:
                score += sum(assocs[(a[0], b[0])]) / 2 
                
        if len(join) == 0 or (split[-1][1].startswith(join[-1]) == False):
            join.append(split[-1][1])
        scores.append((join, score))
    return scores

# %%
split_token('apple')
# Out:
# [[('ap', 'ap'), ('pple', 'ple')],
#  [('ap', 'ap'), ('ppl', 'appl'), ('le', 'apple')],
#  [('ap', 'ap'), ('pp', 'app'), ('pl', 'appl'), ('le', 'apple')],
#  [('ap', 'ap'), ('pp', 'app'), ('ple', 'apple')],
#  [('appl', 'appl'), ('le', 'e')],
#  [('app', 'app'), ('pl', 'appl'), ('le', 'apple')],
#  [('app', 'app'), ('ple', 'le')]]

# %%
def get_max_split(token):
    stack = split_token(token)
    scores = get_scores(stack)
    #print(scores)
    return max(scores, key=lambda x: x[1])

# %%
split = get_max_split(words[3000])
split
# Out:
# (['Classic'], 0.2320549523489015)

# %%
for w in new_sample:
    print(w, get_max_split(w))
# Out:
# hugging (['huggi', 'ng'], 0.4745634842336762)
# defaced (['de', 'faced'], 0.14035851350327516)
# armlets (['arm', 'lets'], 0.2703923385125039)
# engraved (['engr', 'a', 'ved'], 0.33019002671701053)
# dilapidated (['di', 'lapida', 'ted'], 0.53506141035287)
# pedestal (['pede', 'stal'], 0.18801870885913255)
# enshrined (['en', 'shr', 'ined'], 0.33787718007461226)
# preparedness (['prepar', 'edn', 'ess'], 0.46518499636353194)
# parapet (['par', 'ape', 't'], 0.15835777573108437)
# Thought (['Thought'], 0.3539229761976216)
# Noisescapes (['Noisesc', 'apes'], 0.4479072183380498)
# Revolver (['Revolver'], 0.34314409359894565)
# Physicist (['Physicist'], 0.331046017019074)
# impenetrable (['impen', 'etr', 'able'], 0.4587171666122843)
# clarifying (['cla', 'rifying'], 0.548513357779081)
# leftover (['le', 'ftove', 'r'], 0.49591501200704124)
# nightmare (['nightmar', 'e'], 0.527335364281794)
# hardship (['hardship'], 0.326113585080396)
# recharge (['recharge'], 0.2840771394415267)
# chaotic (['cha', 'oti', 'c'], 0.38876964016189364)
# tapping (['tapping'], 0.33183990385591833)
# esteemed (['est', 'eem', 'ed'], 0.3017169856844544)
# Förster (['Först', 'er'], 0.5540348518140594)
# oriental (['oriental'], 0.22570345561576813)
# Bohemia (['Boh', 'emia'], 0.27721035293361096)
# entrepreneur (['ent', 'rep', 're', 'neu', 'r'], 0.5755752325636643)
# volleyball (['volleybal', 'l'], 0.4038973755245373)
# departing (['departing'], 0.43803560476254333)
# obliterated (['oblit', 'erated'], 0.4825516828248295)
# toppled (['to', 'ppl', 'ed'], 0.2310769529211324)
# recorders (['re', 'corders'], 0.3087414431754697)
# photographers (['photographe', 'rs'], 0.6839970631701677)
# neighbourhoods (['neighbou', 'rhoods'], 0.6208976797261601)
# chilling (['chilling'], 0.3503274528932526)
# Economics (['Economics'], 0.44427136761367514)
# Footage (['Footage'], 0.34792549274608503)
# legislatures (['legislatures'], 0.43679057264235766)
# Judgment (['Judgment'], 0.4154594979540255)
# infringement (['in', 'fri', 'ng', 'ement'], 0.6892310190080895)
# intervening (['intervening'], 0.4993054612384428)
# billionaire (['billion', 'air', 'e'], 0.4654601815792163)
# Peoples (['People', 's'], 0.3315706486291142)
# unbroken (['unbroke', 'n'], 0.4146149040305319)
# roadblock (['ro', 'adblock'], 0.37969758841745377)
# Scottie (['Scot', 'tie'], 0.19540187210998794)
# compiling (['comp', 'ili', 'ng'], 0.5233254008296697)
# Sarasota (['Sar', 'a', 'sot', 'a'], 0.41260869016934526)
# rebound (['re', 'bound'], 0.32272981685029495)
# cartilage (['carti', 'lag', 'e'], 0.3219988881470521)
# Managing (['Man', 'agi', 'ng'], 0.43622023092574014)
# eyesight (['eyes', 'ight'], 0.44720884178698006)
# fleeting (['fle', 'eti', 'ng'], 0.37898675291432465)
# Blackmon (['Blac', 'kmo', 'n'], 0.3813838670709896)
# eradicated (['erad', 'icated'], 0.4221211628563567)
# Goebbels (['Goebbels'], 0.44999616641102025)
# cultured (['cultured'], 0.3085184745855651)
# divisive (['divisive'], 0.2503922776955738)
# mundane (['mundane'], 0.23809319351521524)
# plundered (['pl', 'und', 'ered'], 0.2294007493645958)
# summarily (['summa', 'rily'], 0.35179887664315757)
# Classes (['Classes'], 0.23711385214192665)
# textbooks (['textbooks'], 0.41276665837014)
# submissive (['submissive'], 0.4909706677632737)
# respectful (['respectful'], 0.44257545563674966)
# inspections (['in', 'spections'], 0.6592945293816795)
# censors (['ce', 'nso', 'rs'], 0.17951640710762032)
# tearing (['tear', 'ing'], 0.36700745669134316)
# Juliusz (['Juliu', 's', 'z'], 0.5093652944969335)
# punishable (['puni', 's', 'hable'], 0.4151626327945262)
# disseminated (['disseminated'], 0.37253908436512173)
# propagandist (['pro', 'pagand', 'ist'], 0.5323090208128434)
# communism (['communism'], 0.4203913373762316)
# Kazakhstan (['Kazakhst', 'an'], 0.46808218207496993)
# Teaching (['Tea', 'ching'], 0.4391680649676579)
# unauthorized (['unau', 'thorized'], 0.5471081854701199)
# Delegation (['Delegation'], 0.5738829381890904)
# leaflets (['le', 'aflet', 's'], 0.3115283578639086)
# imaginary (['imagi', 'nary'], 0.28287359442749227)
# professions (['professions'], 0.6483899517636252)
# Jaworski (['Jaworski'], 0.5067287404463191)
# Alexandre (['Alexandre'], 0.3837300721377938)
# caricatures (['ca', 'ricatu', 'res'], 0.3563564986627808)
# cabaret (['cabare', 't'], 0.3537362569520526)
# Schultz (['Schultz'], 0.503316346514517)
# migrations (['migrations'], 0.6637082131077872)
# Successful (['Succes', 'sful'], 0.4967600168956116)
# Facilities (['Faci', 'lities'], 0.40023503457134535)
# ballast (['ballast'], 0.1608939534599952)
# Kronprinz (['Kronprinz'], 0.5333302664638216)
# disarmed (['di', 'sarmed'], 0.31298987157922176)
# Yarmouth (['Yar', 'm', 'outh'], 0.30232780874738524)
# isolate (['is', 'ola', 'te'], 0.23779052217435362)
# retaliate (['retalia', 'te'], 0.18265759106145682)
# steaming (['ste', 'ami', 'ng'], 0.3819808807155844)
# scuttling (['scuttling'], 0.4389994328810135)
# impractical (['imp', 'ractical'], 0.4323896129228181)
# Archaeologists (['Archaeologists'], 0.6685353755541121)
# ritualised (['ritualised'], 0.3235654551116192)
# intercede (['inter', 'ced', 'e'], 0.2602973741574325)
# gatherers (['gathere', 'rs'], 0.3264910036813855)
# ancillary (['ancill', 'ary'], 0.2531840123986904)
# Excavations (['Excavations'], 0.6925014414007266)
# Surgeons (['Surg', 'eons'], 0.3331196050308378)
# Proceedings (['Proceedings'], 0.6825575092197503)
# Bayesian (['Bayesian'], 0.31297373554674657)
# fracture (['fracture'], 0.3093240371988575)
# morphologies (['mor', 'phologie', 's'], 0.5208749690250354)
# decomposition (['decomposition'], 0.6217969292972922)
# dismemberment (['di', 'sme', 'mberment'], 0.6064116783253444)
# mutilation (['muti', 'lation'], 0.5319443089158625)
# cannibalism (['can', 'nibali', 'sm'], 0.4794816617279749)
# robbers (['ro', 'bbe', 'rs'], 0.38378313364210004)
# Flinders (['Fli', 'nders'], 0.3685464181341376)
# earthworks (['earthworks'], 0.36645275634964847)
# domination (['domination'], 0.5117534711336915)
# workmanship (['wor', 'km', 'anship'], 0.5008729170682922)
# massively (['massively'], 0.3151994355389513)
# catapult (['ca', 'tapult'], 0.37459284693899414)
# refitted (['refitted'], 0.23038604113291758)
# Ukraina (['Ukrai', 'na'], 0.4924112386322206)
# Narragansett (['Narraga', 'ns', 'ett'], 0.4184559960985166)
# Kingstown (['Ki', 'ngs', 'town'], 0.5636572999143237)
# Corridor (['Corrido', 'r'], 0.3192564869391035)
# Liberties (['Liber', 'tie', 's'], 0.3388953846224724)
# upgrading (['upgrading'], 0.5438184248951454)
# Composers (['Composer', 's'], 0.3588659204606983)
# propulsive (['pr', 'opul', 'siv', 'e'], 0.4993567376299427)
# obsessive (['obsessive'], 0.4060437857640071)
# Vladimir (['Vladim', 'ir'], 0.424946625959807)
# smuggled (['smuggled'], 0.38240830310308815)
# posturing (['posturing'], 0.3761280101181021)
# Yearwood (['Yearwood'], 0.44186400855173963)
# Venetian (['Ven', 'e', 'tia', 'n'], 0.2842997814229941)
# Wanting (['Want', 'ing'], 0.37258276313827954)
# Presley (['Pre', 'sley'], 0.38123221271688934)
# Dedicated (['Ded', 'icated'], 0.4219779075012223)
# applauded (['applauded'], 0.30515486575689393)
# uptempo (['uptem', 'po'], 0.14722064018960768)
# analyst (['analyst'], 0.2295591363701782)
# Widespread (['Wid', 'espread'], 0.32399645433864466)
# southeastward (['southeastward'], 0.5800354467703672)
# beachfront (['beach', 'fro', 'nt'], 0.37998549209780086)
# Milford (['Milfo', 'rd'], 0.3754868532578346)
# showings (['showi', 'ngs'], 0.49066420665389077)
# Westerns (['Wester', 'ns'], 0.3323214202138724)
# dacoits (['dacoit', 's'], 0.3499538350939836)
# cynical (['cyni', 'cal'], 0.39215781749450096)
# affections (['affections'], 0.6416862937742299)
# Jagdeep (['Jagdee', 'p'], 0.416770396126002)
# Inspector (['Inspector'], 0.2982875780675728)
# acquaintances (['acquai', 'ntances'], 0.6371951889405663)
# massacred (['massacred'], 0.26638419144679854)
# Dissanayake (['Dissanayake'], 0.4335751559472672)
# Encyclopedia (['Encycloped', 'ia'], 0.4575134558994329)
# mockery (['mockery'], 0.16083671025692078)
# playback (['pla', 'yba', 'ck'], 0.35658086598974853)
# psychedelic (['psyche', 'del', 'ic'], 0.5351683906756501)
# exemplary (['exemplar', 'y'], 0.43637128911347023)
# imitation (['imita', 'tion'], 0.5446909896709888)
# Quarterly (['Quarterly'], 0.34415780662141904)
# revolutionized (['revolutionized'], 0.7913518896971768)
# subgenre (['subgenr', 'e'], 0.45717148189213724)
# Performances (['Performances'], 0.5586917124164572)
# superstar (['superstar'], 0.3788406587413289)
# sitcoms (['si', 'tco', 'ms'], 0.3572569712620516)
# scatter (['scatt', 'er'], 0.3277807291230943)
# gunshot (['gunshot'], 0.15254324774412403)
# impressing (['impressing'], 0.48808236179153824)
# reverting (['reverting'], 0.4089889365303291)
# Morecambe (['Morec', 'ambe'], 0.33138096600387656)
# abdominal (['abdo', 'minal'], 0.3937928606352763)
# Redbridge (['Redbr', 'idge'], 0.4440442709592949)
# telecommunication (['tel', 'ecommunication'], 0.9485358951076013)
# Paochinda (['Paochind', 'a'], 0.395478034749435)
# Transfer (['Transfe', 'r'], 0.3485476004115881)
# debating (['deba', 'ting'], 0.44157142126612703)
# luggage (['lugga', 'ge'], 0.4250736455519462)
# scanning (['sc', 'ann', 'ing'], 0.35431575041832836)
# checkpoints (['che', 'ckp', 'oints'], 0.44317110131667053)
# unchecked (['unchecke', 'd'], 0.30734368322738614)
# plunged (['pl', 'ung', 'ed'], 0.3478458392898649)
# corrupted (['co', 'rrupt', 'ed'], 0.3883097287614955)
# implicated (['implicated'], 0.36883259169969485)
# discredit (['discr', 'edit'], 0.27944869614827444)
# Tribunal (['Tribuna', 'l'], 0.32940194112590027)
# centimeters (['centimeters'], 0.4069575978076573)
# offending (['offending'], 0.4504790556622604)
# grossly (['gro', 'ssl', 'y'], 0.34804886720724915)
# handkerchief (['ha', 'ndkerc', 'hief'], 0.58242780147722)
# swallow (['swallow'], 0.23528799981963722)
# regurgitated (['re', 'gurgit', 'ated'], 0.5066145549380242)
# entertain (['entertain'], 0.36348179271785763)
# carnivals (['carniva', 'ls'], 0.3408457819719153)
# interpreter (['inter', 'preter'], 0.4037156030450316)
# notoriety (['noto', 'riety'], 0.32361539082021606)
# sacrificial (['sacrificial'], 0.3691730134941609)
# Methods (['Meth', 'ods'], 0.2093188281824202)
# continents (['continents'], 0.3778054645098629)
# ostrich (['ostrich'], 0.12690130096818378)
# interment (['interment'], 0.36507434059202726)
# upheavals (['upheava', 'ls'], 0.44110990324978616)
# wrangling (['wran', 'gling'], 0.45693189826909186)
# ramifications (['ra', 'mif', 'ications'], 0.8135658930024176)
# Brenton (['Bren', 'ton'], 0.19537568788651932)
# Interscope (['Inters', 'cope'], 0.45177028074503667)
# categorized (['categorized'], 0.42588732034547133)
# pleasures (['pleasures'], 0.30196684677375835)
# Calgary (['Calgary'], 0.24999821099261066)
# rocking (['rocking'], 0.3628927142395391)
# SoundScan (['Sound', 'Sca', 'n'], 0.47479645334727627)
# reminding (['reminding'], 0.35328270851479004)
# buttocks (['but', 'toc', 'ks'], 0.35882200117810825)
# Blender (['Blen', 'der'], 0.24972909759416287)
# Aguilera (['Aguile', 'ra'], 0.3211052743798334)
# Worthington (['Wor', 'thi', 'ngton'], 0.6973906806206984)
# Oyebanjo (['Oyebanjo'], 0.6720159200328968)
# Hartlepool (['Har', 'tlepoo', 'l'], 0.4234681899238085)
# Wycombe (['Wyc', 'ombe'], 0.31099658162139754)
# Prosser (['Prosser'], 0.18606242835656103)
# Hayhurst (['Hayhur', 'st'], 0.42287200245333095)
# bettered (['bettered'], 0.2002797097350928)
# metalloid (['meta', 'loi', 'd'], 0.3165140666588504)
# roasting (['roas', 'ting'], 0.39933460871279514)
# improves (['improves'], 0.3044766950500451)
# chlorine (['ch', 'lor', 'ine'], 0.3123476124232769)
# retardants (['ret', 'ard', 'ants'], 0.24383173179290296)
# hardness (['hardne', 'ss'], 0.27752834336877286)
# allotrope (['all', 'otr', 'ope'], 0.34210182900785646)
# stibine (['st', 'ibi', 'ne'], 0.1490564388661038)
# Occurrence (['Occurrence'], 0.39818536031076246)
# valence (['vale', 'nce'], 0.23654174926898827)
# tetroxide (['tetr', 'oxide'], 0.3328388160858779)
# Transition (['Transition'], 0.5139999573988633)
# halides (['hali', 'des'], 0.2552070474207803)
# malleable (['mall', 'eab', 'le'], 0.3603032829773157)
# weakens (['weakens'], 0.16460045076524693)
# Roskill (['Roski', 'll'], 0.39156452860537616)
# expects (['expects'], 0.3549026550745779)
# halogenated (['halog', 'ena', 'ted'], 0.30793534176825227)
# amastigotes (['amastigote', 's'], 0.39402698035024136)
# beryllium (['beryllium'], 0.4653334075326441)
# impaired (['impaired'], 0.196051657186759)
# inflammation (['inflamm', 'ation'], 0.612882652335931)
# Helsinki (['Helsinki'], 0.3822783524764427)
# permissible (['permissible'], 0.38709046917211676)
# relocating (['relocating'], 0.4855191385292051)
# doctorate (['docto', 'rate'], 0.3415805856805336)
# Appointed (['Appointed'], 0.42857410348438996)
# journalism (['journalism'], 0.4117175204009334)
# Increasingly (['Incr', 'e', 'asi', 'ngly'], 0.5995038283962248)
# conventionally (['conventionally'], 0.818678475097023)
# Provost (['Provost'], 0.2870434470502717)
# Rhineland (['Rhinela', 'nd'], 0.4178998371295985)
# embarking (['embarking'], 0.4446745874512269)
# vaulting (['vaulting'], 0.4083729148419305)
# entailed (['enta', 'ile', 'd'], 0.2471014903456062)
# Monmouthshire (['Mon', 'mouths', 'hire'], 0.6094244022010222)
# regionally (['regionally'], 0.46593827740784405)
# impatient (['impatie', 'nt'], 0.3682825176176035)
# cleaned (['cle', 'ane', 'd'], 0.2882503127392051)
# Focusing (['Focusi', 'ng'], 0.5107204786717717)
# acquisitions (['acquisitions'], 0.7288564199507124)
# influenza (['influenza'], 0.3735950207860776)
# Fellowship (['Fell', 'owsh', 'ip'], 0.44791271877753)
# dishonest (['dis', 'hon', 'est'], 0.31302153673083527)
# Woolley (['Wooll', 'ey'], 0.38531920827564836)
# lamenting (['lame', 'nting'], 0.45507094179753627)
# derogatory (['der', 'oga', 'tory'], 0.3097031263383556)
# administrations (['administrations'], 0.8347508769022313)
# Civilization (['Civilization'], 0.7023874144085769)
# envious (['envious'], 0.2729237763510793)
# smuggle (['smuggle'], 0.36409717196521635)
# renting (['renting'], 0.3352297425530105)
# leisurely (['le', 'isu', 'rely'], 0.36687576584908504)
# venerable (['ve', 'nerable'], 0.29781555552256067)
# championed (['championed'], 0.42006098970307637)
# Aspects (['Asp', 'ects'], 0.30034398803161644)
# Radford (['Radford'], 0.3071485030539329)
# Minster (['Mins', 'ter'], 0.25135684233001737)
# trustee (['trus', 'tee'], 0.19604954312814665)
# organise (['organise'], 0.26484814428974235)
# Mallowan (['Mallowa', 'n'], 0.24353546107433183)
# meticulous (['metic', 'ulo', 'us'], 0.3336396512728349)
# mortals (['mortals'], 0.22422290295686254)
# surmounted (['surmounted'], 0.39215412411907047)
# Chakrabarti (['Cha', 'kr', 'ab', 'art', 'i'], 0.5519927713625626)
# Naughty (['Naughty'], 0.40661893339466204)
# amplexus (['amplexus'], 0.3437996987464155)
# europaeus (['europ', 'aeu', 's'], 0.3566503336002508)
# Kimmeridgian (['Kimm', 'erid', 'gia', 'n'], 0.4624887811445276)
# allosaur (['al', 'losaur'], 0.2747374260959562)
# coracoid (['cor', 'acoid'], 0.2831514268897588)
# Biological (['Biol', 'ogical'], 0.4697508698407602)
# footnote (['foot', 'not', 'e'], 0.4172582240341681)
# lucaris (['lucar', 'is'], 0.3486829567078897)
# referral (['refer', 'ral'], 0.29256403108498885)
# Ceratosaurus (['Cera', 'tosaurus'], 0.5595923124233841)
# speculative (['speculative'], 0.5438775776700041)
# Persoon (['Per', 'soo', 'n'], 0.4004021372685641)
# Preliminary (['Pre', 'liminary'], 0.3576742394347038)
# locality (['locality'], 0.29990523718241163)
# exoperidium (['exope', 'ri', 'dium'], 0.5181042639807774)
# crevices (['crevice', 's'], 0.2559364802683971)
# pungent (['pung', 'ent'], 0.28700121522068434)
# adhering (['adher', 'ing'], 0.36740606908094064)
# purplish (['pur', 'pli', 'sh'], 0.31924471625289746)
# gelatinous (['gela', 'ti', 'nous'], 0.38804829260301277)
# inhibit (['in', 'hibit'], 0.30993772148075527)
# steroid (['ste', 'roid'], 0.2217969627237782)
# acetate (['ac', 'eta', 'te'], 0.38736875178753105)
# Pynchon (['Pynch', 'on'], 0.39740281374549363)
# Buckley (['Buckley'], 0.25863558613068266)
# Griffith (['Griffith'], 0.33531615887774524)
# Scorsese (['Scor', 's', 'ese'], 0.3323024055296283)
# Kubrick (['Kubri', 'ck'], 0.2730864336874694)
# realistically (['realistically'], 0.5603747799901844)
# alienation (['ali', 'ena', 'tion'], 0.5586087424205555)
# Lucille (['Lucil', 'le'], 0.3882974299104274)
# Henryson (['Henryso', 'n'], 0.4179675649408271)
# Phrygian (['Phrygia', 'n'], 0.504933595775641)
# Firstly (['Fir', 'stl', 'y'], 0.3628488771784953)
# untrained (['untrained'], 0.24276484050355834)
# discrepancies (['discr', 'e', 'pan', 'cies'], 0.4924010405920975)
# betrays (['betr', 'ays'], 0.23101539495426016)
# collateral (['collateral'], 0.27195808355221757)
# Shreveport (['Shreveport'], 0.5151244787487295)
# reliever (['reliever'], 0.2761081488811212)
# incentive (['incentive'], 0.4093099196489097)
# credentials (['credentials'], 0.3410551190085601)
# Santana (['Sant', 'ana'], 0.16485508379384237)
# curveball (['cur', 'veball'], 0.31901552031498487)
# Thistles (['Th', 'istl', 'es'], 0.3064438338385343)
# Bulldogs (['Bulldogs'], 0.44999437740101816)
# materialize (['materialize'], 0.43923284306014687)
# grocery (['grocery'], 0.22221966649693242)
# attacker (['at', 'tacker'], 0.2591080457947501)
# Brimsek (['Brimsek'], 0.3333323110438444)
# ascetic (['as', 'cet', 'ic'], 0.3137596383392481)
# steeple (['st', 'eeple'], 0.32960552219322925)
# remodelled (['re', 'mod', 'elled'], 0.3581638357648468)
# Franciscans (['Fran', 'ciscan', 's'], 0.4175643859919909)
# diocesan (['diocesa', 'n'], 0.33372335986305746)
# Cecilia (['Cecil', 'ia'], 0.3583856775639575)
# furnished (['furn', 'ished'], 0.33847678164652667)
# summoning (['summo', 'ning'], 0.49538453686106065)
# Fourteen (['Fourtee', 'n'], 0.29731854789377443)
# frontage (['frontage'], 0.2744172174384966)
# romances (['romances'], 0.24745488427178203)
# premarital (['pre', 'mar', 'ital'], 0.23381888951440682)
# mirrored (['mirro', 'red'], 0.3139729404147942)
# Lasance (['Las', 'ance'], 0.32124239726502757)
# deceived (['deceived'], 0.2672606279643523)
# betraying (['betr', 'a', 'yi', 'ng'], 0.4915471302449948)
# awesome (['aweso', 'me'], 0.3592819669960919)
# Sunrise (['Sunri', 'se'], 0.36293876527951885)
# constructive (['constructive'], 0.6109998160786752)
# appoints (['appoints'], 0.31078776356936577)
# Interest (['Interest'], 0.28900989316199577)
# complimentary (['complim', 'entary'], 0.5796017575388704)
# Ocosingo (['Ocosi', 'ngo'], 0.4543559330681877)
# polities (['polities'], 0.2480804167933089)
# abbreviated (['abbrevia', 'ted'], 0.5155495721437083)
# reigned (['reigned'], 0.22978389216795528)
# Ballcourt (['Ballc', 'ourt'], 0.33682748198102747)
# Acropolis (['Acr', 'opolis'], 0.3236967851186892)
# Jacinto (['Jac', 'int', 'o'], 0.2763681967186171)
# Anthropology (['Anthropology'], 0.5222828148782691)
# Historia (['Historia'], 0.2819143664801562)
# embankment (['em', 'bankm', 'ent'], 0.577401339787626)
# Structures (['Structures'], 0.399963406355781)
# stairway (['stairway'], 0.28530975694515137)
# deferred (['deferred'], 0.21701894434653896)
# undertail (['undertail'], 0.26563975106857857)
# Systema (['Sys', 'tema'], 0.23217561471014644)
# marshes (['mars', 'hes'], 0.2165786307530614)
# Madeira (['Madeir', 'a'], 0.3650168789231442)
# fertiliser (['fert', 'i', 'liser'], 0.27351803659627133)
# chickens (['chickens'], 0.19771343372898925)
# laterally (['laterally'], 0.330642492145803)
# thicket (['thicket'], 0.23136732236928856)
# clutches (['clutches'], 0.3522491878577362)
# fertilised (['fert', 'i', 'lised'], 0.2858448383116829)
# cockroaches (['co', 'ckr', 'oaches'], 0.46696473393380766)
# reintroduction (['re', 'int', 'roduction'], 0.8434056002976349)
# shortness (['shortness'], 0.2934259768451244)
# illnesses (['il', 'lne', 'sses'], 0.3605613804216483)
# infiltration (['in', 'filtr', 'ation'], 0.7052777103497971)
# exposures (['exposu', 'res'], 0.47219893295289295)
# benzene (['benze', 'ne'], 0.3537336219662256)
# Diagnosis (['Diagnosi', 's'], 0.33543837389178016)
# aspiration (['aspiration'], 0.4965603177433765)
# irrespective (['irr', 'espective'], 0.4998130537395741)
# clinically (['clini', 'cally'], 0.39918791546915044)
# proliferation (['pro', 'lifera', 'tion'], 0.7486539727321084)
# postremission (['postremission'], 0.4994128095615933)
# infusion (['infusi', 'on'], 0.35267006256062006)
# protocols (['pro', 'tocols'], 0.3673196876965632)
# relapsed (['re', 'lapse', 'd'], 0.34201726191345716)
# Cooperative (['Cooperative'], 0.4980261626316729)
# urinary (['ur', 'ina', 'ry'], 0.14136791452075795)
# pathologist (['pathologist'], 0.4260700661855653)
# Virchow (['Virchow'], 0.38923206581993497)
# Ehrlich (['Ehrlic', 'h'], 0.5027185329165222)
# staining (['staining'], 0.3628761642982936)
# Camille (['Cami', 'lle'], 0.26283226013964534)
# Merrill (['Me', 'ril', 'l'], 0.24353181520409295)
# imagining (['imagi', 'ning'], 0.4053552036790201)
# likening (['li', 'ken', 'ing'], 0.3847870367322016)
# hideous (['hideou', 's'], 0.34966884034454193)
# Ultratip (['Ultr', 'a', 'tip'], 0.3300419361684699)
# infatuated (['in', 'fatuated'], 0.4112524935406511)
# dormitories (['dorm', 'itories'], 0.3624973509522899)
# salaries (['sa', 'lar', 'ies'], 0.23845975147836906)
# lodging (['lo', 'dgi', 'ng'], 0.510211436142643)
# outsiders (['outsiders'], 0.45674265689963106)
# detention (['detention'], 0.4752663813104098)
# instigator (['instigator'], 0.30017964413795767)
# deadliest (['deadlie', 'st'], 0.32254310423077454)
# Lafitte (['Lafit', 'te'], 0.38223496153604575)
# deepwater (['deep', 'wat', 'er'], 0.32732531283325994)
# Winters (['Winters'], 0.2652232062039285)
# Islander (['Islander'], 0.3347280437029127)
# Shriners (['Shri', 'ners'], 0.3312653897057324)
# outreach (['ou', 'treach'], 0.3197235368545739)
# Fortunately (['Fortuna', 'tely'], 0.47154253655450507)
# Mosquito (['Mosquito'], 0.33915092394972307)
# Acoustic (['Acoust', 'ic'], 0.3200346964700944)
# Performing (['Performing'], 0.5562842431242125)
# transatlantic (['trans', 'atl', 'antic'], 0.4157373925362322)
# Restaurants (['Resta', 'ura', 'nts'], 0.3824047185683014)
# Pollard (['Poll', 'ard'], 0.2617478921283457)
# baseman (['baseman'], 0.17753109170925874)
# implements (['implements'], 0.40799177138623605)
# Scandal (['Sca', 'n', 'dal'], 0.23956010619282966)
# Brazoria (['Brazori', 'a'], 0.37934109851555403)
# Contract (['Contract'], 0.23362780513716047)
# Intercontinental (['Intercontinental'], 0.5935159942263694)
# intercity (['inter', 'city'], 0.39595172629912934)
# Sheldon (['Shel', 'don'], 0.22222818564959168)
# Twilight (['Twili', 'ght'], 0.5390484000750307)
# squalls (['squalls'], 0.32082742899677597)
# Bayfest (['Bayfes', 't'], 0.41506856063639036)
# dredging (['dredg', 'ing'], 0.4298598668954404)
# accommodates (['accommoda', 'tes'], 0.511370707936497)
# stacked (['stacked'], 0.18592712390872573)
# terminates (['terminates'], 0.30900666407060334)
# Sherwood (['Sherwood'], 0.3095933753488885)
# neighbourhood (['neighbou', 'rhood'], 0.6057005483403672)
# noticeably (['noticeably'], 0.30295923181291184)
# aboriginal (['aboriginal'], 0.3403142789874549)
# spearhead (['spe', 'arhead'], 0.3116737187873527)
# Bluewater (['Bluewater'], 0.519923977238523)
# startup (['startup'], 0.2905908281903339)
# disabilities (['dis', 'abi', 'lities'], 0.4807984792267388)
# Healthcare (['Healthcar', 'e'], 0.43929915020891164)
# hospice (['hospice'], 0.17679467242196878)
# Realizing (['Real', 'izing'], 0.4945594516948858)
# originate (['originate'], 0.3232027664776317)
# Binghamton (['Bi', 'ngham', 'to', 'n'], 0.5822000072945742)
# homemaker (['ho', 'memaker'], 0.3767481192647535)
# regrets (['regret', 's'], 0.3648393659236627)
# successively (['successively'], 0.5667344127434983)
# recollection (['recollection'], 0.5771492340466693)
# Millions (['Millions'], 0.357665283749216)
# demographics (['de', 'mographics'], 0.6391721475565396)
# worthless (['wor', 'thl', 'ess'], 0.3552736090646109)
# Understanding (['Understanding'], 0.6757827399940406)
# Wilderness (['Wilde', 'r', 'ness'], 0.3458105502087169)
# disparaged (['disparaged'], 0.3356287964688538)
# Examining (['Examining'], 0.4599668205818441)
# turnspeak (['tur', 'nsp', 'eak'], 0.3342341935536422)
# Frankfurter (['Frankfur', 'ter'], 0.48294548999953635)
# Responding (['Responding'], 0.41564384496619444)
# Quoting (['Quoti', 'ng'], 0.43924475229228543)
# Controversies (['Controver', 'sie', 's'], 0.5598742305064702)
# Faculty (['Facu', 'lty'], 0.24629062709236085)
# terribly (['ter', 'ribly'], 0.2730403750058412)
# sterling (['sterling'], 0.36077984925029205)
# originality (['originality'], 0.45339993745938695)
# plagiarized (['plagiar', 'ized'], 0.4958172618140662)
# Prisoners (['Pris', 'oners'], 0.35160221081763576)
# militants (['militants'], 0.2169877612576515)
# blistering (['blistering'], 0.415866305417224)
# agnostic (['agnost', 'ic'], 0.18247998031255916)
# Invasion (['Invasi', 'on'], 0.380482813788586)
# orientations (['orientations'], 0.6312996829279202)
# Reviewed (['Reviewed'], 0.2621270870014166)
# Zeitung (['Zeitun', 'g'], 0.49852277235759035)
# archived (['archived'], 0.30339431599557914)
# Response (['Response'], 0.21806067941226093)
# saprobic (['saprobi', 'c'], 0.2869082357965265)
# observable (['observable'], 0.46290095123060604)
# Universities (['Universities'], 0.5711616199426818)
# Abrahamic (['Abr', 'ahami', 'c'], 0.45093886759586915)
# Afterward (['Aft', 'erward'], 0.44278116528602895)
# burdensome (['burd', 'ens', 'ome'], 0.31483829543395797)
# Commissioned (['Commissioned'], 0.5292693757298429)
# Aquinas (['Aquina', 's'], 0.5008808511084227)
# precepts (['pre', 'cepts'], 0.2928509367105426)
# astrology (['astrology'], 0.3695211622992023)
